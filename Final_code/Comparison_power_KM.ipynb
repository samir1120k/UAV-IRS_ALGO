# %%
import pandas as pd
import numpy as np
import random
import math
from numpy import random
import cmath
import matplotlib.pyplot as plt

# %%
# Load datasets related to Base Stations, UAVs, and Clients
base = pd.read_csv(r'BS_data.csv')
uav = pd.read_csv(r'UAV_data.csv')
people = pd.read_csv(r'people_data.csv')
IRS=pd.read_csv(r'IRS_data.csv')
p_km_UP=pd.read_csv(r'P_km_up.csv')

Angle_df=pd.read_csv(r'Angle.csv') # number of IRS is 500 store in each column
h_l_km_df=pd.read_csv(r'h_l_km.csv') # number of IRS is 500 store in each column
h_l_m_df=pd.read_csv(r'h_l_m.csv') # number of IRS is 500 store in each column

Angle_UP_df=pd.read_csv(r'Angle1.csv') # number of IRS is 500 store in each column
g_l_km_df=pd.read_csv(r'h_l_km1.csv') # number of IRS is 500 store in each column
g_l_m_df=pd.read_csv(r'h_l_m1.csv') # number of IRS is 500 store in each column # corrected filename

Angle_har_df=pd.read_csv(r'Angle2.csv') # number of IRS is 500 store in each column
f_l_km_df=pd.read_csv(r'h_l_km2.csv') # number of IRS is 500 store in each column
f_l_m_df=pd.read_csv(r'h_l_m2.csv') # number of IRS is 500 store in each column # corrected filename
f_km1=pd.read_csv(r'f_km.csv')

# %%
# Constants
Wl = 35.28
H_value= 20
P_m_har = base['P_m_har']
T_m_har = base['T_m_har']
P_m_down = base['P_m_down']
f_km=f_km1['0']
V_lm_vfly = uav['V_lm_vfly']
V_lm_hfly = uav['V_lm_hfly']
D_l_hfly = 100

P_km_up=p_km_UP['0']
# p_max=10 # moved inside loop
p_km_max=10
T_m=10
D_m_current=0.49


# Additional constants for calculations
delta = 2
Ar = 0.1256
s = 0.05
Nr = 4
V_tip = 102
Cd = 0.022
Af = 0.2113
D_km = 0.5
# Dm=0.49
B=10 #MHz
sigma_km=10**(-13)
eta=10
kappa=0.5
num_population=50
Bh = (1 - 2.2558 * pow(10, -5) *H_value)**4.2577
# Bh = max(1, Bh)
p_l_b = (delta / 8) * Bh * Ar * s * pow(V_tip, 3)

# %%
# Determine the maximum possible rows based on the smallest dataframe size
min_rows = min(len(Angle_df), len(h_l_km_df), len(h_l_m_df), len(Angle_UP_df), len(g_l_km_df), len(g_l_m_df), len(Angle_har_df), len(f_l_km_df), len(f_l_m_df), len(f_km1))
num_rows_data_files = min_rows # Dynamically set num_rows_data_files based on the smallest dataframe length
population_size = min(25, num_rows_data_files) # Ensure population_size is not larger than available data

# %%
# Fitness function to calculate total energy consumption
def Fitness(E_ml_har, E_ml_down, E_ml_UAV):
    return E_ml_har + E_ml_down + E_ml_UAV

# Energy consumption of the UAV-IRS
def E_ml_UAV(P_l_vfly, T_l_vfly, P_lm_hfly, T_l_hfly, P_l_hov, T_lm_hov):
    return P_l_vfly * T_l_vfly + P_lm_hfly * T_l_hfly + P_l_hov * T_lm_hov

# Power calculations for different flight modes
def P_l_vfly(Wl, V_l_vfly, P_l_b, Nr, Ar, Bh):
    temp2 = Nr * Bh * Ar
    temp3 = np.sqrt(V_l_vfly**2 + (2 * Wl) / temp2)
    return ((Wl / 2) * (V_l_vfly + temp3)) + Nr * P_l_b

def P_lm_hfly(P_lm_blade, P_lm_fuselage, P_lm_induced):
    return P_lm_blade + P_lm_fuselage + P_lm_induced

def P_lm_blade(Nr, P_l_b, V_tip, V_lm_hfly):
    return Nr * P_l_b * (1 + ((3 * (V_lm_hfly**2)) / pow(V_tip, 2)))

def P_lm_fuselage(Cd, Af, Bh, V_lm_hfly):
    return (1 / 2) * Cd * Af * Bh * (V_lm_hfly**3)

def P_lm_induced(Nr, Bh, Ar, Wl, V_lm_hfly):
    return Wl * ((np.sqrt((Wl**2) / (4 * (Nr**2) * (Bh**2) * (Ar**2)) + ((V_lm_hfly**4) / 4)) - ((V_lm_hfly**2) / 2))**(1 / 2))

def P_l_hov(Wl, P_l_b, Nr, Ar, Bh):
    temp1 = Nr * P_l_b
    temp3 = np.sqrt(2 * (Nr * Bh * Ar))
    temp4 = ((Wl)**3 / 2) / temp3
    return temp1 + temp4

def T_lm_hov(T_km_com, T_kml_up, T_ml_down):
    return T_km_com + T_kml_up + T_ml_down

def R_ml_down(B,P_m_down,h_ml_worst): #eqation number 7
    temp1=(h_ml_worst*P_m_down) # Consider if min is the correct aggregation. It should be multiplication
    if (1+temp1) <= 0:
        return 0  # Return 0 if log argument is non-positive to avoid error
    return B*math.log2(1+temp1)

def h_ml_worst(h_kml_down,sigma_km): #eqation number 8
    return h_kml_down/(sigma_km) # it will return the sigal value which is minimum of all
            # the value for each itaration

def calculate_exp_i_theta(theta): # part of equation 8
  return cmath.exp(1j * theta)
 # 1j represents the imaginary unit in Python

def h_kml_down(Angle,h_l_m,h_l_km): # part of equation 8
    result=[]
    if isinstance(Angle, float): # Check if Angle is float, if so, return 0 or handle appropriately
        return 0 # Or raise an exception or return a default value as needed

    if not isinstance(Angle, pd.Series): # added check to handle non-series input
        raise TypeError(f"Expected Angle to be pd.Series, got {type(Angle)}")

    for i in range(len(Angle)):
        theta_radians = math.radians(Angle.iloc[i]) # Use iloc for position-based indexing
        results= calculate_exp_i_theta(theta_radians)
        result.append(results)

    diagonal=np.diag(result)
    # Ensure h_l_m and h_l_km are correctly formatted as numpy arrays
    h_l_m_np = h_l_m.to_numpy() # Convert Series to numpy array
    h_l_km_np = h_l_km.to_numpy() # Convert Series to numpy array
    if h_l_m_np.ndim == 1:
        h_l_m_np = h_l_m_np.reshape(-1, 1) # Reshape to 2D if necessary
    if h_l_km_np.ndim == 1:
        h_l_km_np = h_l_km_np.reshape(1, -1) # Reshape to 2D if necessary


    a=np.dot(h_l_km_np,diagonal) # Use numpy arrays for dot product
    b=np.dot(a,h_l_m_np)      # Use numpy arrays for dot product
    final=abs(b[0][0]) # Take absolute value and ensure it's a scalar
    return (final**2)

def R_kml_up(B,P_km_up,h_kml_up,Sub,sigma_m): #eqation number 4
    temp1=(P_km_up*h_kml_up)/ (Sub+(sigma_m))
    return B*math.log2(1+temp1)
#this is inside the equation 4 have to take summation of h_i_up and P_i_up
def sub(P_i_up,h_il_up):
    return P_i_up*h_il_up

def E_km_com(f_km,T_km_com):
    return eta*(10**(-28))*(f_km**3)*T_km_com

def E_kml_up(P_km_up,T_km_up):
    return P_km_up*T_km_up

def E_kml_har(P_m_har,T_m_har,h_km_har):
    return kappa*P_m_har*T_m_har*h_km_har

# %%
# Hill Climbing Algorithm Parameters
num_bs = 5
num_irs_ele=50
num_generation = 1 # Number of iterations for Hill Climbing
num_uav_irs = 8
population_size = 25 # Initial population size (used for initial solution in HC)

# Define keys that should be subjected to perturbation (numerical parameters)
numerical_keys_for_hc = [
    'P_m_down_value', 'P_m_har_value', 'T_m_har_value',
    'f_km_value', 'V_lm_vfly_value', 'V_lm_hfly_value',
    'P_km_up_value','f_km_value','Angle1_row','Angle_row','Angle2_row',
]


fitness_sums_HC = [] # Store sum of fitness values for each p_max

P_max_values = np.arange(1, 11, 1) # P_max values from 1 to 11

for p_max in P_max_values: # Iterate over P_max values
    print(f"calculaiton for p_max for HC",p_max)
    all_best_combinations = []
    all_best_individuals = []

    # Main Hill Climbing Algorithm Loop
    for l in range(num_bs):
        all_best_individuals_bs = []
        P_m_har_value = P_m_har.values[l]
        T_m_har_value = T_m_har.values[l]
        P_m_down_value = P_m_down.values[l]

        # Select unique row indices for the current BS
        index_list = list(range(num_rows_data_files)) # Create a list of all indices
        random.shuffle(index_list)
        unique_row_indices = index_list[:population_size] # use population size to pick initial indices
        # Create dataframes with uniquely selected rows for the current BS
        h_l_km_df_bs = h_l_km_df.iloc[unique_row_indices, :].reset_index(drop=True)
        g_l_km_df_bs = g_l_km_df.iloc[unique_row_indices, :].reset_index(drop=True)
        f_l_km_df_bs = f_l_km_df.iloc[unique_row_indices, :].reset_index(drop=True)
        f_km_bs = f_km[unique_row_indices].reset_index(drop=True)
        # Corrected line: Ensure indices are within bounds of P_km_up
        valid_indices = [i for i in unique_row_indices if i < len(P_km_up)]
        P_km_up_bs = P_km_up.iloc[valid_indices].reset_index(drop=True)


        for k in range(num_uav_irs):
            best_fitness = float('inf')
            best_individual = {}

            V_lm_vfly_value = V_lm_vfly.values[k]
            V_lm_hfly_value = V_lm_hfly.values[k]
            D_l_hfly_value = D_l_hfly
            Wl_value = Wl
            Sub_value=0
            # Corrected loop range to use valid_indices length
            for i in range(len(valid_indices)): # Using length of valid_indices
                h_il_up_value=h_kml_down(Angle_UP_df.iloc[i, :],g_l_m_df.iloc[k, :],g_l_km_df_bs.iloc[i, :]) # Pass Series, corrected index to i
                Sub_value+=sub(P_km_up_bs[i],h_il_up_value)

            # Initialize initial solution for Hill Climbing - using first from 'population initialization' of GA
            initial_solution_data = {}
            i=0 # Using first index for initialization
            f_km_value = f_km_bs[i] # Use BS-specific f_km
            P_km_up_value = P_km_up_bs[i] # Use BS-specific P_km_up

            Angle_row = Angle_df.iloc[i, :] # Use BS-specific Angle_df
            h_l_m_row = h_l_m_df.iloc[k, :] # Use BS-specific h_l_m_df
            h_l_km_row = h_l_km_df_bs.iloc[i, :] # Use BS-specific h_l_km_df
            Angle1_row = Angle_UP_df.iloc[i, :] # Use BS-specific Angle_UP_df
            g_l_m_row = g_l_m_df.iloc[k, :] # Use BS-specific g_l_m_df
            g_l_km_row = g_l_km_df_bs.iloc[i, :] # Use BS-specific g_l_km_df
            Angle2_row = Angle_har_df.iloc[i, :] # Use BS-specific Angle_har_df
            f_l_m_row = f_l_m_df.iloc[k, :] # Use BS-specific f_l_m_df
            f_l_km_row = f_l_km_df_bs.iloc[i, :] # Use BS-specific f_l_km_df

            # Calculate power values
            P_lm_blade_value = P_lm_blade(Nr, p_l_b, V_tip, V_lm_hfly_value)
            P_lm_fuselage_value = P_lm_fuselage(Cd, Af, Bh, V_lm_hfly_value)
            P_lm_induced_value = P_lm_induced(Nr, Bh, Ar, Wl_value, V_lm_vfly_value)

            # Calculate time and energy values
            T_l_vfly_value = H_value / V_lm_vfly_value
            T_l_hfly_value = D_l_hfly_value / V_lm_hfly_value # Corrected: D_l_hfly / V_lm_hfly
            E_ml_har_value = P_m_har_value * T_m_har_value
            h_kml_down_value=h_kml_down(Angle_row,h_l_m_row,h_l_km_row) # Pass Series
            h_ml_worst_value=h_ml_worst(h_kml_down_value,sigma_km)
            R_ml_down_value=R_ml_down(B,P_m_down_value,h_ml_worst_value)
            T_ml_down_value=D_m_current/R_ml_down_value
            E_ml_down_value = P_m_down_value * T_ml_down_value
            T_km_com_value = D_km / f_km_value
            h_kml_up_value=h_kml_down(Angle1_row,g_l_m_row,g_l_km_row) # Pass Series, using same function, might need different one if logic is different

            R_kml_up_value=R_kml_up(B,P_km_up_value,h_kml_up_value,Sub_value,sigma_km)
            T_km_up_value=D_m_current/R_kml_up_value # equation number 5
            T_lm_hov_value = T_lm_hov(T_km_com_value, T_km_up_value, T_ml_down_value)
            P_l_hov_value = P_l_hov(Wl_value, p_l_b, Nr, Ar, Bh)
            P_l_vfly_value = P_l_vfly(Wl_value, V_lm_vfly_value, p_l_b, Nr, Ar, Bh)
            P_lm_hfly_value = P_lm_hfly(P_lm_blade_value, P_lm_fuselage_value, P_lm_induced_value)
            E_ml_UAV_value = E_ml_UAV(P_l_vfly_value, T_l_vfly_value, P_lm_hfly_value, T_l_hfly_value, P_l_hov_value, T_lm_hov_value)

            # Calculate fitness for initial solution
            initial_fitness = Fitness(E_ml_har_value, E_ml_down_value, E_ml_UAV_value)

            current_solution = {
                'fitness': initial_fitness,
                'data': {
                    'P_m_down_value': P_m_down_value,
                    'P_m_har_value': P_m_har_value,
                    'T_m_har_value': T_m_har_value,
                    'f_km_value': f_km_value,
                    'T_km_up_value': T_km_up_value,
                    'V_lm_vfly_value': V_lm_vfly_value,
                    'V_lm_hfly_value': V_lm_hfly_value,
                    'P_km_up_value':P_km_up_value,
                    'Angle1_row':Angle1_row,
                    'Angle_row':Angle_row,
                    'Angle2_row': Angle2_row,
                }
            }
            best_individual = current_solution
            best_fitness = initial_fitness


            generations_data = []
            for j in range(num_generation): # Hill Climbing iterations
                # Generate neighbor solution by perturbing the current solution
                neighbor_solution_data = current_solution['data'].copy()
                for i in range(10):
                    for key in numerical_keys_for_hc:
                        if key in ['Angle1_row','Angle_row','Angle2_row']: # Handle Angle Series
                            neighbor_solution_data[key] = pd.Series(index=Angle_df.columns, dtype='float64') # Initialize empty Series for child
                            for col in Angle_df.columns: # Iterate through each column (angle direction)
                                neighbor_solution_data[key][col] = random.normal(loc=0, scale=1, size=(1))[0]
                        else:
                                neighbor_solution_data[key] += random.normal(loc=0, scale=1, size=(1))[0] # Reduced scale for smaller perturbations in HC


                    # Compute neighbor fitness
                    def compute_fitness(data):
                        P_m_down_value = data['P_m_down_value']
                        P_m_har_value = data['P_m_har_value']
                        T_m_har_value = data['T_m_har_value']
                        f_km_value = data['f_km_value']
                        T_km_up_value = data['T_km_up_value']
                        V_lm_vfly_value = data['V_lm_vfly_value']
                        V_lm_hfly_value = data['V_lm_hfly_value']
                        P_km_up_value=data['P_km_up_value']
                        Angle_row = data['Angle_row'] # Retrieve angle row from neighbor data
                        Angle1_row = data['Angle1_row'] # Retrieve angle row from neighbor data
                        Angle2_row = data['Angle2_row'] # Retrieve angle row from neighbor data

                        # Calculate power values
                        P_lm_blade_value = P_lm_blade(Nr, p_l_b, V_tip, V_lm_hfly_value)
                        P_lm_fuselage_value = P_lm_fuselage(Cd, Af, Bh, V_lm_hfly_value)
                        P_lm_induced_value = P_lm_induced(Nr, Bh, Ar, Wl_value, V_lm_vfly_value)

                        # Calculate time and energy values
                        T_l_vfly_value = H_value / V_lm_vfly_value
                        T_l_hfly_value = D_l_hfly_value / V_lm_hfly_value # Corrected: D_l_hfly / V_lm_hfly
                        E_ml_har_value = P_m_har_value * T_m_har_value # Corrected:

                        h_kml_down_value_compute=h_kml_down(Angle_row,h_l_m_row,h_l_km_row) # Using original Angle_row, h_l_m_row, h_l_km_row for neighbor as well - might need to be based on neighbor data if angles are also part of optimization
                        h_ml_worst_value=h_ml_worst(h_kml_down_value_compute,sigma_km)
                        R_ml_down_value=R_ml_down(B,P_m_down_value,h_ml_worst_value)
                        if R_ml_down_value <= 0: # check if R_ml_down_value is zero or negative
                            R_ml_down_value = 1e-9 # Assign a small positive value to avoid division by zero
                        T_ml_down_value=D_m_current/R_ml_down_value
                        E_ml_down_value = P_m_down_value * T_ml_down_value
                        T_km_com_value = D_km / f_km_value
                        T_lm_hov_value = T_lm_hov(T_km_com_value, T_km_up_value, T_ml_down_value)
                        P_l_hov_value = P_l_hov(Wl_value, p_l_b, Nr, Ar, Bh)
                        P_l_vfly_value = P_l_vfly(Wl_value, V_lm_vfly_value, p_l_b, Nr, Ar, Bh)
                        P_lm_hfly_value = P_lm_hfly(P_lm_blade_value, P_lm_fuselage_value, P_lm_induced_value)
                        E_ml_UAV_value = E_ml_UAV(P_l_vfly_value, T_l_vfly_value, P_lm_hfly_value, T_l_hfly_value, P_l_hov_value, T_lm_hov_value)
                        h_kml_har_value_compute=h_kml_down(Angle2_row,f_l_m_row,f_l_km_row) # Corrected index to Angle2_row
                        E_kml_har_value=E_kml_har(P_m_har_value,T_m_har_value,h_kml_har_value_compute) # Corrected function call for E_kml_har
                        E_kml_com_value = E_km_com(f_km_value, T_km_com_value)
                        E_kml_up_value=E_kml_up(P_km_up_value,T_km_up_value)


                        # Calculate fitness
                        fitness_value = Fitness(E_ml_har_value, E_ml_down_value, E_ml_UAV_value)
                        current_data = {
                            'P_m_down_value': P_m_down_value,
                            'P_m_har_value': P_m_har_value,
                            'T_m_har_value': T_m_har_value,
                            'f_km_value': f_km_value,
                            'T_km_up_value': T_km_up_value,
                            'V_lm_vfly_value': V_lm_vfly_value,
                            'V_lm_hfly_value': V_lm_hfly_value,
                            'P_km_up_value':P_km_up_value,
                            'Angle1_row':Angle1_row,
                            'Angle_row':Angle_row,
                            'Angle2_row': Angle2_row, # Carry forward original index
                                                                                }
                        if V_lm_hfly_value>0 and T_m_har_value>0 and T_ml_down_value>0 and T_km_up_value>0 and P_m_har_value<=p_max and P_m_down_value<=p_max and P_km_up_value<=p_km_max and (T_km_com_value+T_km_up_value+T_ml_down_value)<=T_m and f_km_value>0  and E_kml_har_value>=(E_kml_up_value+E_kml_com_value) and V_lm_vfly_value>0:
                            return fitness_value, current_data
                        else:
                            return  float('inf'),{} # Return empty dict instead of float('inf') for data


                    neighbor_fitness, neighbor_data1 = compute_fitness(neighbor_solution_data)


                    # Decide whether to accept the neighbor
                    if neighbor_fitness < current_solution['fitness']:
                        current_solution = {'fitness': neighbor_fitness, 'data': neighbor_data1}
                        
                generations_data.append(current_solution.copy())


            best_individual_pair = current_solution.copy()
            best_individual_pair['generation'] = j + 1 # Use last j from loop, corrected index
            best_individual_pair['type'] = 'HC'
            best_individual_pair['bs_index'] = l
            best_individual_pair['uav_index'] = k
            all_best_individuals_bs.append(best_individual_pair)

            all_best_combinations.append({
                'bs_index': l,
                'uav_index': k,
                'best_fitness': current_solution['fitness'],
                'best_individual': best_individual_pair,
                'generation_fitness': [gen['fitness'] for gen in generations_data],
                'unique_row_indices': unique_row_indices # Store unique_row_indices in best_combinations
            })
            # print(f"Best Fitness for BS {l}, UAV {k}: {current_solution['fitness']:.4f}")

        # Find best individual for current BS across all UAVs
        best_individual_for_bs = min(all_best_individuals_bs, key=lambda x: x['fitness'])
        # print(f"Best Fitness for BS {l} across all UAVs: {best_individual_for_bs['fitness']:.4f}")


    # Select the best unique Base station and UAV-IRS pair using Auction based method
    combination_lookup = {}
    for combination in all_best_combinations:
        if combination['bs_index'] not in combination_lookup:
            combination_lookup[combination['bs_index']] = {}
        combination_lookup[combination['bs_index']][combination['uav_index']] = combination

    # Auction-based assignment
    best_assignments = []
    unassigned_bs = list(range(num_bs))
    unassigned_uavs = list(range(num_uav_irs))

    while unassigned_bs and unassigned_uavs:
        best_combination_overall = None

        for l in unassigned_bs:
            best_fitness_for_bs = float('inf')
            best_combination_for_bs = None
            for k in unassigned_uavs:
                if l in combination_lookup and k in combination_lookup[l]:
                    combination = combination_lookup[l][k]
                    if combination['best_fitness'] < best_fitness_for_bs: # Use 'best_fitness' instead of 'best_individual']['fitness']
                        best_fitness_for_bs = combination['best_fitness']
                        best_combination_for_bs = combination

            if best_combination_for_bs:
                if best_combination_overall is None or best_combination_for_bs['best_fitness'] < best_combination_overall['best_fitness']: # Compare with current best overall
                    best_combination_overall = best_combination_for_bs

        if best_combination_overall:
            best_assignments.append(best_combination_overall)
            unassigned_bs.remove(best_combination_overall['bs_index'])
            unassigned_uavs.remove(best_combination_overall['uav_index'])

    # # Print and Plotting
    print(f"\n--- Best Unique UAV Assignments (Auction Based Method) using Hill Climbing ---")
    best_pair_for_plot = None
    min_fitness_for_plot = float('inf')

    sum_fitness_current_p_max = 0 # Sum of best fitness for current p_max
    for assignment in best_assignments:
        print(f"\nBest Assignment for BS {assignment['bs_index']}:")
        print(f" UAV Index: {assignment['uav_index']}")
        best_ind = assignment['best_individual']
        print(f" Best Individual:")
        print(f"  Generation: {best_ind['generation']}, Type: {best_ind['type']}")
        print(f"  Fitness: {best_ind['fitness']:.4f}") # Print current best fitness only
        unique_indices_to_print = assignment['unique_row_indices'] # Retrieve unique_row_indices
        for key, value in best_ind['data'].items():
            if isinstance(value, pd.Series):
                print(f"  {key}: Series: \n{value.iloc[unique_indices_to_print]}") # Print sliced Series
            elif isinstance(value, list): # Handle list type values explicitly
                print(f"  {key}: {value}") # print list directly without formatting
            else:
                print(f"  {key}: {value:.4f}") # Format scalar values

        print("-" * 20)
        sum_fitness_current_p_max += best_ind['fitness'] # Sum fitness values

        if assignment['best_individual']['fitness'] < min_fitness_for_plot:
            min_fitness_for_plot = assignment['best_individual']['fitness']
            best_pair_for_plot = assignment

    fitness_sums_HC.append(sum_fitness_current_p_max) # Store sum of fitness for this p_max

    # Unassigned BS/UAVs
    if unassigned_bs:
        print("\n--- Base Stations without Assigned UAVs ---")
        for bs_index in unassigned_bs:
            print(f"  BS {bs_index} : No UAV is assigned")
            print("-" * 20)

    if unassigned_uavs:
        print("\n--- UAVs without Assigned Base Stations ---")
        for uav_index in unassigned_uavs:
            print(f"  UAV {uav_index} : No BS is assigned")
            print("-" * 20)
# Out:
# calculaiton for p_max for HC 1
#
# --- Best Unique UAV Assignments (Auction Based Method) using Hill Climbing ---
#
# Best Assignment for BS 0:
#  UAV Index: 3
#  Best Individual:
#   Generation: 1, Type: HC
#   Fitness: 71816.5361
#   P_m_down_value: 0.1974
#   P_m_har_value: 0.1353
#   T_m_har_value: 0.3937
#   f_km_value: 0.6173
#   T_km_up_value: 0.7736
#   V_lm_vfly_value: 66.6344
#   V_lm_hfly_value: 66.8574
#   P_km_up_value: 5.6422
#   Angle1_row: Series:
# 206    107.365197
# 196    121.762896
# 47     164.528915
# 22     148.467459
# 50      65.917940
# 64     100.047653
# 464    128.774582
# 106     56.907344
# 384      2.882137
# 238     97.291935
# 190     20.555434
# 197    138.368047
# 387    158.297512
# 320     48.057353
# 208     85.157227
# 405    154.655392
# 177     30.052807
# 220    138.383159
# 390    104.187121
# 255    169.193305
# 83     100.315026
# 301    127.397562
# 418    170.590961
# 221    121.273500
# 288      1.394534
# Name: 0, dtype: float64
#   Angle_row: Series:
# 206     84.488615
# 196    135.895754
# 47       3.969908
# 22      12.463104
# 50     158.516603
# 64     162.993461
# 464     52.706298
# 106      5.697644
# 384    166.862732
# 238    129.484149
# 190      9.153004
# 197    104.831307
# 387     12.837519
# 320    115.635672
# 208     76.886101
# 405     96.959784
# 177    148.667401
# 220    177.425920
# 390     98.879345
# 255     64.715944
# 83      75.774449
# 301    105.022347
# 418     78.158513
# 221    162.312692
# 288    115.310495
# Name: 0, dtype: float64
#   Angle2_row: Series:
# 206     62.750567
# 196     55.081277
# 47       5.020283
# 22     122.719697
# 50      13.233923
# 64      22.139740
# 464    152.899682
# 106    118.701878
# 384    148.089467
# 238    156.263545
# 190    124.183498
# 197     36.541378
# 387    167.974486
# 320    112.226845
# 208    173.723496
# 405    164.851264
# 177      8.694290
# 220     83.492604
# 390    150.800849
# 255     50.163578
# 83      16.057227
# 301    117.106004
# 418    162.779364
# 221    160.685846
# 288    107.769715
# Name: 0, dtype: float64
# --------------------
#
# Best Assignment for BS 3:
#  UAV Index: 1
#  Best Individual:
#   Generation: 1, Type: HC
#   Fitness: 78680.1748
#   P_m_down_value: 0.9554
#   P_m_har_value: 0.4164
#   T_m_har_value: 0.7701
#   f_km_value: 0.4748
#   T_km_up_value: 0.7823
#   V_lm_vfly_value: 72.6939
#   V_lm_hfly_value: 64.4919
#   P_km_up_value: 6.1808
#   Angle1_row: Series:
# 151     74.148836
# 41      78.258936
# 90     148.226374
# 393      7.264731
# 351    171.257204
# 182     71.113099
# 249      4.269181
# 64     100.047653
# 271    154.760417
# 135    170.422358
# 374    170.048095
# 429      6.246942
# 388      3.941931
# 458     42.036778
# 285    162.963278
# 438      5.070280
# 229     99.023089
# 230    156.968146
# 205     18.323672
# 165    153.313946
# 28       6.736053
# 226     61.028013
# 280    136.558703
# 186     72.641084
# 173    166.984019
# Name: 0, dtype: float64
#   Angle_row: Series:
# 151     36.516213
# 41       7.347894
# 90     141.760620
# 393     63.077409
# 351    152.147519
# 182    160.952935
# 249    157.254702
# 64     162.993461
# 271     57.274955
# 135    122.972113
# 374    164.546345
# 429    176.787327
# 388     26.719704
# 458    138.537252
# 285    136.545399
# 438     58.801431
# 229    154.784237
# 230    176.342361
# 205    105.605954
# 165     27.887588
# 28     121.256166
# 226    144.338413
# 280     96.500089
# 186    113.627515
# 173     36.127973
# Name: 0, dtype: float64
#   Angle2_row: Series:
# 151    166.429337
# 41     121.068747
# 90     113.763976
# 393    172.271657
# 351     12.912442
# 182    157.685270
# 249     82.098033
# 64      22.139740
# 271    147.536235
# 135     49.166522
# 374     82.233202
# 429     60.033892
# 388     66.744276
# 458    115.160486
# 285     32.239112
# 438     98.145061
# 229    151.511090
# 230    107.172938
# 205     44.153320
# 165     66.086346
# 28      70.760816
# 226     79.421489
# 280     37.477074
# 186     84.023235
# 173     66.016089
# Name: 0, dtype: float64
# --------------------
#
# Best Assignment for BS 4:
#  UAV Index: 2
#  Best Individual:
#   Generation: 1, Type: HC
#   Fitness: 142382.7332
#   P_m_down_value: 0.5754
#   P_m_har_value: 0.8595
#   T_m_har_value: 0.3629
#   f_km_value: 0.1714
#   T_km_up_value: 1.1380
#   V_lm_vfly_value: 59.4068
#   V_lm_hfly_value: 61.2868
#   P_km_up_value: 4.0877
#   Angle1_row: Series:
# 52      75.217001
# 16      56.490913
# 387    158.297512
# 46      28.566073
# 322    160.085779
# 380     34.721487
# 77      88.614111
# 140     13.214465
# 296     47.632403
# 356    167.597616
# 336    155.967255
# 128    167.447414
# 345    150.413226
# 19     122.773477
# 142    171.596389
# 73      54.291084
# 248     78.419304
# 156    146.828092
# 195     89.504721
# 243    130.818366
# 174     51.360941
# 158    118.915618
# 391     13.046292
# 94      81.254557
# 14      89.536183
# Name: 0, dtype: float64
#   Angle_row: Series:
# 52      68.861270
# 16      97.977491
# 387     12.837519
# 46     128.674886
# 322    168.183964
# 380     66.690280
# 77      90.301532
# 140    156.890298
# 296     34.945711
# 356     37.589314
# 336     94.725842
# 128    118.052553
# 345    133.555619
# 19     132.459102
# 142    115.254931
# 73      54.979968
# 248     69.950072
# 156     27.437723
# 195    121.668596
# 243    118.390555
# 174     75.120867
# 158     15.590498
# 391     14.384855
# 94      66.163289
# 14     117.355833
# Name: 0, dtype: float64
#   Angle2_row: Series:
# 52      44.568433
# 16      35.290788
# 387    167.974486
# 46     126.742356
# 322    179.679193
# 380    114.829627
# 77      17.383988
# 140    135.353972
# 296     20.329733
# 356    123.736170
# 336     53.621333
# 128     57.623140
# 345    147.668816
# 19     165.836249
# 142    159.558804
# 73      96.762917
# 248     50.744205
# 156    125.840470
# 195     81.911340
# 243    172.459161
# 174     75.288628
# 158    121.672789
# 391    142.977717
# 94       7.116799
# 14      39.070498
# Name: 0, dtype: float64
# --------------------
#
# Best Assignment for BS 2:
#  UAV Index: 5
#  Best Individual:
#   Generation: 1, Type: HC
#   Fitness: 151071.0868
#   P_m_down_value: 0.9092
#   P_m_har_value: 0.7848
#   T_m_har_value: 0.4714
#   f_km_value: 0.1329
#   T_km_up_value: 0.4933
#   V_lm_vfly_value: 46.4898
#   V_lm_hfly_value: 35.5884
#   P_km_up_value: 9.0815
#   Angle1_row: Series:
# 345    150.413226
# 495    102.783337
# 207    173.927156
# 342     88.437960
# 341    150.671445
# 331     33.687025
# 458     42.036778
# 214     30.515682
# 499     64.493665
# 294     50.966295
# 369    175.149129
# 339     20.060744
# 171    126.833819
# 115     50.032518
# 80      72.456882
# 335     21.358621
# 219    178.890596
# 29      97.398055
# 252    164.535334
# 456     22.547935
# 16      56.490913
# 355    150.419275
# 439     90.227816
# 194     22.498569
# 483      1.372706
# Name: 0, dtype: float64
#   Angle_row: Series:
# 345    133.555619
# 495    122.412090
# 207     56.827752
# 342    154.425546
# 341    108.921491
# 331     26.634065
# 458    138.537252
# 214    130.285773
# 499     56.049961
# 294     11.856520
# 369     75.421034
# 339     16.933688
# 171    125.159675
# 115     58.718853
# 80      42.479018
# 335    173.369825
# 219      8.401557
# 29     159.564753
# 252    140.011881
# 456     84.463712
# 16      97.977491
# 355     12.138093
# 439     57.753881
# 194    178.450897
# 483     22.790423
# Name: 0, dtype: float64
#   Angle2_row: Series:
# 345    147.668816
# 495    105.322942
# 207    165.881750
# 342     81.310660
# 341     74.012245
# 331     60.117712
# 458    115.160486
# 214     90.336083
# 499    105.994762
# 294     88.574787
# 369    133.161293
# 339     66.606970
# 171     15.103348
# 115     16.870948
# 80      89.407264
# 335    148.074849
# 219     68.097791
# 29     118.992774
# 252    147.450919
# 456     90.280284
# 16      35.290788
# 355     19.638199
# 439     75.137519
# 194     63.678605
# 483    160.505993
# Name: 0, dtype: float64
# --------------------
#
# Best Assignment for BS 1:
#  UAV Index: 7
#  Best Individual:
#   Generation: 1, Type: HC
#   Fitness: 188127.4903
#   P_m_down_value: 0.6128
#   P_m_har_value: 0.5173
#   T_m_har_value: 0.6195
#   f_km_value: 0.2179
#   T_km_up_value: 3.2346
#   V_lm_vfly_value: 22.4843
#   V_lm_hfly_value: 55.0057
#   P_km_up_value: 1.3417
#   Angle1_row: Series:
# 489    142.927682
# 198     39.167082
# 112      6.512990
# 168    151.652060
# 494    141.707960
# 419     72.106598
# 28       6.736053
# 498     20.383101
# 3      113.455504
# 115     50.032518
# 390    104.187121
# 441     85.189324
# 226     61.028013
# 269     37.737548
# 39      61.393954
# 149     54.632853
# 42     103.445152
# 339     20.060744
# 480    132.201145
# 96      50.491057
# 456     22.547935
# 187     41.319848
# 282     37.563960
# 161     26.034233
# 463    103.686330
# Name: 0, dtype: float64
#   Angle_row: Series:
# 489     79.920885
# 198     25.505258
# 112    101.883590
# 168     52.423680
# 494     71.223887
# 419    175.340592
# 28     121.256166
# 498     33.293758
# 3      178.387272
# 115     58.718853
# 390     98.879345
# 441    111.937103
# 226    144.338413
# 269    174.591498
# 39     172.704530
# 149     26.297131
# 42     157.048124
# 339     16.933688
# 480     91.102401
# 96      71.198867
# 456     84.463712
# 187    136.431362
# 282    105.256903
# 161    106.016714
# 463     28.114137
# Name: 0, dtype: float64
#   Angle2_row: Series:
# 489     87.924149
# 198    137.834159
# 112    106.051970
# 168     43.807337
# 494    108.067484
# 419     67.291790
# 28      70.760816
# 498     60.436954
# 3      176.780151
# 115     16.870948
# 390    150.800849
# 441      6.543527
# 226     79.421489
# 269    166.445850
# 39      23.301450
# 149     82.548032
# 42      69.632270
# 339     66.606970
# 480    175.291351
# 96      48.998814
# 456     90.280284
# 187    102.586745
# 282     63.828588
# 161     84.119969
# 463     20.870982
# Name: 0, dtype: float64
# --------------------
#
# --- UAVs without Assigned Base Stations ---
#   UAV 0 : No BS is assigned
# --------------------
#   UAV 4 : No BS is assigned
# --------------------
#   UAV 6 : No BS is assigned
# --------------------
# calculaiton for p_max for HC 2
#
# --- Best Unique UAV Assignments (Auction Based Method) using Hill Climbing ---
#
# Best Assignment for BS 0:
#  UAV Index: 2
#  Best Individual:
#   Generation: 1, Type: HC
#   Fitness: 40764.1074
#   P_m_down_value: 1.1228
#   P_m_har_value: 0.5611
#   T_m_har_value: 2.6557
#   f_km_value: 4.2390
#   T_km_up_value: 0.3763
#   V_lm_vfly_value: 60.1487
#   V_lm_hfly_value: 64.7398
#   P_km_up_value: 8.4160
#   Angle1_row: Series:
# 359   -0.145715
# 401    1.123486
# 208    0.035546
# 250    0.196543
# 109    0.267727
# 154    0.545469
# 455   -0.352838
# 106    0.899389
# 438   -0.237076
# 459   -0.131746
# 182    0.183159
# 334   -0.662271
# 120   -0.287640
# 95     1.533835
# 343   -0.249890
# 124   -0.332966
# 18    -0.484150
# 498   -1.500745
# 485    0.483882
# 89    -1.856839
# 265    0.859504
# 266    0.958484
# 417    0.638728
# 277    2.513101
# 86    -0.631140
# dtype: float64
#   Angle_row: Series:
# 359   -0.495363
# 401   -0.354855
# 208   -1.586554
# 250    0.295843
# 109   -0.451715
# 154   -1.929476
# 455   -0.141567
# 106    0.259783
# 438   -0.160384
# 459    0.443251
# 182   -0.573975
# 334   -0.006227
# 120   -0.056695
# 95    -1.001007
# 343    0.301104
# 124   -0.767158
# 18     0.415823
# 498    1.770905
# 485    0.009552
# 89    -0.121573
# 265   -0.076858
# 266    1.630931
# 417    0.584140
# 277    0.585347
# 86    -0.925907
# dtype: float64
#   Angle2_row: Series:
# 359   -0.674167
# 401   -0.059674
# 208    0.274627
# 250   -0.350812
# 109    1.045784
# 154    0.572603
# 455   -0.946941
# 106   -1.091291
# 438    0.573536
# 459   -0.572741
# 182   -0.054441
# 334   -0.061303
# 120    0.178292
# 95     2.143226
# 343    0.102614
# 124   -0.370775
# 18    -1.891750
# 498   -0.960875
# 485    1.241263
# 89     0.166882
# 265    0.401900
# 266    1.503530
# 417    1.129129
# 277   -0.369618
# 86    -0.217538
# dtype: float64
# --------------------
#
# Best Assignment for BS 1:
#  UAV Index: 5
#  Best Individual:
#   Generation: 1, Type: HC
#   Fitness: 50337.6046
#   P_m_down_value: 1.7632
#   P_m_har_value: 1.9548
#   T_m_har_value: 2.5779
#   f_km_value: 2.3692
#   T_km_up_value: 0.5356
#   V_lm_vfly_value: 47.9379
#   V_lm_hfly_value: 36.9181
#   P_km_up_value: 9.0069
#   Angle1_row: Series:
# 199    0.781435
# 328   -0.282879
# 127   -1.731950
# 13     2.010513
# 295   -0.054780
# 236    0.480132
# 257   -0.875697
# 314   -1.130609
# 202    0.237406
# 69     1.260187
# 141   -0.414716
# 133   -0.759299
# 427    2.745268
# 446   -0.066173
# 307   -0.723826
# 204    0.856061
# 414    0.866019
# 359   -0.124894
# 452    0.878154
# 193    1.009329
# 117    1.454600
# 184   -1.247168
# 137   -1.842355
# 372    1.439049
# 87     0.013552
# dtype: float64
#   Angle_row: Series:
# 199   -0.920849
# 328   -1.183212
# 127   -0.180499
# 13     0.450376
# 295   -0.226872
# 236   -0.724711
# 257    0.677729
# 314    0.843357
# 202    1.102584
# 69    -2.029081
# 141   -1.537174
# 133   -0.314497
# 427   -0.654561
# 446   -0.143890
# 307   -0.760693
# 204   -0.396785
# 414    0.795434
# 359   -0.292482
# 452   -0.124613
# 193    1.072335
# 117   -2.768496
# 184   -0.631491
# 137   -1.148389
# 372    1.135368
# 87     0.656588
# dtype: float64
#   Angle2_row: Series:
# 199    1.326197
# 328    0.275688
# 127    2.068968
# 13     1.055526
# 295    1.740982
# 236   -0.607651
# 257   -0.898913
# 314    0.415791
# 202    0.367032
# 69     1.751774
# 141    0.021379
# 133    0.680648
# 427    0.806021
# 446    1.495992
# 307   -0.481911
# 204   -0.103284
# 414    0.856317
# 359   -0.871870
# 452   -0.482887
# 193   -0.311250
# 117   -1.687893
# 184   -0.618345
# 137   -0.890413
# 372   -0.240054
# 87     0.455118
# dtype: float64
# --------------------
#
# Best Assignment for BS 2:
#  UAV Index: 3
#  Best Individual:
#   Generation: 1, Type: HC
#   Fitness: 57053.2836
#   P_m_down_value: 0.9092
#   P_m_har_value: 0.7848
#   T_m_har_value: 0.4714
#   f_km_value: 0.8836
#   T_km_up_value: 0.5011
#   V_lm_vfly_value: 66.6344
#   V_lm_hfly_value: 66.8574
#   P_km_up_value: 8.8982
#   Angle1_row: Series:
# 283    170.713779
# 53     143.162146
# 63      46.573677
# 407     37.581463
# 461    175.542411
# 174     51.360941
# 222     72.702190
# 83     100.315026
# 140     13.214465
# 183      5.307910
# 441     85.189324
# 72       4.441650
# 463    103.686330
# 343     63.645374
# 20     141.388984
# 419     72.106598
# 55      38.790302
# 31      98.767866
# 380     34.721487
# 219    178.890596
# 482    102.247465
# 265     92.764843
# 261    176.023941
# 51     103.844481
# 268      6.500748
# Name: 0, dtype: float64
#   Angle_row: Series:
# 283     20.822229
# 53      92.385470
# 63      37.378695
# 407    153.818880
# 461    171.141060
# 174     75.120867
# 222    123.168685
# 83      75.774449
# 140    156.890298
# 183     83.089425
# 441    111.937103
# 72     151.081089
# 463     28.114137
# 343    122.816529
# 20       1.615197
# 419    175.340592
# 55     104.011079
# 31      57.620061
# 380     66.690280
# 219      8.401557
# 482    172.577169
# 265    159.868605
# 261     40.316174
# 51     102.633520
# 268     86.735610
# Name: 0, dtype: float64
#   Angle2_row: Series:
# 283     49.485809
# 53       0.532192
# 63     139.005695
# 407     84.040563
# 461     90.998869
# 174     75.288628
# 222    178.938294
# 83      16.057227
# 140    135.353972
# 183     33.534442
# 441      6.543527
# 72     142.803772
# 463     20.870982
# 343    126.641841
# 20      73.528784
# 419     67.291790
# 55     120.200851
# 31      59.225369
# 380    114.829627
# 219     68.097791
# 482    143.050513
# 265     12.808151
# 261    147.323888
# 51      82.033630
# 268     52.517633
# Name: 0, dtype: float64
# --------------------
#
# Best Assignment for BS 4:
#  UAV Index: 1
#  Best Individual:
#   Generation: 1, Type: HC
#   Fitness: 97758.8115
#   P_m_down_value: 0.5754
#   P_m_har_value: 0.8595
#   T_m_har_value: 0.3629
#   f_km_value: 0.3540
#   T_km_up_value: 1.0903
#   V_lm_vfly_value: 72.6939
#   V_lm_hfly_value: 64.4919
#   P_km_up_value: 5.3472
#   Angle1_row: Series:
# 479     28.750945
# 368    105.957877
# 295      5.319093
# 495    102.783337
# 297     76.737712
# 89     166.982947
# 34      45.087377
# 452      4.449993
# 14      89.536183
# 50      65.917940
# 340      6.085251
# 298    137.868739
# 147    119.834760
# 149     54.632853
# 116     95.990574
# 42     103.445152
# 311    168.248108
# 70      86.941011
# 55      38.790302
# 113     42.792631
# 240     16.447058
# 460    144.817261
# 98      64.775508
# 449     67.112145
# 481    149.709606
# Name: 0, dtype: float64
#   Angle_row: Series:
# 479    168.514798
# 368    168.211848
# 295     93.273129
# 495    122.412090
# 297    122.670404
# 89     174.498016
# 34     126.309947
# 452     31.986092
# 14     117.355833
# 50     158.516603
# 340    110.284095
# 298    124.637128
# 147    145.684467
# 149     26.297131
# 116     43.614050
# 42     157.048124
# 311    153.450394
# 70       3.212880
# 55     104.011079
# 113      1.559380
# 240     60.592929
# 460    160.511021
# 98     136.979925
# 449     28.594006
# 481     85.625903
# Name: 0, dtype: float64
#   Angle2_row: Series:
# 479     95.622885
# 368     12.869447
# 295    114.397035
# 495    105.322942
# 297     64.846024
# 89       6.298906
# 34      87.328264
# 452     65.273630
# 14      39.070498
# 50      13.233923
# 340    140.038767
# 298    156.446154
# 147     17.322259
# 149     82.548032
# 116    120.185600
# 42      69.632270
# 311    179.627117
# 70      88.780670
# 55     120.200851
# 113    132.092660
# 240     74.425768
# 460    159.488913
# 98      57.084375
# 449    101.645861
# 481    150.213573
# Name: 0, dtype: float64
# --------------------
#
# Best Assignment for BS 3:
#  UAV Index: 6
#  Best Individual:
#   Generation: 1, Type: HC
#   Fitness: 118801.9165
#   P_m_down_value: 0.9554
#   P_m_har_value: 0.4164
#   T_m_har_value: 0.7701
#   f_km_value: 0.9074
#   T_km_up_value: 2.3799
#   V_lm_vfly_value: 97.1460
#   V_lm_hfly_value: 23.5466
#   P_km_up_value: 1.7356
#   Angle1_row: Series:
# 462     72.637429
# 454    157.734064
# 325    132.064691
# 19     122.773477
# 73      54.291084
# 465    116.759934
# 402    174.666290
# 341    150.671445
# 219    178.890596
# 321     49.253083
# 153     52.008976
# 230    156.968146
# 169     25.448254
# 210     64.835333
# 382     70.672402
# 149     54.632853
# 304     54.321010
# 45     143.094330
# 229     99.023089
# 83     100.315026
# 481    149.709606
# 322    160.085779
# 74      29.170528
# 298    137.868739
# 422     33.954051
# Name: 0, dtype: float64
#   Angle_row: Series:
# 462     56.664832
# 454     79.435379
# 325      1.742911
# 19     132.459102
# 73      54.979968
# 465     49.321056
# 402    155.518129
# 341    108.921491
# 219      8.401557
# 321     37.371693
# 153     62.118837
# 230    176.342361
# 169     36.643020
# 210     90.096043
# 382    125.945094
# 149     26.297131
# 304    130.725302
# 45     175.233340
# 229    154.784237
# 83      75.774449
# 481     85.625903
# 322    168.183964
# 74     101.679398
# 298    124.637128
# 422     75.548976
# Name: 0, dtype: float64
#   Angle2_row: Series:
# 462     15.177629
# 454     48.686048
# 325     67.649842
# 19     165.836249
# 73      96.762917
# 465      0.957282
# 402      4.466835
# 341     74.012245
# 219     68.097791
# 321     21.129232
# 153     28.661693
# 230    107.172938
# 169    176.306942
# 210     12.520229
# 382    110.491240
# 149     82.548032
# 304     96.383573
# 45      60.474468
# 229    151.511090
# 83      16.057227
# 481    150.213573
# 322    179.679193
# 74     146.592960
# 298    156.446154
# 422     19.655888
# Name: 0, dtype: float64
# --------------------
#
# --- UAVs without Assigned Base Stations ---
#   UAV 0 : No BS is assigned
# --------------------
#   UAV 4 : No BS is assigned
# --------------------
#   UAV 7 : No BS is assigned
# --------------------
# calculaiton for p_max for HC 3
#
# --- Best Unique UAV Assignments (Auction Based Method) using Hill Climbing ---
#
# Best Assignment for BS 2:
#  UAV Index: 5
#  Best Individual:
#   Generation: 1, Type: HC
#   Fitness: 49393.3651
#   P_m_down_value: 1.0014
#   P_m_har_value: 1.5088
#   T_m_har_value: 3.0822
#   f_km_value: 1.6828
#   T_km_up_value: 0.4073
#   V_lm_vfly_value: 47.1291
#   V_lm_hfly_value: 36.1777
#   P_km_up_value: 8.8232
#   Angle1_row: Series:
# 99     0.391044
# 482   -1.345737
# 37    -1.111223
# 196    1.413164
# 326   -0.970104
# 455   -0.855672
# 318   -0.376592
# 426    2.570658
# 233   -0.353789
# 140    1.208939
# 34     1.017117
# 347    0.029123
# 87    -0.323651
# 393   -1.118079
# 81    -1.451830
# 207    0.354167
# 336    1.383652
# 366   -0.241404
# 243   -0.883936
# 107    0.590320
# 498    0.300298
# 433    0.765841
# 63     0.209612
# 116    0.503976
# 219    0.371287
# dtype: float64
#   Angle_row: Series:
# 99    -0.528085
# 482   -0.250935
# 37    -1.433285
# 196    0.218056
# 326   -0.160836
# 455   -0.804806
# 318    0.576927
# 426   -1.204838
# 233    1.931137
# 140    0.323146
# 34     0.191784
# 347   -0.050852
# 87    -0.980785
# 393   -1.222428
# 81    -0.075202
# 207   -0.199132
# 336    0.258734
# 366   -0.089470
# 243    0.072460
# 107    0.755478
# 498   -0.538561
# 433   -0.270042
# 63     0.571725
# 116    0.295123
# 219   -0.104487
# dtype: float64
#   Angle2_row: Series:
# 99    -0.684707
# 482   -0.245198
# 37    -0.821282
# 196   -0.807107
# 326    1.484147
# 455   -0.324483
# 318   -0.083851
# 426   -0.413338
# 233   -0.126486
# 140   -1.114908
# 34     0.442515
# 347   -0.957809
# 87    -2.381045
# 393   -2.024323
# 81     0.721078
# 207   -0.520902
# 336    0.957345
# 366    0.289716
# 243    0.793139
# 107   -0.715662
# 498   -0.895659
# 433    1.688537
# 63     0.417900
# 116    1.561912
# 219    3.777299
# dtype: float64
# --------------------
#
# Best Assignment for BS 4:
#  UAV Index: 2
#  Best Individual:
#   Generation: 1, Type: HC
#   Fitness: 82282.6121
#   P_m_down_value: 1.7372
#   P_m_har_value: 1.4528
#   T_m_har_value: 3.3235
#   f_km_value: 2.2704
#   T_km_up_value: 1.7311
#   V_lm_vfly_value: 59.3756
#   V_lm_hfly_value: 61.9763
#   P_km_up_value: 2.5326
#   Angle1_row: Series:
# 292    1.004979
# 373   -0.833504
# 452    0.081031
# 73     0.785418
# 210   -0.544203
# 412   -1.180347
# 342   -0.446180
# 381   -0.196828
# 345    0.454257
# 275    0.490958
# 5      1.070325
# 209    0.116068
# 282   -1.381861
# 440   -0.022569
# 388    2.223192
# 431   -0.302579
# 326   -1.383527
# 438    2.230541
# 3      0.548460
# 86    -0.358243
# 125   -1.476964
# 90     0.446805
# 479   -0.732967
# 51     0.138158
# 259   -1.147003
# dtype: float64
#   Angle_row: Series:
# 292   -1.744815
# 373    0.836466
# 452   -0.356959
# 73     1.018838
# 210    0.328716
# 412   -1.286262
# 342   -0.244113
# 381    1.036560
# 345    0.714201
# 275    0.521625
# 5      0.931297
# 209    0.868914
# 282   -2.088103
# 440   -1.049082
# 388    0.214461
# 431    0.267883
# 326    0.640289
# 438   -0.889546
# 3     -0.865640
# 86     0.027284
# 125   -0.934377
# 90     0.741163
# 479   -2.559508
# 51     0.805439
# 259   -1.377496
# dtype: float64
#   Angle2_row: Series:
# 292    1.008273
# 373    0.188781
# 452   -0.466927
# 73     0.587889
# 210   -0.095929
# 412    0.041756
# 342   -0.382122
# 381   -0.581601
# 345    0.018583
# 275   -0.352393
# 5     -1.219768
# 209    0.231570
# 282    0.135212
# 440    0.389533
# 388   -0.702118
# 431    0.389463
# 326   -0.758215
# 438   -0.183375
# 3     -0.602995
# 86    -0.820148
# 125   -0.031572
# 90    -0.321699
# 479    0.379976
# 51    -1.793660
# 259    0.136024
# dtype: float64
# --------------------
#
# Best Assignment for BS 1:
#  UAV Index: 3
#  Best Individual:
#   Generation: 1, Type: HC
#   Fitness: 85874.5568
#   P_m_down_value: 0.6128
#   P_m_har_value: 0.5173
#   T_m_har_value: 0.6195
#   f_km_value: 0.4099
#   T_km_up_value: 0.8556
#   V_lm_vfly_value: 66.6344
#   V_lm_hfly_value: 66.8574
#   P_km_up_value: 4.9994
#   Angle1_row: Series:
# 321     49.253083
# 67     120.996444
# 188    115.648604
# 239      0.100327
# 55      38.790302
# 38      29.345036
# 443     56.036441
# 289     54.955741
# 458     42.036778
# 80      72.456882
# 279     46.001641
# 394     16.133109
# 426    163.695871
# 3      113.455504
# 2       33.462215
# 337    144.886136
# 28       6.736053
# 27      21.818495
# 95     164.306736
# 294     50.966295
# 450     15.220383
# 395     73.068568
# 480    132.201145
# 398      6.520182
# 56      71.388741
# Name: 0, dtype: float64
#   Angle_row: Series:
# 321     37.371693
# 67     125.213637
# 188     85.886051
# 239     36.117753
# 55     104.011079
# 38     139.009653
# 443    152.951480
# 289    141.483604
# 458    138.537252
# 80      42.479018
# 279    142.143525
# 394    153.526950
# 426    170.316918
# 3      178.387272
# 2      133.727994
# 337     86.270152
# 28     121.256166
# 27      40.157171
# 95      49.631715
# 294     11.856520
# 450    125.138026
# 395    150.614389
# 480     91.102401
# 398     10.194440
# 56      29.200991
# Name: 0, dtype: float64
#   Angle2_row: Series:
# 321     21.129232
# 67      18.045346
# 188     15.558912
# 239     63.245034
# 55     120.200851
# 38     115.750045
# 443     93.319428
# 289    175.496821
# 458    115.160486
# 80      89.407264
# 279     45.049705
# 394     64.627719
# 426     26.081371
# 3      176.780151
# 2       77.449059
# 337     93.849920
# 28      70.760816
# 27     168.862002
# 95     128.764590
# 294     88.574787
# 450    116.784661
# 395      5.382875
# 480    175.291351
# 398      4.885510
# 56      73.906591
# Name: 0, dtype: float64
# --------------------
#
# Best Assignment for BS 3:
#  UAV Index: 7
#  Best Individual:
#   Generation: 1, Type: HC
#   Fitness: 160640.1397
#   P_m_down_value: 0.5756
#   P_m_har_value: 2.8423
#   T_m_har_value: 0.8036
#   f_km_value: 1.2720
#   T_km_up_value: 4.1518
#   V_lm_vfly_value: 20.3937
#   V_lm_hfly_value: 54.5583
#   P_km_up_value: 2.7464
#   Angle1_row: Series:
# 124    0.157335
# 291    1.821425
# 282   -0.584188
# 249   -2.047822
# 306    3.025558
# 60     0.690319
# 353   -0.711837
# 458    0.821389
# 248   -1.556575
# 447    0.008828
# 109    0.385001
# 186    0.410091
# 118   -0.071852
# 375   -1.489178
# 6     -0.197875
# 31    -2.309447
# 125    2.918868
# 141   -0.369615
# 212   -0.464296
# 37     0.102529
# 349   -0.753706
# 466    0.250738
# 51     0.584880
# 121   -1.248112
# 76    -1.740865
# dtype: float64
#   Angle_row: Series:
# 124   -0.163795
# 291    0.596447
# 282   -0.884388
# 249    0.154575
# 306   -0.159467
# 60    -1.120339
# 353   -0.713645
# 458    2.172274
# 248    1.086451
# 447   -0.321640
# 109    0.049510
# 186    0.161235
# 118    0.888934
# 375   -0.115301
# 6     -1.200253
# 31    -0.143401
# 125   -0.191985
# 141   -1.059740
# 212    0.023484
# 37     0.762179
# 349    0.449558
# 466    1.454787
# 51    -2.350963
# 121   -0.564441
# 76    -1.135851
# dtype: float64
#   Angle2_row: Series:
# 124    0.282672
# 291   -1.248374
# 282   -0.317605
# 249   -2.247598
# 306    0.145480
# 60    -0.683303
# 353    1.925558
# 458    0.206105
# 248    0.281139
# 447   -0.365269
# 109    2.186278
# 186   -0.731974
# 118   -0.100579
# 375    0.327424
# 6      0.006114
# 31    -0.364854
# 125    0.372208
# 141    0.444059
# 212   -0.602890
# 37     0.639771
# 349    0.465661
# 466    2.066238
# 51     0.128930
# 121    0.034815
# 76    -0.665672
# dtype: float64
# --------------------
#
# Best Assignment for BS 0:
#  UAV Index: 1
#  Best Individual:
#   Generation: 1, Type: HC
#   Fitness: 169308.7490
#   P_m_down_value: 0.1974
#   P_m_har_value: 0.1353
#   T_m_har_value: 0.3937
#   f_km_value: 0.1233
#   T_km_up_value: 0.9512
#   V_lm_vfly_value: 72.6939
#   V_lm_hfly_value: 64.4919
#   P_km_up_value: 5.5050
#   Angle1_row: Series:
# 10      35.252186
# 481    149.709606
# 210     64.835333
# 406     14.401046
# 162     22.609349
# 207    173.927156
# 72       4.441650
# 238     97.291935
# 306    102.795779
# 395     73.068568
# 302     74.004758
# 96      50.491057
# 465    116.759934
# 259    167.692088
# 446    100.926221
# 12      65.187590
# 121     82.090382
# 135    170.422358
# 310     95.970969
# 149     54.632853
# 165    153.313946
# 448     69.522019
# 95     164.306736
# 168    151.652060
# 77      88.614111
# Name: 0, dtype: float64
#   Angle_row: Series:
# 10     110.124557
# 481     85.625903
# 210     90.096043
# 406    154.843372
# 162     88.865306
# 207     56.827752
# 72     151.081089
# 238    129.484149
# 306    136.001350
# 395    150.614389
# 302    118.394213
# 96      71.198867
# 465     49.321056
# 259      5.394411
# 446      8.121212
# 12     176.637165
# 121      9.577370
# 135    122.972113
# 310     93.655544
# 149     26.297131
# 165     27.887588
# 448    164.015526
# 95      49.631715
# 168     52.423680
# 77      90.301532
# Name: 0, dtype: float64
#   Angle2_row: Series:
# 10       0.486053
# 481    150.213573
# 210     12.520229
# 406      1.152084
# 162    104.281562
# 207    165.881750
# 72     142.803772
# 238    156.263545
# 306    176.679588
# 395      5.382875
# 302     13.203328
# 96      48.998814
# 465      0.957282
# 259     21.912906
# 446    142.932920
# 12     138.690123
# 121    120.226317
# 135     49.166522
# 310    176.419796
# 149     82.548032
# 165     66.086346
# 448     39.098810
# 95     128.764590
# 168     43.807337
# 77      17.383988
# Name: 0, dtype: float64
# --------------------
#
# --- UAVs without Assigned Base Stations ---
#   UAV 0 : No BS is assigned
# --------------------
#   UAV 4 : No BS is assigned
# --------------------
#   UAV 6 : No BS is assigned
# --------------------
# calculaiton for p_max for HC 4
#
# --- Best Unique UAV Assignments (Auction Based Method) using Hill Climbing ---
#
# Best Assignment for BS 1:
#  UAV Index: 1
#  Best Individual:
#   Generation: 1, Type: HC
#   Fitness: 47912.1251
#   P_m_down_value: 0.7416
#   P_m_har_value: 0.3002
#   T_m_har_value: 1.3119
#   f_km_value: 2.4695
#   T_km_up_value: 0.5449
#   V_lm_vfly_value: 71.6322
#   V_lm_hfly_value: 68.5584
#   P_km_up_value: 5.7845
#   Angle1_row: Series:
# 166   -0.922598
# 80     1.375762
# 449    0.296359
# 362    1.959535
# 377    0.338227
# 482    1.130414
# 56    -0.133320
# 468    0.221795
# 270   -0.757246
# 462    0.066453
# 260   -0.351109
# 397   -0.275183
# 423   -0.324984
# 113   -0.381228
# 269   -0.646148
# 186    0.199068
# 205   -0.860017
# 70     0.971289
# 277    0.035886
# 480   -0.810262
# 156   -0.005058
# 161    0.615605
# 68     0.568319
# 306    0.000674
# 66     0.984092
# dtype: float64
#   Angle_row: Series:
# 166   -0.314359
# 80     0.658085
# 449   -0.690378
# 362   -0.915082
# 377   -0.070118
# 482    0.171629
# 56     0.905487
# 468    1.520676
# 270   -1.999336
# 462    0.310658
# 260   -1.326658
# 397   -1.248228
# 423   -0.424283
# 113    0.008201
# 269   -1.523223
# 186   -2.847015
# 205    0.279363
# 70     0.468391
# 277    1.101199
# 480   -0.534875
# 156    2.949455
# 161   -0.414470
# 68    -0.391533
# 306   -1.513004
# 66    -0.174902
# dtype: float64
#   Angle2_row: Series:
# 166    1.429494
# 80     0.038265
# 449    0.196344
# 362   -0.763215
# 377   -1.251068
# 482    0.366616
# 56     0.837916
# 468    0.899029
# 270   -1.779634
# 462   -0.715045
# 260    0.273252
# 397    0.026311
# 423   -0.083727
# 113   -0.211518
# 269    0.005000
# 186   -1.168657
# 205    0.246934
# 70     0.157357
# 277    2.018286
# 480   -0.629890
# 156   -0.882716
# 161    0.571835
# 68    -0.987968
# 306   -0.472515
# 66    -1.181025
# dtype: float64
# --------------------
#
# Best Assignment for BS 3:
#  UAV Index: 2
#  Best Individual:
#   Generation: 1, Type: HC
#   Fitness: 49810.9195
#   P_m_down_value: 0.3845
#   P_m_har_value: 0.4282
#   T_m_har_value: 2.5386
#   f_km_value: 3.5284
#   T_km_up_value: 0.6741
#   V_lm_vfly_value: 60.5315
#   V_lm_hfly_value: 62.4709
#   P_km_up_value: 8.5040
#   Angle1_row: Series:
# 335   -1.174235
# 350    0.678704
# 131   -0.373424
# 492   -1.726326
# 495    0.939283
# 287   -0.845649
# 187   -0.063630
# 406   -0.356236
# 393   -2.757849
# 76    -0.092793
# 489   -0.796470
# 446   -0.062505
# 442   -2.011861
# 214   -0.100827
# 407    1.240710
# 283   -0.385512
# 51     1.754580
# 364    0.052077
# 86     0.107943
# 427   -0.538468
# 134   -0.076737
# 392    0.804763
# 212   -0.475840
# 449    0.267588
# 264   -0.675519
# dtype: float64
#   Angle_row: Series:
# 335    0.599244
# 350   -0.201337
# 131   -0.919690
# 492   -1.830610
# 495   -1.638618
# 287   -0.490235
# 187   -0.129676
# 406    0.872017
# 393    0.029757
# 76     0.474873
# 489   -0.348197
# 446    1.760074
# 442   -0.726575
# 214   -0.582436
# 407   -0.195728
# 283    0.722374
# 51     0.111635
# 364   -0.853519
# 86     1.026477
# 427    1.304489
# 134    1.610915
# 392   -0.151131
# 212   -0.556940
# 449   -0.405355
# 264    1.665725
# dtype: float64
#   Angle2_row: Series:
# 335   -0.598696
# 350   -0.555663
# 131    0.140842
# 492    2.021592
# 495   -0.443111
# 287   -0.826169
# 187   -0.317795
# 406   -1.004427
# 393    0.882282
# 76     0.053366
# 489   -0.037827
# 446    0.262591
# 442   -0.223322
# 214    0.503663
# 407    0.367387
# 283    2.085452
# 51    -0.760159
# 364   -0.843124
# 86    -1.308398
# 427   -0.887755
# 134    0.594968
# 392   -0.502192
# 212   -0.224995
# 449   -0.479989
# 264   -0.105439
# dtype: float64
# --------------------
#
# Best Assignment for BS 2:
#  UAV Index: 3
#  Best Individual:
#   Generation: 1, Type: HC
#   Fitness: 91469.8172
#   P_m_down_value: 0.6057
#   P_m_har_value: 1.2573
#   T_m_har_value: 2.8358
#   f_km_value: 6.6211
#   T_km_up_value: 2.2040
#   V_lm_vfly_value: 69.9830
#   V_lm_hfly_value: 64.7745
#   P_km_up_value: -1.0742
#   Angle1_row: Series:
# 484   -2.151594
# 248    0.835320
# 496   -0.193161
# 220    1.512417
# 333   -0.178107
# 426   -0.094825
# 128   -0.180022
# 202   -0.702364
# 45     1.649006
# 47    -0.120364
# 499    0.139137
# 119    0.038751
# 116    0.885101
# 136    0.415530
# 459   -1.089655
# 476   -1.785535
# 91     1.578864
# 205    1.549879
# 447    0.267885
# 84    -0.781213
# 92     0.070185
# 260    0.306937
# 1     -2.690810
# 256    1.561368
# 89    -0.841763
# dtype: float64
#   Angle_row: Series:
# 484    0.659914
# 248   -1.329101
# 496   -0.172403
# 220   -1.059188
# 333    0.562950
# 426    0.425242
# 128   -1.589700
# 202   -0.948595
# 45    -0.234369
# 47    -0.331665
# 499    0.927642
# 119    1.440554
# 116   -0.259530
# 136   -0.440284
# 459   -0.590463
# 476   -0.915648
# 91     1.287317
# 205   -0.419556
# 447    1.472474
# 84    -1.605453
# 92    -0.868134
# 260    0.026070
# 1      2.907700
# 256    1.121843
# 89    -0.836016
# dtype: float64
#   Angle2_row: Series:
# 484    0.396146
# 248    0.439092
# 496   -0.145691
# 220   -1.864553
# 333    0.904280
# 426    0.444354
# 128   -1.505510
# 202    1.491224
# 45     0.663074
# 47    -1.570531
# 499    0.130951
# 119   -0.335980
# 116   -0.462589
# 136   -0.743287
# 459    1.665521
# 476    0.088411
# 91    -0.707749
# 205    0.431605
# 447    0.492305
# 84     0.804471
# 92     0.597998
# 260    0.276884
# 1     -0.343932
# 256   -1.026735
# 89     0.116993
# dtype: float64
# --------------------
#
# Best Assignment for BS 4:
#  UAV Index: 6
#  Best Individual:
#   Generation: 1, Type: HC
#   Fitness: 101552.6611
#   P_m_down_value: 0.1441
#   P_m_har_value: 1.8563
#   T_m_har_value: 1.2169
#   f_km_value: 0.3949
#   T_km_up_value: 1.1011
#   V_lm_vfly_value: 94.7814
#   V_lm_hfly_value: 24.8062
#   P_km_up_value: 3.1643
#   Angle1_row: Series:
# 89    -0.844178
# 159    0.228613
# 109   -0.455587
# 208   -0.405230
# 295   -0.193948
# 332   -1.311986
# 247    3.236519
# 444    0.110768
# 152    0.989527
# 255   -0.202251
# 62     0.985685
# 202   -1.851149
# 287    1.075728
# 473    1.861849
# 345   -0.334758
# 263    1.158710
# 275    1.904907
# 230    0.763399
# 157   -0.275473
# 60    -1.362350
# 320   -0.046603
# 32     0.695009
# 414    0.520549
# 138    0.722875
# 288   -1.338498
# dtype: float64
#   Angle_row: Series:
# 89     0.722736
# 159   -0.153700
# 109    1.686616
# 208    0.202012
# 295   -1.017205
# 332    1.100487
# 247   -0.204369
# 444    0.789740
# 152    0.893221
# 255    2.040113
# 62    -0.830194
# 202    2.028791
# 287   -0.328749
# 473   -1.021914
# 345   -1.126807
# 263   -0.115423
# 275    0.988239
# 230   -0.617881
# 157   -0.576223
# 60    -0.013180
# 320    3.073622
# 32    -0.660352
# 414   -2.361001
# 138   -0.197783
# 288    1.638398
# dtype: float64
#   Angle2_row: Series:
# 89     1.359491
# 159   -0.105148
# 109    0.734067
# 208    1.115327
# 295   -1.560966
# 332    3.034647
# 247   -0.543763
# 444   -0.286563
# 152   -1.174792
# 255   -1.038025
# 62    -0.263280
# 202    1.744650
# 287    0.707980
# 473   -0.152878
# 345   -0.480580
# 263    0.563067
# 275    0.739100
# 230   -1.286346
# 157   -0.299681
# 60     1.091624
# 320    1.437686
# 32    -0.826400
# 414    0.912808
# 138    0.249595
# 288   -1.207395
# dtype: float64
# --------------------
#
# Best Assignment for BS 0:
#  UAV Index: 7
#  Best Individual:
#   Generation: 1, Type: HC
#   Fitness: 214759.2270
#   P_m_down_value: 0.1974
#   P_m_har_value: 0.1353
#   T_m_har_value: 0.3937
#   f_km_value: 0.2752
#   T_km_up_value: 4.6442
#   V_lm_vfly_value: 22.4843
#   V_lm_hfly_value: 55.0057
#   P_km_up_value: 0.8461
#   Angle1_row: Series:
# 383    147.074469
# 376     43.438250
# 236    178.010566
# 8       67.455781
# 452      4.449993
# 215     14.056460
# 359    113.517292
# 447    102.715656
# 290     50.662074
# 302     74.004758
# 429      6.246942
# 183      5.307910
# 83     100.315026
# 330     32.368907
# 147    119.834760
# 249      4.269181
# 487    113.626248
# 298    137.868739
# 430     81.326592
# 174     51.360941
# 489    142.927682
# 476    105.941041
# 123     84.784524
# 33     177.335823
# 6      156.697950
# Name: 0, dtype: float64
#   Angle_row: Series:
# 383     60.748307
# 376      3.028750
# 236    110.209899
# 8        9.299199
# 452     31.986092
# 215     36.356568
# 359     18.396651
# 447    174.999693
# 290     32.958660
# 302    118.394213
# 429    176.787327
# 183     83.089425
# 83      75.774449
# 330    118.881453
# 147    145.684467
# 249    157.254702
# 487     26.280741
# 298    124.637128
# 430     51.691324
# 174     75.120867
# 489     79.920885
# 476    175.859733
# 123     28.731612
# 33       8.365745
# 6       84.470200
# Name: 0, dtype: float64
#   Angle2_row: Series:
# 383     71.294703
# 376    103.974887
# 236    123.888557
# 8       41.271809
# 452     65.273630
# 215    102.997080
# 359    132.492008
# 447     35.313787
# 290     51.154816
# 302     13.203328
# 429     60.033892
# 183     33.534442
# 83      16.057227
# 330    129.804386
# 147     17.322259
# 249     82.098033
# 487     93.614904
# 298    156.446154
# 430      6.782483
# 174     75.288628
# 489     87.924149
# 476     10.872227
# 123     35.380866
# 33     121.782029
# 6      113.170820
# Name: 0, dtype: float64
# --------------------
#
# --- UAVs without Assigned Base Stations ---
#   UAV 0 : No BS is assigned
# --------------------
#   UAV 4 : No BS is assigned
# --------------------
#   UAV 5 : No BS is assigned
# --------------------
# calculaiton for p_max for HC 5
#
# --- Best Unique UAV Assignments (Auction Based Method) using Hill Climbing ---
#
# Best Assignment for BS 1:
#  UAV Index: 3
#  Best Individual:
#   Generation: 1, Type: HC
#   Fitness: 52561.3337
#   P_m_down_value: 1.2468
#   P_m_har_value: 2.1625
#   T_m_har_value: 1.7271
#   f_km_value: 1.2183
#   T_km_up_value: 0.4966
#   V_lm_vfly_value: 67.4403
#   V_lm_hfly_value: 68.1397
#   P_km_up_value: 8.4526
#   Angle1_row: Series:
# 100   -2.204276
# 64     0.067857
# 60     0.434875
# 152    0.186795
# 68     1.085525
# 161   -0.239009
# 384   -0.721422
# 437   -0.258369
# 455   -1.992508
# 162    1.459864
# 368    0.171961
# 478    0.466035
# 362    0.211706
# 220   -0.335402
# 198    0.135576
# 125    2.045580
# 499   -0.248867
# 299    1.002368
# 397   -1.964521
# 14     0.379077
# 246    0.392545
# 485    0.500939
# 439    1.436845
# 78     0.388714
# 10    -1.439273
# dtype: float64
#   Angle_row: Series:
# 100   -0.088014
# 64    -0.220098
# 60    -0.589818
# 152    0.402168
# 68     0.772991
# 161    0.499309
# 384    1.591493
# 437    1.382560
# 455   -0.100405
# 162    0.044032
# 368   -0.414462
# 478   -1.110786
# 362    0.587195
# 220   -1.240358
# 198   -0.982571
# 125    0.692994
# 499    1.294087
# 299    0.996203
# 397   -0.574184
# 14    -0.206301
# 246   -0.635838
# 485   -1.026002
# 439   -0.446645
# 78     0.827632
# 10    -0.434192
# dtype: float64
#   Angle2_row: Series:
# 100    1.860449
# 64    -0.787899
# 60    -0.385227
# 152   -1.240488
# 68     0.427102
# 161   -0.046720
# 384    1.351229
# 437   -0.702823
# 455    0.079502
# 162   -2.126364
# 368   -0.099173
# 478   -0.772683
# 362   -1.135021
# 220   -1.159946
# 198    0.174340
# 125   -1.341419
# 499   -0.777660
# 299    1.389720
# 397   -0.145857
# 14     0.333243
# 246    1.340159
# 485    0.305667
# 439    0.465476
# 78     0.308848
# 10    -0.299183
# dtype: float64
# --------------------
#
# Best Assignment for BS 3:
#  UAV Index: 1
#  Best Individual:
#   Generation: 1, Type: HC
#   Fitness: 58999.5869
#   P_m_down_value: 3.4431
#   P_m_har_value: 0.5593
#   T_m_har_value: 0.5967
#   f_km_value: 2.0513
#   T_km_up_value: 0.9029
#   V_lm_vfly_value: 72.7829
#   V_lm_hfly_value: 64.5112
#   P_km_up_value: 5.4858
#   Angle1_row: Series:
# 132    0.115109
# 483    1.967776
# 454    1.316271
# 108   -0.585881
# 371    0.692882
# 226    0.933390
# 147   -0.545024
# 238   -0.642947
# 198    0.502491
# 311   -0.561138
# 79    -0.073350
# 498   -0.265946
# 331    2.196556
# 0     -0.398611
# 299   -1.571407
# 417   -1.020766
# 254   -2.004075
# 182   -0.772295
# 276    0.122521
# 250    1.176391
# 213    0.629025
# 11     0.730825
# 266   -0.075161
# 481    1.342045
# 295   -0.096693
# dtype: float64
#   Angle_row: Series:
# 132    1.659596
# 483    1.264135
# 454    0.234675
# 108    0.270782
# 371   -1.407552
# 226    0.488448
# 147    0.798221
# 238    0.112919
# 198    1.044706
# 311    0.443566
# 79    -1.544701
# 498    1.387781
# 331    0.099063
# 0      0.431310
# 299    0.434974
# 417    1.060160
# 254   -0.074605
# 182   -0.170220
# 276    0.331576
# 250    0.233990
# 213    0.031953
# 11     0.710532
# 266    0.738439
# 481   -0.626004
# 295    0.487415
# dtype: float64
#   Angle2_row: Series:
# 132    0.513822
# 483   -0.516838
# 454    2.077965
# 108   -0.860339
# 371   -0.650574
# 226   -1.224972
# 147   -1.310926
# 238    0.071440
# 198    1.299531
# 311   -1.253181
# 79     0.778517
# 498   -1.106608
# 331    1.271026
# 0      1.233754
# 299    1.294468
# 417    1.459847
# 254   -0.183048
# 182    0.701398
# 276   -0.707837
# 250   -0.003544
# 213   -0.244066
# 11    -0.141519
# 266   -0.152358
# 481    2.233762
# 295   -0.175743
# dtype: float64
# --------------------
#
# Best Assignment for BS 2:
#  UAV Index: 7
#  Best Individual:
#   Generation: 1, Type: HC
#   Fitness: 71965.5223
#   P_m_down_value: 1.2103
#   P_m_har_value: 1.4138
#   T_m_har_value: 1.4827
#   f_km_value: 2.2340
#   T_km_up_value: 1.2413
#   V_lm_vfly_value: 22.6261
#   V_lm_hfly_value: 56.3405
#   P_km_up_value: 2.8341
#   Angle1_row: Series:
# 357    0.071236
# 420    1.335048
# 393   -1.257786
# 302    0.340902
# 4     -1.432966
# 183    0.436332
# 161   -0.950836
# 107   -0.940308
# 227   -0.256165
# 215   -0.599199
# 196   -0.400566
# 283    1.208001
# 113   -0.205289
# 344   -0.034262
# 102   -0.243589
# 219    1.311452
# 249    1.106900
# 469   -1.436413
# 290   -0.028195
# 109    1.387936
# 422    0.224009
# 27     0.907536
# 339    0.334232
# 443    0.110321
# 213    0.001757
# dtype: float64
#   Angle_row: Series:
# 357    2.044081
# 420    1.239994
# 393    0.177922
# 302   -0.098382
# 4      1.214159
# 183   -1.617173
# 161   -0.926746
# 107   -1.463319
# 227   -1.753941
# 215    0.928050
# 196   -0.937202
# 283   -0.391569
# 113    0.960625
# 344    0.995968
# 102   -0.456944
# 219   -0.383635
# 249    0.669054
# 469   -1.282544
# 290    0.466459
# 109    3.033572
# 422    2.820246
# 27    -2.049497
# 339   -1.810362
# 443   -1.044423
# 213   -0.334957
# dtype: float64
#   Angle2_row: Series:
# 357    1.512397
# 420    0.026134
# 393    0.628412
# 302   -1.419460
# 4     -0.617517
# 183    0.419918
# 161    0.606076
# 107   -0.109609
# 227    0.649213
# 215    0.406587
# 196    0.019211
# 283    0.651863
# 113    0.416370
# 344   -0.698386
# 102   -0.417105
# 219   -0.913265
# 249   -0.585069
# 469   -0.029834
# 290    0.825312
# 109    0.077944
# 422   -0.780498
# 27    -0.362732
# 339    0.231681
# 443    0.732306
# 213   -0.204574
# dtype: float64
# --------------------
#
# Best Assignment for BS 4:
#  UAV Index: 2
#  Best Individual:
#   Generation: 1, Type: HC
#   Fitness: 94889.9093
#   P_m_down_value: 0.4424
#   P_m_har_value: 0.8419
#   T_m_har_value: 0.7347
#   f_km_value: 1.4848
#   T_km_up_value: 2.0557
#   V_lm_vfly_value: 59.6857
#   V_lm_hfly_value: 62.3314
#   P_km_up_value: 3.0613
#   Angle1_row: Series:
# 94    -0.546486
# 191    1.601996
# 424   -1.863611
# 478   -1.147477
# 414    0.455512
# 14     0.318033
# 119    0.346682
# 28     0.134422
# 142    0.240545
# 457    1.003400
# 255   -0.149641
# 37     0.576497
# 77    -0.662718
# 127    0.304492
# 152    0.170371
# 174    1.240939
# 363   -0.032564
# 484    1.259984
# 144    2.214820
# 226   -1.235683
# 374   -2.009834
# 305    1.018722
# 115   -1.195603
# 420   -1.892325
# 163   -0.603574
# dtype: float64
#   Angle_row: Series:
# 94    -2.453684
# 191   -0.517111
# 424   -0.087935
# 478   -0.472486
# 414    0.821357
# 14    -0.295636
# 119    2.340049
# 28     1.532913
# 142   -1.207096
# 457    0.424394
# 255    0.526677
# 37    -0.490261
# 77     1.354309
# 127    0.412890
# 152   -1.599652
# 174    1.542114
# 363    0.550619
# 484    0.723955
# 144   -0.565520
# 226    0.873134
# 374    0.818812
# 305    1.972676
# 115    1.000507
# 420   -0.991756
# 163    0.639725
# dtype: float64
#   Angle2_row: Series:
# 94    -1.720444
# 191    0.007286
# 424    1.656296
# 478    0.564692
# 414   -0.753625
# 14     0.152227
# 119   -0.085581
# 28     0.506697
# 142   -1.264713
# 457   -1.839748
# 255    0.390044
# 37     1.641667
# 77     0.424965
# 127    0.433944
# 152   -1.278986
# 174    0.293689
# 363    0.439557
# 484   -0.077582
# 144    0.480088
# 226   -0.455876
# 374    0.570541
# 305    0.350965
# 115   -1.658973
# 420   -0.491136
# 163    0.657066
# dtype: float64
# --------------------
#
# Best Assignment for BS 0:
#  UAV Index: 5
#  Best Individual:
#   Generation: 1, Type: HC
#   Fitness: 159932.1127
#   P_m_down_value: 1.2589
#   P_m_har_value: 2.0470
#   T_m_har_value: 0.2253
#   f_km_value: 3.2573
#   T_km_up_value: 4.4051
#   V_lm_vfly_value: 46.7240
#   V_lm_hfly_value: 34.9954
#   P_km_up_value: -0.0188
#   Angle1_row: Series:
# 124   -0.721063
# 236    0.332802
# 431    1.942990
# 418   -0.641145
# 470    1.604619
# 397   -1.686799
# 488    0.267567
# 412   -0.166733
# 367    2.584192
# 477    1.328227
# 138    0.463961
# 293   -0.748619
# 383    1.032667
# 42     0.291425
# 334    0.213144
# 466   -0.125273
# 350   -0.011601
# 232   -0.243318
# 203    0.165665
# 250    0.501635
# 35     1.607796
# 328    0.571148
# 212    0.469427
# 39     0.515776
# 137    1.671285
# dtype: float64
#   Angle_row: Series:
# 124    0.181139
# 236    0.474161
# 431   -0.534655
# 418   -2.107877
# 470    1.233246
# 397    0.991892
# 488    0.069787
# 412    0.026171
# 367   -1.109956
# 477   -0.409830
# 138   -1.098966
# 293   -0.799157
# 383    0.155653
# 42    -0.181091
# 334    0.409067
# 466   -0.222137
# 350    0.856394
# 232    0.510513
# 203   -1.332774
# 250    0.602542
# 35     0.035705
# 328   -1.227034
# 212    0.557464
# 39     0.221586
# 137   -0.205497
# dtype: float64
#   Angle2_row: Series:
# 124    0.471824
# 236   -1.318662
# 431   -0.236168
# 418    0.486182
# 470    1.925595
# 397   -0.326794
# 488   -0.276033
# 412    0.385087
# 367    0.655864
# 477   -1.243042
# 138    1.250906
# 293    1.026597
# 383    0.058646
# 42     0.695788
# 334    0.025233
# 466   -0.850885
# 350    1.049263
# 232    1.795481
# 203    2.400559
# 250    0.596051
# 35    -0.702089
# 328    0.355739
# 212    0.194617
# 39    -1.289137
# 137   -1.703290
# dtype: float64
# --------------------
#
# --- UAVs without Assigned Base Stations ---
#   UAV 0 : No BS is assigned
# --------------------
#   UAV 4 : No BS is assigned
# --------------------
#   UAV 6 : No BS is assigned
# --------------------
# calculaiton for p_max for HC 6
#
# --- Best Unique UAV Assignments (Auction Based Method) using Hill Climbing ---
#
# Best Assignment for BS 2:
#  UAV Index: 2
#  Best Individual:
#   Generation: 1, Type: HC
#   Fitness: 41255.3165
#   P_m_down_value: 1.2392
#   P_m_har_value: 1.9041
#   T_m_har_value: 0.2530
#   f_km_value: 5.1603
#   T_km_up_value: 0.4258
#   V_lm_vfly_value: 62.9668
#   V_lm_hfly_value: 60.3741
#   P_km_up_value: 5.5458
#   Angle1_row: Series:
# 362   -0.323051
# 153   -0.952503
# 488   -1.217230
# 123   -0.613883
# 25     0.292378
# 346   -0.436816
# 107   -1.434128
# 15     1.188164
# 335    1.039546
# 280   -0.855398
# 354   -0.272676
# 415    0.966919
# 304   -0.055231
# 224    1.860123
# 422    0.287458
# 250    1.035920
# 406   -1.072750
# 278    0.595454
# 165    0.656320
# 410    0.001968
# 471    0.360886
# 214   -0.632617
# 326   -1.264056
# 307    2.068922
# 54     1.478439
# dtype: float64
#   Angle_row: Series:
# 362   -0.014144
# 153   -0.384902
# 488    0.602386
# 123   -0.735362
# 25    -0.470923
# 346    0.237109
# 107    0.424250
# 15     0.513618
# 335   -0.240045
# 280   -0.823723
# 354    0.839282
# 415    0.664438
# 304   -0.080123
# 224    0.019899
# 422    0.552079
# 250    0.118645
# 406    0.833726
# 278    1.080628
# 165    0.367661
# 410   -0.685436
# 471   -0.372176
# 214   -0.273392
# 326   -0.201356
# 307   -1.506227
# 54    -1.189162
# dtype: float64
#   Angle2_row: Series:
# 362    0.213806
# 153   -0.013071
# 488    1.753637
# 123    0.691093
# 25     0.938649
# 346   -1.378100
# 107   -0.702468
# 15    -0.900231
# 335   -0.812631
# 280    0.324448
# 354    0.420709
# 415    0.429851
# 304    1.376612
# 224   -1.719590
# 422   -0.886077
# 250   -0.723827
# 406    0.106517
# 278    0.021814
# 165   -0.280283
# 410   -0.868189
# 471   -1.325637
# 214   -0.038514
# 326   -1.378993
# 307    0.115800
# 54    -0.784373
# dtype: float64
# --------------------
#
# Best Assignment for BS 3:
#  UAV Index: 1
#  Best Individual:
#   Generation: 1, Type: HC
#   Fitness: 48038.5108
#   P_m_down_value: 0.8087
#   P_m_har_value: 0.7217
#   T_m_har_value: 1.0353
#   f_km_value: 2.1035
#   T_km_up_value: 0.5284
#   V_lm_vfly_value: 73.8534
#   V_lm_hfly_value: 63.4829
#   P_km_up_value: 9.8111
#   Angle1_row: Series:
# 395   -0.139896
# 223    1.407717
# 135    0.058070
# 9      1.015614
# 381    1.688964
# 269   -1.046287
# 421   -2.094188
# 85     0.596124
# 167   -0.629921
# 487    0.540525
# 311    0.579564
# 476    0.669187
# 256   -1.268118
# 102    0.932995
# 174   -0.873943
# 479    0.161970
# 200    0.314942
# 390   -0.392056
# 280    0.171682
# 43     1.790117
# 456    0.771592
# 325   -0.351219
# 178   -1.174625
# 4     -0.171190
# 494   -0.473010
# dtype: float64
#   Angle_row: Series:
# 395   -1.167900
# 223    0.435315
# 135    1.102648
# 9     -0.850386
# 381   -0.181517
# 269   -0.803925
# 421    1.707921
# 85    -1.400541
# 167   -0.587540
# 487    0.399760
# 311   -0.267947
# 476    0.862980
# 256   -0.998107
# 102    0.426227
# 174    1.111539
# 479   -0.498415
# 200    1.933016
# 390    1.576068
# 280    0.172976
# 43     0.240661
# 456   -0.696929
# 325    1.286546
# 178    0.154379
# 4     -0.500376
# 494   -0.200930
# dtype: float64
#   Angle2_row: Series:
# 395   -2.082043
# 223   -0.704999
# 135    1.034334
# 9      0.921044
# 381   -1.268701
# 269   -0.434065
# 421    0.191690
# 85    -0.384645
# 167    2.423716
# 487   -0.979929
# 311   -0.879306
# 476   -0.152913
# 256    0.506626
# 102    1.615062
# 174   -0.138299
# 479   -0.372355
# 200    0.347020
# 390    1.003964
# 280    0.684527
# 43     0.617625
# 456    0.845311
# 325    0.855906
# 178   -0.985350
# 4     -0.075369
# 494   -0.755251
# dtype: float64
# --------------------
#
# Best Assignment for BS 1:
#  UAV Index: 5
#  Best Individual:
#   Generation: 1, Type: HC
#   Fitness: 54150.9806
#   P_m_down_value: 0.9505
#   P_m_har_value: 2.0763
#   T_m_har_value: 2.0734
#   f_km_value: 4.9702
# ...
# 370   -0.389299
# 464   -1.575244
# 297   -0.460780
# 67     0.142839
# 189    1.503996
# 357   -1.278353
# 135   -1.357745
# dtype: float64
#   Angle2_row: Series:
# 287    1.174051
# 14     1.669562
# 141   -0.803393
# 71    -0.393989
# 234    0.572194
# 496   -0.525340
# 127   -0.813171
# 108   -0.004412
# 143    0.749951
# 273   -0.801672
# 43    -0.649742
# 3      1.192740
# 462    0.547510
# 401    1.110095
# 355    1.064531
# 323    0.793079
# 258    0.988233
# 248    1.353620
# 370    0.783877
# 464   -1.172191
# 297    1.119431
# 67    -0.017405
# 189    0.109746
# 357   -0.874274
# 135    0.286629
# dtype: float64
# --------------------
#
# Best Assignment for BS 4:
#  UAV Index: 2
#  Best Individual:
#   Generation: 1, Type: HC
#   Fitness: 42726.2849
#   P_m_down_value: 0.9323
#   P_m_har_value: 1.1300
#   T_m_har_value: 1.5638
#   f_km_value: 6.9923
#   T_km_up_value: 0.4941
#   V_lm_vfly_value: 56.2576
#   V_lm_hfly_value: 59.9672
#   P_km_up_value: 6.5558
#   Angle1_row: Series:
# 345   -1.263770
# 310   -0.336639
# 332   -0.344816
# 169    1.629725
# 266   -0.405124
# 478    0.906114
# 223   -0.382198
# 77     0.141334
# 403   -0.390827
# 224   -1.256397
# 303    1.427781
# 291   -0.403383
# 397    0.824032
# 271   -0.219954
# 385   -0.017164
# 196    0.532552
# 167   -0.293519
# 87     0.434898
# 407    0.549061
# 457    1.091171
# 383   -1.867690
# 110   -0.395587
# 31    -0.671329
# 347    0.489894
# 17    -1.183990
# dtype: float64
#   Angle_row: Series:
# 345    1.554364
# 310   -0.439755
# 332    1.800983
# 169   -0.883699
# 266   -1.192433
# 478   -0.925401
# 223   -1.026391
# 77    -0.264991
# 403    0.906723
# 224    0.078786
# 303    0.179042
# 291   -1.830954
# 397   -0.232539
# 271   -0.548499
# 385    0.700464
# 196   -2.156041
# 167    1.072852
# 87     0.191086
# 407   -2.112713
# 457   -0.411403
# 383    1.482745
# 110    0.073148
# 31    -0.316586
# 347    1.623021
# 17     0.419488
# dtype: float64
#   Angle2_row: Series:
# 345    2.072006
# 310   -1.133959
# 332   -0.724746
# 169   -1.868412
# 266    1.595574
# 478    0.097951
# 223   -1.687723
# 77     0.556192
# 403    0.004659
# 224   -0.922255
# 303   -0.482012
# 291    1.219175
# 397   -0.408092
# 271   -0.144663
# 385   -0.290551
# 196    0.521367
# 167   -0.628736
# 87     0.859147
# 407    1.330994
# 457   -2.088711
# 383   -0.946992
# 110    1.141105
# 31     1.287101
# 347    1.096952
# 17    -1.122138
# dtype: float64
# --------------------
#
# Best Assignment for BS 2:
#  UAV Index: 6
#  Best Individual:
#   Generation: 1, Type: HC
#   Fitness: 48618.0900
#   P_m_down_value: 2.6079
#   P_m_har_value: 2.3146
#   T_m_har_value: 6.7868
#   f_km_value: 12.2355
#   T_km_up_value: 0.5008
#   V_lm_vfly_value: 92.4759
#   V_lm_hfly_value: 25.7757
#   P_km_up_value: 9.9532
#   Angle1_row: Series:
# 117    0.209370
# 174   -1.197657
# 134   -2.387990
# 142    1.194759
# 66    -1.281063
# 175    0.540684
# 286    0.495593
# 196    1.008581
# 369   -0.169094
# 150    0.482790
# 342   -1.998713
# 359    1.779605
# 444   -0.595928
# 106   -1.240149
# 149   -1.559026
# 97     0.193692
# 476   -0.199615
# 313   -0.235556
# 300    0.774065
# 325   -0.519207
# 243    0.369822
# 443    2.015448
# 128    2.743166
# 263    0.080791
# 365   -0.003619
# dtype: float64
#   Angle_row: Series:
# 117    0.574334
# 174   -0.272592
# 134    1.577508
# 142   -0.106442
# 66     1.069588
# 175   -0.684213
# 286   -0.521121
# 196   -0.957436
# 369    0.154869
# 150    0.613521
# 342   -0.873902
# 359   -0.048844
# 444   -2.404890
# 106    0.741557
# 149   -0.265832
# 97     1.466209
# 476    0.366996
# 313    0.353925
# 300    0.999929
# 325   -0.253338
# 243   -0.342809
# 443   -0.809283
# 128   -0.853618
# 263    1.090086
# 365    1.075520
# dtype: float64
#   Angle2_row: Series:
# 117   -2.369139
# 174    0.495949
# 134    1.239253
# 142    1.175027
# 66    -1.465047
# 175   -0.383271
# 286    1.631505
# 196   -0.142388
# 369   -1.079561
# 150   -1.929752
# 342   -1.316599
# 359    1.827555
# 444   -0.764687
# 106    0.824043
# 149   -0.551116
# 97     0.107271
# 476   -0.758469
# 313   -0.428031
# 300   -0.088367
# 325    0.989849
# 243    0.331331
# 443    0.882271
# 128   -0.283348
# 263   -0.496888
# 365   -0.396687
# dtype: float64
# --------------------
#
# Best Assignment for BS 0:
#  UAV Index: 5
#  Best Individual:
#   Generation: 1, Type: HC
#   Fitness: 58485.6585
#   P_m_down_value: 1.4477
#   P_m_har_value: 0.0564
#   T_m_har_value: 1.7853
#   f_km_value: 5.8394
#   T_km_up_value: 0.9321
#   V_lm_vfly_value: 43.8462
#   V_lm_hfly_value: 36.4292
#   P_km_up_value: 4.4503
#   Angle1_row: Series:
# 370    0.282389
# 2     -0.003042
# 230    0.082034
# 490   -0.054441
# 212   -0.995204
# 38     0.223331
# 113    1.606950
# 189    1.490336
# 161   -0.828835
# 26    -1.775164
# 224   -0.143411
# 459    1.674505
# 182    0.248075
# 24    -1.009889
# 82     0.124604
# 367    0.939873
# 377    0.115075
# 190    1.526836
# 372   -0.153947
# 296   -0.361904
# 353    0.053014
# 435   -1.109462
# 424   -1.132216
# 469   -0.913646
# 155    0.115606
# dtype: float64
#   Angle_row: Series:
# 370    0.949422
# 2     -0.988723
# 230   -1.869178
# 490    1.220842
# 212   -1.717181
# 38    -1.549002
# 113   -0.908718
# 189   -0.738136
# 161    0.379181
# 26     0.532169
# 224   -1.661721
# 459   -1.239586
# 182    1.522643
# 24     0.030859
# 82     0.174055
# 367   -0.214587
# 377   -1.225594
# 190   -0.173382
# 372    0.462911
# 296    0.073667
# 353   -0.697637
# 435   -0.541699
# 424   -1.064286
# 469   -0.614682
# 155    0.932714
# dtype: float64
#   Angle2_row: Series:
# 370   -0.606486
# 2      0.466018
# 230   -2.048802
# 490    0.041484
# 212   -0.776970
# 38    -0.048295
# 113   -1.846445
# 189   -1.052920
# 161    0.970856
# 26     0.787122
# 224    0.259751
# 459    0.324916
# 182   -1.028873
# 24     0.355741
# 82     1.821458
# 367    0.824269
# 377   -0.769374
# 190    0.893545
# 372   -0.352759
# 296   -0.449746
# 353   -0.316527
# 435   -0.270319
# 424   -0.967181
# 469    3.053435
# 155    0.881429
# dtype: float64
# --------------------
#
# Best Assignment for BS 1:
#  UAV Index: 7
#  Best Individual:
#   Generation: 1, Type: HC
#   Fitness: 81223.2901
#   P_m_down_value: 0.6750
#   P_m_har_value: 5.3973
#   T_m_har_value: 2.4041
#   f_km_value: 4.4399
#   T_km_up_value: 1.6759
#   V_lm_vfly_value: 22.7331
#   V_lm_hfly_value: 52.5934
#   P_km_up_value: 5.2577
#   Angle1_row: Series:
# 9      1.565526
# 269   -0.520996
# 266    1.978365
# 154   -0.001363
# 216   -0.965794
# 260   -1.097914
# 411    0.359270
# 481    0.266268
# 238   -0.059434
# 25     0.388062
# 41     0.585520
# 162   -0.531182
# 271    1.235201
# 218    0.152531
# 267    1.193799
# 421    0.222423
# 208    0.639292
# 79     0.131328
# 213   -0.684465
# 52     0.293619
# 268   -0.213136
# 131    0.148165
# 439    0.849828
# 302    0.569307
# 40    -1.889669
# dtype: float64
#   Angle_row: Series:
# 9      0.879054
# 269    1.220538
# 266   -1.097250
# 154   -0.058205
# 216   -0.838086
# 260   -0.038311
# 411    1.189318
# 481   -0.547211
# 238   -0.123641
# 25    -0.162796
# 41    -0.044782
# 162    0.095906
# 271    0.824461
# 218   -0.205435
# 267    0.492619
# 421   -0.996846
# 208    0.640700
# 79     0.950209
# 213    1.083281
# 52     0.923069
# 268    0.464498
# 131    0.241013
# 439    2.123403
# 302    0.538677
# 40     0.005176
# dtype: float64
#   Angle2_row: Series:
# 9     -0.091289
# 269    1.344489
# 266    1.683514
# 154   -0.915941
# 216    0.606250
# 260   -2.064874
# 411    0.137762
# 481    1.136173
# 238    0.029603
# 25     0.467563
# 41     1.492202
# 162    0.431049
# 271    0.054158
# 218   -0.337393
# 267   -0.939344
# 421   -1.185440
# 208   -0.323098
# 79    -1.252811
# 213    0.641851
# 52     1.358056
# 268   -0.169323
# 131    0.657449
# 439    1.239609
# 302    0.270088
# 40    -0.801883
# dtype: float64
# --------------------
#
# --- UAVs without Assigned Base Stations ---
#   UAV 0 : No BS is assigned
# --------------------
#   UAV 1 : No BS is assigned
# --------------------
#   UAV 4 : No BS is assigned
# --------------------
# calculaiton for p_max for HC 10
#
# --- Best Unique UAV Assignments (Auction Based Method) using Hill Climbing ---
#
# Best Assignment for BS 2:
#  UAV Index: 5
#  Best Individual:
#   Generation: 1, Type: HC
#   Fitness: 43994.8881
#   P_m_down_value: 6.3085
#   P_m_har_value: 2.9177
#   T_m_har_value: 1.5476
#   f_km_value: 4.4054
#   T_km_up_value: 0.3899
#   V_lm_vfly_value: 49.2529
#   V_lm_hfly_value: 34.7213
#   P_km_up_value: 9.0818
#   Angle1_row: Series:
# 367   -1.764014
# 263   -0.591599
# 477   -0.264882
# 81    -0.272416
# 429   -0.834202
# 207   -0.728310
# 73     0.897584
# 194   -0.162584
# 377    0.624312
# 195   -0.728543
# 416   -1.403202
# 179   -0.295872
# 218    0.855268
# 24     0.217240
# 469   -0.376547
# 100   -0.164884
# 399    0.948196
# 479    0.194781
# 446   -1.374863
# 383   -0.525510
# 171    0.375980
# 168   -1.239600
# 350   -0.965099
# 53    -0.557638
# 297   -0.660199
# dtype: float64
#   Angle_row: Series:
# 367   -0.680989
# 263   -1.442854
# 477   -0.374620
# 81     0.176260
# 429    0.314717
# 207   -1.542191
# 73    -0.133673
# 194    1.105363
# 377   -2.130012
# 195    0.543170
# 416   -2.348567
# 179   -0.645630
# 218   -0.327141
# 24    -1.652932
# 469    0.726489
# 100   -1.510038
# 399    0.255647
# 479   -0.047075
# 446   -0.821162
# 383   -1.211825
# 171   -0.040777
# 168   -0.839023
# 350    1.795531
# 53    -0.353840
# 297   -0.050947
# dtype: float64
#   Angle2_row: Series:
# 367   -0.048167
# 263   -0.049191
# 477    0.161295
# 81     1.533255
# 429   -0.325695
# 207    0.862496
# 73     0.107024
# 194    0.030406
# 377   -0.950421
# 195   -0.858808
# 416    0.251683
# 179    1.183154
# 218    0.288064
# 24    -0.958155
# 469   -0.451274
# 100    1.082254
# 399    1.924896
# 479    1.001043
# 446   -0.448146
# 383    1.061362
# 171   -0.032724
# 168    1.768104
# 350   -0.945199
# 53    -0.725486
# 297    0.250794
# dtype: float64
# --------------------
#
# Best Assignment for BS 4:
#  UAV Index: 7
#  Best Individual:
#   Generation: 1, Type: HC
#   Fitness: 53100.5783
#   P_m_down_value: 1.1368
#   P_m_har_value: 0.6433
#   T_m_har_value: 0.6689
#   f_km_value: 7.7759
#   T_km_up_value: 0.7540
#   V_lm_vfly_value: 24.1277
#   V_lm_hfly_value: 55.8398
#   P_km_up_value: 8.0990
#   Angle1_row: Series:
# 436   -1.165723
# 17    -0.343324
# 38    -1.384614
# 298   -0.600155
# 138   -0.611001
# 284    0.522418
# 270    1.724549
# 451    0.578089
# 4      0.517284
# 492    0.832492
# 424   -0.297481
# 36    -0.700283
# 107    2.383233
# 220    0.352861
# 194   -0.319893
# 313   -1.149601
# 94    -0.517302
# 14    -0.871547
# 311    0.018916
# 208    0.075705
# 475   -1.317859
# 100    0.085537
# 157   -0.385954
# 84    -0.717698
# 130   -0.625068
# dtype: float64
#   Angle_row: Series:
# 436   -1.281018
# 17     0.964091
# 38     0.601476
# 298   -1.773308
# 138    1.817179
# 284   -0.673328
# 270   -1.538160
# 451    0.548142
# 4     -1.618034
# 492    1.300976
# 424   -1.955907
# 36    -1.631149
# 107   -0.265552
# 220   -0.077047
# 194    0.561255
# 313   -0.143359
# 94    -0.288357
# 14     0.115480
# 311    0.589648
# 208    0.393431
# 475   -0.933384
# 100   -2.768411
# 157    0.635882
# 84     0.239786
# 130   -0.932390
# dtype: float64
#   Angle2_row: Series:
# 436   -0.734354
# 17    -0.786751
# 38     0.947771
# 298   -0.280876
# 138   -0.897308
# 284    0.131213
# 270   -1.967673
# 451    0.527925
# 4      0.454201
# 492   -0.557614
# 424    0.242560
# 36    -1.231060
# 107    1.758595
# 220    1.940159
# 194    1.017593
# 313    0.048685
# 94     1.633687
# 14     0.252687
# 311   -0.238444
# 208   -0.801921
# 475   -0.421206
# 100   -0.272670
# 157   -1.300635
# 84     1.091276
# 130   -0.266503
# dtype: float64
# --------------------
#
# Best Assignment for BS 1:
#  UAV Index: 2
#  Best Individual:
#   Generation: 1, Type: HC
#   Fitness: 62973.0480
#   P_m_down_value: 0.4643
#   P_m_har_value: 0.9216
#   T_m_har_value: 0.1383
#   f_km_value: 1.9141
#   T_km_up_value: 1.0162
#   V_lm_vfly_value: 59.0654
#   V_lm_hfly_value: 60.5731
#   P_km_up_value: 4.6585
#   Angle1_row: Series:
# 17    -0.803056
# 146    0.185026
# 350    0.189546
# 25    -0.321212
# 297   -0.473915
# 204   -0.798046
# 154   -0.514043
# 142   -0.344856
# 463    2.030617
# 201   -0.353568
# 130   -1.431398
# 75     0.466322
# 145   -0.429596
# 296   -2.324565
# 227    1.060553
# 308    0.724756
# 23     0.125455
# 80     0.613128
# 446   -0.753832
# 364    1.004303
# 241    1.700514
# 208   -0.206010
# 465   -0.844518
# 156    0.201021
# 157   -1.284180
# dtype: float64
#   Angle_row: Series:
# 17    -0.408325
# 146    0.266568
# 350    0.780885
# 25     2.022449
# 297   -0.588825
# 204    0.526183
# 154   -0.217557
# 142   -0.191837
# 463    0.661775
# 201   -0.033270
# 130   -1.095228
# 75    -0.334853
# 145    0.740122
# 296   -0.381960
# 227   -0.245608
# 308   -1.745460
# 23    -0.524273
# 80    -0.315167
# 446    0.652187
# 364   -0.663374
# 241    0.050779
# 208   -1.346941
# 465   -0.271157
# 156    0.463198
# 157   -0.112699
# dtype: float64
#   Angle2_row: Series:
# 17     0.920042
# 146   -1.644392
# 350   -1.686275
# 25    -1.751680
# 297   -0.357293
# 204   -1.484361
# 154   -0.112030
# 142   -0.889619
# 463   -0.703671
# 201    0.844851
# 130    1.370979
# 75     0.827104
# 145    2.109351
# 296    1.556988
# 227   -0.266066
# 308    1.515470
# 23     0.421720
# 80    -1.148132
# 446    0.088880
# 364    1.670581
# 241    0.560752
# 208   -2.955483
# 465    0.398240
# 156    0.376799
# 157    0.819234
# dtype: float64
# --------------------
#
# Best Assignment for BS 3:
#  UAV Index: 0
#  Best Individual:
#   Generation: 1, Type: HC
#   Fitness: 63094.5462
#   P_m_down_value: 1.5685
#   P_m_har_value: 2.0024
#   T_m_har_value: 0.0222
#   f_km_value: 3.4511
#   T_km_up_value: 0.8553
#   V_lm_vfly_value: 18.4521
#   V_lm_hfly_value: 89.3662
#   P_km_up_value: 7.8776
#   Angle1_row: Series:
# 71    -0.100853
# 156    0.430320
# 313   -0.562937
# 461    0.898119
# 327   -0.157973
# 351    0.223026
# 458    0.007587
# 126    0.731291
# 188   -1.131536
# 113   -1.723374
# 212    1.044893
# 160    1.317680
# 59    -0.218900
# 84    -1.900523
# 40     1.042062
# 322   -0.260695
# 263    0.803363
# 238    0.761817
# 355    1.116951
# 376    0.912001
# 239   -0.541774
# 335   -0.039002
# 317    1.116285
# 86    -0.216850
# 47    -1.347799
# dtype: float64
#   Angle_row: Series:
# 71    -1.549631
# 156    0.851586
# 313   -1.554367
# 461    0.275326
# 327   -1.072001
# 351    0.549753
# 458    0.083007
# 126   -1.720087
# 188   -0.279431
# 113   -0.837112
# 212    0.426930
# 160   -0.006187
# 59    -1.092654
# 84    -0.791587
# 40    -0.293122
# 322   -1.968463
# 263    0.350097
# 238   -2.480394
# 355    0.327692
# 376   -2.187177
# 239   -2.165790
# 335    2.369917
# 317    0.001989
# 86    -0.721658
# 47     1.285619
# dtype: float64
#   Angle2_row: Series:
# 71    -0.100851
# 156    0.094685
# 313   -0.394603
# 461   -1.061629
# 327    1.777325
# 351   -0.075939
# 458   -0.385161
# 126    0.148648
# 188   -0.972531
# 113    0.274784
# 212   -0.560494
# 160   -0.392601
# 59    -0.505999
# 84    -1.679713
# 40     0.397666
# 322    0.660619
# 263    1.092418
# 238    0.899082
# 355    0.595607
# 376    1.235632
# 239   -1.583150
# 335   -1.853225
# 317   -0.446459
# 86     0.453776
# 47     0.265417
# dtype: float64
# --------------------
#
# Best Assignment for BS 0:
#  UAV Index: 3
#  Best Individual:
#   Generation: 1, Type: HC
#   Fitness: 67804.1804
#   P_m_down_value: 0.1974
#   P_m_har_value: 0.1353
#   T_m_har_value: 0.3937
#   f_km_value: 0.8638
#   T_km_up_value: 0.8643
#   V_lm_vfly_value: 66.6344
#   V_lm_hfly_value: 66.8574
#   P_km_up_value: 4.9546
#   Angle1_row: Series:
# 16      56.490913
# 353    155.985132
# 236    178.010566
# 430     81.326592
# 69     158.710383
# 82      27.830623
# 230    156.968146
# 287     47.079932
# 399     45.918459
# 207    173.927156
# 140     13.214465
# 93     124.500440
# 37     144.865710
# 334    133.604209
# 498     20.383101
# 141     29.407201
# 407     37.581463
# 229     99.023089
# 111    124.395683
# 103     87.899543
# 275    146.809456
# 470    113.236733
# 341    150.671445
# 302     74.004758
# 163     25.493543
# Name: 0, dtype: float64
#   Angle_row: Series:
# 16      97.977491
# 353     85.637016
# 236    110.209899
# 430     51.691324
# 69      77.484095
# 82      38.207492
# 230    176.342361
# 287    154.246882
# 399    170.389529
# 207     56.827752
# 140    156.890298
# 93      56.356221
# 37     128.585131
# 334     26.166507
# 498     33.293758
# 141      3.514565
# 407    153.818880
# 229    154.784237
# 111    105.977376
# 103    155.713325
# 275    149.800276
# 470    123.869987
# 341    108.921491
# 302    118.394213
# 163     44.692477
# Name: 0, dtype: float64
#   Angle2_row: Series:
# 16      35.290788
# 353     50.018852
# 236    123.888557
# 430      6.782483
# 69      83.352078
# 82      46.782139
# 230    107.172938
# 287    125.870421
# 399     40.990861
# 207    165.881750
# 140    135.353972
# 93     111.082399
# 37      27.065531
# 334     22.399857
# 498     60.436954
# 141    156.717772
# 407     84.040563
# 229    151.511090
# 111     15.097911
# 103     10.709178
# 275     85.585090
# 470    104.877950
# 341     74.012245
# 302     13.203328
# 163    160.393081
# Name: 0, dtype: float64
# --------------------
#
# --- UAVs without Assigned Base Stations ---
#   UAV 1 : No BS is assigned
# --------------------
#   UAV 4 : No BS is assigned
# --------------------
#   UAV 6 : No BS is assigned
# --------------------

# %%
# Plotting graph for Sum of Fitness vs num_irs_ele
irs_element_values =np.arange(1, 11, 1)
plt.figure(figsize=(10, 6))
plt.rcParams["font.size"] = "20"
plt.plot(irs_element_values, fitness_sums_HC, marker='o', linestyle='-')
plt.xlabel('Power',size=22)
plt.ylabel('Energy',size=22)
plt.title('Energy vs Power')
plt.xticks(irs_element_values)
plt.tight_layout()
plt.show()

# %%
num_bs = 5
num_irs_ele=50
num_generation = 1 # Number of generations, increased for GA to evolve
num_uav_irs = 8
population_size = 25 # Population size for GA

# Define keys that should be subjected to crossover and mutation (numerical parameters)
numerical_keys_for_crossover = [
    'P_m_down_value', 'P_m_har_value', 'T_m_har_value',
    'f_km_value', 'V_lm_vfly_value', 'V_lm_hfly_value',
    'P_km_up_value','f_km_value','Angle1_row','Angle_row',
    'Angle2_row',
]


fitness_sums_GA= [] # Store sum of fitness values for each p_max

p_max_values = np.arange(1, 11, 1) # D_km values from 0.1 to 1

for p_max in p_max_values: # Iterate over D_km values
    print(f"calculaiton for p_max for GA",p_max)
    all_best_combinations = []
    all_best_individuals = []

    # Main Genetic Algorithm Loop
    for l in range(num_bs):
        all_best_individuals_bs = []
        P_m_har_value = P_m_har.values[l]
        T_m_har_value = T_m_har.values[l]
        P_m_down_value = P_m_down.values[l]

        # Select unique row indices for the current BS

        index_list = list(range(num_rows_data_files)) # Create a list of all indices
        random.shuffle(index_list)
        unique_row_indices = index_list[:population_size]
        # Create dataframes with uniquely selected rows for the current BS

        h_l_km_df_bs = h_l_km_df.iloc[unique_row_indices, :].reset_index(drop=True)
        g_l_km_df_bs = g_l_km_df.iloc[unique_row_indices, :].reset_index(drop=True)
        f_l_km_df_bs = f_l_km_df.iloc[unique_row_indices, :].reset_index(drop=True)
        f_km_bs = f_km[unique_row_indices].reset_index(drop=True)
        # Corrected line: Ensure indices are within bounds of P_km_up
        valid_indices = [i for i in unique_row_indices if i < len(P_km_up)]
        P_km_up_bs = P_km_up.iloc[valid_indices].reset_index(drop=True)


        for k in range(num_uav_irs):
            best_fitness = float('inf')
            best_individual = {}
            population = []
            V_lm_vfly_value = V_lm_vfly.values[k]
            V_lm_hfly_value = V_lm_hfly.values[k]
            D_l_hfly_value = D_l_hfly
            Wl_value = Wl
            Sub_value=0
            # Corrected loop range to use valid_indices length
            for i in range(len(valid_indices)): # Using length of valid_indices
                h_il_up_value=h_kml_down(Angle_UP_df.iloc[i, :],g_l_m_df.iloc[k, :],g_l_km_df_bs.iloc[i, :]) # Pass Series, corrected index to i
                Sub_value+=sub(P_km_up_bs[i],h_il_up_value)

            # Initialize population
            # Corrected loop range to use valid_indices length
            for i in range(len(valid_indices)): # Using length of valid_indices
                f_km_value = f_km_bs[i] # Use BS-specific f_km
                P_km_up_value = P_km_up_bs[i] # Use BS-specific P_km_up

                Angle_row = Angle_df.iloc[i, :] # Use BS-specific Angle_df
                h_l_m_row = h_l_m_df.iloc[k, :] # Use BS-specific h_l_m_df
                h_l_km_row = h_l_km_df_bs.iloc[i, :] # Use BS-specific h_l_km_df
                Angle1_row = Angle_UP_df.iloc[i, :] # Use BS-specific Angle_UP_df
                g_l_m_row = g_l_m_df.iloc[k, :] # Use BS-specific g_l_m_df
                g_l_km_row = g_l_km_df_bs.iloc[i, :] # Use BS-specific g_l_km_df
                Angle2_row = Angle_har_df.iloc[i, :] # Use BS-specific Angle_har_df
                f_l_m_row = f_l_m_df.iloc[k, :] # Use BS-specific f_l_m_df
                f_l_km_row = f_l_km_df_bs.iloc[i, :] # Use BS-specific f_l_km_df

                # Calculate power values
                P_lm_blade_value = P_lm_blade(Nr, p_l_b, V_tip, V_lm_hfly_value)
                P_lm_fuselage_value = P_lm_fuselage(Cd, Af, Bh, V_lm_hfly_value)
                P_lm_induced_value = P_lm_induced(Nr, Bh, Ar, Wl_value, V_lm_vfly_value)

                # Calculate time and energy values
                T_l_vfly_value = H_value / V_lm_vfly_value
                T_l_hfly_value = D_l_hfly_value / V_lm_hfly_value # Corrected: D_l_hfly / V_lm_hfly
                E_ml_har_value = P_m_har_value * T_m_har_value
                h_kml_down_value=h_kml_down(Angle_row,h_l_m_row,h_l_km_row) # Pass Series
                h_ml_worst_value=h_ml_worst(h_kml_down_value,sigma_km)
                R_ml_down_value=R_ml_down(B,P_m_down_value,h_ml_worst_value)
                T_ml_down_value=D_m_current/R_ml_down_value
                E_ml_down_value = P_m_down_value * T_ml_down_value
                T_km_com_value = D_km / f_km_value
                h_kml_up_value=h_kml_down(Angle1_row,g_l_m_row,g_l_km_row) # Pass Series, using same function, might need different one if logic is different

                R_kml_up_value=R_kml_up(B,P_km_up_value,h_kml_up_value,Sub_value,sigma_km)
                T_km_up_value=D_m_current/R_kml_up_value # equation number 5
                T_lm_hov_value = T_lm_hov(T_km_com_value, T_km_up_value, T_ml_down_value)
                P_l_hov_value = P_l_hov(Wl_value, p_l_b, Nr, Ar, Bh)
                P_l_vfly_value = P_l_vfly(Wl_value, V_lm_vfly_value, p_l_b, Nr, Ar, Bh)
                P_lm_hfly_value = P_lm_hfly(P_lm_blade_value, P_lm_fuselage_value, P_lm_induced_value)
                E_ml_UAV_value = E_ml_UAV(P_l_vfly_value, T_l_vfly_value, P_lm_hfly_value, T_l_hfly_value, P_l_hov_value, T_lm_hov_value)

                # Calculate fitness
                result_fitness = Fitness(E_ml_har_value, E_ml_down_value, E_ml_UAV_value)

                # Store initial population data
                population.append({
                    'fitness': result_fitness,
                    'data':  {
                        'P_m_down_value': P_m_down_value,
                        'P_m_har_value': P_m_har_value,
                        'T_m_har_value': T_m_har_value,
                        'f_km_value': f_km_value,
                        'T_km_up_value': T_km_up_value,
                        'V_lm_vfly_value': V_lm_vfly_value,
                        'V_lm_hfly_value': V_lm_hfly_value,
                        'P_km_up_value':P_km_up_value,
                        'Angle1_row':Angle1_row,
                        'Angle_row':Angle_row,
                        'Angle2_row': Angle2_row,
                        }
                    })

            generations_data = []
            for j in range(num_generation):
                child_population = []
                # Corrected loop range to use valid_indices length
                for x in range(0, len(valid_indices), 2): # Loop through population with step of 2
                    if x + 1 >= len(valid_indices): # Check if i+1 is within bounds, if not break to avoid error in accessing population[i+1]
                        break
                    # Crossover
                    ranodmpopulation=[]
                    for i in range(10):
                        ranodmpopulation.append(random.choice(population))
                    ranodmpopulation = sorted(ranodmpopulation, key=lambda x: x['fitness'])
                    parent1 = ranodmpopulation[0]
                    parent2 = ranodmpopulation[1]
                    child_data = {}
                    for key in parent1['data']:
                        if key in numerical_keys_for_crossover:
                            if key in ['Angle1_row','Angle_row','Angle2_row']: # Handle Angle Series
                                child_data[key] = pd.Series(index=Angle_df.columns, dtype='float64') # Initialize empty Series for child
                                for col in Angle_df.columns: # Iterate through each column (angle direction)
                                    child_data[key][col] = float(parent1['data'][key][col]) * 0.6 + float(parent2['data'][key][col]) * (1 - 0.6)
                            else: # Handle other numerical values as before
                                child_data[key] = float(parent1['data'][key]) * 0.6 + float(parent2['data'][key]) * (1 - 0.6)
                        else:
                            child_data[key] = float(parent1['data'][key]) * 0.6 + float(parent2['data'][key]) * (1 - 0.6)


                    # Mutation
                    u = np.random.uniform(0, 1, 1)[0]
                    P_mutation = 0.5
                    if u < P_mutation:
                        for key in numerical_keys_for_crossover: # Apply mutation only to numerical keys
                            if key in ['Angle1_row','Angle_row','Angle2_row']: # Handle Angle Series
                                child_data[key] = pd.Series(index=Angle_df.columns, dtype='float64') # Initialize empty Series for child
                                for col in Angle_df.columns: # Iterate through each column (angle direction)
                                    child_data[key][col] = random.normal(loc=0, scale=1, size=(1))[0]
                            else:
                                child_data[key] += random.normal(loc=0, scale=1, size=(1))[0] # Reduced scale for smaller perturbations in HC

                    # Compute child fitness
                    def compute_fitness(data):
                        P_m_down_value = data['P_m_down_value']
                        P_m_har_value = data['P_m_har_value']
                        T_m_har_value = data['T_m_har_value']
                        f_km_value = data['f_km_value']
                        T_km_up_value = data['T_km_up_value']
                        V_lm_vfly_value = data['V_lm_vfly_value']
                        V_lm_hfly_value = data['V_lm_hfly_value']
                        P_km_up_value=data['P_km_up_value']
                        Angle_row = data['Angle_row'] # Retrieve angle row from child data
                        Angle1_row = data['Angle1_row'] # Retrieve angle row from child data
                        Angle2_row = data['Angle2_row'] # Retrieve angle row from child data

                        # Calculate power values
                        P_lm_blade_value = P_lm_blade(Nr, p_l_b, V_tip, V_lm_hfly_value)
                        P_lm_fuselage_value = P_lm_fuselage(Cd, Af, Bh, V_lm_hfly_value)
                        P_lm_induced_value = P_lm_induced(Nr, Bh, Ar, Wl_value, V_lm_vfly_value)

                        # Calculate time and energy values
                        T_l_vfly_value = H_value / V_lm_vfly_value
                        T_l_hfly_value = D_l_hfly_value / V_lm_hfly_value # Corrected: D_l_hfly / V_lm_hfly
                        E_ml_har_value = P_m_har_value * T_m_har_value # Corrected: 


                        h_kml_down_value_compute=h_kml_down(Angle_row,h_l_m_row,h_l_km_row) # Using original Angle_row, h_l_m_row, h_l_km_row for child as well - might need to be based on child data if angles are also part of optimization
                        h_ml_worst_value=h_ml_worst(h_kml_down_value_compute,sigma_km)
                        R_ml_down_value=R_ml_down(B,P_m_down_value,h_ml_worst_value)
                        if R_ml_down_value <= 0: # check if R_ml_down_value is zero or negative
                            R_ml_down_value = 1e-9 # Assign a small positive value to avoid division by zero
                        T_ml_down_value=D_m_current/R_ml_down_value
                        E_ml_down_value = P_m_down_value * T_ml_down_value
                        T_km_com_value = D_km / f_km_value
                        T_lm_hov_value = T_lm_hov(T_km_com_value, T_km_up_value, T_ml_down_value)
                        P_l_hov_value = P_l_hov(Wl_value, p_l_b, Nr, Ar, Bh)
                        P_l_vfly_value = P_l_vfly(Wl_value, V_lm_vfly_value, p_l_b, Nr, Ar, Bh)
                        P_lm_hfly_value = P_lm_hfly(P_lm_blade_value, P_lm_fuselage_value, P_lm_induced_value)
                        E_ml_UAV_value = E_ml_UAV(P_l_vfly_value, T_l_vfly_value, P_lm_hfly_value, T_l_hfly_value, P_l_hov_value, T_lm_hov_value)
                        h_kml_har_value_compute=h_kml_down(Angle2_row,f_l_m_row,f_l_km_row) # Corrected index to Angle2_row
                        E_kml_har_value=E_kml_har(P_m_har_value,T_m_har_value,h_kml_har_value_compute) # Corrected function call for E_kml_har
                        E_kml_com_value = E_km_com(f_km_value, T_km_com_value)
                        E_kml_up_value=E_kml_up(P_km_up_value,T_km_up_value)


                        # Calculate fitness
                        fitness_value = Fitness(E_ml_har_value, E_ml_down_value, E_ml_UAV_value)
                        current_data = {
                            'P_m_down_value': P_m_down_value,
                            'P_m_har_value': P_m_har_value,
                            'T_m_har_value': T_m_har_value,
                            'f_km_value': f_km_value,
                            'T_km_up_value': T_km_up_value,
                            'V_lm_vfly_value': V_lm_vfly_value,
                            'V_lm_hfly_value': V_lm_hfly_value,
                            'P_km_up_value':P_km_up_value,
                            'Angle1_row':Angle1_row,
                            'Angle_row':Angle_row,
                            'Angle2_row': Angle2_row, # Carry forward original index
                                                        }
                        if V_lm_hfly_value>0 and T_m_har_value>0 and T_ml_down_value>0 and T_km_up_value>0 and P_m_har_value<=p_max and P_m_down_value<=p_max and P_km_up_value<=p_km_max and (T_km_com_value+T_km_up_value+T_ml_down_value)<=T_m and f_km_value>0  and E_kml_har_value>=(E_kml_up_value+E_kml_com_value) and V_lm_vfly_value>0:
                            return fitness_value, current_data
                        else:
                            return  float('inf'),{} # Return empty dict instead of float('inf') for data

                    child_fitness, child_data1 = compute_fitness(child_data)
                    child_population.append({'fitness': child_fitness, 'data': child_data1})

                # Create new population
                new_population = population + child_population
                new_population = sorted(new_population, key=lambda x: x['fitness'])
                population = new_population[:population_size]
                generations_data.append(population[0].copy())
                # print(population[0])

            best_individual_pair = population[0].copy()
            best_individual_pair['generation'] = j + 1 # Use last j from loop, corrected index
            best_individual_pair['type'] = 'GA'
            best_individual_pair['bs_index'] = l
            best_individual_pair['uav_index'] = k
            all_best_individuals_bs.append(best_individual_pair)

            all_best_combinations.append({
                'bs_index': l,
                'uav_index': k,
                'best_fitness': population[0]['fitness'],
                'best_individual': best_individual_pair,
                'generation_fitness': [gen['fitness'] for gen in generations_data],
                'unique_row_indices': unique_row_indices # Store unique_row_indices in best_combinations
            })
            # print(f"Best Fitness for BS {l}, UAV {k}: {population[0]['fitness']:.4f}")

        # Find best individual for current BS across all UAVs
        best_individual_for_bs = min(all_best_individuals_bs, key=lambda x: x['fitness'])
        # print(f"Best Fitness for BS {l} across all UAVs: {best_individual_for_bs['fitness']:.4f}")


    # Select the best unique Base station and UAV-IRS pair using Auction based method
    combination_lookup = {}
    for combination in all_best_combinations:
        if combination['bs_index'] not in combination_lookup:
            combination_lookup[combination['bs_index']] = {}
        combination_lookup[combination['bs_index']][combination['uav_index']] = combination

    # Auction-based assignment
    best_assignments = []
    unassigned_bs = list(range(num_bs))
    unassigned_uavs = list(range(num_uav_irs))

    while unassigned_bs and unassigned_uavs:
        best_combination_overall = None

        for l in unassigned_bs:
            best_fitness_for_bs = float('inf')
            best_combination_for_bs = None
            for k in unassigned_uavs:
                if l in combination_lookup and k in combination_lookup[l]:
                    combination = combination_lookup[l][k]
                    if combination['best_fitness'] < best_fitness_for_bs: # Use 'best_fitness' instead of 'best_individual']['fitness']
                        best_fitness_for_bs = combination['best_fitness']
                        best_combination_for_bs = combination

            if best_combination_for_bs:
                if best_combination_overall is None or best_combination_for_bs['best_fitness'] < best_combination_overall['best_fitness']: # Compare with current best overall
                    best_combination_overall = best_combination_for_bs

        if best_combination_overall:
            best_assignments.append(best_combination_overall)
            unassigned_bs.remove(best_combination_overall['bs_index'])
            unassigned_uavs.remove(best_combination_overall['uav_index'])

    # Print and Plotting
    print(f"\n--- Best Unique UAV Assignments (Auction Based Method) ---")
    best_pair_for_plot = None
    min_fitness_for_plot = float('inf')

    sum_fitness_current_p_max = 0 # Sum of best fitness for current p_max
    for assignment in best_assignments:
        print(f"\nBest Assignment for BS {assignment['bs_index']}:")
        print(f" UAV Index: {assignment['uav_index']}")
        best_ind = assignment['best_individual']
        print(f" Best Individual:")
        print(f"  Generation: {best_ind['generation']}, Type: {best_ind['type']}")
        print(f"  Fitness: {best_ind['fitness']:.4f}") # Print current best fitness only
        unique_indices_to_print = assignment['unique_row_indices'] # Retrieve unique_row_indices
        for key, value in best_ind['data'].items():
            if isinstance(value, pd.Series):
                print(f"  {key}: Series: \n{value.iloc[unique_indices_to_print]}") # Print sliced Series
            elif isinstance(value, list): # Handle list type values explicitly
                print(f"  {key}: {value}") # print list directly without formatting
            else:
                print(f"  {key}: {value:.4f}") # Format scalar values

        print("-" * 20)
        sum_fitness_current_p_max += best_ind['fitness'] # Sum fitness values

        if assignment['best_individual']['fitness'] < min_fitness_for_plot:
            min_fitness_for_plot = assignment['best_individual']['fitness']
            best_pair_for_plot = assignment

    fitness_sums_GA.append(sum_fitness_current_p_max) # Store sum of fitness for this p_max

    # Unassigned BS/UAVs
    if unassigned_bs:
        print("\n--- Base Stations without Assigned UAVs ---")
        for bs_index in unassigned_bs:
            print(f"  BS {bs_index} : No UAV is assigned")
            print("-" * 20)

    if unassigned_uavs:
        print("\n--- UAVs without Assigned Base Stations ---")
        for uav_index in unassigned_uavs:
            print(f"  UAV {uav_index} : No BS is assigned")
            print("-" * 20)
# Out:
# calculaiton for p_max for GA 1
#
# --- Best Unique UAV Assignments (Auction Based Method) ---
#
# Best Assignment for BS 1:
#  UAV Index: 2
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 45082.5199
#   P_m_down_value: 0.4857
#   P_m_har_value: 0.5747
#   T_m_har_value: 1.6353
#   f_km_value: 3.5010
#   T_km_up_value: 0.5070
#   V_lm_vfly_value: 58.5026
#   V_lm_hfly_value: 61.0779
#   P_km_up_value: 8.2419
#   Angle1_row: Series:
# 38     1.163079
# 40     0.661523
# 305    0.887490
# 251   -0.338651
# 311    1.028192
# 192    0.039802
# 260   -0.410138
# 111    0.294718
# 50    -0.758193
# 4     -0.399285
# 180    0.923197
# 171   -1.592771
# 359    0.946414
# 387    0.199528
# 127    1.330732
# 442   -0.990991
# 72     1.189626
# 488   -1.582221
# 26    -0.021876
# 76     0.057668
# 409   -0.086357
# 463   -0.353344
# 223   -0.507426
# 10    -0.495648
# 347   -1.119748
# dtype: float64
#   Angle_row: Series:
# 38     0.438526
# 40    -1.524178
# 305    1.330605
# 251    0.181484
# 311   -0.422912
# 192    1.127752
# 260    1.317994
# 111    0.582148
# 50     0.230854
# 4      0.308989
# 180    0.888915
# 171    0.500003
# 359    0.508162
# 387    0.105138
# 127   -1.275075
# 442    0.051711
# 72     1.250316
# 488    1.567188
# 26    -0.694170
# 76     0.384765
# 409    0.505099
# 463   -0.877037
# 223   -0.463318
# 10    -1.768293
# 347    0.611661
# dtype: float64
#   Angle2_row: Series:
# 38    -0.883700
# 40     1.408199
# 305   -0.108332
# 251   -0.232637
# 311   -0.281568
# 192   -0.804824
# 260   -2.320332
# 111    0.484085
# 50    -0.359962
# 4     -0.877336
# 180    0.250646
# 171   -1.378854
# 359   -0.062210
# 387    0.668665
# 127   -0.771042
# 442   -1.046284
# 72     1.259007
# 488   -0.684889
# 26    -1.339723
# 76     0.373955
# 409   -0.364077
# 463   -1.344987
# 223   -0.592700
# 10    -0.117771
# 347   -1.391349
# dtype: float64
# --------------------
#
# Best Assignment for BS 2:
#  UAV Index: 6
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 53287.7389
#   P_m_down_value: 0.6224
#   P_m_har_value: 0.1587
#   T_m_har_value: 0.4846
#   f_km_value: 2.5576
#   T_km_up_value: 0.4558
#   V_lm_vfly_value: 98.4643
#   V_lm_hfly_value: 23.9030
#   P_km_up_value: 9.8196
#   Angle1_row: Series:
# 221    0.080827
# 434    0.762612
# 454   -1.074336
# 211   -2.132133
# 258   -1.224605
# 403   -2.049916
# 213    0.514312
# 416    0.679673
# 425    0.027817
# 491    1.249637
# 466    0.562494
# 74    -0.209284
# 28    -0.979530
# 251    1.156564
# 88    -0.084407
# 172    0.237456
# 417   -0.260020
# 141   -0.842661
# 194   -0.784432
# 85     1.404220
# 167   -1.784400
# 379   -1.645770
# 421   -0.680455
# 26     0.143967
# 160    0.895107
# dtype: float64
#   Angle_row: Series:
# 221    0.107538
# 434    0.112857
# 454   -0.825932
# 211   -0.705818
# 258    0.178315
# 403    0.014348
# 213    1.239589
# 416    0.159725
# 425   -0.555842
# 491   -0.297022
# 466   -0.560536
# 74     0.056890
# 28    -0.603937
# 251   -0.674189
# 88    -0.664451
# 172    0.065171
# 417   -1.182767
# 141   -0.786690
# 194   -0.431107
# 85     0.685907
# 167   -0.812289
# 379   -0.484644
# 421    1.457955
# 26     1.641695
# 160   -1.441102
# dtype: float64
#   Angle2_row: Series:
# 221    0.272834
# 434    1.144540
# 454    0.608948
# 211   -0.491118
# 258    0.618514
# 403    0.391011
# 213    0.526454
# 416   -0.184954
# 425    1.123205
# 491    0.682261
# 466    0.939803
# 74    -0.825831
# 28    -0.197052
# 251   -0.460247
# 88     0.719475
# 172   -0.461587
# 417    0.852576
# 141    0.999520
# 194    0.766267
# 85    -0.075976
# 167   -0.036810
# 379    0.269202
# 421   -0.132732
# 26     0.590112
# 160    1.739131
# dtype: float64
# --------------------
#
# Best Assignment for BS 4:
#  UAV Index: 7
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 53857.5021
#   P_m_down_value: 0.9426
#   P_m_har_value: 0.9736
#   T_m_har_value: 0.5136
#   f_km_value: 2.4374
#   T_km_up_value: 0.6079
#   V_lm_vfly_value: 20.8217
#   V_lm_hfly_value: 54.6176
#   P_km_up_value: 7.5292
#   Angle1_row: Series:
# 483    1.379421
# 57     0.376678
# 270   -1.178697
# 178   -1.448215
# 493   -1.771240
# 487   -0.591941
# 94    -0.335531
# 31    -0.020716
# 300    0.165561
# 108   -1.042406
# 407   -0.476629
# 64     0.994691
# 310    0.721443
# 344    1.040838
# 72     0.218055
# 164    0.519086
# 38     0.286702
# 326   -0.422793
# 121    0.103038
# 110    0.154183
# 465   -0.699511
# 87    -1.313310
# 399   -1.742566
# 428    0.296900
# 299   -1.052402
# dtype: float64
#   Angle_row: Series:
# 483    0.977206
# 57    -0.372609
# 270    1.087844
# 178   -0.750599
# 493   -0.555604
# 487   -2.134265
# 94     1.289454
# 31    -0.182087
# 300   -1.330741
# 108   -2.192905
# 407    0.078413
# 64    -0.163479
# 310   -0.689495
# 344   -0.941881
# 72    -0.614186
# 164   -0.133822
# 38     0.423578
# 326   -0.552811
# 121   -0.680480
# 110   -0.501963
# 465   -0.429079
# 87     0.811636
# 399   -0.202273
# 428   -0.424588
# 299    1.363605
# dtype: float64
#   Angle2_row: Series:
# 483   -0.580772
# 57     0.774311
# 270   -0.565744
# 178    0.582714
# 493   -1.531617
# 487   -0.527547
# 94    -0.394589
# 31     0.144810
# 300   -0.394796
# 108    1.970332
# 407   -0.964759
# 64     0.716761
# 310   -2.309704
# 344    1.717515
# 72    -0.937098
# 164   -0.315697
# 38    -1.373126
# 326    0.397342
# 121   -0.365558
# 110   -0.009269
# 465    0.375446
# 87    -0.052173
# 399    0.552647
# 428    0.221090
# 299    0.201821
# dtype: float64
# --------------------
#
# Best Assignment for BS 3:
#  UAV Index: 3
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 54058.5361
#   P_m_down_value: 0.9758
#   P_m_har_value: 0.5020
#   T_m_har_value: 0.2252
#   f_km_value: 1.9880
#   T_km_up_value: 0.7104
#   V_lm_vfly_value: 66.9640
#   V_lm_hfly_value: 67.0657
#   P_km_up_value: 7.6175
#   Angle1_row: Series:
# 346    0.938801
# 230   -2.692700
# 9     -1.824793
# 265   -0.778364
# 363   -0.922220
# 261    0.344548
# 140   -3.600934
# 293    0.289034
# 394    0.348861
# 364    1.697889
# 398   -0.614065
# 87     0.146157
# 165    0.327333
# 382   -1.837281
# 372    0.236549
# 194    0.672081
# 131    0.270800
# 182   -1.079715
# 31     0.300926
# 481    0.298609
# 344    1.111671
# 6     -1.117845
# 304   -2.143997
# 271   -0.653192
# 160   -1.520745
# dtype: float64
#   Angle_row: Series:
# 346   -1.494448
# 230   -1.439892
# 9     -0.150440
# 265    0.340655
# 363   -2.195357
# 261    0.516724
# 140   -0.118701
# 293    0.953774
# 394    0.359204
# 364    0.265989
# 398   -0.682256
# 87    -0.619696
# 165    1.449373
# 382    1.041628
# 372    0.005894
# 194    0.513156
# 131    0.003017
# 182    1.266134
# 31    -0.050444
# 481    0.514137
# 344    0.454827
# 6      1.353183
# 304   -0.241364
# 271   -0.444904
# 160    1.520495
# dtype: float64
#   Angle2_row: Series:
# 346    0.268757
# 230    0.413344
# 9      0.257070
# 265    0.901708
# 363    1.974029
# 261    0.334302
# 140   -0.645854
# 293   -1.035412
# 394   -0.366331
# 364   -0.625516
# 398    1.054487
# 87     0.650718
# 165    0.335970
# 382    0.384834
# 372    0.246692
# 194   -0.235691
# 131    2.466242
# 182   -0.043366
# 31    -0.335603
# 481   -0.078708
# 344   -0.335322
# 6     -0.651248
# 304   -1.857390
# 271   -1.850940
# 160   -1.833304
# dtype: float64
# --------------------
#
# Best Assignment for BS 0:
#  UAV Index: 1
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 55057.3123
#   P_m_down_value: 0.1974
#   P_m_har_value: 0.1353
#   T_m_har_value: 0.3937
#   f_km_value: 0.9922
#   T_km_up_value: 0.5046
#   V_lm_vfly_value: 72.6939
#   V_lm_hfly_value: 64.4919
#   P_km_up_value: 7.4286
#   Angle1_row: Series:
# 395    144.942072
# 304    122.852992
# 458     72.481597
# 209    123.242660
# 277     34.771052
# 6       71.297319
# 440     42.603202
# 313     38.408905
# 54      81.482132
# 306     82.965330
# 75      82.489504
# 22     122.680999
# 155     82.360767
# 324     62.241800
# 116     80.939068
# 354    140.690808
# 375     84.783273
# 449      9.061352
# 51      95.899362
# 42     160.742887
# 144     71.495718
# 303    158.390613
# 329    123.420299
# 1      166.332615
# 480     69.946019
# dtype: float64
#   Angle_row: Series:
# 395     34.278044
# 304    175.427976
# 458     75.995522
# 209     18.204925
# 277    100.466085
# 6        1.261341
# 440     68.411533
# 313    136.084860
# 54       6.788155
# 306     23.887840
# 75     158.483450
# 22     142.372196
# 155     61.132658
# 324    106.366719
# 116      2.096861
# 354    125.135983
# 375     74.324526
# 449    118.949519
# 51      23.862262
# 42     167.713399
# 144     29.286413
# 303     54.763921
# 329     36.448901
# 1       13.957565
# 480     60.107169
# dtype: float64
#   Angle2_row: Series:
# 395     21.647230
# 304    143.414361
# 458    179.343852
# 209    152.956850
# 277      6.676427
# 6       72.224288
# 440    167.695836
# 313    159.812674
# 54      61.089888
# 306    146.015584
# 75     100.472398
# 22     129.995242
# 155     22.440776
# 324     44.804319
# 116    177.644431
# 354    104.601466
# 375    113.100497
# 449    132.487891
# 51      22.745557
# 42      69.913273
# 144      2.393010
# 303     47.822807
# 329     28.398949
# 1      149.324078
# 480      0.371405
# dtype: float64
# --------------------
#
# --- UAVs without Assigned Base Stations ---
#   UAV 0 : No BS is assigned
# --------------------
#   UAV 4 : No BS is assigned
# --------------------
#   UAV 5 : No BS is assigned
# --------------------
# calculaiton for p_max for GA 2
#
# --- Best Unique UAV Assignments (Auction Based Method) ---
#
# Best Assignment for BS 3:
#  UAV Index: 2
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 45371.6903
#   P_m_down_value: 0.6529
#   P_m_har_value: 0.0362
#   T_m_har_value: 0.1289
#   f_km_value: 2.8504
#   T_km_up_value: 0.4867
#   V_lm_vfly_value: 58.5476
#   V_lm_hfly_value: 59.4061
#   P_km_up_value: 8.7252
#   Angle1_row: Series:
# 206    0.279876
# 50    -0.193174
# 200    0.924498
# 355    0.413137
# 471   -0.471978
# 83     0.876894
# 446   -0.192369
# 19    -0.861918
# 54     2.207776
# 491    0.055308
# 465   -0.648345
# 290   -0.423989
# 14     0.161609
# 202   -0.973048
# 69    -0.393892
# 316   -1.719139
# 251    0.482998
# 428    0.323787
# 306   -1.964715
# 282    0.864738
# 207    0.653484
# 470    0.639891
# 298    0.211413
# 499    0.468416
# 176   -0.566198
# dtype: float64
#   Angle_row: Series:
# 206   -0.772261
# 50     0.636297
# 200   -0.826952
# 355    0.369683
# 471   -1.336227
# 83     0.308311
# 446    0.307638
# 19     0.768640
# 54    -1.777287
# 491    0.239248
# 465   -1.909690
# 290   -0.171879
# 14     2.074992
# 202   -0.767939
# 69     1.234428
# 316    1.810791
# 251   -0.101998
# 428    0.948669
# 306   -0.148785
# 282    0.878823
# 207    0.602612
# 470    0.932666
# 298   -1.246149
# 499   -0.118367
# 176    0.818238
# dtype: float64
#   Angle2_row: Series:
# 206    0.395839
# 50     0.878348
# 200    0.145398
# 355   -0.240222
# 471   -1.429568
# 83    -1.015082
# 446   -0.014957
# 19     0.704403
# 54    -0.468154
# 491    0.295540
# 465    1.647347
# 290   -0.027570
# 14     1.510806
# 202    0.226360
# 69     0.709777
# 316    1.339859
# 251   -0.395099
# 428   -0.414324
# 306   -0.807359
# 282   -0.016919
# 207    1.070475
# 470    0.506157
# 298   -0.467347
# 499    2.017068
# 176   -0.088539
# dtype: float64
# --------------------
#
# Best Assignment for BS 1:
#  UAV Index: 1
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 46159.5381
#   P_m_down_value: 0.6832
#   P_m_har_value: 0.2571
#   T_m_har_value: 1.6072
#   f_km_value: 3.2171
#   T_km_up_value: 0.5445
#   V_lm_vfly_value: 74.1972
#   V_lm_hfly_value: 63.8297
#   P_km_up_value: 8.5651
#   Angle1_row: Series:
# 285   -0.199639
# 273   -0.648822
# 32     0.939997
# 51     0.229376
# 63     0.092823
# 178   -0.059040
# 408    0.900651
# 370    1.630204
# 54     0.270372
# 406   -0.283035
# 428   -0.814381
# 274    1.168841
# 346    0.995693
# 197   -0.183279
# 81     0.547247
# 499   -1.131457
# 383   -1.138754
# 438   -0.186237
# 399    0.815727
# 252   -1.473880
# 80     0.363840
# 471    0.048150
# 181    0.405035
# 151    0.892334
# 89    -1.640249
# dtype: float64
#   Angle_row: Series:
# 285    0.190020
# 273   -0.011820
# 32    -1.490343
# 51    -0.979078
# 63     1.006424
# 178   -1.597563
# 408   -0.598795
# 370    0.769597
# 54     0.003042
# 406   -1.025516
# 428    0.825288
# 274   -0.756344
# 346   -0.602370
# 197    1.525982
# 81     1.677143
# 499   -0.495931
# 383   -1.409934
# 438   -0.527131
# 399    1.171555
# 252   -0.779944
# 80    -1.150563
# 471    1.097596
# 181   -0.271487
# 151   -1.432252
# 89    -0.725055
# dtype: float64
#   Angle2_row: Series:
# 285   -0.577754
# 273   -0.732202
# 32     0.242757
# 51    -0.994934
# 63     0.007984
# 178   -1.699069
# 408    1.734578
# 370   -0.170733
# 54     3.150966
# 406   -0.495564
# 428    0.593321
# 274    0.673492
# 346    0.710800
# 197    0.560548
# 81     0.381401
# 499   -1.311524
# 383   -0.679030
# 438   -0.194636
# 399    0.866284
# 252   -0.014492
# 80    -1.527154
# 471   -0.502892
# 181    1.026385
# 151    0.481433
# 89     1.082918
# dtype: float64
# --------------------
#
# Best Assignment for BS 2:
#  UAV Index: 3
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 49644.1114
#   P_m_down_value: 1.0332
#   P_m_har_value: 1.8760
#   T_m_har_value: 0.2727
#   f_km_value: 2.8900
#   T_km_up_value: 0.6255
#   V_lm_vfly_value: 65.8392
#   V_lm_hfly_value: 69.8019
#   P_km_up_value: 6.4788
#   Angle1_row: Series:
# 141   -2.015798
# 7     -0.310502
# 113    0.843495
# 289    0.265765
# 83    -1.403385
# 32    -1.040450
# 392   -0.483720
# 384   -0.244494
# 8      0.410188
# 237   -1.043967
# 221    0.283380
# 167   -1.035708
# 240    0.149147
# 375    0.419230
# 68     0.850469
# 491   -0.083294
# 58    -0.500739
# 426   -1.796989
# 163    2.530672
# 338   -0.483638
# 14    -0.894647
# 233   -0.821577
# 248   -0.712556
# 11     1.597626
# 74     0.493016
# dtype: float64
#   Angle_row: Series:
# 141    0.723599
# 7      0.218023
# 113    0.344564
# 289   -0.177508
# 83     0.762570
# 32    -0.368064
# 392   -1.172418
# 384   -0.438842
# 8      0.291248
# 237    0.034068
# 221    0.132602
# 167   -0.155501
# 240    0.276284
# 375   -0.325160
# 68     2.186180
# 491   -0.384621
# 58    -1.965557
# 426   -0.541784
# 163   -0.450271
# 338    1.010325
# 14    -0.337964
# 233   -0.331126
# 248   -0.582149
# 11    -0.353792
# 74    -0.197500
# dtype: float64
#   Angle2_row: Series:
# 141    1.843812
# 7     -0.878743
# 113    0.541166
# 289    0.331642
# 83     0.239138
# 32     1.029422
# 392    0.269595
# 384    0.951123
# 8     -0.346442
# 237    0.243335
# 221   -0.048492
# 167   -0.447767
# 240   -0.428309
# 375    1.615882
# 68     0.928829
# 491   -1.099406
# 58     0.472213
# 426    0.558176
# 163    1.124765
# 338    1.343191
# 14     0.975807
# 233   -0.033081
# 248    0.378601
# 11    -0.034330
# 74     1.045262
# dtype: float64
# --------------------
#
# Best Assignment for BS 0:
#  UAV Index: 7
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 50923.5854
#   P_m_down_value: 1.2369
#   P_m_har_value: 0.1646
#   T_m_har_value: 1.4448
#   f_km_value: 4.0251
#   T_km_up_value: 0.6088
#   V_lm_vfly_value: 23.0724
#   V_lm_hfly_value: 55.8350
#   P_km_up_value: 8.1013
#   Angle1_row: Series:
# 165   -0.845703
# 275   -0.374924
# 237   -2.534466
# 85     0.854554
# 328    0.220862
# 480    0.236174
# 210   -0.281308
# 132    1.253838
# 127    0.264082
# 241    2.913345
# 114    2.648747
# 424    0.350070
# 337   -0.904653
# 350    1.450573
# 345    2.864135
# 264    1.345410
# 289    0.837500
# 200    0.358787
# 46     0.454933
# 91    -1.772809
# 321    0.246266
# 253   -0.419010
# 67    -0.314477
# 286    0.947612
# 97     1.496244
# dtype: float64
#   Angle_row: Series:
# 165   -0.082856
# 275   -0.146589
# 237   -0.199751
# 85     0.937822
# 328    0.359824
# 480   -1.584762
# 210    1.298016
# 132   -0.558694
# 127   -0.448653
# 241    1.040598
# 114   -0.005323
# 424   -0.595784
# 337    0.154817
# 350   -0.222953
# 345    1.016009
# 264    0.665435
# 289   -0.871316
# 200    0.033731
# 46     0.181277
# 91     0.643235
# 321   -0.608652
# 253    0.361131
# 67     0.290213
# 286   -0.373279
# 97    -0.482831
# dtype: float64
#   Angle2_row: Series:
# 165    2.968190
# 275    1.046970
# 237    0.333835
# 85     0.136273
# 328   -0.353579
# 480   -0.672071
# 210    0.644115
# 132    0.957529
# 127   -0.250738
# 241   -0.618148
# 114   -0.822840
# 424   -0.042930
# 337   -0.433582
# 350   -0.244558
# 345    0.173448
# 264    0.103815
# 289   -0.524735
# 200   -0.539750
# 46    -1.286077
# 91    -0.621798
# 321    0.448717
# 253    0.854142
# 67     3.619236
# 286   -0.251873
# 97     0.338128
# dtype: float64
# --------------------
#
# Best Assignment for BS 4:
#  UAV Index: 6
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 58885.2805
#   P_m_down_value: 0.0463
#   P_m_har_value: 0.3614
#   T_m_har_value: 0.6315
#   f_km_value: 1.5104
#   T_km_up_value: 0.5266
#   V_lm_vfly_value: 98.3828
#   V_lm_hfly_value: 24.2227
#   P_km_up_value: 7.8338
#   Angle1_row: Series:
# 366    0.037452
# 197   -1.179031
# 494    0.467889
# 97    -0.718650
# 480   -0.445845
# 462   -0.598025
# 434    0.229441
# 158   -1.151888
# 299   -0.203758
# 98    -0.383224
# 360    1.362871
# 490    0.857039
# 442    1.096424
# 469    0.500458
# 227    0.535157
# 65     0.222750
# 443    0.146466
# 246    1.117365
# 483   -0.046538
# 274   -0.932726
# 101    0.442861
# 323    1.107633
# 371    0.807686
# 333    0.820430
# 284   -0.130687
# dtype: float64
#   Angle_row: Series:
# 366    0.634635
# 197    1.100889
# 494   -1.834428
# 97    -0.870009
# 480    0.856022
# 462   -0.421977
# 434   -0.729533
# 158    0.236147
# 299   -2.563680
# 98    -0.466328
# 360    1.160566
# 490   -0.411380
# 442   -0.001556
# 469    0.869189
# 227   -0.323112
# 65     1.446717
# 443    1.913675
# 246    1.261608
# 483    1.234521
# 274   -0.042060
# 101    1.005179
# 323    0.415367
# 371    1.809089
# 333   -0.180864
# 284   -0.688997
# dtype: float64
#   Angle2_row: Series:
# 366    0.305865
# 197    1.784163
# 494    0.219483
# 97    -0.407184
# 480   -0.306839
# 462   -1.592652
# 434    1.350558
# 158   -1.197119
# 299    0.014255
# 98     0.566789
# 360    0.721403
# 490    1.944981
# 442    0.466754
# 469   -0.311009
# 227    1.647028
# 65    -0.121990
# 443   -0.268303
# 246   -0.923308
# 483    0.436018
# 274   -0.249864
# 101   -0.510111
# 323    0.893930
# 371   -0.069286
# 333    1.085900
# 284    0.901292
# dtype: float64
# --------------------
#
# --- UAVs without Assigned Base Stations ---
#   UAV 0 : No BS is assigned
# --------------------
#   UAV 4 : No BS is assigned
# --------------------
#   UAV 5 : No BS is assigned
# --------------------
# calculaiton for p_max for GA 3
#
# --- Best Unique UAV Assignments (Auction Based Method) ---
#
# Best Assignment for BS 2:
#  UAV Index: 3
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 44907.5390
#   P_m_down_value: 0.5541
#   P_m_har_value: 1.7237
#   T_m_har_value: 0.4040
#   f_km_value: 2.5429
#   T_km_up_value: 0.4475
#   V_lm_vfly_value: 67.9311
#   V_lm_hfly_value: 66.4857
#   P_km_up_value: 6.8075
#   Angle1_row: Series:
# 319    1.671158
# 387    0.687294
# 413    1.648302
# 440    1.215436
# 495   -0.270553
# 35    -0.359756
# 189    0.572842
# 42    -0.450862
# 293    0.818410
# 131   -0.391877
# 236   -0.295882
# 378   -1.989055
# 111   -0.458697
# 83    -0.650772
# 496    0.066664
# 168   -0.629141
# 41     0.949456
# 468   -0.620193
# 275    1.004792
# 426    0.481917
# 96     1.568431
# 105    1.577181
# 350    0.315623
# 389    0.889930
# 145   -1.109094
# dtype: float64
#   Angle_row: Series:
# 319   -0.644889
# 387   -0.057602
# 413    0.654378
# 440    1.482573
# 495   -2.134620
# 35    -2.341824
# 189    0.682186
# 42    -1.190121
# 293   -0.080317
# 131    0.255869
# 236    0.754025
# 378    0.118993
# 111    2.330138
# 83     0.046869
# 496    0.340970
# 168   -1.704719
# 41     0.664461
# 468    0.149810
# 275   -0.339307
# 426    1.299852
# 96    -0.161526
# 105    0.064781
# 350    0.486968
# 389   -0.074839
# 145   -1.175685
# dtype: float64
#   Angle2_row: Series:
# 319    0.469916
# 387    0.411458
# 413    1.068904
# 440   -0.904947
# 495   -0.379602
# 35    -0.432556
# 189    0.079996
# 42     0.300667
# 293    0.251949
# 131   -0.169037
# 236   -0.837298
# 378    1.784253
# 111    1.172411
# 83     1.097360
# 496    0.522031
# 168    0.795298
# 41    -0.413322
# 468    1.385754
# 275   -0.056293
# 426   -0.042939
# 96    -0.163281
# 105    0.956176
# 350    0.852371
# 389    1.124828
# 145   -0.325374
# dtype: float64
# --------------------
#
# Best Assignment for BS 1:
#  UAV Index: 2
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 49155.4132
#   P_m_down_value: 1.0054
#   P_m_har_value: 0.6165
#   T_m_har_value: 1.8195
#   f_km_value: 3.0693
#   T_km_up_value: 0.6332
#   V_lm_vfly_value: 60.3061
#   V_lm_hfly_value: 60.1273
#   P_km_up_value: 5.7532
#   Angle1_row: Series:
# 357    1.017437
# 140   -0.872982
# 457   -0.595979
# 434   -1.184777
# 20    -0.032788
# 64    -0.790604
# 381   -0.887902
# 130   -0.284464
# 100    0.269711
# 339   -1.548098
# 74    -0.348593
# 192   -0.148331
# 327   -0.748980
# 16     0.575254
# 468   -0.702872
# 270   -2.062691
# 400    0.546414
# 348    2.012064
# 167   -0.633135
# 307   -1.156858
# 48    -0.274098
# 90     1.605098
# 32     1.752664
# 369   -0.612076
# 291    0.434024
# dtype: float64
#   Angle_row: Series:
# 357    0.904851
# 140   -1.576138
# 457    2.222503
# 434    0.482972
# 20    -0.376413
# 64     3.574599
# 381    1.060310
# 130    0.209060
# 100    0.896779
# 339    0.095063
# 74    -0.115416
# 192   -0.649634
# 327    0.463857
# 16    -0.794986
# 468    0.230358
# 270   -1.503254
# 400   -1.130330
# 348   -0.041978
# 167   -0.053719
# 307   -1.817148
# 48    -0.437936
# 90     0.788048
# 32    -2.749627
# 369    0.924092
# 291    0.114609
# dtype: float64
#   Angle2_row: Series:
# 357   -0.733920
# 140   -0.033324
# 457    0.131860
# 434   -0.991822
# 20     1.082703
# 64     1.056904
# 381   -0.264810
# 130   -0.464810
# 100   -0.123124
# 339   -0.545468
# 74     0.651365
# 192   -0.663495
# 327   -0.670119
# 16     1.422768
# 468    0.393477
# 270   -0.503114
# 400    1.588830
# 348    1.649509
# 167    0.592095
# 307    0.491198
# 48    -0.923532
# 90    -0.520435
# 32     0.305308
# 369   -1.397441
# 291   -0.664159
# dtype: float64
# --------------------
#
# Best Assignment for BS 4:
#  UAV Index: 1
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 50477.9252
#   P_m_down_value: 0.9648
#   P_m_har_value: 0.8130
#   T_m_har_value: 1.7619
#   f_km_value: 1.9735
#   T_km_up_value: 0.5981
#   V_lm_vfly_value: 73.3007
#   V_lm_hfly_value: 63.1887
#   P_km_up_value: 8.3369
#   Angle1_row: Series:
# 383   -0.031614
# 348    0.552537
# 127    1.143524
# 84     0.550910
# 430    2.253852
# 140   -0.919439
# 230   -0.156000
# 496    0.628955
# 205   -0.868371
# 349    1.886008
# 239    0.483505
# 157   -0.484723
# 326    1.201652
# 264    1.042526
# 85     0.856464
# 296    1.369073
# 438    0.904343
# 197   -0.662938
# 179   -0.934412
# 57    -1.449456
# 50     0.032056
# 56    -0.323696
# 336    0.619306
# 403    2.031786
# 244   -0.629498
# dtype: float64
#   Angle_row: Series:
# 383   -0.694427
# 348   -0.326879
# 127    0.696480
# 84     0.866765
# 430    0.232530
# 140    0.333436
# 230   -0.480247
# 496   -0.407510
# 205   -0.568821
# 349   -0.193600
# 239    2.040768
# 157    0.800915
# 326    0.996499
# 264   -0.315989
# 85    -0.477224
# 296    0.558072
# 438   -0.610447
# 197   -0.958887
# 179   -0.169530
# 57    -1.909636
# 50     0.041721
# 56    -2.149473
# 336    1.044774
# 403    0.618447
# 244   -0.477026
# dtype: float64
#   Angle2_row: Series:
# 383   -0.319754
# 348   -1.570971
# 127   -0.158869
# 84     0.929993
# 430    0.844104
# 140    0.222735
# 230   -0.702643
# 496    2.049176
# 205    0.263167
# 349    1.369974
# 239   -1.796194
# 157   -0.760164
# 326    0.515155
# 264    0.137358
# 85    -0.758703
# 296    0.169665
# 438    1.174912
# 197   -0.319051
# 179    1.974822
# 57    -0.715182
# 50    -0.532932
# 56     1.228635
# 336   -0.971955
# 403   -1.003879
# 244    0.758484
# dtype: float64
# --------------------
#
# Best Assignment for BS 3:
#  UAV Index: 7
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 52357.4789
#   P_m_down_value: 0.5984
#   P_m_har_value: 0.4660
#   T_m_har_value: 0.9787
#   f_km_value: 2.7469
#   T_km_up_value: 0.5989
#   V_lm_vfly_value: 22.8355
#   V_lm_hfly_value: 54.7965
#   P_km_up_value: 9.6024
#   Angle1_row: Series:
# 358    0.684190
# 187   -0.452394
# 228    0.491899
# 136    0.270907
# 185    1.154169
# 25    -0.550902
# 230   -0.075010
# 398   -1.313572
# 100    1.271845
# 92     0.826685
# 405   -1.006706
# 195    0.716109
# 463    0.551838
# 393    0.834279
# 467   -1.753048
# 451   -0.028464
# 452    2.082253
# 428    0.303057
# 33    -1.802283
# 69     1.909879
# 168   -0.064709
# 63    -0.216247
# 138   -1.125885
# 44     0.086123
# 177    0.183804
# dtype: float64
#   Angle_row: Series:
# 358    0.747772
# 187    0.501000
# 228    0.250880
# 136    1.204056
# 185   -1.688566
# 25     0.866368
# 230    0.184932
# 398    1.800768
# 100   -0.271789
# 92    -1.247697
# 405   -0.302696
# 195   -0.284309
# 463   -0.764005
# 393   -2.428518
# 467   -0.785438
# 451   -0.329118
# 452    0.714544
# 428    1.631617
# 33    -1.344868
# 69     0.672596
# 168   -0.817274
# 63    -0.513006
# 138   -0.659998
# 44     0.275671
# 177   -0.269749
# dtype: float64
#   Angle2_row: Series:
# 358   -1.565215
# 187   -0.611975
# 228    0.011711
# 136   -0.368190
# 185   -0.020700
# 25     0.310767
# 230   -0.483409
# 398    0.455369
# 100    0.687250
# 92     1.449246
# 405   -1.725001
# 195   -0.321565
# 463   -0.048122
# 393   -1.363557
# 467   -0.287026
# 451    0.093105
# 452   -1.991091
# 428    0.442843
# 33    -0.806621
# 69    -0.176476
# 168   -0.310061
# 63     0.213732
# 138   -1.055112
# 44    -0.634109
# 177   -0.851689
# dtype: float64
# --------------------
#
# Best Assignment for BS 0:
#  UAV Index: 5
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 54446.5719
#   P_m_down_value: 1.3569
#   P_m_har_value: 0.6667
#   T_m_har_value: 0.5896
#   f_km_value: 2.3515
#   T_km_up_value: 0.6522
#   V_lm_vfly_value: 47.4369
#   V_lm_hfly_value: 34.6617
#   P_km_up_value: 8.0035
#   Angle1_row: Series:
# 257    0.569676
# 241   -0.697786
# 285   -0.459152
# 97    -0.262862
# 403   -0.992891
# 408    1.858400
# 266    0.721650
# 73    -0.502957
# 120    0.563843
# 357   -0.542549
# 349   -2.113459
# 180    1.141828
# 313   -1.201397
# 312   -1.144963
# 223    0.879314
# 50     1.075982
# 472   -0.958344
# 455   -0.243180
# 77     0.116891
# 352    0.629188
# 36     1.997627
# 410   -0.377139
# 441    0.218992
# 27     0.161674
# 19     1.234210
# dtype: float64
#   Angle_row: Series:
# 257    0.287994
# 241   -0.208529
# 285   -1.091386
# 97    -0.141268
# 403   -0.694759
# 408   -0.006993
# 266   -0.265491
# 73    -1.271730
# 120   -0.270511
# 357    0.626262
# 349   -0.387974
# 180   -1.214519
# 313   -0.784432
# 312   -1.584011
# 223    0.395727
# 50    -0.437496
# 472   -0.750575
# 455    0.753792
# 77     0.152446
# 352    0.042115
# 36     1.381110
# 410   -0.162635
# 441   -0.408014
# 27    -0.853891
# 19     0.957693
# dtype: float64
#   Angle2_row: Series:
# 257    0.061700
# 241   -0.246968
# 285    3.257696
# 97    -0.038729
# 403   -0.186093
# 408   -1.825500
# 266    0.133542
# 73     0.378617
# 120    0.949089
# 357   -0.301108
# 349   -0.496742
# 180    0.053467
# 313    0.356473
# 312   -0.138131
# 223    2.527379
# 50     0.907233
# 472   -0.788245
# 455    2.353001
# 77     1.132802
# 352   -0.720748
# 36     0.003918
# 410    0.442102
# 441    0.349727
# 27    -1.614665
# 19    -0.252785
# dtype: float64
# --------------------
#
# --- UAVs without Assigned Base Stations ---
#   UAV 0 : No BS is assigned
# --------------------
#   UAV 4 : No BS is assigned
# --------------------
#   UAV 6 : No BS is assigned
# --------------------
# calculaiton for p_max for GA 4
#
# --- Best Unique UAV Assignments (Auction Based Method) ---
#
# Best Assignment for BS 4:
#  UAV Index: 2
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 47059.2260
#   P_m_down_value: 1.4933
#   P_m_har_value: 2.0458
#   T_m_har_value: 1.3519
#   f_km_value: 2.3570
#   T_km_up_value: 0.5096
#   V_lm_vfly_value: 59.5956
#   V_lm_hfly_value: 60.1015
#   P_km_up_value: 8.9041
#   Angle1_row: Series:
# 193   -0.239315
# 47    -0.486367
# 213   -0.220991
# 242   -0.076527
# 364   -0.236408
# 352   -1.094615
# 482   -0.539535
# 188   -0.581929
# 474    0.421007
# 220   -1.252576
# 337    1.114253
# 411   -0.664610
# 462    1.441459
# 336   -0.333003
# 391    0.817868
# 479    0.792720
# 403    0.133561
# 154   -0.269863
# 124   -1.147231
# 7      0.329516
# 363    2.307349
# 451    0.770815
# 61     0.839551
# 147   -2.053223
# 200    0.182140
# dtype: float64
#   Angle_row: Series:
# 193   -2.033766
# 47     1.577767
# 213   -0.321511
# 242    0.831186
# 364    0.258330
# 352   -0.921562
# 482   -0.062776
# 188    0.184517
# 474   -1.530572
# 220    0.288077
# 337    0.672115
# 411    0.598527
# 462    1.327197
# 336    0.282858
# 391    2.089391
# 479   -1.361611
# 403   -0.968537
# 154    1.152845
# 124    0.248877
# 7     -0.319443
# 363    1.197749
# 451    1.871032
# 61     1.907088
# 147   -0.176959
# 200   -0.701349
# dtype: float64
#   Angle2_row: Series:
# 193    0.991718
# 47    -1.826307
# 213    0.614141
# 242    1.773096
# 364    0.100022
# 352    0.651577
# 482    0.234145
# 188   -0.569182
# 474   -0.783846
# 220   -0.925517
# 337   -1.140825
# 411   -1.026624
# 462   -0.941357
# 336    2.454623
# 391    0.339645
# 479   -0.775139
# 403   -1.908059
# 154   -1.130774
# 124   -0.406749
# 7      0.017621
# 363   -0.377240
# 451    0.118063
# 61     0.901528
# 147   -0.431373
# 200   -0.605997
# dtype: float64
# --------------------
#
# Best Assignment for BS 2:
#  UAV Index: 7
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 49795.9230
#   P_m_down_value: 0.6801
#   P_m_har_value: 1.1332
#   T_m_har_value: 0.3884
#   f_km_value: 3.7071
#   T_km_up_value: 0.5473
#   V_lm_vfly_value: 21.8952
#   V_lm_hfly_value: 54.4780
#   P_km_up_value: 8.7542
#   Angle1_row: Series:
# 115    0.033014
# 151   -0.240383
# 456    0.009980
# 372   -0.901307
# 453    0.152461
# 327   -0.775705
# 56     1.297568
# 297   -0.259915
# 405    1.017790
# 278   -0.012057
# 421   -1.777108
# 497   -0.202179
# 325    0.250606
# 188   -0.330682
# 40    -1.143844
# 259   -0.286606
# 9      0.677397
# 176    1.046752
# 489    0.395188
# 461    1.117138
# 353    1.678108
# 243    0.530399
# 161    0.971422
# 8      0.980591
# 271   -0.929856
# dtype: float64
#   Angle_row: Series:
# 115   -0.567194
# 151    0.061954
# 456    1.036795
# 372   -0.110826
# 453    0.805729
# 327    0.163046
# 56     0.218960
# 297    0.190427
# 405   -0.093779
# 278    0.879128
# 421    0.640632
# 497    0.286816
# 325   -0.815556
# 188    0.834254
# 40     1.120437
# 259    1.209291
# 9     -0.467739
# 176    0.395737
# 489   -0.111915
# 461   -0.196432
# 353    0.343963
# 243   -1.144886
# 161    0.516926
# 8     -0.625181
# 271    1.161313
# dtype: float64
#   Angle2_row: Series:
# 115    1.409467
# 151    0.907348
# 456   -0.681605
# 372   -0.747981
# 453    0.375852
# 327   -0.122954
# 56     0.772911
# 297    2.184806
# 405    0.019116
# 278   -0.918185
# 421   -0.394218
# 497    0.736318
# 325    0.209913
# 188   -0.574131
# 40    -1.064034
# 259    0.201646
# 9     -0.665945
# 176   -0.181203
# 489   -0.634510
# 461    0.925905
# 353   -0.987248
# 243    0.169510
# 161    1.018634
# 8      0.001813
# 271    0.418264
# dtype: float64
# --------------------
#
# Best Assignment for BS 0:
#  UAV Index: 0
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 52088.7279
#   P_m_down_value: 0.9044
#   P_m_har_value: 1.4570
#   T_m_har_value: 0.4434
#   f_km_value: 2.3119
#   T_km_up_value: 0.4361
#   V_lm_vfly_value: 20.7843
#   V_lm_hfly_value: 87.7692
#   P_km_up_value: 8.6794
#   Angle1_row: Series:
# 57     0.196984
# 204   -0.069355
# 480    1.346140
# 17     0.018662
# 258    1.278416
# 431   -0.332721
# 6      0.398098
# 23     1.061704
# 115   -0.062361
# 216    0.700424
# 188   -0.001933
# 387   -0.025136
# 66    -0.236812
# 286   -1.184934
# 112    0.465803
# 136    1.102203
# 417   -0.544134
# 110    0.817155
# 55     0.065357
# 73     0.307104
# 154    1.291879
# 470   -1.231748
# 194   -0.854179
# 375   -0.109182
# 1      0.074289
# dtype: float64
#   Angle_row: Series:
# 57    -2.123747
# 204   -0.393638
# 480   -1.727629
# 17     0.222957
# 258   -1.138793
# 431    0.846662
# 6     -0.178456
# 23     1.061227
# 115   -1.283532
# 216   -2.142058
# 188    0.255299
# 387    0.304693
# 66     0.758605
# 286    1.019793
# 112   -3.001490
# 136   -0.208781
# 417   -0.241927
# 110    0.026201
# 55    -0.010713
# 73    -0.211863
# 154   -1.178202
# 470    0.170840
# 194    0.131226
# 375   -0.259635
# 1      0.558577
# dtype: float64
#   Angle2_row: Series:
# 57    -0.501310
# 204    1.539932
# 480    0.477206
# 17    -0.220739
# 258    1.328677
# 431    0.657676
# 6     -1.385494
# 23     0.812846
# 115   -2.683004
# 216    0.491844
# 188    0.142448
# 387    0.443321
# 66     1.503026
# 286    1.390226
# 112   -1.417911
# 136   -1.343942
# 417   -0.040034
# 110    2.172978
# 55     0.620131
# 73    -0.962226
# 154    0.265593
# 470    1.080510
# 194    1.202231
# 375   -2.330155
# 1      0.062388
# dtype: float64
# --------------------
#
# Best Assignment for BS 3:
#  UAV Index: 5
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 52846.5730
#   P_m_down_value: 0.4582
#   P_m_har_value: 0.2994
#   T_m_har_value: 0.7103
#   f_km_value: 1.8335
#   T_km_up_value: 0.5417
#   V_lm_vfly_value: 44.4429
#   V_lm_hfly_value: 35.7373
#   P_km_up_value: 8.7465
#   Angle1_row: Series:
# 175    0.868106
# 1     -1.930277
# 63    -2.033570
# 417    0.062174
# 154    1.206278
# 243   -0.726234
# 271   -0.581794
# 385   -0.639660
# 209    0.283700
# 491    1.113816
# 392    0.355110
# 124    1.053778
# 232   -0.984611
# 374    0.264169
# 259   -1.442895
# 58    -0.028318
# 402   -0.243129
# 191    0.229106
# 335    0.886952
# 346    0.504682
# 14    -0.392364
# 132   -1.106785
# 188   -0.083701
# 183   -0.118056
# 467   -0.074600
# dtype: float64
#   Angle_row: Series:
# 175   -0.548094
# 1     -0.529015
# 63    -0.925643
# 417    0.477532
# 154    1.484363
# 243    2.719384
# 271   -0.720980
# 385    2.845414
# 209   -0.224186
# 491    0.954658
# 392    0.493814
# 124    0.615704
# 232   -0.483729
# 374    0.118455
# 259    0.003740
# 58     0.763811
# 402   -0.282636
# 191    1.495745
# 335   -1.372878
# 346   -0.787619
# 14     0.695302
# 132    0.298800
# 188    0.641337
# 183   -0.882633
# 467    1.877796
# dtype: float64
#   Angle2_row: Series:
# 175   -1.240981
# 1     -0.105441
# 63     0.312202
# 417   -1.257470
# 154    1.214145
# 243    1.774923
# 271    1.062145
# 385    0.963282
# 209    0.413269
# 491    0.991084
# 392    0.455478
# 124    0.049761
# 232    1.285145
# 374    0.625394
# 259   -0.443528
# 58     1.950846
# 402   -0.335196
# 191    0.377809
# 335   -0.776250
# 346   -0.523046
# 14     1.306419
# 132   -0.330353
# 188    0.627137
# 183    0.891700
# 467   -0.039256
# dtype: float64
# --------------------
#
# Best Assignment for BS 1:
#  UAV Index: 1
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 53118.9351
#   P_m_down_value: 1.8500
#   P_m_har_value: 0.9840
#   T_m_har_value: 0.7440
#   f_km_value: 2.5709
#   T_km_up_value: 0.7483
#   V_lm_vfly_value: 73.2647
#   V_lm_hfly_value: 63.7509
#   P_km_up_value: 7.4227
#   Angle1_row: Series:
# 99    -2.769360
# 367   -0.646722
# 153   -1.693594
# 398   -0.857075
# 220   -1.021364
# 325   -0.803426
# 64    -0.256547
# 218   -0.004220
# 361    1.531785
# 8     -0.241608
# 352    0.646902
# 374    0.438315
# 268    1.710035
# 43    -0.354270
# 326   -1.036907
# 45     0.210622
# 273    1.800114
# 375    1.574652
# 255   -2.071074
# 371    0.560036
# 245   -1.324673
# 253    0.430595
# 217   -0.586232
# 235    0.235622
# 146   -1.888492
# dtype: float64
#   Angle_row: Series:
# 99     0.638982
# 367   -0.990729
# 153   -0.574242
# 398    1.777258
# 220    0.115705
# 325    1.009695
# 64    -0.710888
# 218    1.204076
# 361    0.477313
# 8     -1.225838
# 352   -1.387016
# 374   -1.390225
# 268    0.299031
# 43    -1.069798
# 326   -0.957669
# 45    -1.289276
# 273   -1.320995
# 375   -0.585806
# 255    0.171145
# 371    0.622606
# 245    0.353458
# 253   -1.001096
# 217   -0.310267
# 235    1.103816
# 146    0.462058
# dtype: float64
#   Angle2_row: Series:
# 99     1.079643
# 367    0.671479
# 153    1.300770
# 398   -1.812318
# 220   -1.704395
# 325   -0.942385
# 64    -1.316031
# 218    0.094885
# 361   -0.611152
# 8      0.622458
# 352   -0.211313
# 374   -0.098527
# 268   -0.366036
# 43    -0.722830
# 326   -0.708220
# 45    -1.900875
# 273    0.300830
# 375    0.472773
# 255   -0.350123
# 371    0.833934
# 245   -0.047554
# 253    1.574901
# 217   -0.562456
# 235   -0.994941
# 146   -1.140359
# dtype: float64
# --------------------
#
# --- UAVs without Assigned Base Stations ---
#   UAV 3 : No BS is assigned
# --------------------
#   UAV 4 : No BS is assigned
# --------------------
#   UAV 6 : No BS is assigned
# --------------------
# calculaiton for p_max for GA 5
#
# --- Best Unique UAV Assignments (Auction Based Method) ---
#
# Best Assignment for BS 4:
#  UAV Index: 1
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 46959.4101
#   P_m_down_value: 1.1958
#   P_m_har_value: 0.6394
#   T_m_har_value: 0.7006
#   f_km_value: 2.8820
#   T_km_up_value: 0.5501
#   V_lm_vfly_value: 73.4366
#   V_lm_hfly_value: 65.5029
#   P_km_up_value: 9.0933
#   Angle1_row: Series:
# 281   -0.739381
# 477    0.716086
# 70    -0.567212
# 32    -0.803906
# 21    -0.492141
# 323    0.289540
# 193   -0.927621
# 274   -0.047557
# 60    -0.924692
# 295   -1.199154
# 40    -0.614351
# 44     0.048531
# 424    0.100546
# 136    0.290639
# 64    -0.407431
# 484    0.781702
# 158   -1.309815
# 153   -1.734409
# 330    0.608665
# 77     0.084358
# 434    1.656763
# 65    -1.315597
# 31     0.082205
# 272   -0.275273
# 454   -0.719916
# dtype: float64
#   Angle_row: Series:
# 281    1.673376
# 477   -0.875375
# 70    -0.858352
# 32    -0.623006
# 21     0.293693
# 323    0.116163
# 193    0.372218
# 274    1.026736
# 60     0.877792
# 295   -0.123747
# 40     0.874498
# 44    -1.577962
# 424    0.565750
# 136    0.557106
# 64    -0.149115
# 484   -1.341165
# 158    0.478078
# 153   -1.987015
# 330    0.843146
# 77    -0.178333
# 434   -0.069437
# 65    -1.179238
# 31     0.328351
# 272    0.124888
# 454    0.779940
# dtype: float64
#   Angle2_row: Series:
# 281    1.278913
# 477   -0.250271
# 70    -0.470453
# 32     0.495418
# 21    -0.113499
# 323   -0.846463
# 193   -0.636291
# 274   -0.393935
# 60     0.522870
# 295   -0.662753
# 40     0.636701
# 44     1.340216
# 424    1.392700
# 136   -0.874638
# 64     1.972763
# 484    0.488299
# 158   -0.175476
# 153    0.006662
# 330   -0.890594
# 77    -0.169802
# 434   -0.276975
# 65    -0.455138
# 31     0.276896
# 272    1.555346
# 454    0.172775
# dtype: float64
# --------------------
#
# Best Assignment for BS 1:
#  UAV Index: 2
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 48701.7427
#   P_m_down_value: 0.6317
#   P_m_har_value: 1.1133
#   T_m_har_value: 1.7521
#   f_km_value: 1.6466
#   T_km_up_value: 0.4719
#   V_lm_vfly_value: 58.4347
#   V_lm_hfly_value: 61.6322
#   P_km_up_value: 9.6669
#   Angle1_row: Series:
# 356    1.512642
# 349   -0.018630
# 223    0.393189
# 238   -1.734917
# 46    -0.098578
# 426   -0.451488
# 181    1.029765
# 195    0.044790
# 478   -1.032836
# 445   -0.590739
# 496    0.558919
# 2      0.667645
# 465    0.484293
# 221    0.339716
# 351   -0.064565
# 247   -0.193432
# 476    0.203986
# 196   -1.186115
# 116   -0.026966
# 344   -0.620872
# 424    2.315668
# 487    0.922353
# 148   -0.899430
# 342   -0.825585
# 219   -0.866130
# dtype: float64
#   Angle_row: Series:
# 356    0.524822
# 349   -0.071045
# 223    0.046058
# 238    0.822250
# 46     0.278075
# 426    0.530638
# 181    0.289258
# 195    0.552837
# 478    0.863644
# 445    0.376083
# 496    0.115315
# 2      0.770072
# 465   -0.445874
# 221    0.003975
# 351    0.010670
# 247    0.069885
# 476   -0.917402
# 196    1.078914
# 116   -0.060927
# 344    0.785175
# 424    1.432056
# 487    1.680310
# 148    0.319472
# 342   -0.464047
# 219    0.749955
# dtype: float64
#   Angle2_row: Series:
# 356   -0.257665
# 349   -1.785998
# 223    1.696208
# 238    2.271602
# 46     0.230834
# 426    1.272431
# 181    0.652495
# 195    1.807492
# 478    1.404315
# 445    0.059104
# 496    0.555998
# 2      0.607698
# 465   -0.680195
# 221    0.211375
# 351   -0.236293
# 247   -0.663461
# 476   -1.099638
# 196   -0.400558
# 116   -0.238277
# 344   -1.092795
# 424   -1.568798
# 487   -0.492599
# 148    0.811701
# 342    0.867210
# 219    0.510958
# dtype: float64
# --------------------
#
# Best Assignment for BS 3:
#  UAV Index: 3
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 50136.0481
#   P_m_down_value: 0.8036
#   P_m_har_value: 0.5412
#   T_m_har_value: 0.1608
#   f_km_value: 1.7839
#   T_km_up_value: 0.5419
#   V_lm_vfly_value: 66.2334
#   V_lm_hfly_value: 67.7171
#   P_km_up_value: 7.4912
#   Angle1_row: Series:
# 305    0.389466
# 387   -0.329122
# 417    1.268570
# 30     0.710052
# 443   -0.116982
# 297   -0.311833
# 362   -0.067174
# 109   -1.178512
# 103    0.715040
# 368   -0.680243
# 244   -0.162878
# 29     0.494217
# 60    -0.900024
# 89     0.611274
# 229    2.109797
# 293   -0.981432
# 79    -1.776016
# 303    0.417639
# 295    0.417984
# 325   -0.810450
# 319    3.507672
# 323    0.361979
# 105   -0.086771
# 66    -0.685618
# 262    0.813797
# dtype: float64
#   Angle_row: Series:
# 305   -0.156272
# 387   -0.676474
# 417   -0.378852
# 30    -0.306283
# 443   -0.081292
# 297   -0.183509
# 362   -0.585240
# 109   -0.404543
# 103   -0.021212
# 368   -0.234769
# 244   -1.089171
# 29     0.116370
# 60    -0.619396
# 89    -0.773193
# 229    0.092599
# 293   -0.251294
# 79    -1.788025
# 303   -0.278209
# 295   -0.432355
# 325    1.173682
# 319   -1.241231
# 323   -1.519643
# 105   -0.543454
# 66     0.434663
# 262   -0.776000
# dtype: float64
#   Angle2_row: Series:
# 305    1.519213
# 387   -0.381623
# 417   -1.573934
# 30    -0.912732
# 443    0.497866
# 297   -0.125473
# 362   -0.638018
# 109    0.376137
# 103    0.280575
# 368   -1.424632
# 244    0.878255
# 29    -1.065212
# 60    -0.419476
# 89    -0.046094
# 229    0.223481
# 293   -0.838238
# 79    -0.665883
# 303   -1.111314
# 295   -0.211345
# 325    0.451307
# 319   -0.274240
# 323   -1.797201
# 105    0.682894
# 66    -0.915376
# 262    1.222457
# dtype: float64
# --------------------
#
# Best Assignment for BS 2:
#  UAV Index: 7
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 51692.9530
#   P_m_down_value: 1.6550
#   P_m_har_value: 1.6697
#   T_m_har_value: 0.8980
#   f_km_value: 4.1859
#   T_km_up_value: 0.6399
#   V_lm_vfly_value: 23.0069
#   V_lm_hfly_value: 55.7134
#   P_km_up_value: 8.9755
#   Angle1_row: Series:
# 253    0.704939
# 25    -0.503491
# 113    0.199257
# 295    0.071375
# 330    0.733746
# 283   -0.862401
# 300    0.985679
# 336    0.741410
# 249    0.738425
# 271   -0.104459
# 116   -0.524236
# 63    -0.590003
# 350    1.899148
# 293    1.437344
# 476    1.082492
# 74    -0.890535
# 112    0.940672
# 82     0.188298
# 413    1.470545
# 274   -0.048191
# 172   -0.243860
# 59    -0.244156
# 173   -0.158980
# 107    0.545646
# 240   -0.214605
# dtype: float64
#   Angle_row: Series:
# 253    2.140976
# 25    -0.543992
# 113    0.220157
# 295   -0.516754
# 330    1.561259
# 283    1.947114
# 300    0.801866
# 336   -0.468953
# 249    0.974573
# 271    0.641309
# 116    0.192722
# 63    -0.373266
# 350   -0.944434
# 293    0.300952
# 476   -0.179902
# 74    -0.062201
# 112   -1.837843
# 82     0.280798
# 413   -0.158399
# 274   -0.068642
# 172    0.632247
# 59     0.639688
# 173    1.757653
# 107    0.046928
# 240    2.159476
# dtype: float64
#   Angle2_row: Series:
# 253    0.850851
# 25     0.019222
# 113   -0.249104
# 295   -0.292031
# 330   -1.040669
# 283   -1.687841
# 300    0.313379
# 336    0.074578
# 249    1.488997
# 271    0.977722
# 116    0.901111
# 63     0.079406
# 350   -0.673852
# 293   -1.231678
# 476   -0.357750
# 74     2.369468
# 112    0.801194
# 82     1.554200
# 413    0.626371
# 274   -0.329260
# 172    0.033837
# 59    -0.464745
# 173    1.338148
# 107    0.181922
# 240    0.628577
# dtype: float64
# --------------------
#
# Best Assignment for BS 0:
#  UAV Index: 5
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 57542.4600
#   P_m_down_value: 1.7783
#   P_m_har_value: 0.6715
#   T_m_har_value: 0.9691
#   f_km_value: 1.1183
#   T_km_up_value: 0.5299
#   V_lm_vfly_value: 46.4102
#   V_lm_hfly_value: 35.1769
#   P_km_up_value: 6.9308
#   Angle1_row: Series:
# 244   -0.660183
# 229   -0.346637
# 104   -1.392822
# 294    2.132454
# 221    0.718975
# 355    0.087831
# 203   -0.809721
# 383    0.229102
# 162    0.341049
# 472   -0.640328
# 231    1.138381
# 37     0.215137
# 323    0.472996
# 212    0.593091
# 398    1.543937
# 213    0.380550
# 167    0.574337
# 125    0.041886
# 245   -1.167956
# 463    1.114391
# 313    1.262730
# 453   -0.369269
# 233    0.402744
# 27     0.355661
# 376   -0.482539
# dtype: float64
#   Angle_row: Series:
# 244   -0.229653
# 229   -0.503272
# 104   -0.769178
# 294    1.318190
# 221   -0.369024
# 355    1.207813
# 203    0.378872
# 383    1.035063
# 162    0.030115
# 472   -0.217604
# 231    0.052989
# 37    -0.657393
# 323   -0.158621
# 212    0.599363
# 398   -0.371215
# 213    0.277533
# 167   -0.393491
# 125   -0.487939
# 245   -0.035745
# 463   -0.150975
# 313    0.105574
# 453    0.105194
# 233    0.651736
# 27    -0.439707
# 376    0.245063
# dtype: float64
#   Angle2_row: Series:
# 244    0.780384
# 229    1.424701
# 104    0.127399
# 294    0.899632
# 221   -0.354606
# 355   -1.518427
# 203   -0.437246
# 383   -0.592015
# 162   -0.330479
# 472    0.267070
# 231    1.142460
# 37     1.772222
# 323    0.379591
# 212    0.016533
# 398   -0.301973
# 213   -1.047643
# 167   -1.069419
# 125    0.523241
# 245   -1.238942
# 463   -0.511053
# 313    0.778236
# 453   -0.933529
# 233   -0.540362
# 27    -1.251849
# 376   -1.388954
# dtype: float64
# --------------------
#
# --- UAVs without Assigned Base Stations ---
#   UAV 0 : No BS is assigned
# --------------------
#   UAV 4 : No BS is assigned
# --------------------
#   UAV 6 : No BS is assigned
# --------------------
# calculaiton for p_max for GA 6
#
# --- Best Unique UAV Assignments (Auction Based Method) ---
#
# Best Assignment for BS 2:
#  UAV Index: 1
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 43182.2270
#   P_m_down_value: 0.9276
#   P_m_har_value: 2.4594
#   T_m_har_value: 0.1923
#   f_km_value: 2.2996
#   T_km_up_value: 0.3738
#   V_lm_vfly_value: 72.7104
#   V_lm_hfly_value: 65.3317
#   P_km_up_value: 7.3892
#   Angle1_row: Series:
# 219   -1.508796
# 36    -0.032395
# 310    0.053967
# 413    0.280369
# 270    0.708690
# 227   -0.562585
# 208    0.521969
# 450    2.353816
# 247    0.406920
# 460    0.371420
# 391   -0.406972
# 424    0.164096
# 9     -1.981209
# 15    -1.005257
# 163    1.006060
# 198   -1.180350
# 211   -0.623988
# 118    0.983392
# 114    0.685757
# 388    1.514671
# 386    0.736214
# 441   -0.841734
# 53    -1.454039
# 233    1.202252
# 330   -1.728538
# dtype: float64
#   Angle_row: Series:
# 219    0.722889
# 36    -3.189195
# 310    1.489856
# 413    0.528823
# 270   -1.315988
# 227    0.288435
# 208    1.261991
# 450    1.004529
# 247   -0.646985
# 460   -0.336770
# 391   -0.060849
# 424   -1.380102
# 9      0.103376
# 15     0.945747
# 163   -0.947317
# 198   -0.638070
# 211   -0.142538
# 118    0.759919
# 114    1.099219
# 388    0.782259
# 386    0.628364
# 441    0.272762
# 53     1.004996
# 233   -0.394110
# 330   -0.464662
# dtype: float64
#   Angle2_row: Series:
# 219   -0.143358
# 36     0.059304
# 310   -0.835457
# 413   -1.045948
# 270    0.264278
# 227    0.423331
# 208   -0.254763
# 450    0.310942
# 247   -1.785881
# 460    0.580864
# 391   -0.415206
# 424    0.661289
# 9      0.228794
# 15     0.833108
# 163   -0.083571
# 198    0.931646
# 211   -1.420964
# 118    0.813863
# 114   -0.020581
# 388    0.006459
# 386   -0.264102
# 441    0.444623
# 53     1.336756
# 233    1.081923
# 330    0.307660
# dtype: float64
# --------------------
#
# Best Assignment for BS 4:
#  UAV Index: 7
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 47062.3311
#   P_m_down_value: 0.3295
#   P_m_har_value: 1.6013
#   T_m_har_value: 1.0200
#   f_km_value: 3.4320
#   T_km_up_value: 0.4495
#   V_lm_vfly_value: 22.8016
#   V_lm_hfly_value: 54.3893
#   P_km_up_value: 8.0842
#   Angle1_row: Series:
# 142   -1.928937
# 169    0.692198
# 276    0.562475
# 457   -0.611722
# 105    0.277558
# 176   -0.002832
# 231   -0.326962
# 121    0.424818
# 489   -0.250046
# 431    0.979370
# 310    0.777438
# 196    0.349686
# 49    -0.704133
# 103   -1.128728
# 265   -0.164469
# 141    0.242761
# 480   -1.090727
# 419    0.345189
# 135   -1.063746
# 317   -1.155424
# 486   -0.183455
# 150    1.103715
# 344   -0.250278
# 25    -0.935547
# 10    -0.465113
# dtype: float64
#   Angle_row: Series:
# 142    1.865819
# 169    0.156338
# 276    0.317708
# 457    0.227055
# 105    1.822363
# 176   -1.785594
# 231   -0.678133
# 121    0.384132
# 489    0.654296
# 431   -0.955268
# 310   -0.545818
# 196   -0.742123
# 49    -0.840447
# 103    0.844405
# 265   -1.008012
# 141   -1.183180
# 480   -0.285013
# 419   -0.621587
# 135   -0.944521
# 317   -0.529092
# 486   -0.349014
# 150   -0.820238
# 344    2.675638
# 25     0.028547
# 10    -0.609871
# dtype: float64
#   Angle2_row: Series:
# 142   -1.501090
# 169    1.010273
# 276    0.695165
# 457   -0.668241
# 105   -1.996031
# 176    0.737807
# 231    0.833349
# 121    2.491891
# 489   -0.300731
# 431   -0.341604
# 310   -0.159130
# 196    1.573841
# 49    -0.677883
# 103    0.378131
# 265   -1.690283
# 141   -0.830100
# 480   -1.455600
# 419   -0.632743
# 135    0.184542
# 317   -2.168217
# 486    2.224928
# 150    0.166329
# 344   -0.899188
# 25    -0.196157
# 10    -0.621903
# dtype: float64
# --------------------
#
# Best Assignment for BS 0:
#  UAV Index: 2
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 52178.1231
#   P_m_down_value: 0.1974
#   P_m_har_value: 0.1353
#   T_m_har_value: 0.3937
#   f_km_value: 0.9824
#   T_km_up_value: 0.3901
#   V_lm_vfly_value: 59.4068
#   V_lm_hfly_value: 61.2868
#   P_km_up_value: 9.3996
#   Angle1_row: Series:
# 255    119.003406
# 105     51.709939
# 295     27.201182
# 488     46.205861
# 270    112.058916
# 129     69.828220
# 36      20.826497
# 13      92.326423
# 90      71.932194
# 222     40.855588
# 8      175.247009
# 186     68.299060
# 40      14.204536
# 218     38.229441
# 182    161.099568
# 309    132.200842
# 378     66.983384
# 390    151.778557
# 316     73.008940
# 53      53.891412
# 480     53.985596
# 103     31.190441
# 490     47.564742
# 95      73.352963
# 296     95.840715
# Name: 12, dtype: float64
#   Angle_row: Series:
# 255     53.822201
# 105     14.824568
# 295    153.671708
# 488    169.890226
# 270    105.700186
# 129    128.977092
# 36     153.094122
# 13     159.353163
# 90      49.160110
# 222      4.987893
# 8       23.992567
# 186    166.234871
# 40       9.240648
# 218    179.782711
# 182     32.576956
# 309     77.374693
# 378    167.820141
# 390      1.792739
# 316     78.997962
# 53      15.055762
# 480    127.402103
# 103     95.543597
# 490     97.748428
# 95      16.280153
# 296    125.285178
# Name: 12, dtype: float64
#   Angle2_row: Series:
# 255     16.161892
# 105     48.534070
# 295     50.657683
# 488      7.437910
# 270    108.395776
# 129    159.956814
# 36      10.555865
# 13       2.831155
# 90      29.420378
# 222     55.844245
# 8       31.634978
# 186     14.404584
# 40      85.583171
# 218    173.748549
# 182      8.613729
# 309    138.317288
# 378    167.217740
# 390     49.583781
# 316     17.341786
# 53     167.967027
# 480     16.920524
# 103     88.461296
# 490     20.482263
# 95     169.174756
# 296    162.434004
# Name: 12, dtype: float64
# --------------------
#
# Best Assignment for BS 3:
#  UAV Index: 5
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 53482.9350
#   P_m_down_value: 1.1928
#   P_m_har_value: 0.8632
#   T_m_har_value: 1.0350
#   f_km_value: 2.2289
#   T_km_up_value: 0.6116
#   V_lm_vfly_value: 47.3484
#   V_lm_hfly_value: 35.0859
#   P_km_up_value: 8.2660
#   Angle1_row: Series:
# ...
# 108    1.190415
# 120    0.624808
# 83    -1.352565
# 76     2.492488
# 193    0.377363
# 128    0.772788
# 480   -0.836527
# 156    0.123508
# dtype: float64
#   Angle2_row: Series:
# 414   -1.938980
# 6      1.021932
# 209   -1.025752
# 194    0.192617
# 266    0.221282
# 319   -1.004799
# 446   -0.046748
# 390   -0.147822
# 317    0.398338
# 451    0.137094
# 203   -0.306813
# 399   -1.303144
# 489   -1.814253
# 63    -0.479209
# 170    0.572773
# 337    2.189816
# 135    0.100528
# 108   -1.394804
# 120    1.180956
# 83     0.395530
# 76     0.164492
# 193   -0.749608
# 128    1.302208
# 480   -0.135495
# 156   -0.157529
# dtype: float64
# --------------------
#
# Best Assignment for BS 4:
#  UAV Index: 2
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 47307.8328
#   P_m_down_value: 0.8417
#   P_m_har_value: 0.2146
#   T_m_har_value: 2.0643
#   f_km_value: 2.5488
#   T_km_up_value: 0.5327
#   V_lm_vfly_value: 58.9245
#   V_lm_hfly_value: 60.6648
#   P_km_up_value: 9.5089
#   Angle1_row: Series:
# 271    0.115127
# 40     1.100405
# 489   -0.865336
# 137    1.086807
# 465    0.021271
# 136    1.201046
# 37    -0.618224
# 54     0.267739
# 394   -0.652389
# 295   -1.964392
# 457   -0.507032
# 96     0.261673
# 204   -2.519369
# 373    0.079045
# 133    0.656979
# 310    0.610763
# 185    1.118873
# 207    0.158772
# 143   -1.110634
# 95    -0.506967
# 189   -0.645193
# 246   -0.987439
# 248    1.297161
# 218   -0.364589
# 385   -0.930213
# dtype: float64
#   Angle_row: Series:
# 271   -1.697241
# 40     1.050985
# 489   -0.268895
# 137    0.727075
# 465    0.166532
# 136    0.001754
# 37     0.189191
# 54    -1.073285
# 394   -0.152814
# 295   -0.066740
# 457    1.743624
# 96     0.456654
# 204   -0.759199
# 373    0.287001
# 133    0.067661
# 310   -0.768987
# 185    0.644275
# 207   -1.745896
# 143    0.088313
# 95    -0.471967
# 189    1.424558
# 246   -0.914450
# 248   -0.887588
# 218    0.200001
# 385    1.709979
# dtype: float64
#   Angle2_row: Series:
# 271   -0.195528
# 40     1.774861
# 489   -0.323075
# 137    0.824312
# 465    0.038150
# 136    0.134604
# 37    -1.599798
# 54    -0.515948
# 394   -1.848265
# 295   -0.723000
# 457    1.093911
# 96     0.315750
# 204    2.477355
# 373    1.297718
# 133    0.414362
# 310   -0.745191
# 185    1.133289
# 207    1.068090
# 143    0.724620
# 95    -0.760701
# 189   -0.398842
# 246   -0.921527
# 248    0.030172
# 218    0.098995
# 385   -1.396969
# dtype: float64
# --------------------
#
# Best Assignment for BS 0:
#  UAV Index: 7
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 49641.1072
#   P_m_down_value: 0.3888
#   P_m_har_value: 1.3201
#   T_m_har_value: 0.1126
#   f_km_value: 3.1781
#   T_km_up_value: 0.5269
#   V_lm_vfly_value: 22.6498
#   V_lm_hfly_value: 55.5282
#   P_km_up_value: 8.4424
#   Angle1_row: Series:
# 311   -1.392856
# 367    0.283519
# 388   -1.091572
# 126   -0.192536
# 322   -0.934098
# 469    0.428431
# 263    0.305694
# 34     0.384747
# 439    1.719780
# 42    -0.735138
# 349    0.330368
# 457   -0.028886
# 98     1.451048
# 278    1.698339
# 1     -1.087452
# 3     -0.658272
# 261   -1.368300
# 462    0.421306
# 269   -0.417774
# 481   -1.324609
# 430    0.830662
# 167   -0.338887
# 432   -0.430849
# 384   -0.053532
# 217   -1.226676
# dtype: float64
#   Angle_row: Series:
# 311   -1.128040
# 367   -0.460478
# 388   -0.022839
# 126    0.347569
# 322    0.518137
# 469   -0.186053
# 263   -0.722064
# 34    -0.546650
# 439   -1.439527
# 42    -0.472961
# 349    0.331702
# 457   -0.377260
# 98     1.557611
# 278    1.503259
# 1     -1.499715
# 3      2.382280
# 261   -0.057622
# 462    0.269457
# 269   -0.769322
# 481   -0.863463
# 430    0.970899
# 167   -0.716979
# 432    0.176651
# 384   -1.763153
# 217    0.130558
# dtype: float64
#   Angle2_row: Series:
# 311   -0.448229
# 367    0.324230
# 388    1.822094
# 126    0.051141
# 322    1.944167
# 469    0.846251
# 263   -1.913969
# 34     0.058617
# 439   -1.333124
# 42     0.313990
# 349   -0.327780
# 457   -0.558296
# 98    -1.233507
# 278   -0.179219
# 1     -0.437696
# 3      0.787021
# 261   -0.631645
# 462   -1.542091
# 269    1.137562
# 481    0.848755
# 430    0.002703
# 167    0.077145
# 432    0.523180
# 384   -2.055322
# 217   -1.702829
# dtype: float64
# --------------------
#
# Best Assignment for BS 3:
#  UAV Index: 5
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 54825.7239
#   P_m_down_value: 0.3107
#   P_m_har_value: 0.7386
#   T_m_har_value: 1.3982
#   f_km_value: 2.4426
#   T_km_up_value: 0.6632
#   V_lm_vfly_value: 45.7316
#   V_lm_hfly_value: 34.1528
#   P_km_up_value: 6.4098
#   Angle1_row: Series:
# 106   -1.493395
# 443    1.387400
# 251   -0.210226
# 218    0.711178
# 99    -0.332951
# 228   -1.459116
# 95    -0.521472
# 479   -0.606035
# 363    0.042739
# 424    1.081954
# 198    1.936074
# 161   -0.387034
# 409   -1.074732
# 110    2.042820
# 167   -0.695450
# 240   -1.678610
# 306    1.261521
# 108    0.251818
# 298    0.078904
# 39    -0.268085
# 390   -0.649257
# 235    0.441065
# 289    0.720907
# 4      0.204090
# 88    -1.047627
# dtype: float64
#   Angle_row: Series:
# 106    1.361376
# 443    1.236841
# 251    1.231230
# 218   -1.115218
# 99    -0.626692
# 228   -1.089998
# 95    -0.532796
# 479    0.237358
# 363   -0.899397
# 424   -0.651011
# 198    1.369641
# 161    0.454786
# 409   -0.149164
# 110   -2.051084
# 167   -0.815851
# 240   -1.224084
# 306    0.741058
# 108    0.827688
# 298   -0.443993
# 39     1.351095
# 390    1.891413
# 235   -0.310868
# 289    0.562524
# 4     -1.687879
# 88    -0.411614
# dtype: float64
#   Angle2_row: Series:
# 106   -0.111446
# 443   -0.209973
# 251    0.435787
# 218    0.104405
# 99    -0.245317
# 228    1.394583
# 95     0.352221
# 479   -0.253850
# 363    1.299422
# 424   -0.483237
# 198    0.252903
# 161    1.289581
# 409    1.599576
# 110    0.173334
# 167   -2.206764
# 240   -1.628040
# 306    0.914641
# 108   -1.284876
# 298    0.670164
# 39     0.629421
# 390   -0.293120
# 235    0.627235
# 289   -0.638275
# 4      0.539454
# 88     0.495269
# dtype: float64
# --------------------
#
# Best Assignment for BS 2:
#  UAV Index: 0
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 56826.7651
#   P_m_down_value: 0.9798
#   P_m_har_value: 1.6540
#   T_m_har_value: 0.6012
#   f_km_value: 1.9665
#   T_km_up_value: 0.5424
#   V_lm_vfly_value: 19.4737
#   V_lm_hfly_value: 88.9427
#   P_km_up_value: 8.1292
#   Angle1_row: Series:
# 103   -0.320692
# 406   -1.497748
# 346    1.001230
# 467    1.099164
# 481   -0.018246
# 348    2.396795
# 455   -1.194316
# 37     0.027075
# 100    0.782784
# 5     -0.874403
# 497    1.231227
# 412   -0.800031
# 215    0.846888
# 229    2.151888
# 411    0.088889
# 38     0.696025
# 161    2.023502
# 224    0.681251
# 372   -0.250784
# 135    1.350769
# 233    0.917406
# 369   -2.480634
# 131    2.078323
# 110   -1.675967
# 96     0.530282
# dtype: float64
#   Angle_row: Series:
# 103    1.107459
# 406   -0.917752
# 346   -0.803857
# 467    0.528388
# 481    0.794892
# 348    0.541714
# 455    0.151989
# 37     0.228977
# 100   -0.568302
# 5      1.023143
# 497    1.257141
# 412   -1.181855
# 215   -0.049545
# 229   -0.927532
# 411    0.884995
# 38    -1.058139
# 161   -0.695978
# 224   -1.725940
# 372    0.900265
# 135    0.130044
# 233   -2.091112
# 369    0.979824
# 131   -1.226015
# 110   -0.092812
# 96    -1.522672
# dtype: float64
#   Angle2_row: Series:
# 103    0.569567
# 406   -0.106167
# 346   -0.175245
# 467   -0.315695
# 481   -2.430210
# 348   -0.076830
# 455   -1.405400
# 37     0.671725
# 100    0.621116
# 5     -1.344991
# 497   -0.017739
# 412    1.451694
# 215   -0.408709
# 229    0.110018
# 411    0.450264
# 38    -0.161155
# 161    0.310172
# 224   -1.423114
# 372    1.066614
# 135   -1.741031
# 233    0.432945
# 369   -1.168883
# 131    1.453399
# 110   -2.072425
# 96    -0.134261
# dtype: float64
# --------------------
#
# --- UAVs without Assigned Base Stations ---
#   UAV 1 : No BS is assigned
# --------------------
#   UAV 4 : No BS is assigned
# --------------------
#   UAV 6 : No BS is assigned
# --------------------
# calculaiton for p_max for GA 10
#
# --- Best Unique UAV Assignments (Auction Based Method) ---
#
# Best Assignment for BS 2:
#  UAV Index: 5
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 46286.8456
#   P_m_down_value: 1.6747
#   P_m_har_value: 0.3651
#   T_m_har_value: 0.3252
#   f_km_value: 2.7504
#   T_km_up_value: 0.4093
#   V_lm_vfly_value: 46.4179
#   V_lm_hfly_value: 35.8831
#   P_km_up_value: 8.0088
#   Angle1_row: Series:
# 270    1.696553
# 87     0.317458
# 9      0.529999
# 22     0.500765
# 329   -1.108329
# 234   -0.102205
# 142    0.299615
# 340    0.486496
# 359    0.452280
# 316    1.345243
# 150   -1.107297
# 489    1.602400
# 220   -0.817959
# 55    -0.062940
# 282    0.803398
# 446    0.024892
# 77     0.735262
# 26     0.523664
# 372   -0.085826
# 246    2.107793
# 365   -0.628929
# 445   -0.818285
# 470   -0.170924
# 275    3.340055
# 466   -0.254985
# dtype: float64
#   Angle_row: Series:
# 270   -0.365256
# 87     1.830056
# 9     -0.758486
# 22    -0.484235
# 329    1.159121
# 234   -0.743282
# 142   -2.311257
# 340    0.946322
# 359   -0.034317
# 316    1.214739
# 150   -0.858512
# 489   -2.587394
# 220   -0.335990
# 55     0.630478
# 282    0.478202
# 446    0.109992
# 77    -0.819559
# 26     0.911803
# 372   -1.692261
# 246   -0.949255
# 365    1.073888
# 445    0.794530
# 470   -0.236250
# 275    0.375527
# 466   -0.448851
# dtype: float64
#   Angle2_row: Series:
# 270    0.548724
# 87    -2.123665
# 9     -1.584887
# 22    -0.200327
# 329    0.910577
# 234   -0.521675
# 142    0.332449
# 340    0.327645
# 359    0.147549
# 316   -0.119141
# 150   -1.362091
# 489   -1.927930
# 220   -0.297349
# 55    -1.170837
# 282    0.076935
# 446    0.520047
# 77     2.421210
# 26     1.316343
# 372   -1.779815
# 246   -0.811255
# 365   -0.759950
# 445   -0.138175
# 470   -1.714812
# 275    0.781388
# 466    0.303673
# dtype: float64
# --------------------
#
# Best Assignment for BS 4:
#  UAV Index: 1
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 46841.0956
#   P_m_down_value: 2.4399
#   P_m_har_value: 1.7515
#   T_m_har_value: 1.8025
#   f_km_value: 1.5594
#   T_km_up_value: 0.4013
#   V_lm_vfly_value: 71.6669
#   V_lm_hfly_value: 63.5742
#   P_km_up_value: 9.5706
#   Angle1_row: Series:
# 52    -1.340484
# 254    0.035683
# 87    -0.697494
# 313   -1.474619
# 155    0.316907
# 230    0.342998
# 345    0.433679
# 39     0.312091
# 395    0.284594
# 285    0.877923
# 156    0.421608
# 124   -0.283027
# 317   -0.154128
# 208   -1.189842
# 418   -0.101939
# 306    2.175597
# 331   -0.137179
# 242    1.238276
# 469    2.207257
# 276   -1.107224
# 240   -0.354098
# 472   -0.390876
# 71    -2.001297
# 60    -0.144697
# 397   -0.316779
# dtype: float64
#   Angle_row: Series:
# 52     0.988173
# 254   -0.467355
# 87     0.324394
# 313   -0.568825
# 155    0.885862
# 230    0.859824
# 345    0.698818
# 39     0.348064
# 395   -0.180247
# 285    0.916629
# 156   -0.735287
# 124   -0.729566
# 317    0.906824
# 208    0.120148
# 418   -2.784099
# 306    0.728090
# 331   -0.514636
# 242    0.224455
# 469    0.586766
# 276    1.395430
# 240    0.198148
# 472   -0.993475
# 71    -1.977576
# 60     2.054485
# 397    2.161828
# dtype: float64
#   Angle2_row: Series:
# 52    -0.314869
# 254   -0.476173
# 87     1.840833
# 313   -0.083585
# 155    0.661778
# 230   -1.097905
# 345    0.162859
# 39     1.305254
# 395   -1.150517
# 285   -0.451492
# 156    0.896322
# 124    3.289035
# 317   -1.332814
# 208   -0.698940
# 418   -0.881103
# 306   -0.671821
# 331   -0.825709
# 242   -0.593950
# 469   -0.185589
# 276   -1.484430
# 240   -0.287687
# 472    1.218498
# 71     0.261513
# 60     0.855186
# 397   -0.824915
# dtype: float64
# --------------------
#
# Best Assignment for BS 1:
#  UAV Index: 3
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 47426.8827
#   P_m_down_value: 2.1406
#   P_m_har_value: 1.4442
#   T_m_har_value: 1.1276
#   f_km_value: 2.9574
#   T_km_up_value: 0.5580
#   V_lm_vfly_value: 65.2735
#   V_lm_hfly_value: 67.4047
#   P_km_up_value: 7.5217
#   Angle1_row: Series:
# 288   -0.367382
# 245    0.307071
# 403   -0.308585
# 266   -0.279144
# 283   -0.502312
# 370    0.806310
# 221    0.253115
# 173    1.324003
# 238    1.792077
# 239   -0.476826
# 11     0.147634
# 482    1.691263
# 168   -0.021607
# 265    0.860379
# 128   -1.335188
# 96     2.061594
# 328    1.690915
# 268   -1.958723
# 296   -1.564463
# 412   -0.452518
# 397    1.580789
# 181    0.036681
# 326   -2.230736
# 290   -0.018741
# 4      1.374255
# dtype: float64
#   Angle_row: Series:
# 288    0.322466
# 245   -0.849152
# 403   -0.527326
# 266   -0.104525
# 283   -1.537937
# 370    0.192384
# 221    0.608280
# 173    0.003572
# 238   -1.302605
# 239    0.661799
# 11     0.671107
# 482   -2.091105
# 168   -0.054220
# 265   -1.770199
# 128    0.264159
# 96    -0.257880
# 328   -0.898768
# 268    0.087408
# 296    0.344546
# 412   -1.026613
# 397   -0.707417
# 181   -0.888542
# 326   -0.757603
# 290   -1.004417
# 4      1.627087
# dtype: float64
#   Angle2_row: Series:
# 288    0.952096
# 245   -0.623932
# 403    0.872943
# 266   -1.012475
# 283   -0.530487
# 370   -0.227280
# 221    1.327898
# 173    0.948409
# 238   -1.358755
# 239    0.414464
# 11    -0.403713
# 482    1.232451
# 168    0.271604
# 265    0.081763
# 128   -0.505815
# 96     1.159670
# 328    0.359394
# 268    1.540615
# 296    0.288714
# 412    0.397679
# 397   -0.008837
# 181    0.126628
# 326    0.536113
# 290   -1.854167
# 4     -0.824435
# dtype: float64
# --------------------
#
# Best Assignment for BS 3:
#  UAV Index: 2
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 47871.7378
#   P_m_down_value: 0.8463
#   P_m_har_value: 0.4040
#   T_m_har_value: 3.1374
#   f_km_value: 2.9525
#   T_km_up_value: 0.5795
#   V_lm_vfly_value: 59.4350
#   V_lm_hfly_value: 60.9446
#   P_km_up_value: 7.7273
#   Angle1_row: Series:
# 357   -0.499580
# 469   -1.550081
# 286   -0.217497
# 454    0.504006
# 148    0.996810
# 153   -1.644894
# 347   -0.007423
# 159    0.465730
# 303    0.370070
# 267    1.059542
# 149    1.236067
# 8      0.294261
# 13    -0.305561
# 128    0.187097
# 171   -0.848095
# 217   -0.180593
# 254    0.650098
# 115   -0.541975
# 354   -0.652078
# 96     1.496320
# 419   -0.783394
# 144   -1.397469
# 25    -0.594381
# 201    0.095865
# 351   -0.299749
# dtype: float64
#   Angle_row: Series:
# 357   -0.152119
# 469    1.576856
# 286   -0.314270
# 454    0.413003
# 148   -0.494679
# 153   -0.241761
# 347   -0.554179
# 159   -0.186278
# 303    0.624906
# 267   -0.912701
# 149    0.947214
# 8      1.060505
# 13     0.554621
# 128    1.326373
# 171    0.148973
# 217   -0.567411
# 254    1.622513
# 115   -1.652908
# 354    0.573199
# 96    -0.131192
# 419   -0.471638
# 144    0.766175
# 25    -0.574127
# 201   -1.001037
# 351   -0.536099
# dtype: float64
#   Angle2_row: Series:
# 357   -1.391650
# 469   -0.270119
# 286    0.705464
# 454   -1.996337
# 148    1.458544
# 153    1.435774
# 347    0.734354
# 159    0.209479
# 303   -1.148308
# 267    0.440619
# 149    0.112294
# 8      1.125006
# 13     0.138291
# 128    0.499504
# 171   -1.365478
# 217    0.932570
# 254    0.561654
# 115    0.217160
# 354    0.232221
# 96    -2.233092
# 419   -1.620306
# 144   -0.415963
# 25     0.606540
# 201   -0.045160
# 351   -0.230395
# dtype: float64
# --------------------
#
# Best Assignment for BS 0:
#  UAV Index: 7
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 59708.4846
#   P_m_down_value: 0.1974
#   P_m_har_value: 0.1353
#   T_m_har_value: 0.3937
#   f_km_value: 0.8711
#   T_km_up_value: 0.4609
#   V_lm_vfly_value: 22.4843
#   V_lm_hfly_value: 55.0057
#   P_km_up_value: 9.8218
#   Angle1_row: Series:
# 158    119.110198
# 53      40.908484
# 384     56.097026
# 396     75.421339
# 462    143.383482
# 441     66.802301
# 232    165.365174
# 481    104.643274
# 279     88.153377
# 128    172.103837
# 155    119.753058
# 11     169.973372
# 292      3.995536
# 413    139.584268
# 1        9.309730
# 145    134.424228
# 92     150.118020
# 387      9.731052
# 236     39.475330
# 76      66.495361
# 44      38.287150
# 71     175.168766
# 37     154.718936
# 465    119.022171
# 427    160.674162
# Name: 24, dtype: float64
#   Angle_row: Series:
# 158    170.852420
# 53     109.974180
# 384     43.235198
# 396    156.660819
# 462    130.404836
# 441     39.447223
# 232     12.325822
# 481     35.374226
# 279    161.539972
# 128     60.676697
# 155     81.226942
# 11      61.191559
# 292    149.198570
# 413      2.498868
# 1      158.611137
# 145     63.707229
# 92     155.802285
# 387     99.939146
# 236     37.754771
# 76     174.450701
# 44     133.057697
# 71     150.950006
# 37      57.318686
# 465    114.803659
# 427    144.689211
# Name: 24, dtype: float64
#   Angle2_row: Series:
# 158     70.118200
# 53     126.967073
# 384      8.909076
# 396     82.526512
# 462    168.955618
# 441    152.592593
# 232    101.931093
# 481    157.305712
# 279     43.963145
# 128    101.405829
# 155    111.052727
# 11     159.667996
# 292    148.237345
# 413     59.154602
# 1       82.337315
# 145      8.754008
# 92      14.971732
# 387     56.011161
# 236    122.130137
# 76      21.953471
# 44      94.559465
# 71     127.660309
# 37     139.416961
# 465    117.706699
# 427    136.369396
# Name: 24, dtype: float64
# --------------------
#
# --- UAVs without Assigned Base Stations ---
#   UAV 0 : No BS is assigned
# --------------------
#   UAV 4 : No BS is assigned
# --------------------
#   UAV 6 : No BS is assigned
# --------------------

# %%
# Plotting graph for Sum of Fitness vs num_irs_ele
irs_element_values =np.arange(1, 11, 1)
plt.figure(figsize=(10, 6))
plt.rcParams["font.size"] = "20"
plt.plot(irs_element_values, fitness_sums_GA, marker='o', linestyle='-')
plt.xlabel('Power',size=22)
plt.ylabel('Energy',size=22)
plt.title('Energy vs Power')
plt.xticks(irs_element_values)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 7))
T_m_range = np.arange(1, 11, 1)

plt.rcParams["font.size"] = "20"
plt.plot(T_m_range, fitness_sums_HC, label = "HC-A")
plt.plot(T_m_range, fitness_sums_GA, label = "C2GA")
plt.xlabel('Power',size=20)
plt.ylabel('Energy',size=22)
plt.legend()
plt.savefig("Energy vs Power.pdf", format="pdf", bbox_inches="tight", dpi=800)
plt.show()

# %%
percentage_improvements = []
better_algorithm_counts = {'HC-A': 0, 'C2GA': 0, 'Tie': 0}
average_percentage_improvement_HC_A = 0
average_percentage_improvement_C2GA = 0

print("\n--- Algorithm Comparison ---")
for i in range(len(T_m_range)):
    hc_a_fitness = fitness_sums_HC[i]
    c2ga_fitness = fitness_sums_GA[i]
    data_size = T_m_range[i]

    if hc_a_fitness < c2ga_fitness:
        better_fitness = hc_a_fitness
        worse_fitness = c2ga_fitness
        better_algorithm = "HC-A"
        worse_algorithm = "C2GA"
        better_algorithm_counts['HC-A'] += 1
    elif c2ga_fitness < hc_a_fitness:
        better_fitness = c2ga_fitness
        worse_fitness = hc_a_fitness
        better_algorithm = "C2GA"
        worse_algorithm = "HC-A"
        better_algorithm_counts['C2GA'] += 1
    else:
        better_algorithm = "Tie"
        better_algorithm_counts['Tie'] += 1
        percentage_improvement = 0 # No improvement if it's a tie
        percentage_improvements.append(percentage_improvement) # Append 0 for tie
        print(f"Data size {data_size:.1f}: Tie in Energy ({hc_a_fitness:.2f} vs {c2ga_fitness:.2f}) - 0.00% Improvement")
        continue # Skip percentage calculation for tie

    percentage_improvement = ((worse_fitness - better_fitness) / worse_fitness) * 100
    percentage_improvements.append(percentage_improvement)

    print(f"Data size {data_size:.1f}: {better_algorithm} is better by {percentage_improvement:.2f}% (Energy: {better_fitness:.2f} vs {worse_fitness:.2f})")


# Calculate average percentage improvement for cases where HC-A is better
hc_a_improvements = [p for i, p in enumerate(percentage_improvements) if fitness_sums_HC[i] < fitness_sums_GA[i]]
if hc_a_improvements:
    average_percentage_improvement_HC_A = np.mean(hc_a_improvements)

# Calculate average percentage improvement for cases where C2GA is better
c2ga_improvements = [p for i, p in enumerate(percentage_improvements) if fitness_sums_GA[i] < fitness_sums_HC[i]]
if c2ga_improvements:
    average_percentage_improvement_C2GA = np.mean(c2ga_improvements)


print("\n--- Summary ---")
print("Algorithm Performance Comparison:")
print(f"  HC-A was better in {better_algorithm_counts['HC-A']} out of {len(T_m_range)} cases.")
print(f"  C2GA was better in {better_algorithm_counts['C2GA']} out of {len(T_m_range)} cases.")
print(f"  Tie in {better_algorithm_counts['Tie']} out of {len(T_m_range)} cases.")

if better_algorithm_counts['HC-A'] > better_algorithm_counts['C2GA']:
    if hc_a_improvements:
        print(f"\nOverall, HC-A (Hill Climbing) is generally better.")
        print(f"On average, when HC-A is better, it reduces energy consumption by approximately {average_percentage_improvement_HC_A:.2f}%.")

elif better_algorithm_counts['C2GA'] > better_algorithm_counts['HC-A']:
    if c2ga_improvements:
        print(f"\nOverall, C2GA (Genetic Algorithm) is generally better.")
        print(f"On average, when C2GA is better, it reduces energy consumption by approximately {average_percentage_improvement_C2GA:.2f}%.")
else:
    print("\nOverall, both algorithms perform similarly on average based on the number of better cases.")
# Out:
# --- Algorithm Comparison ---
# Data size 1.0: C2GA is better by 58.65% (Energy: 261343.61 vs 632078.02)
# Data size 2.0: C2GA is better by 31.18% (Energy: 250984.21 vs 364715.72)
# Data size 3.0: C2GA is better by 54.09% (Energy: 251344.93 vs 547499.42)
# Data size 4.0: C2GA is better by 49.57% (Energy: 254909.39 vs 505504.75)
# Data size 5.0: C2GA is better by 41.82% (Energy: 255032.61 vs 438348.46)
# Data size 6.0: C2GA is better by 38.34% (Energy: 255053.44 vs 413648.31)
# Data size 7.0: C2GA is better by 72.92% (Energy: 252358.72 vs 931990.96)
# Data size 8.0: C2GA is better by 28.40% (Energy: 255214.44 vs 356453.38)
# Data size 9.0: C2GA is better by 7.36% (Energy: 252067.25 vs 272082.52)
# Data size 10.0: C2GA is better by 14.72% (Energy: 248135.05 vs 290967.24)
#
# --- Summary ---
# Algorithm Performance Comparison:
#   HC-A was better in 0 out of 10 cases.
#   C2GA was better in 10 out of 10 cases.
#   Tie in 0 out of 10 cases.
#
# Overall, C2GA (Genetic Algorithm) is generally better.
# On average, when C2GA is better, it reduces energy consumption by approximately 39.71%.
