# %%
import pandas as pd
import numpy as np
import random
import math
from numpy import random
import cmath
import matplotlib.pyplot as plt

# %%
# Load datasets related to Base Stations, UAVs, and Clients
base = pd.read_csv(r'BS_data.csv')
uav = pd.read_csv(r'UAV_data.csv')
people = pd.read_csv(r'people_data.csv')
IRS=pd.read_csv(r'IRS_data.csv')
p_km_UP=pd.read_csv(r'P_km_up.csv')

Angle_df=pd.read_csv(r'Angle.csv') # number of IRS is 500 store in each column
h_l_km_df=pd.read_csv(r'h_l_km.csv') # number of IRS is 500 store in each column
h_l_m_df=pd.read_csv(r'h_l_m.csv') # number of IRS is 500 store in each column

Angle_UP_df=pd.read_csv(r'Angle1.csv') # number of IRS is 500 store in each column
g_l_km_df=pd.read_csv(r'h_l_km1.csv') # number of IRS is 500 store in each column
g_l_m_df=pd.read_csv(r'h_l_m1.csv') # number of IRS is 500 store in each column # corrected filename

Angle_har_df=pd.read_csv(r'Angle2.csv') # number of IRS is 500 store in each column
f_l_km_df=pd.read_csv(r'h_l_km2.csv') # number of IRS is 500 store in each column
f_l_m_df=pd.read_csv(r'h_l_m2.csv') # number of IRS is 500 store in each column # corrected filename
f_km1=pd.read_csv(r'f_km.csv')

# %%
# Constants
Wl = 35.28
H_value= 20
P_m_har = base['P_m_har']
T_m_har = base['T_m_har']
P_m_down = base['P_m_down']
f_km=f_km1['0']
V_lm_vfly = uav['V_lm_vfly']
V_lm_hfly = uav['V_lm_hfly']
D_l_hfly = 100

P_km_up=p_km_UP['0']
p_max=10 # moved inside loop
p_km_max=10
T_m=10
D_m_current=0.49


# Additional constants for calculations
delta = 2
Ar = 0.1256
s = 0.05
Nr = 4
V_tip = 102
Cd = 0.022
Af = 0.2113
D_km = 0.5
# Dm=0.49
B=10 #MHz
sigma_km=10**(-13)
eta=10
kappa=0.5
num_population=50
Bh = (1 - 2.2558 * pow(10, -5) *H_value)**4.2577
# Bh = max(1, Bh)
p_l_b = (delta / 8) * Bh * Ar * s * pow(V_tip, 3)

# %%
# Determine the maximum possible rows based on the smallest dataframe size
min_rows = min(len(Angle_df), len(h_l_km_df), len(h_l_m_df), len(Angle_UP_df), len(g_l_km_df), len(g_l_m_df), len(Angle_har_df), len(f_l_km_df), len(f_l_m_df), len(f_km1))
num_rows_data_files = min_rows # Dynamically set num_rows_data_files based on the smallest dataframe length
population_size = min(25, num_rows_data_files) # Ensure population_size is not larger than available data

# %%
# Fitness function to calculate total energy consumption
def Fitness(E_ml_har, E_ml_down, E_ml_UAV):
    return E_ml_har + E_ml_down + E_ml_UAV

# Energy consumption of the UAV-IRS
def E_ml_UAV(P_l_vfly, T_l_vfly, P_lm_hfly, T_l_hfly, P_l_hov, T_lm_hov):
    return P_l_vfly * T_l_vfly + P_lm_hfly * T_l_hfly + P_l_hov * T_lm_hov

# Power calculations for different flight modes
def P_l_vfly(Wl, V_l_vfly, P_l_b, Nr, Ar, Bh):
    temp2 = Nr * Bh * Ar
    temp3 = np.sqrt(V_l_vfly**2 + (2 * Wl) / temp2)
    return ((Wl / 2) * (V_l_vfly + temp3)) + Nr * P_l_b

def P_lm_hfly(P_lm_blade, P_lm_fuselage, P_lm_induced):
    return P_lm_blade + P_lm_fuselage + P_lm_induced

def P_lm_blade(Nr, P_l_b, V_tip, V_lm_hfly):
    return Nr * P_l_b * (1 + ((3 * (V_lm_hfly**2)) / pow(V_tip, 2)))

def P_lm_fuselage(Cd, Af, Bh, V_lm_hfly):
    return (1 / 2) * Cd * Af * Bh * (V_lm_hfly**3)

def P_lm_induced(Nr, Bh, Ar, Wl, V_lm_hfly):
    return Wl * ((np.sqrt((Wl**2) / (4 * (Nr**2) * (Bh**2) * (Ar**2)) + ((V_lm_hfly**4) / 4)) - ((V_lm_hfly**2) / 2))**(1 / 2))

def P_l_hov(Wl, P_l_b, Nr, Ar, Bh):
    temp1 = Nr * P_l_b
    temp3 = np.sqrt(2 * (Nr * Bh * Ar))
    temp4 = ((Wl)**3 / 2) / temp3
    return temp1 + temp4

def T_lm_hov(T_km_com, T_kml_up, T_ml_down):
    return T_km_com + T_kml_up + T_ml_down

def R_ml_down(B,P_m_down,h_ml_worst): #eqation number 7
    temp1=(h_ml_worst*P_m_down) # Consider if min is the correct aggregation. It should be multiplication
    if (1+temp1) <= 0:
        return 0  # Return 0 if log argument is non-positive to avoid error
    return B*math.log2(1+temp1)

def h_ml_worst(h_kml_down,sigma_km): #eqation number 8
    return h_kml_down/(sigma_km) # it will return the sigal value which is minimum of all
            # the value for each itaration

def calculate_exp_i_theta(theta): # part of equation 8
  return cmath.exp(1j * theta)
 # 1j represents the imaginary unit in Python

def h_kml_down(Angle,h_l_m,h_l_km, num_irs_ele): # Modified: Added num_irs_ele argument
    result=[]
    if isinstance(Angle, float):
        return 0

    if not isinstance(Angle, pd.Series):
        raise TypeError(f"Expected Angle to be pd.Series, got {type(Angle)}")

    # Slice Series to num_irs_ele inside the function
    Angle_sliced = Angle.iloc[:num_irs_ele]
    h_l_m_sliced = h_l_m.iloc[:num_irs_ele]
    h_l_km_sliced = h_l_km.iloc[:num_irs_ele]

    for i in range(len(Angle_sliced)): # Iterate over the sliced Angle
        theta_radians = math.radians(Angle_sliced.iloc[i])
        results= calculate_exp_i_theta(theta_radians)
        result.append(results)

    diagonal=np.diag(result)
    h_l_m_np = h_l_m_sliced.to_numpy() # Convert sliced Series to numpy array
    h_l_km_np = h_l_km_sliced.to_numpy() # Convert sliced Series to numpy array
    if h_l_m_np.ndim == 1:
        h_l_m_np = h_l_m_np.reshape(1, -1)
    if h_l_km_np.ndim == 1:
        h_l_km_np = h_l_km_np.reshape(-1, 1)


    a=np.dot(h_l_m_np,diagonal)
    b=np.dot(a,h_l_km_np)
    final=abs(b[0][0])
    return (final**2)

def R_kml_up(B,P_km_up,h_kml_up,Sub,sigma_m): #eqation number 4
    temp1=(P_km_up*h_kml_up)/ (Sub+(sigma_m))
    return B*math.log2(1+temp1)
#this is inside the equation 4 have to take summation of h_i_up and P_i_up
def sub(P_i_up,h_il_up):
    return P_i_up*h_il_up

def E_km_com(f_km,T_km_com):
    return eta*(10**(-28))*(f_km**3)*T_km_com

def E_kml_up(P_km_up,T_km_up):
    return P_km_up*T_km_up

def E_kml_har(P_m_har,T_m_har,h_km_har):
    return kappa*P_m_har*T_m_har*h_km_har

# %%
num_population=25
num_bs = 5
num_generation = 1
num_uav_irs = 8
population_size = 25

numerical_keys_for_crossover = [
    'P_m_down_value', 'P_m_har_value', 'T_m_har_value',
    'f_km_value', 'V_lm_vfly_value', 'V_lm_hfly_value',
    'P_km_up_value','f_km_value',
]

fitness_sums_GA = [] # Store sum of fitness values for each num_irs_ele
irs_element_values = range(10, 51, 5) # num_irs_ele values from 10 to 50 in steps of 5


for num_irs_ele in irs_element_values: # Loop through different num_irs_ele values
    print(f"Calculation for num_irs_ele: {num_irs_ele}")

    Angle_df=pd.read_csv(r'Angle.csv') # number of IRS is 500 store in each column
    h_l_km_df=pd.read_csv(r'h_l_km.csv') # number of IRS is 500 store in each column
    h_l_m_df=pd.read_csv(r'h_l_m.csv') # number of IRS is 500 store in each column

    Angle_UP_df=pd.read_csv(r'Angle1.csv') # number of IRS is 500 store in each column
    g_l_km_df=pd.read_csv(r'h_l_km1.csv') # number of IRS is 500 store in each column
    g_l_m_df=pd.read_csv(r'h_l_m1.csv') # number of IRS is 500 store in each column # corrected filename

    Angle_har_df=pd.read_csv(r'Angle2.csv') # number of IRS is 500 store in each column
    f_l_km_df=pd.read_csv(r'h_l_km2.csv') # number of IRS is 500 store in each column
    f_l_m_df=pd.read_csv(r'h_l_m2.csv') # number of IRS is 500 store in each column # corrected filename


    all_best_combinations = []
    all_best_individuals = []

    for l in range(num_bs):
        all_best_individuals_bs = []
        P_m_har_value = P_m_har.values[l]
        T_m_har_value = T_m_har.values[l]
        P_m_down_value = P_m_down.values[l]


        index_list = list(range(500))
        random.shuffle(index_list)
        unique_row_indices = index_list[:population_size]

        h_l_km_df_bs = h_l_km_df.iloc[unique_row_indices, :num_irs_ele].reset_index(drop=True) # Sliced columns
        g_l_km_df_bs = g_l_km_df.iloc[unique_row_indices, :num_irs_ele].reset_index(drop=True) # Sliced columns
        f_l_km_df_bs = f_l_km_df.iloc[unique_row_indices, :num_irs_ele].reset_index(drop=True) # Sliced columns
        f_km_bs = f_km[unique_row_indices].reset_index(drop=True)
        valid_indices = [i for i in unique_row_indices if i < len(P_km_up)]
        P_km_up_bs = P_km_up.iloc[valid_indices].reset_index(drop=True)


        for k in range(num_uav_irs):
            best_fitness = float('inf')
            best_individual = {}
            population = []
            V_lm_vfly_value = V_lm_vfly.values[k]
            V_lm_hfly_value = V_lm_hfly.values[k]
            D_l_hfly_value = D_l_hfly
            Wl_value = Wl
            Sub_value=0

            for i in range(len(valid_indices)):
                # Slice the Angle_UP_df, g_l_m_df, g_l_km_df_bs to num_irs_ele columns
                Angle_UP_df_sliced = Angle_UP_df.iloc[i, :num_irs_ele]
                g_l_m_df_sliced = g_l_m_df.iloc[k, :num_irs_ele]
                g_l_km_df_bs_sliced = g_l_km_df_bs.iloc[i, :num_irs_ele]

                h_il_up_value=h_kml_down(Angle_UP_df_sliced, g_l_m_df_sliced, g_l_km_df_bs_sliced, num_irs_ele) # Pass num_irs_ele
                Sub_value+=sub(P_km_up_bs[i],h_il_up_value)


            for i in range(population_size):
                f_km_value = f_km_bs[i]
                P_km_up_value = P_km_up_bs[i]

                # Slice the Angle_df, h_l_m_df, h_l_km_df_bs, Angle_har_df, f_l_m_df, f_l_km_df_bs to num_irs_ele columns
                Angle_row = Angle_df.iloc[i, :num_irs_ele]
                h_l_m_row = h_l_m_df.iloc[k, :num_irs_ele]
                h_l_km_row = h_l_km_df_bs.iloc[i, :num_irs_ele]
                Angle1_row = Angle_UP_df.iloc[i, :num_irs_ele] # using sliced version not needed again
                g_l_m_row = g_l_m_df.iloc[k, :num_irs_ele]  # using sliced version not needed again
                g_l_km_row = g_l_km_df_bs.iloc[i, :num_irs_ele] # using sliced version not needed again
                Angle2_row = Angle_har_df.iloc[i, :num_irs_ele]
                f_l_m_row = f_l_m_df.iloc[k, :num_irs_ele]
                f_l_km_row = f_l_km_df_bs.iloc[i, :num_irs_ele]


                P_lm_blade_value = P_lm_blade(Nr, p_l_b, V_tip, V_lm_hfly_value)
                P_lm_fuselage_value = P_lm_fuselage(Cd, Af, Bh, V_lm_hfly_value)
                P_lm_induced_value = P_lm_induced(Nr, Bh, Ar, Wl_value, V_lm_vfly_value)

                T_l_vfly_value = H_value / V_lm_vfly_value
                T_l_hfly_value = D_l_hfly_value / V_lm_hfly_value
                E_ml_har_value = P_m_har_value * T_m_har_value
                h_kml_down_value=h_kml_down(Angle_row,h_l_m_row,h_l_km_row, num_irs_ele) # Pass num_irs_ele
                h_ml_worst_value=h_ml_worst(h_kml_down_value,sigma_km)
                R_ml_down_value=R_ml_down(B,P_m_down_value,h_ml_worst_value)
                T_ml_down_value=D_m_current/R_ml_down_value # using global Dm
                E_ml_down_value = P_m_down_value * T_ml_down_value
                T_km_com_value = D_km / f_km_value
                h_kml_up_value=h_kml_down(Angle1_row,g_l_m_row,g_l_km_row, num_irs_ele) # Pass num_irs_ele

                R_kml_up_value=R_kml_up(B,P_km_up_value,h_kml_up_value,Sub_value,sigma_km)
                T_km_up_value=D_m_current/R_kml_up_value # using global Dm
                T_lm_hov_value = T_lm_hov(T_km_com_value, T_km_up_value, T_ml_down_value)
                P_l_hov_value = P_l_hov(Wl_value, p_l_b, Nr, Ar, Bh)
                P_l_vfly_value = P_l_vfly(Wl_value, V_lm_vfly_value, p_l_b, Nr, Ar, Bh)
                P_lm_hfly_value = P_lm_hfly(P_lm_blade_value, P_lm_fuselage_value, P_lm_induced_value)
                E_ml_UAV_value = E_ml_UAV(P_l_vfly_value, T_l_vfly_value, P_lm_hfly_value, T_l_hfly_value, P_l_hov_value, T_lm_hov_value)

                result_fitness = Fitness(E_ml_har_value, E_ml_down_value, E_ml_UAV_value)

                population.append({
                    'fitness': result_fitness,
                    'data':  {
                        'P_m_down_value': P_m_down_value,
                        'P_m_har_value': P_m_har_value,
                        'T_m_har_value': T_m_har_value,
                        'f_km_value': f_km_value,
                        'T_km_up_value': T_km_up_value,
                        'V_lm_vfly_value': V_lm_vfly_value,
                        'V_lm_hfly_value': V_lm_hfly_value,
                        'P_km_up_value':P_km_up_value,
                        'Angle1_row':Angle1_row,
                        'Angle_row':Angle_row,
                        'Angle2_row': Angle2_row,
                        }
                    })

            generations_data = []
            for j in range(num_generation):
                child_population = []
                                    # Corrected loop range to use valid_indices length
                for i in range(0, len(valid_indices), 2): # Loop through population with step of 2
                    if i + 1 >= len(valid_indices): # Check if i+1 is within bounds, if not break to avoid error in accessing population[i+1]
                        break
                    ranodmpopulation=[]
                    for i in range(10):
                        ranodmpopulation.append(random.choice(population))
                    ranodmpopulation = sorted(ranodmpopulation, key=lambda x: x['fitness'])
                    parent1 = ranodmpopulation[0]
                    parent2 = ranodmpopulation[1]
                    child_data = {}
                    for key in parent1['data']:
                        if key in numerical_keys_for_crossover:
                            if key in ['Angle1_row','Angle_row','Angle2_row']: # Handle Angle Series
                                child_data[key] = pd.Series(index=Angle_df.columns, dtype='float64') # Initialize empty Series for child
                                for col in Angle_df.columns: # Iterate through each column (angle direction)
                                    child_data[key][col] = float(parent1['data'][key][col]) * 0.6 + float(parent2['data'][key][col]) * (1 - 0.6)
                            else: # Handle other numerical values as before
                                child_data[key] = float(parent1['data'][key]) * 0.6 + float(parent2['data'][key]) * (1 - 0.6)
                        else:
                            child_data[key] = parent1['data'][key] # Corrected line: Direct copy for non-numerical keys

                    # Mutation
                    u = np.random.uniform(0, 1, 1)[0]
                    P_mutation = 0.5
                    if u < P_mutation:
                        for key in numerical_keys_for_crossover: # Apply mutation only to numerical keys
                            if key in ['Angle1_row','Angle_row','Angle2_row']: # Handle Angle Series
                                child_data[key] = pd.Series(index=Angle_df.columns, dtype='float64') # Initialize empty Series for child
                                for col in Angle_df.columns: # Iterate through each column (angle direction)
                                    child_data[key][col] = random.normal(loc=0, scale=1, size=(1))[0]
                            else:
                                child_data[key] += random.normal(loc=0, scale=1, size=(1))[0] # Reduced scale for smaller perturbations in HC



                def compute_fitness(data):
                    P_m_down_value = data['P_m_down_value']
                    P_m_har_value = data['P_m_har_value']
                    T_m_har_value = data['T_m_har_value']
                    f_km_value = data['f_km_value']
                    T_km_up_value = data['T_km_up_value']
                    V_lm_vfly_value = data['V_lm_vfly_value']
                    V_lm_hfly_value = data['V_lm_hfly_value']
                    P_km_up_value=data['P_km_up_value']
                    Angle_row = data['Angle_row']
                    Angle1_row = data['Angle1_row']
                    Angle2_row = data['Angle2_row']




                    P_lm_blade_value = P_lm_blade(Nr, p_l_b, V_tip, V_lm_hfly_value)
                    P_lm_fuselage_value = P_lm_fuselage(Cd, Af, Bh, V_lm_hfly_value)
                    P_lm_induced_value = P_lm_induced(Nr, Bh, Ar, Wl_value, V_lm_vfly_value)

                    T_l_vfly_value = H_value / V_lm_vfly_value
                    T_l_hfly_value = D_l_hfly_value / V_lm_hfly_value
                    E_ml_har_value = P_m_har_value * T_m_har_value

                    h_kml_down_value_compute=h_kml_down(Angle_row,h_l_m_row,h_l_km_row, num_irs_ele) # Pass num_irs_ele
                    h_ml_worst_value=h_ml_worst(h_kml_down_value_compute,sigma_km)
                    R_ml_down_value=R_ml_down(B,P_m_down_value,h_ml_worst_value)
                    if R_ml_down_value <= 0:
                        R_ml_down_value = 1e-9
                    T_ml_down_value=D_m_current/R_ml_down_value # using global Dm
                    E_ml_down_value = P_m_down_value * T_ml_down_value
                    T_km_com_value = D_km / f_km_value
                    T_lm_hov_value = T_lm_hov(T_km_com_value, T_km_up_value, T_ml_down_value)
                    P_l_hov_value = P_l_hov(Wl_value, p_l_b, Nr, Ar, Bh)
                    P_l_vfly_value = P_l_vfly(Wl_value, V_lm_vfly_value, p_l_b, Nr, Ar, Bh)
                    P_lm_hfly_value = P_lm_hfly(P_lm_blade_value, P_lm_fuselage_value, P_lm_induced_value)
                    E_ml_UAV_value = E_ml_UAV(P_l_vfly_value, T_l_vfly_value, P_lm_hfly_value, T_l_hfly_value, P_l_hov_value, T_lm_hov_value)
                    h_kml_har_value_compute=h_kml_down(Angle2_row,f_l_m_row,f_l_km_row, num_irs_ele) # Pass num_irs_ele
                    E_kml_har_value=E_kml_har(P_m_har_value,T_m_har_value,h_kml_har_value_compute) # Corrected: removed h_kml_har
                    E_kml_com_value = E_km_com(f_km_value, T_km_com_value)
                    E_kml_up_value=E_kml_up(P_km_up_value,T_km_up_value)

                    fitness_value = Fitness(E_ml_har_value, E_ml_down_value, E_ml_UAV_value)
                    current_data = {
                            'P_m_down_value': P_m_down_value,
                            'P_m_har_value': P_m_har_value,
                            'T_m_har_value': T_m_har_value,
                            'f_km_value': f_km_value,
                            'T_km_up_value': T_km_up_value,
                            'V_lm_vfly_value': V_lm_vfly_value,
                            'V_lm_hfly_value': V_lm_hfly_value,
                            'P_km_up_value':P_km_up_value,
                            'Angle1_row':Angle1_row,
                            'Angle_row':Angle_row,
                            'Angle2_row': Angle2_row,
                                                }
                    if V_lm_hfly_value>0 and T_m_har_value>0 and T_ml_down_value>0 and T_km_up_value>0 and P_m_har_value<=p_max and P_m_down_value<=p_max and P_km_up_value<=p_km_max and (T_km_com_value+T_km_up_value+T_ml_down_value)<=T_m and f_km_value>0  and E_kml_har_value>=(E_kml_up_value+E_kml_com_value) and V_lm_vfly_value>0:
                        return fitness_value, current_data
                    else:
                        return  float('inf'),{}

                child_fitness, child_data1 = compute_fitness(child_data)
                child_population.append({'fitness': child_fitness, 'data': child_data1})
            # Create new population
                new_population = population + child_population
                new_population = sorted(new_population, key=lambda x: x['fitness'])
                population = new_population[:population_size]
                generations_data.append(population[0].copy())
                # print(population[0])

            best_individual_pair = population[0].copy()
            best_individual_pair['generation'] = j + 1 # Use last j from loop, corrected index
            best_individual_pair['type'] = 'GA'
            best_individual_pair['bs_index'] = l
            best_individual_pair['uav_index'] = k
            all_best_individuals_bs.append(best_individual_pair)

            all_best_combinations.append({
                'bs_index': l,
                'uav_index': k,
                'best_fitness': population[0]['fitness'],
                'best_individual': best_individual_pair,
                'generation_fitness': [gen['fitness'] for gen in generations_data],
                'unique_row_indices': unique_row_indices # Store unique_row_indices in best_combinations
            })
            # print(f"Best Fitness for BS {l}, UAV {k}: {population[0]['fitness']:.4f}")

        # Find best individual for current BS across all UAVs
        best_individual_for_bs = min(all_best_individuals_bs, key=lambda x: x['fitness'])
        # print(f"Best Fitness for BS {l} across all UAVs: {best_individual_for_bs['fitness']:.4f}")


    # Select the best unique Base station and UAV-IRS pair using Auction based method
    combination_lookup = {}
    for combination in all_best_combinations:
        if combination['bs_index'] not in combination_lookup:
            combination_lookup[combination['bs_index']] = {}
        combination_lookup[combination['bs_index']][combination['uav_index']] = combination

    # Auction-based assignment
    best_assignments = []
    unassigned_bs = list(range(num_bs))
    unassigned_uavs = list(range(num_uav_irs))

    while unassigned_bs and unassigned_uavs:
        best_combination_overall = None

        for l in unassigned_bs:
            best_fitness_for_bs = float('inf')
            best_combination_for_bs = None
            for k in unassigned_uavs:
                if l in combination_lookup and k in combination_lookup[l]:
                    combination = combination_lookup[l][k]
                    if combination['best_fitness'] < best_fitness_for_bs: # Use 'best_fitness' instead of 'best_individual']['fitness']
                        best_fitness_for_bs = combination['best_fitness']
                        best_combination_for_bs = combination

            if best_combination_for_bs:
                if best_combination_overall is None or best_combination_for_bs['best_fitness'] < best_combination_overall['best_fitness']: # Compare with current best overall
                    best_combination_overall = best_combination_for_bs

        if best_combination_overall:
            best_assignments.append(best_combination_overall)
            unassigned_bs.remove(best_combination_overall['bs_index'])
            unassigned_uavs.remove(best_combination_overall['uav_index'])

    # Print and Plotting
    print(f"\n--- Best Unique UAV Assignments (Auction Based Method) ---")
    best_pair_for_plot = None
    min_fitness_for_plot = float('inf')

    sum_fitness_current_p_max = 0 # Sum of best fitness for current p_max
    for assignment in best_assignments:
        print(f"\nBest Assignment for BS {assignment['bs_index']}:")
        print(f" UAV Index: {assignment['uav_index']}")
        best_ind = assignment['best_individual']
        print(f" Best Individual:")
        print(f"  Generation: {best_ind['generation']}, Type: {best_ind['type']}")
        print(f"  Fitness: {best_ind['fitness']:.4f}") # Print current best fitness only
        unique_indices_to_print = assignment['unique_row_indices'] # Retrieve unique_row_indices
        for key, value in best_ind['data'].items():
            if isinstance(value, pd.Series):
                print(f"  {key}: Series: \n{value}") # Print the entire Series directly - corrected line
            elif isinstance(value, list): # Handle list type values explicitly
                print(f"  {key}: {value}") # print list directly without formatting
            else:
                print(f"  {key}: {value:.4f}") # Format scalar values

        print("-" * 20)
        sum_fitness_current_p_max += best_ind['fitness'] # Sum fitness values

        if assignment['best_individual']['fitness'] < min_fitness_for_plot:
            min_fitness_for_plot = assignment['best_individual']['fitness']
            best_pair_for_plot = assignment

    fitness_sums_GA.append(sum_fitness_current_p_max) # Store sum of fitness for this p_max

    # Unassigned BS/UAVs
    if unassigned_bs:
        print("\n--- Base Stations without Assigned UAVs ---")
        for bs_index in unassigned_bs:
            print(f"  BS {bs_index} : No UAV is assigned")
            print("-" * 20)

    if unassigned_uavs:
        print("\n--- UAVs without Assigned Base Stations ---")
        for uav_index in unassigned_uavs:
            print(f"  UAV {uav_index} : No BS is assigned")
            print("-" * 20)
# Out:
# Calculation for num_irs_ele: 10
#
# --- Best Unique UAV Assignments (Auction Based Method) ---
#
# Best Assignment for BS 4:
#  UAV Index: 0
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 49866.2367
#   P_m_down_value: 1.2065
#   P_m_har_value: 0.5795
#   T_m_har_value: 0.0959
#   f_km_value: 2.2806
#   T_km_up_value: 0.3218
#   V_lm_vfly_value: 18.8068
#   V_lm_hfly_value: 89.5535
#   P_km_up_value: 3.5929
#   Angle1_row: Series:
# 0     80.039371
# 1    145.196085
# 2    156.764960
# 3     26.653597
# 4    102.012866
# 5    165.394952
# 6    109.530622
# 7    146.757098
# 8     77.013072
# 9    108.171475
# Name: 23, dtype: float64
#   Angle_row: Series:
# 0    166.484430
# 1     83.525242
# 2    169.579609
# 3    143.718892
# 4     74.726273
# 5     68.995337
# 6    101.389850
# 7      0.466934
# 8    176.049865
# 9    164.723820
# Name: 23, dtype: float64
#   Angle2_row: Series:
# 0     49.012029
# 1     99.617798
# 2    136.027265
# 3     27.683858
# 4    107.101404
# 5    177.012042
# 6     61.186046
# 7     84.073280
# 8     55.828250
# 9     37.657146
# Name: 23, dtype: float64
# --------------------
#
# Best Assignment for BS 2:
#  UAV Index: 5
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 50491.3520
#   P_m_down_value: 2.0844
#   P_m_har_value: 1.6220
#   T_m_har_value: 1.5214
#   f_km_value: 2.1617
#   T_km_up_value: 0.5051
#   V_lm_vfly_value: 45.0354
#   V_lm_hfly_value: 36.0317
#   P_km_up_value: 3.7066
#   Angle1_row: Series:
# 0     80.371870
# 1    152.194257
# 2    129.891304
# 3     70.747545
# 4    109.839533
# 5     56.306498
# 6     74.573129
# 7     33.049486
# 8    117.666171
# 9      7.500662
# Name: 2, dtype: float64
#   Angle_row: Series:
# 0     44.066885
# 1    151.163399
# 2    126.017455
# 3     18.115815
# 4    115.091892
# 5     52.291003
# 6     28.397004
# 7     79.868805
# 8     63.964412
# 9     68.577862
# Name: 2, dtype: float64
#   Angle2_row: Series:
# 0     20.132903
# 1    161.144297
# 2     25.407528
# 3    126.392645
# 4    165.422661
# 5    134.967238
# 6    143.334333
# 7    132.516267
# 8     60.754601
# 9      3.982965
# Name: 2, dtype: float64
# --------------------
#
# Best Assignment for BS 1:
#  UAV Index: 3
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 51226.5593
#   P_m_down_value: 0.6128
#   P_m_har_value: 0.5173
#   T_m_har_value: 0.6195
#   f_km_value: 0.8836
#   T_km_up_value: 0.2970
#   V_lm_vfly_value: 66.6344
#   V_lm_hfly_value: 66.8574
#   P_km_up_value: 8.8982
#   Angle1_row: Series:
# 0     18.390139
# 1     61.627309
# 2    126.653788
# 3     74.783633
# 4    161.991019
# 5    146.039044
# 6     28.069266
# 7    148.153960
# 8     91.536583
# 9     37.557356
# Name: 19, dtype: float64
#   Angle_row: Series:
# 0    154.845348
# 1    152.044671
# 2     86.940033
# 3     60.982494
# 4    140.849726
# 5     18.242092
# 6     87.747517
# 7    101.633498
# 8    136.031833
# 9     51.149791
# Name: 19, dtype: float64
#   Angle2_row: Series:
# 0    139.920643
# 1    174.710003
# 2    112.588100
# 3     30.011653
# 4     20.037931
# 5      4.563747
# 6     34.385517
# 7    156.574488
# 8    161.893288
# 9     17.936693
# Name: 19, dtype: float64
# --------------------
#
# Best Assignment for BS 3:
#  UAV Index: 2
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 54562.6709
#   P_m_down_value: 0.9554
#   P_m_har_value: 0.4164
#   T_m_har_value: 0.7701
#   f_km_value: 0.8270
#   T_km_up_value: 0.3778
#   V_lm_vfly_value: 59.4068
#   V_lm_hfly_value: 61.2868
#   P_km_up_value: 6.8521
#   Angle1_row: Series:
# 0    113.082724
# 1    151.017922
# 2    142.115900
# 3     31.419633
# 4     69.984550
# 5     53.227830
# 6      9.495722
# 7    136.042088
# 8     22.702253
# 9     62.927526
# Name: 20, dtype: float64
#   Angle_row: Series:
# 0    172.416681
# 1     38.108032
# 2    148.593165
# 3     36.041038
# 4     82.411035
# 5     63.853155
# 6    160.342941
# 7    114.287309
# 8     73.635971
# 9    110.769000
# Name: 20, dtype: float64
#   Angle2_row: Series:
# 0    133.015726
# 1     21.119524
# 2    145.532469
# 3     58.688534
# 4      1.655359
# 5    158.256124
# 6     36.667315
# 7      1.257712
# 8    126.460620
# 9     16.706273
# Name: 20, dtype: float64
# --------------------
#
# Best Assignment for BS 0:
#  UAV Index: 1
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 59195.9210
#   P_m_down_value: 0.1974
#   P_m_har_value: 0.1353
#   T_m_har_value: 0.3937
#   f_km_value: 0.5679
#   T_km_up_value: 0.2729
#   V_lm_vfly_value: 72.6939
#   V_lm_hfly_value: 64.4919
#   P_km_up_value: 5.6402
#   Angle1_row: Series:
# 0     80.371870
# 1    152.194257
# 2    129.891304
# 3     70.747545
# 4    109.839533
# 5     56.306498
# 6     74.573129
# 7     33.049486
# 8    117.666171
# 9      7.500662
# Name: 2, dtype: float64
#   Angle_row: Series:
# 0     44.066885
# 1    151.163399
# 2    126.017455
# 3     18.115815
# 4    115.091892
# 5     52.291003
# 6     28.397004
# 7     79.868805
# 8     63.964412
# 9     68.577862
# Name: 2, dtype: float64
#   Angle2_row: Series:
# 0     20.132903
# 1    161.144297
# 2     25.407528
# 3    126.392645
# 4    165.422661
# 5    134.967238
# 6    143.334333
# 7    132.516267
# 8     60.754601
# 9      3.982965
# Name: 2, dtype: float64
# --------------------
#
# --- UAVs without Assigned Base Stations ---
#   UAV 4 : No BS is assigned
# --------------------
#   UAV 6 : No BS is assigned
# --------------------
#   UAV 7 : No BS is assigned
# --------------------
# Calculation for num_irs_ele: 15
#
# --- Best Unique UAV Assignments (Auction Based Method) ---
#
# Best Assignment for BS 1:
#  UAV Index: 3
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 44916.0414
#   P_m_down_value: 0.1945
#   P_m_har_value: 1.2848
#   T_m_har_value: 1.4241
#   f_km_value: 2.4671
#   T_km_up_value: 0.4371
#   V_lm_vfly_value: 66.6354
#   V_lm_hfly_value: 67.6836
#   P_km_up_value: 7.7487
#   Angle1_row: Series:
# 0      22.490127
# 1      32.901399
# 2      81.578507
# 3     128.024752
# 4      31.124195
# 5      21.833467
# 6      50.367883
# 7      43.776222
# 8      57.441629
# 9      36.618525
# 10    166.564115
# 11    107.138674
# 12      5.971314
# 13    102.935820
# 14     11.185135
# Name: 16, dtype: float64
#   Angle_row: Series:
# 0      63.875620
# 1     157.441232
# 2      71.446273
# 3     159.346617
# 4      94.060126
# 5      14.691808
# 6     113.341246
# 7     128.317380
# 8       5.693050
# 9      62.695650
# 10    136.114150
# 11    145.635478
# 12    151.039239
# 13     74.115101
# 14    177.182520
# Name: 16, dtype: float64
#   Angle2_row: Series:
# 0     176.438467
# 1     139.757659
# 2      61.070880
# 3     172.056799
# 4      55.318019
# 5       9.208988
# 6     113.637443
# 7      92.859830
# 8      88.463040
# 9     112.399533
# 10     45.184955
# 11     29.474469
# 12     42.751137
# 13    162.357144
# 14     94.623947
# Name: 16, dtype: float64
# --------------------
#
# Best Assignment for BS 3:
#  UAV Index: 1
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 45938.3127
#   P_m_down_value: 0.3114
#   P_m_har_value: 0.4448
#   T_m_har_value: 1.0229
#   f_km_value: 2.5320
#   T_km_up_value: 0.4900
#   V_lm_vfly_value: 74.5002
#   V_lm_hfly_value: 65.9914
#   P_km_up_value: 8.0911
#   Angle1_row: Series:
# 0     124.575126
# 1     129.801670
# 2      60.713401
# 3     168.601746
# 4      71.996327
# 5       6.432813
# 6     142.574824
# 7     151.068232
# 8     132.658310
# 9     174.996462
# 10     88.450347
# 11     61.937195
# 12     76.518895
# 13     48.715239
# 14    155.300122
# Name: 21, dtype: float64
#   Angle_row: Series:
# 0     140.085198
# 1     122.974584
# 2      20.282329
# 3     121.135034
# 4     115.929800
# 5       3.485440
# 6      93.726393
# 7      17.607077
# 8      96.700469
# 9     167.746994
# 10     77.108176
# 11     73.552104
# 12     27.300849
# 13    151.428191
# 14     90.937285
# Name: 21, dtype: float64
#   Angle2_row: Series:
# 0      74.261961
# 1     112.942214
# 2     151.644695
# 3      57.603027
# 4      51.448255
# 5     143.007300
# 6      52.331160
# 7     127.970795
# 8      80.571862
# 9      71.997810
# 10    133.562746
# 11     40.030711
# 12     63.860459
# 13    156.486732
# 14    109.195053
# Name: 21, dtype: float64
# --------------------
#
# Best Assignment for BS 0:
#  UAV Index: 5
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 47358.2635
#   P_m_down_value: 1.2113
#   P_m_har_value: 0.4494
#   T_m_har_value: 2.2142
#   f_km_value: 2.7393
#   T_km_up_value: 0.4449
#   V_lm_vfly_value: 45.4140
#   V_lm_hfly_value: 36.0004
#   P_km_up_value: 6.9061
#   Angle1_row: Series:
# 0     145.717281
# 1     124.791092
# 2      31.363671
# 3     151.941256
# 4     159.468062
# 5       5.379153
# 6      12.264056
# 7      64.762919
# 8     109.892032
# 9      94.464851
# 10     25.756253
# 11    169.687057
# 12     18.580392
# 13     36.939369
# 14     29.466159
# Name: 3, dtype: float64
#   Angle_row: Series:
# 0      26.488363
# 1     143.865084
# 2       4.853058
# 3     131.492548
# 4     129.607475
# 5     134.003439
# 6     153.728728
# 7     166.786411
# 8     160.227633
# 9      48.900436
# 10     14.988147
# 11     57.796022
# 12    148.620031
# 13    137.071158
# 14    173.471828
# Name: 3, dtype: float64
#   Angle2_row: Series:
# 0       4.585177
# 1      56.428883
# 2       5.821653
# 3     138.500714
# 4     126.377660
# 5     140.029944
# 6     146.085404
# 7     179.733377
# 8     100.863674
# 9     141.858262
# 10    161.018889
# 11     60.813385
# 12    114.558490
# 13    160.985671
# 14     63.337082
# Name: 3, dtype: float64
# --------------------
#
# Best Assignment for BS 4:
#  UAV Index: 2
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 54871.2320
#   P_m_down_value: 0.5754
#   P_m_har_value: 0.8595
#   T_m_har_value: 0.3629
#   f_km_value: 0.7072
#   T_km_up_value: 0.2862
#   V_lm_vfly_value: 59.4068
#   V_lm_hfly_value: 61.2868
#   P_km_up_value: 9.1773
#   Angle1_row: Series:
# 0       9.718200
# 1     166.332615
# 2     141.113217
# 3     151.388791
# 4      54.837360
# 5     104.195971
# 6      71.297319
# 7      92.815033
# 8     139.034341
# 9     156.345706
# 10     58.865258
# 11    123.285790
# 12    170.270228
# 13     61.165396
# 14     40.235002
# Name: 13, dtype: float64
#   Angle_row: Series:
# 0     124.487003
# 1      13.957565
# 2     171.049873
# 3     143.360909
# 4      22.602544
# 5     132.068929
# 6       1.261341
# 7     165.534018
# 8     154.765610
# 9     150.938196
# 10     19.596072
# 11     12.157789
# 12    118.530190
# 13     69.844550
# 14    118.208351
# Name: 13, dtype: float64
#   Angle2_row: Series:
# 0     151.993182
# 1     149.324078
# 2     139.140159
# 3     158.752199
# 4     113.697749
# 5      19.239400
# 6      72.224288
# 7     154.482516
# 8      95.943569
# 9      50.207436
# 10     11.953457
# 11     57.541914
# 12    148.809188
# 13     46.511576
# 14    130.847720
# Name: 13, dtype: float64
# --------------------
#
# Best Assignment for BS 2:
#  UAV Index: 0
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 61490.6494
#   P_m_down_value: 0.9092
#   P_m_har_value: 0.7848
#   T_m_har_value: 0.4714
#   f_km_value: 0.7248
#   T_km_up_value: 0.2814
#   V_lm_vfly_value: 20.2764
#   V_lm_hfly_value: 88.5908
#   P_km_up_value: 8.7852
#   Angle1_row: Series:
# 0      76.267654
# 1      81.422305
# 2     132.241222
# 3      69.129860
# 4      28.089600
# 5     136.664021
# 6     123.939352
# 7      27.333332
# 8      16.734789
# 9      11.823278
# 10    108.293631
# 11     56.643737
# 12     52.921650
# 13    118.873387
# 14     53.579715
# Name: 11, dtype: float64
#   Angle_row: Series:
# 0      71.093420
# 1     117.176311
# 2     177.369062
# 3      87.190656
# 4      57.333286
# 5      68.620816
# 6     106.277195
# 7     128.828184
# 8     103.148427
# 9      24.774205
# 10    123.647441
# 11    108.413388
# 12     29.526227
# 13    142.675758
# 14    153.738393
# Name: 11, dtype: float64
#   Angle2_row: Series:
# 0      29.956870
# 1     140.251706
# 2     103.167212
# 3     124.027088
# 4     159.557622
# 5      98.725344
# 6     104.547199
# 7      63.346282
# 8     139.467368
# 9     119.136386
# 10     54.728162
# 11     75.840291
# 12     47.361038
# 13    171.581999
# 14    121.165241
# Name: 11, dtype: float64
# --------------------
#
# --- UAVs without Assigned Base Stations ---
#   UAV 4 : No BS is assigned
# --------------------
#   UAV 6 : No BS is assigned
# --------------------
#   UAV 7 : No BS is assigned
# --------------------
# Calculation for num_irs_ele: 20
#
# --- Best Unique UAV Assignments (Auction Based Method) ---
#
# Best Assignment for BS 3:
#  UAV Index: 1
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 43677.5190
#   P_m_down_value: 1.0022
#   P_m_har_value: 1.8330
#   T_m_har_value: 1.0552
#   f_km_value: 2.4899
#   T_km_up_value: 0.4123
#   V_lm_vfly_value: 72.1954
#   V_lm_hfly_value: 62.7885
#   P_km_up_value: 7.0592
#   Angle1_row: Series:
# 0      62.520641
# 1       9.309730
# 2     135.019831
# 3      69.248187
# 4      28.524192
# 5      51.048633
# 6     142.708487
# 7      93.906518
# 8     156.270465
# 9     168.981415
# 10     98.933058
# 11    169.973372
# 12     82.681113
# 13    179.580476
# 14      2.031629
# 15    121.726712
# 16    112.727751
# 17     70.623508
# 18     99.097782
# 19     95.500889
# Name: 24, dtype: float64
#   Angle_row: Series:
# 0      64.995765
# 1     158.611137
# 2     107.560762
# 3      98.914922
# 4     140.850267
# 5      45.329920
# 6     102.233791
# 7     110.898385
# 8      72.633155
# 9      48.983315
# 10    165.391370
# 11     61.191559
# 12    111.154403
# 13     19.769736
# 14    126.374812
# 15     30.550720
# 16    165.434741
# 17     65.490055
# 18     54.128805
# 19    173.082465
# Name: 24, dtype: float64
#   Angle2_row: Series:
# 0     105.875664
# 1      82.337315
# 2     141.530279
# 3      60.040130
# 4     165.996358
# 5     109.545664
# 6     108.563327
# 7       5.341311
# 8      89.950198
# 9      68.586845
# 10     96.951939
# 11    159.667996
# 12    149.176744
# 13    179.049400
# 14     11.089609
# 15    141.572050
# 16     50.027609
# 17    131.497408
# 18     65.892377
# 19    102.186637
# Name: 24, dtype: float64
# --------------------
#
# Best Assignment for BS 0:
#  UAV Index: 3
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 51174.4387
#   P_m_down_value: 0.1974
#   P_m_har_value: 0.1353
#   T_m_har_value: 0.3937
#   f_km_value: 0.9603
#   T_km_up_value: 0.3404
#   V_lm_vfly_value: 66.6344
#   V_lm_hfly_value: 66.8574
#   P_km_up_value: 7.9132
#   Angle1_row: Series:
# 0      22.490127
# 1      32.901399
# 2      81.578507
# 3     128.024752
# 4      31.124195
# 5      21.833467
# 6      50.367883
# 7      43.776222
# 8      57.441629
# 9      36.618525
# 10    166.564115
# 11    107.138674
# 12      5.971314
# 13    102.935820
# 14     11.185135
# 15    140.763483
# 16    123.089596
# 17    104.909228
# 18    112.095552
# 19     48.788629
# Name: 16, dtype: float64
#   Angle_row: Series:
# 0      63.875620
# 1     157.441232
# 2      71.446273
# 3     159.346617
# 4      94.060126
# 5      14.691808
# 6     113.341246
# 7     128.317380
# 8       5.693050
# 9      62.695650
# 10    136.114150
# 11    145.635478
# 12    151.039239
# 13     74.115101
# 14    177.182520
# 15     96.780982
# 16    120.295215
# 17    102.259369
# 18     34.612720
# 19     53.356669
# Name: 16, dtype: float64
#   Angle2_row: Series:
# 0     176.438467
# 1     139.757659
# 2      61.070880
# 3     172.056799
# 4      55.318019
# 5       9.208988
# 6     113.637443
# 7      92.859830
# 8      88.463040
# 9     112.399533
# 10     45.184955
# 11     29.474469
# 12     42.751137
# 13    162.357144
# 14     94.623947
# 15     39.274972
# 16    173.730651
# 17     95.708710
# 18      4.938505
# 19    127.109952
# Name: 16, dtype: float64
# --------------------
#
# Best Assignment for BS 2:
#  UAV Index: 2
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 56597.1517
#   P_m_down_value: 0.9092
#   P_m_har_value: 0.7848
#   T_m_har_value: 0.4714
#   f_km_value: 0.9102
#   T_km_up_value: 0.5043
#   V_lm_vfly_value: 59.4068
#   V_lm_hfly_value: 61.2868
#   P_km_up_value: 9.4069
#   Angle1_row: Series:
# 0     159.731653
# 1     100.882508
# 2     117.025134
# 3      58.986262
# 4      67.676113
# 5       9.015351
# 6     137.176396
# 7      85.629941
# 8     113.887495
# 9      79.734899
# 10     45.423233
# 11     16.658369
# 12    165.591524
# 13    132.597173
# 14     81.619671
# 15     75.582003
# 16    117.480342
# 17    162.122165
# 18     97.035993
# 19    168.681995
# Name: 1, dtype: float64
#   Angle_row: Series:
# 0      71.250767
# 1     101.531555
# 2     114.095297
# 3      53.357049
# 4      99.145927
# 5     150.877689
# 6     172.367077
# 7      92.774781
# 8      71.824795
# 9     119.576509
# 10     42.411583
# 11     49.753117
# 12     84.914220
# 13     43.065784
# 14    156.028741
# 15     17.895235
# 16    179.804624
# 17     46.360543
# 18     42.342374
# 19     17.396707
# Name: 1, dtype: float64
#   Angle2_row: Series:
# 0       3.387480
# 1      10.609468
# 2     176.984264
# 3      18.448483
# 4      16.631885
# 5     152.970278
# 6     119.087032
# 7     125.377830
# 8      14.146494
# 9      98.213664
# 10     53.125074
# 11     58.903653
# 12     16.424381
# 13     67.537245
# 14    111.412319
# 15    119.151402
# 16     92.476461
# 17     91.149087
# 18     68.775328
# 19     90.191659
# Name: 1, dtype: float64
# --------------------
#
# Best Assignment for BS 4:
#  UAV Index: 7
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 57159.2430
#   P_m_down_value: 0.5754
#   P_m_har_value: 0.8595
#   T_m_har_value: 0.3629
#   f_km_value: 0.8529
#   T_km_up_value: 0.3594
#   V_lm_vfly_value: 22.4843
#   V_lm_hfly_value: 55.0057
#   P_km_up_value: 5.6943
#   Angle1_row: Series:
# 0      80.371870
# 1     152.194257
# 2     129.891304
# 3      70.747545
# 4     109.839533
# 5      56.306498
# 6      74.573129
# 7      33.049486
# 8     117.666171
# 9       7.500662
# 10     18.946094
# 11    160.459512
# 12     64.697310
# 13     15.811134
# 14    150.995294
# 15    107.193304
# 16     79.164745
# 17    100.525471
# 18     56.525886
# 19    154.849543
# Name: 2, dtype: float64
#   Angle_row: Series:
# 0      44.066885
# 1     151.163399
# 2     126.017455
# 3      18.115815
# 4     115.091892
# 5      52.291003
# 6      28.397004
# 7      79.868805
# 8      63.964412
# 9      68.577862
# 10      5.995630
# 11     76.854183
# 12     47.165239
# 13     36.012040
# 14     25.212759
# 15    131.824136
# 16     39.234673
# 17    166.593594
# 18     79.103607
# 19     59.391976
# Name: 2, dtype: float64
#   Angle2_row: Series:
# 0      20.132903
# 1     161.144297
# 2      25.407528
# 3     126.392645
# 4     165.422661
# 5     134.967238
# 6     143.334333
# 7     132.516267
# 8      60.754601
# 9       3.982965
# 10     90.393741
# 11     72.005656
# 12    160.900646
# 13     15.486255
# 14     65.718818
# 15    167.966510
# 16    103.297783
# 17    147.526145
# 18     56.508865
# 19    129.052387
# Name: 2, dtype: float64
# --------------------
#
# Best Assignment for BS 1:
#  UAV Index: 5
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 62519.1798
#   P_m_down_value: 0.6128
#   P_m_har_value: 0.5173
#   T_m_har_value: 0.6195
#   f_km_value: 0.7532
#   T_km_up_value: 0.4920
#   V_lm_vfly_value: 46.4898
#   V_lm_hfly_value: 35.5884
#   P_km_up_value: 4.0423
#   Angle1_row: Series:
# 0     171.818530
# 1       6.740407
# 2     156.130519
# 3      86.665515
# 4     159.330318
# 5     108.317274
# 6     132.721741
# 7      66.385455
# 8      71.892986
# 9     137.677193
# 10     70.163401
# 11    164.389024
# 12      5.673685
# 13     45.262277
# 14    101.165502
# 15    170.263617
# 16    125.423179
# 17     51.879194
# 18    134.602970
# 19     78.551863
# Name: 22, dtype: float64
#   Angle_row: Series:
# 0     134.519252
# 1      57.586249
# 2     155.304283
# 3     107.311874
# 4     140.112454
# 5     134.492311
# 6      52.491877
# 7     124.165645
# 8      34.549078
# 9      71.621229
# 10     95.487903
# 11    118.032819
# 12     26.786331
# 13     61.679598
# 14     14.136726
# 15     40.311988
# 16     29.494343
# 17    102.550417
# 18     20.652666
# 19     12.274742
# Name: 22, dtype: float64
#   Angle2_row: Series:
# 0      37.784011
# 1      94.785721
# 2      10.036085
# 3      52.533915
# 4      33.342797
# 5      44.646445
# 6      88.221111
# 7     122.012859
# 8      83.350313
# 9      20.437755
# 10    177.927146
# 11      6.255751
# 12    176.446639
# 13     93.834996
# 14     90.570343
# 15    173.792444
# 16    113.112128
# 17    126.722791
# 18    168.842432
# 19     98.917702
# Name: 22, dtype: float64
# --------------------
#
# --- UAVs without Assigned Base Stations ---
#   UAV 0 : No BS is assigned
# --------------------
#   UAV 4 : No BS is assigned
# --------------------
#   UAV 6 : No BS is assigned
# --------------------
# Calculation for num_irs_ele: 25
#
# --- Best Unique UAV Assignments (Auction Based Method) ---
#
# Best Assignment for BS 1:
#  UAV Index: 1
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 49317.0342
#   P_m_down_value: 0.6128
#   P_m_har_value: 0.5173
#   T_m_har_value: 0.6195
#   f_km_value: 0.9824
#   T_km_up_value: 0.2986
#   V_lm_vfly_value: 72.6939
#   V_lm_hfly_value: 64.4919
#   P_km_up_value: 9.3996
#   Angle1_row: Series:
# 0      18.390139
# 1      61.627309
# 2     126.653788
# 3      74.783633
# 4     161.991019
# 5     146.039044
# 6      28.069266
# 7     148.153960
# 8      91.536583
# 9      37.557356
# 10    169.681912
# 11     23.805785
# 12     42.357378
# 13     95.587172
# 14    160.366576
# 15     49.897795
# 16     88.616417
# 17     48.228893
# 18    136.310610
# 19    136.439100
# 20    177.106430
# 21    124.497285
# 22     79.612048
# 23     62.723138
# 24    124.829448
# Name: 19, dtype: float64
#   Angle_row: Series:
# 0     154.845348
# 1     152.044671
# 2      86.940033
# 3      60.982494
# 4     140.849726
# 5      18.242092
# 6      87.747517
# 7     101.633498
# 8     136.031833
# 9      51.149791
# 10    125.269862
# 11     96.886968
# 12    111.166518
# 13     77.762404
# 14    177.204309
# 15    100.973616
# 16    135.458780
# 17     93.228836
# 18    166.980638
# 19     85.049686
# 20    143.634277
# 21    128.421308
# 22     86.742725
# 23    116.841350
# 24     41.469495
# Name: 19, dtype: float64
#   Angle2_row: Series:
# 0     139.920643
# 1     174.710003
# 2     112.588100
# 3      30.011653
# 4      20.037931
# 5       4.563747
# 6      34.385517
# 7     156.574488
# 8     161.893288
# 9      17.936693
# 10    111.758093
# 11     91.018339
# 12     93.109868
# 13      0.992704
# 14    178.143346
# 15    108.593625
# 16    129.727843
# 17      8.651160
# 18    164.777680
# 19    152.329143
# 20     62.150624
# 21     47.369422
# 22     54.598874
# 23    153.306730
# 24     61.916111
# Name: 19, dtype: float64
# --------------------
#
# Best Assignment for BS 3:
#  UAV Index: 3
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 51318.2000
#   P_m_down_value: 0.9554
#   P_m_har_value: 0.4164
#   T_m_har_value: 0.7701
#   f_km_value: 0.9361
#   T_km_up_value: 0.3320
#   V_lm_vfly_value: 66.6344
#   V_lm_hfly_value: 66.8574
#   P_km_up_value: 8.8458
#   Angle1_row: Series:
# 0     159.731653
# 1     100.882508
# 2     117.025134
# 3      58.986262
# 4      67.676113
# 5       9.015351
# 6     137.176396
# 7      85.629941
# 8     113.887495
# 9      79.734899
# 10     45.423233
# 11     16.658369
# 12    165.591524
# 13    132.597173
# 14     81.619671
# 15     75.582003
# 16    117.480342
# 17    162.122165
# 18     97.035993
# 19    168.681995
# 20    133.240629
# 21     86.358403
# 22     78.063678
# 23     38.721916
# 24      8.643860
# Name: 1, dtype: float64
#   Angle_row: Series:
# 0      71.250767
# 1     101.531555
# 2     114.095297
# 3      53.357049
# 4      99.145927
# 5     150.877689
# 6     172.367077
# 7      92.774781
# 8      71.824795
# 9     119.576509
# 10     42.411583
# 11     49.753117
# 12     84.914220
# 13     43.065784
# 14    156.028741
# 15     17.895235
# 16    179.804624
# 17     46.360543
# 18     42.342374
# 19     17.396707
# 20     59.475830
# 21     61.703387
# 22     20.227152
# 23     73.520683
# 24     61.852677
# Name: 1, dtype: float64
#   Angle2_row: Series:
# 0       3.387480
# 1      10.609468
# 2     176.984264
# 3      18.448483
# 4      16.631885
# 5     152.970278
# 6     119.087032
# 7     125.377830
# 8      14.146494
# 9      98.213664
# 10     53.125074
# 11     58.903653
# 12     16.424381
# 13     67.537245
# 14    111.412319
# 15    119.151402
# 16     92.476461
# 17     91.149087
# 18     68.775328
# 19     90.191659
# 20     33.139247
# 21     69.983150
# 22    129.981928
# 23     59.140574
# 24     13.308565
# Name: 1, dtype: float64
# --------------------
#
# Best Assignment for BS 0:
#  UAV Index: 5
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 52570.6829
#   P_m_down_value: 0.5844
#   P_m_har_value: 0.1289
#   T_m_har_value: 0.3178
#   f_km_value: 0.9305
#   T_km_up_value: 0.2875
#   V_lm_vfly_value: 47.0882
#   V_lm_hfly_value: 37.1077
#   P_km_up_value: 7.4334
#   Angle1_row: Series:
# 0     113.082724
# 1     151.017922
# 2     142.115900
# 3      31.419633
# 4      69.984550
# 5      53.227830
# 6       9.495722
# 7     136.042088
# 8      22.702253
# 9      62.927526
# 10    125.572709
# 11     90.364578
# 12    132.677686
# 13     12.649976
# 14     49.895434
# 15    130.095544
# 16     95.681999
# 17     37.756910
# 18     61.744740
# 19     88.693967
# 20     15.909653
# 21     79.835786
# 22     71.916066
# 23     90.192108
# 24     11.342780
# Name: 20, dtype: float64
#   Angle_row: Series:
# 0     172.416681
# 1      38.108032
# 2     148.593165
# 3      36.041038
# 4      82.411035
# 5      63.853155
# 6     160.342941
# 7     114.287309
# 8      73.635971
# 9     110.769000
# 10    118.502195
# 11     54.143109
# 12     36.793966
# 13     89.865057
# 14     34.200566
# 15     38.819137
# 16      0.976928
# 17    137.898275
# 18    101.882034
# 19    115.455214
# 20     61.909877
# 21     10.590341
# 22     78.155161
# 23      1.466728
# 24    170.255327
# Name: 20, dtype: float64
#   Angle2_row: Series:
# 0     133.015726
# 1      21.119524
# 2     145.532469
# 3      58.688534
# 4       1.655359
# 5     158.256124
# 6      36.667315
# 7       1.257712
# 8     126.460620
# 9      16.706273
# 10    166.615052
# 11     42.434371
# 12    123.634186
# 13      4.691419
# 14     64.346745
# 15     84.899494
# 16    111.243469
# 17     36.508332
# 18      6.026316
# 19     70.654834
# 20     92.570156
# 21     81.972062
# 22     95.046816
# 23     48.975339
# 24     16.581435
# Name: 20, dtype: float64
# --------------------
#
# Best Assignment for BS 4:
#  UAV Index: 2
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 56808.7181
#   P_m_down_value: 0.5754
#   P_m_har_value: 0.8595
#   T_m_har_value: 0.3629
#   f_km_value: 0.8287
#   T_km_up_value: 0.4577
#   V_lm_vfly_value: 59.4068
#   V_lm_hfly_value: 61.2868
#   P_km_up_value: 8.7993
#   Angle1_row: Series:
# 0      45.689100
# 1     153.790117
# 2      78.619186
# 3     165.606276
# 4     165.496330
# 5     169.805745
# 6       9.518851
# 7     169.843179
# 8      51.361915
# 9      46.364637
# 10    178.819686
# 11     88.070819
# 12    137.788329
# 13    102.641148
# 14     81.817364
# 15      1.194344
# 16     47.566132
# 17     52.575323
# 18    126.387559
# 19     37.997157
# 20    137.330091
# 21     95.499735
# 22    117.140057
# 23    166.326303
# 24    157.488761
# Name: 14, dtype: float64
#   Angle_row: Series:
# 0      98.884384
# 1      87.355435
# 2       0.630564
# 3     103.807164
# 4      13.525195
# 5     121.362051
# 6     110.351598
# 7     176.545826
# 8     106.896071
# 9     163.964158
# 10     15.951733
# 11      3.913105
# 12     96.287433
# 13     21.938907
# 14    109.742731
# 15     51.285928
# 16     27.644938
# 17     75.629459
# 18    153.327076
# 19    167.264152
# 20     85.702376
# 21    166.227496
# 22     42.901578
# 23      9.344609
# 24     46.729552
# Name: 14, dtype: float64
#   Angle2_row: Series:
# 0     122.416412
# 1     138.511410
# 2      14.387826
# 3      60.610832
# 4     168.660786
# 5     100.325903
# 6     174.076458
# 7      10.278599
# 8     100.532935
# 9     168.779383
# 10    170.556014
# 11    129.781695
# 12     33.403479
# 13    141.370896
# 14     39.407847
# 15    155.635419
# 16    108.933698
# 17      8.509413
# 18    140.279617
# 19     68.182603
# 20    103.574957
# 21    108.306679
# 22     71.160555
# 23     22.759427
# 24    154.954348
# Name: 14, dtype: float64
# --------------------
#
# Best Assignment for BS 2:
#  UAV Index: 7
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 63210.2654
#   P_m_down_value: 0.5858
#   P_m_har_value: 1.1416
#   T_m_har_value: 0.5385
#   f_km_value: 0.9932
#   T_km_up_value: 0.6502
#   V_lm_vfly_value: 22.1243
#   V_lm_hfly_value: 57.0528
#   P_km_up_value: 6.7351
#   Angle1_row: Series:
# 0       9.718200
# 1     166.332615
# 2     141.113217
# 3     151.388791
# 4      54.837360
# 5     104.195971
# 6      71.297319
# 7      92.815033
# 8     139.034341
# 9     156.345706
# 10     58.865258
# 11    123.285790
# 12    170.270228
# 13     61.165396
# 14     40.235002
# 15    166.222932
# 16    117.624323
# 17    150.782547
# 18    171.210178
# 19     90.064639
# 20     16.174505
# 21     39.636909
# 22    122.680999
# 23     42.695552
# 24    177.414787
# Name: 13, dtype: float64
#   Angle_row: Series:
# 0     124.487003
# 1      13.957565
# 2     171.049873
# 3     143.360909
# 4      22.602544
# 5     132.068929
# 6       1.261341
# 7     165.534018
# 8     154.765610
# 9     150.938196
# 10     19.596072
# 11     12.157789
# 12    118.530190
# 13     69.844550
# 14    118.208351
# 15    101.253568
# 16     66.031639
# 17    109.644809
# 18     80.495294
# 19     25.338916
# 20    120.107497
# 21     65.407585
# 22    142.372196
# 23      1.748551
# 24     80.817300
# Name: 13, dtype: float64
#   Angle2_row: Series:
# 0     151.993182
# 1     149.324078
# 2     139.140159
# 3     158.752199
# 4     113.697749
# 5      19.239400
# 6      72.224288
# 7     154.482516
# 8      95.943569
# 9      50.207436
# 10     11.953457
# 11     57.541914
# 12    148.809188
# 13     46.511576
# 14    130.847720
# 15      6.142841
# 16     36.490153
# 17     93.653308
# 18     22.220973
# 19     11.106428
# 20     44.083890
# 21    144.927410
# 22    129.995242
# 23    159.991752
# 24    105.165862
# Name: 13, dtype: float64
# --------------------
#
# --- UAVs without Assigned Base Stations ---
#   UAV 0 : No BS is assigned
# --------------------
#   UAV 4 : No BS is assigned
# --------------------
#   UAV 6 : No BS is assigned
# --------------------
# Calculation for num_irs_ele: 30
#
# --- Best Unique UAV Assignments (Auction Based Method) ---
#
# Best Assignment for BS 4:
#  UAV Index: 3
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 48177.4193
#   P_m_down_value: 1.1151
#   P_m_har_value: 0.5731
#   T_m_har_value: 0.7855
#   f_km_value: 2.6508
#   T_km_up_value: 0.5688
#   V_lm_vfly_value: 65.9465
#   V_lm_hfly_value: 66.0725
#   P_km_up_value: 7.1518
#   Angle1_row: Series:
# 0      76.267654
# 1      81.422305
# 2     132.241222
# 3      69.129860
# 4      28.089600
# 5     136.664021
# 6     123.939352
# 7      27.333332
# 8      16.734789
# 9      11.823278
# 10    108.293631
# 11     56.643737
# 12     52.921650
# 13    118.873387
# 14     53.579715
# 15     70.617304
# 16     99.349636
# 17     50.939219
# 18     79.750986
# 19    120.264697
# 20    149.290440
# 21     10.193946
# 22     36.080532
# 23    128.986302
# 24     26.457226
# 25     68.350412
# 26     75.052635
# 27     76.019673
# 28     83.088389
# 29     11.200406
# Name: 11, dtype: float64
#   Angle_row: Series:
# 0      71.093420
# 1     117.176311
# 2     177.369062
# 3      87.190656
# 4      57.333286
# 5      68.620816
# 6     106.277195
# 7     128.828184
# 8     103.148427
# 9      24.774205
# 10    123.647441
# 11    108.413388
# 12     29.526227
# 13    142.675758
# 14    153.738393
# 15    163.671811
# 16     60.983124
# 17     97.847862
# 18    128.615459
# 19    156.283014
# 20    103.359309
# 21     73.087225
# 22     94.902055
# 23    140.533781
# 24     89.907863
# 25    109.908993
# 26    150.076063
# 27     16.723191
# 28     16.233387
# 29    161.544735
# Name: 11, dtype: float64
#   Angle2_row: Series:
# 0      29.956870
# 1     140.251706
# 2     103.167212
# 3     124.027088
# 4     159.557622
# 5      98.725344
# 6     104.547199
# 7      63.346282
# 8     139.467368
# 9     119.136386
# 10     54.728162
# 11     75.840291
# 12     47.361038
# 13    171.581999
# 14    121.165241
# 15    156.570764
# 16    120.648980
# 17      5.513301
# 18     54.851939
# 19     53.835855
# 20     98.725952
# 21    123.432551
# 22     63.895514
# 23    139.672657
# 24    179.484705
# 25     65.096452
# 26    123.262886
# 27     62.348885
# 28     39.226559
# 29    138.722613
# Name: 11, dtype: float64
# --------------------
#
# Best Assignment for BS 1:
#  UAV Index: 2
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 53270.9225
#   P_m_down_value: 0.6128
#   P_m_har_value: 0.5173
#   T_m_har_value: 0.6195
#   f_km_value: 0.9460
#   T_km_up_value: 0.4087
#   V_lm_vfly_value: 59.4068
#   V_lm_hfly_value: 61.2868
#   P_km_up_value: 9.7784
#   Angle1_row: Series:
# 0       9.718200
# 1     166.332615
# 2     141.113217
# 3     151.388791
# 4      54.837360
# 5     104.195971
# 6      71.297319
# 7      92.815033
# 8     139.034341
# 9     156.345706
# 10     58.865258
# 11    123.285790
# 12    170.270228
# 13     61.165396
# 14     40.235002
# 15    166.222932
# 16    117.624323
# 17    150.782547
# 18    171.210178
# 19     90.064639
# 20     16.174505
# 21     39.636909
# 22    122.680999
# 23     42.695552
# 24    177.414787
# 25     99.229802
# 26    175.650457
# 27    170.992922
# 28     96.882153
# 29      4.651826
# Name: 13, dtype: float64
#   Angle_row: Series:
# 0     124.487003
# 1      13.957565
# 2     171.049873
# 3     143.360909
# 4      22.602544
# 5     132.068929
# 6       1.261341
# 7     165.534018
# 8     154.765610
# 9     150.938196
# 10     19.596072
# 11     12.157789
# 12    118.530190
# 13     69.844550
# 14    118.208351
# 15    101.253568
# 16     66.031639
# 17    109.644809
# 18     80.495294
# 19     25.338916
# 20    120.107497
# 21     65.407585
# 22    142.372196
# 23      1.748551
# 24     80.817300
# 25     95.367385
# 26     26.291132
# 27     75.311414
# 28    129.202906
# 29    141.923730
# Name: 13, dtype: float64
#   Angle2_row: Series:
# 0     151.993182
# 1     149.324078
# 2     139.140159
# 3     158.752199
# 4     113.697749
# 5      19.239400
# 6      72.224288
# 7     154.482516
# 8      95.943569
# 9      50.207436
# 10     11.953457
# 11     57.541914
# 12    148.809188
# 13     46.511576
# 14    130.847720
# 15      6.142841
# 16     36.490153
# 17     93.653308
# 18     22.220973
# 19     11.106428
# 20     44.083890
# 21    144.927410
# 22    129.995242
# 23    159.991752
# 24    105.165862
# 25    151.173403
# 26    178.910933
# 27    160.246300
# 28    100.361039
# 29    179.401325
# Name: 13, dtype: float64
# --------------------
#
# Best Assignment for BS 0:
#  UAV Index: 1
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 54073.6329
#   P_m_down_value: 0.1974
#   P_m_har_value: 0.1353
#   T_m_har_value: 0.3937
#   f_km_value: 0.7893
#   T_km_up_value: 0.3406
#   V_lm_vfly_value: 72.6939
#   V_lm_hfly_value: 64.4919
#   P_km_up_value: 8.2803
#   Angle1_row: Series:
# 0      62.520641
# 1       9.309730
# 2     135.019831
# 3      69.248187
# 4      28.524192
# 5      51.048633
# 6     142.708487
# 7      93.906518
# 8     156.270465
# 9     168.981415
# 10     98.933058
# 11    169.973372
# 12     82.681113
# 13    179.580476
# 14      2.031629
# 15    121.726712
# 16    112.727751
# 17     70.623508
# 18     99.097782
# 19     95.500889
# 20    166.622138
# 21     45.653457
# 22     97.072891
# 23     18.829907
# 24    145.290240
# 25     86.814987
# 26     45.169919
# 27    159.178350
# 28     49.125463
# 29    155.894832
# Name: 24, dtype: float64
#   Angle_row: Series:
# 0      64.995765
# 1     158.611137
# 2     107.560762
# 3      98.914922
# 4     140.850267
# 5      45.329920
# 6     102.233791
# 7     110.898385
# 8      72.633155
# 9      48.983315
# 10    165.391370
# 11     61.191559
# 12    111.154403
# 13     19.769736
# 14    126.374812
# 15     30.550720
# 16    165.434741
# 17     65.490055
# 18     54.128805
# 19    173.082465
# 20    160.036523
# 21    149.333108
# 22    116.792105
# 23     78.281087
# 24     85.820649
# 25     77.289026
# 26     20.457514
# 27     42.338013
# 28    144.706326
# 29    142.787529
# Name: 24, dtype: float64
#   Angle2_row: Series:
# 0     105.875664
# 1      82.337315
# 2     141.530279
# 3      60.040130
# 4     165.996358
# 5     109.545664
# 6     108.563327
# 7       5.341311
# 8      89.950198
# 9      68.586845
# 10     96.951939
# 11    159.667996
# 12    149.176744
# 13    179.049400
# 14     11.089609
# 15    141.572050
# 16     50.027609
# 17    131.497408
# 18     65.892377
# 19    102.186637
# 20     72.250340
# 21     58.012254
# 22    129.928755
# 23     12.851644
# 24     58.781650
# 25     37.256892
# 26    151.652400
# 27     53.054747
# 28    108.780555
# 29    136.743121
# Name: 24, dtype: float64
# --------------------
#
# Best Assignment for BS 2:
#  UAV Index: 5
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 58494.1714
#   P_m_down_value: 0.9092
#   P_m_har_value: 0.7848
#   T_m_har_value: 0.4714
#   f_km_value: 0.7072
#   T_km_up_value: 0.3081
#   V_lm_vfly_value: 46.4898
#   V_lm_hfly_value: 35.5884
#   P_km_up_value: 9.1773
#   Angle1_row: Series:
# 0      76.267654
# 1      81.422305
# 2     132.241222
# 3      69.129860
# 4      28.089600
# 5     136.664021
# 6     123.939352
# 7      27.333332
# 8      16.734789
# 9      11.823278
# 10    108.293631
# 11     56.643737
# 12     52.921650
# 13    118.873387
# 14     53.579715
# 15     70.617304
# 16     99.349636
# 17     50.939219
# 18     79.750986
# 19    120.264697
# 20    149.290440
# 21     10.193946
# 22     36.080532
# 23    128.986302
# 24     26.457226
# 25     68.350412
# 26     75.052635
# 27     76.019673
# 28     83.088389
# 29     11.200406
# Name: 11, dtype: float64
#   Angle_row: Series:
# 0      71.093420
# 1     117.176311
# 2     177.369062
# 3      87.190656
# 4      57.333286
# 5      68.620816
# 6     106.277195
# 7     128.828184
# 8     103.148427
# 9      24.774205
# 10    123.647441
# 11    108.413388
# 12     29.526227
# 13    142.675758
# 14    153.738393
# 15    163.671811
# 16     60.983124
# 17     97.847862
# 18    128.615459
# 19    156.283014
# 20    103.359309
# 21     73.087225
# 22     94.902055
# 23    140.533781
# 24     89.907863
# 25    109.908993
# 26    150.076063
# 27     16.723191
# 28     16.233387
# 29    161.544735
# Name: 11, dtype: float64
#   Angle2_row: Series:
# 0      29.956870
# 1     140.251706
# 2     103.167212
# 3     124.027088
# 4     159.557622
# 5      98.725344
# 6     104.547199
# 7      63.346282
# 8     139.467368
# 9     119.136386
# 10     54.728162
# 11     75.840291
# 12     47.361038
# 13    171.581999
# 14    121.165241
# 15    156.570764
# 16    120.648980
# 17      5.513301
# 18     54.851939
# 19     53.835855
# 20     98.725952
# 21    123.432551
# 22     63.895514
# 23    139.672657
# 24    179.484705
# 25     65.096452
# 26    123.262886
# 27     62.348885
# 28     39.226559
# 29    138.722613
# Name: 11, dtype: float64
# --------------------
#
# Best Assignment for BS 3:
#  UAV Index: 7
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 59274.8862
#   P_m_down_value: 0.9646
#   P_m_har_value: 0.4153
#   T_m_har_value: 0.3699
#   f_km_value: 0.8082
#   T_km_up_value: 0.3952
#   V_lm_vfly_value: 21.9034
#   V_lm_hfly_value: 54.3223
#   P_km_up_value: 6.1497
#   Angle1_row: Series:
# 0      18.390139
# 1      61.627309
# 2     126.653788
# 3      74.783633
# 4     161.991019
# 5     146.039044
# 6      28.069266
# 7     148.153960
# 8      91.536583
# 9      37.557356
# 10    169.681912
# 11     23.805785
# 12     42.357378
# 13     95.587172
# 14    160.366576
# 15     49.897795
# 16     88.616417
# 17     48.228893
# 18    136.310610
# 19    136.439100
# 20    177.106430
# 21    124.497285
# 22     79.612048
# 23     62.723138
# 24    124.829448
# 25     96.395983
# 26    152.370745
# 27    132.343018
# 28     65.458095
# 29     32.828866
# Name: 19, dtype: float64
#   Angle_row: Series:
# 0     154.845348
# 1     152.044671
# 2      86.940033
# 3      60.982494
# 4     140.849726
# 5      18.242092
# 6      87.747517
# 7     101.633498
# 8     136.031833
# 9      51.149791
# 10    125.269862
# 11     96.886968
# 12    111.166518
# 13     77.762404
# 14    177.204309
# 15    100.973616
# 16    135.458780
# 17     93.228836
# 18    166.980638
# 19     85.049686
# 20    143.634277
# 21    128.421308
# 22     86.742725
# 23    116.841350
# 24     41.469495
# 25     79.467010
# 26     77.566968
# 27    104.630796
# 28    101.830454
# 29     86.151422
# Name: 19, dtype: float64
#   Angle2_row: Series:
# 0     139.920643
# 1     174.710003
# 2     112.588100
# 3      30.011653
# 4      20.037931
# 5       4.563747
# 6      34.385517
# 7     156.574488
# 8     161.893288
# 9      17.936693
# 10    111.758093
# 11     91.018339
# 12     93.109868
# 13      0.992704
# 14    178.143346
# 15    108.593625
# 16    129.727843
# 17      8.651160
# 18    164.777680
# 19    152.329143
# 20     62.150624
# 21     47.369422
# 22     54.598874
# 23    153.306730
# 24     61.916111
# 25    115.042258
# 26     95.017407
# 27      3.367914
# 28    162.661325
# 29     43.631547
# Name: 19, dtype: float64
# --------------------
#
# --- UAVs without Assigned Base Stations ---
#   UAV 0 : No BS is assigned
# --------------------
#   UAV 4 : No BS is assigned
# --------------------
#   UAV 6 : No BS is assigned
# --------------------
# Calculation for num_irs_ele: 35
#
# --- Best Unique UAV Assignments (Auction Based Method) ---
#
# Best Assignment for BS 4:
#  UAV Index: 3
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 46341.9770
#   P_m_down_value: 0.1784
#   P_m_har_value: 0.9862
#   T_m_har_value: 0.2373
#   f_km_value: 1.4518
#   T_km_up_value: 0.3452
#   V_lm_vfly_value: 66.8758
#   V_lm_hfly_value: 67.8419
#   P_km_up_value: 8.3817
#   Angle1_row: Series:
# 0     128.033591
# 1     115.310211
# 2       1.516120
# 3       2.079005
# 4      12.233987
# 5     177.432386
# 6      43.529909
# 7     126.458427
# 8       0.537457
# 9      16.150987
# 10    104.323289
# 11     46.327363
# 12    107.757075
# 13     45.694777
# 14     79.415130
# 15    107.530239
# 16     74.359492
# 17    137.352938
# 18    126.392404
# 19     28.269669
# 20    157.540088
# 21     81.890834
# 22     62.117831
# 23    100.653426
# 24     41.266634
# 25    148.069032
# 26     49.988767
# 27     57.359663
# 28     96.752522
# 29    137.366344
# 30     67.166449
# 31    144.951930
# 32     47.429627
# 33    124.234113
# 34    159.747704
# Name: 17, dtype: float64
#   Angle_row: Series:
# 0      35.782887
# 1      22.793960
# 2     103.944478
# 3      21.392565
# 4      19.690999
# 5     117.168579
# 6      91.159241
# 7     144.852743
# 8      97.237079
# 9      40.008964
# 10     99.913103
# 11    136.070996
# 12     65.607709
# 13     97.438677
# 14     88.383579
# 15     52.106601
# 16    115.674757
# 17    176.513441
# 18    105.016880
# 19     52.264607
# 20     17.490794
# 21    125.440563
# 22    166.379221
# 23     98.150871
# 24      5.863917
# 25    154.668819
# 26     99.680321
# 27      5.289248
# 28     98.792621
# 29     85.059318
# 30      9.595780
# 31    121.368624
# 32    129.761065
# 33    150.477446
# 34    130.179232
# Name: 17, dtype: float64
#   Angle2_row: Series:
# 0      44.398724
# 1      44.081596
# 2     117.773159
# 3     165.713683
# 4      30.402284
# 5      17.634319
# 6     112.678263
# 7      62.705585
# 8      33.036293
# 9     125.266017
# 10     84.142208
# 11     40.877336
# 12     25.675208
# 13     96.149186
# 14    109.079371
# 15    102.986263
# 16     13.892863
# 17     57.909687
# 18    174.575247
# 19     98.823718
# 20     10.466069
# 21    175.028219
# 22    173.224976
# 23    109.697008
# 24     54.876295
# 25     69.294012
# 26     17.229893
# 27     49.262417
# 28     90.295963
# 29    123.790593
# 30     59.443318
# 31    133.686727
# 32    125.159492
# 33     68.044033
# 34     64.930437
# Name: 17, dtype: float64
# --------------------
#
# Best Assignment for BS 0:
#  UAV Index: 1
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 52950.9855
#   P_m_down_value: 0.1974
#   P_m_har_value: 0.1353
#   T_m_har_value: 0.3937
#   f_km_value: 0.8537
#   T_km_up_value: 0.3491
#   V_lm_vfly_value: 72.6939
#   V_lm_hfly_value: 64.4919
#   P_km_up_value: 8.1915
#   Angle1_row: Series:
# 0      80.039371
# 1     145.196085
# 2     156.764960
# 3      26.653597
# 4     102.012866
# 5     165.394952
# 6     109.530622
# 7     146.757098
# 8      77.013072
# 9     108.171475
# 10    177.894865
# 11     72.890430
# 12    101.138488
# 13    148.526975
# 14    110.909309
# 15    166.930083
# 16     56.132192
# 17     43.795722
# 18    101.170399
# 19     29.971679
# 20     33.163035
# 21    133.943904
# 22     41.016547
# 23     45.067420
# 24    142.246857
# 25    108.677334
# 26    163.550356
# 27    151.806972
# 28     99.219392
# 29    167.962701
# 30    140.866014
# 31     64.671151
# 32     97.472372
# 33    116.357707
# 34    124.103746
# Name: 23, dtype: float64
#   Angle_row: Series:
# 0     166.484430
# 1      83.525242
# 2     169.579609
# 3     143.718892
# 4      74.726273
# 5      68.995337
# 6     101.389850
# 7       0.466934
# 8     176.049865
# 9     164.723820
# 10    150.142223
# 11     84.093096
# 12    168.639983
# 13     70.628980
# 14     18.429407
# 15     20.752725
# 16     99.082317
# 17     88.240355
# 18     74.356284
# 19     11.240584
# 20     28.785381
# 21    116.711291
# 22    134.848735
# 23    151.958134
# 24    118.806311
# 25     79.492774
# 26    140.570266
# 27     98.193599
# 28    112.931686
# 29    139.617969
# 30    126.680465
# 31     53.723225
# 32     67.823577
# 33    109.660279
# 34     49.014998
# Name: 23, dtype: float64
#   Angle2_row: Series:
# 0      49.012029
# 1      99.617798
# 2     136.027265
# 3      27.683858
# 4     107.101404
# 5     177.012042
# 6      61.186046
# 7      84.073280
# 8      55.828250
# 9      37.657146
# 10     44.172448
# 11     77.635749
# 12    121.982315
# 13    110.647198
# 14    118.750303
# 15     31.653386
# 16    118.903224
# 17    103.071935
# 18     19.588421
# 19    153.416286
# 20    150.008592
# 21     36.459600
# 22    108.014623
# 23     99.350694
# 24     33.025338
# 25     94.469711
# 26    154.840314
# 27     22.208632
# 28     37.048837
# 29     54.368089
# 30     99.783519
# 31    116.075030
# 32     69.759802
# 33    118.334087
# 34    102.844458
# Name: 23, dtype: float64
# --------------------
#
# Best Assignment for BS 3:
#  UAV Index: 2
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 53151.6784
#   P_m_down_value: 0.9554
#   P_m_har_value: 0.4164
#   T_m_har_value: 0.7701
#   f_km_value: 0.9262
#   T_km_up_value: 0.3932
#   V_lm_vfly_value: 59.4068
#   V_lm_hfly_value: 61.2868
#   P_km_up_value: 9.4802
#   Angle1_row: Series:
# 0      18.390139
# 1      61.627309
# 2     126.653788
# 3      74.783633
# 4     161.991019
# 5     146.039044
# 6      28.069266
# 7     148.153960
# 8      91.536583
# 9      37.557356
# 10    169.681912
# 11     23.805785
# 12     42.357378
# 13     95.587172
# 14    160.366576
# 15     49.897795
# 16     88.616417
# 17     48.228893
# 18    136.310610
# 19    136.439100
# 20    177.106430
# 21    124.497285
# 22     79.612048
# 23     62.723138
# 24    124.829448
# 25     96.395983
# 26    152.370745
# 27    132.343018
# 28     65.458095
# 29     32.828866
# 30    157.767578
# 31     51.868134
# 32    135.358228
# 33     68.528853
# 34     82.470702
# Name: 19, dtype: float64
#   Angle_row: Series:
# 0     154.845348
# 1     152.044671
# 2      86.940033
# 3      60.982494
# 4     140.849726
# 5      18.242092
# 6      87.747517
# 7     101.633498
# 8     136.031833
# 9      51.149791
# 10    125.269862
# 11     96.886968
# 12    111.166518
# 13     77.762404
# 14    177.204309
# 15    100.973616
# 16    135.458780
# 17     93.228836
# 18    166.980638
# 19     85.049686
# 20    143.634277
# 21    128.421308
# 22     86.742725
# 23    116.841350
# 24     41.469495
# 25     79.467010
# 26     77.566968
# 27    104.630796
# 28    101.830454
# 29     86.151422
# 30    158.765152
# 31     18.587139
# 32    116.589399
# 33     52.947453
# 34      8.044820
# Name: 19, dtype: float64
#   Angle2_row: Series:
# 0     139.920643
# 1     174.710003
# 2     112.588100
# 3      30.011653
# 4      20.037931
# 5       4.563747
# 6      34.385517
# 7     156.574488
# 8     161.893288
# 9      17.936693
# 10    111.758093
# 11     91.018339
# 12     93.109868
# 13      0.992704
# 14    178.143346
# 15    108.593625
# 16    129.727843
# 17      8.651160
# 18    164.777680
# 19    152.329143
# 20     62.150624
# 21     47.369422
# 22     54.598874
# 23    153.306730
# 24     61.916111
# 25    115.042258
# 26     95.017407
# 27      3.367914
# 28    162.661325
# 29     43.631547
# 30    105.957001
# 31    171.109129
# 32    158.999211
# 33    169.549207
# 34     69.222321
# Name: 19, dtype: float64
# --------------------
#
# Best Assignment for BS 1:
#  UAV Index: 7
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 56206.7657
#   P_m_down_value: 0.6128
#   P_m_har_value: 0.5173
#   T_m_har_value: 0.6195
#   f_km_value: 0.7893
#   T_km_up_value: 0.2789
#   V_lm_vfly_value: 22.4843
#   V_lm_hfly_value: 55.0057
#   P_km_up_value: 8.2803
#   Angle1_row: Series:
# 0     159.731653
# 1     100.882508
# 2     117.025134
# 3      58.986262
# 4      67.676113
# 5       9.015351
# 6     137.176396
# 7      85.629941
# 8     113.887495
# 9      79.734899
# 10     45.423233
# 11     16.658369
# 12    165.591524
# 13    132.597173
# 14     81.619671
# 15     75.582003
# 16    117.480342
# 17    162.122165
# 18     97.035993
# 19    168.681995
# 20    133.240629
# 21     86.358403
# 22     78.063678
# 23     38.721916
# 24      8.643860
# 25    100.182634
# 26    106.610854
# 27     19.677112
# 28     47.299342
# 29     31.285795
# 30    114.892579
# 31     85.328616
# 32     92.918365
# 33     96.678678
# 34    153.978736
# Name: 1, dtype: float64
#   Angle_row: Series:
# 0      71.250767
# 1     101.531555
# 2     114.095297
# 3      53.357049
# 4      99.145927
# 5     150.877689
# 6     172.367077
# 7      92.774781
# 8      71.824795
# 9     119.576509
# 10     42.411583
# 11     49.753117
# 12     84.914220
# 13     43.065784
# 14    156.028741
# 15     17.895235
# 16    179.804624
# 17     46.360543
# 18     42.342374
# 19     17.396707
# 20     59.475830
# 21     61.703387
# 22     20.227152
# 23     73.520683
# 24     61.852677
# 25     54.400113
# 26    126.154216
# 27    129.259966
# 28     34.418910
# 29     25.547576
# 30    147.958132
# 31     71.277480
# 32     87.242927
# 33    150.670758
# 34     86.730173
# Name: 1, dtype: float64
#   Angle2_row: Series:
# 0       3.387480
# 1      10.609468
# 2     176.984264
# 3      18.448483
# 4      16.631885
# 5     152.970278
# 6     119.087032
# 7     125.377830
# 8      14.146494
# 9      98.213664
# 10     53.125074
# 11     58.903653
# 12     16.424381
# 13     67.537245
# 14    111.412319
# 15    119.151402
# 16     92.476461
# 17     91.149087
# 18     68.775328
# 19     90.191659
# 20     33.139247
# 21     69.983150
# 22    129.981928
# 23     59.140574
# 24     13.308565
# 25     68.947823
# 26     82.921736
# 27    152.397093
# 28    120.984652
# 29    177.624653
# 30    173.088987
# 31    158.068642
# 32     94.807899
# 33    124.387998
# 34     43.625608
# Name: 1, dtype: float64
# --------------------
#
# Best Assignment for BS 2:
#  UAV Index: 5
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 64364.5767
#   P_m_down_value: 0.9092
#   P_m_har_value: 0.7848
#   T_m_har_value: 0.4714
#   f_km_value: 0.5229
#   T_km_up_value: 0.2643
#   V_lm_vfly_value: 46.4898
#   V_lm_hfly_value: 35.5884
#   P_km_up_value: 9.2035
#   Angle1_row: Series:
# 0      76.267654
# 1      81.422305
# 2     132.241222
# 3      69.129860
# 4      28.089600
# 5     136.664021
# 6     123.939352
# 7      27.333332
# ...
# 22    176.857295
# 23      2.990441
# 24     48.845001
# 25    158.093942
# 26    124.942703
# 27     22.075022
# 28     14.027225
# 29     12.339921
# 30    118.448808
# 31    140.233472
# 32     57.767728
# 33     65.396520
# 34    104.907688
# 35     62.041436
# 36     79.247959
# 37     97.834095
# 38     39.139785
# 39    143.425782
# 40    109.592724
# 41    122.671351
# 42    131.245104
# 43    167.820283
# 44    104.378319
# Name: 21, dtype: float64
# --------------------
#
# --- UAVs without Assigned Base Stations ---
#   UAV 4 : No BS is assigned
# --------------------
#   UAV 5 : No BS is assigned
# --------------------
#   UAV 6 : No BS is assigned
# --------------------
# Calculation for num_irs_ele: 50
#
# --- Best Unique UAV Assignments (Auction Based Method) ---
#
# Best Assignment for BS 1:
#  UAV Index: 2
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 47157.6978
#   P_m_down_value: 2.0151
#   P_m_har_value: 1.2096
#   T_m_har_value: 0.9434
#   f_km_value: 2.2359
#   T_km_up_value: 0.4998
#   V_lm_vfly_value: 59.4732
#   V_lm_hfly_value: 61.2746
#   P_km_up_value: 7.1052
#   Angle1_row: Series:
# 0     171.003268
# 1     157.875529
# 2      81.274287
# 3      59.297332
# 4      50.142228
# 5     172.696773
# 6      17.384087
# 7     124.718601
# 8      40.538602
# 9      44.386630
# 10    163.151980
# 11     13.758262
# 12    110.921478
# 13     49.873260
# 14     88.029337
# 15     38.637946
# 16    167.780368
# 17    134.263929
# 18    117.673119
# 19      9.731574
# 20     82.159252
# 21     70.762914
# 22     46.057979
# 23      1.554653
# 24     89.039081
# 25     51.296547
# 26    110.199850
# 27     56.060241
# 28    137.212153
# 29    148.446320
# 30     72.265277
# 31     83.017427
# 32    143.213460
# 33     76.229965
# 34    162.681266
# 35    109.185108
# 36    145.852973
# 37    160.641636
# 38     18.432363
# 39    148.058419
# 40    154.395815
# 41     84.948120
# 42     72.384966
# 43    127.088678
# 44    119.467250
# 45    107.674466
# 46    169.241300
# 47     57.084428
# 48     81.758670
# 49     96.331519
# Name: 15, dtype: float64
#   Angle_row: Series:
# 0     116.671150
# 1      68.400432
# 2     168.457007
# 3     107.868742
# 4     173.302122
# 5      56.413703
# 6       3.235303
# 7      88.453267
# 8      98.328744
# 9      73.652569
# 10     82.963764
# 11     50.227077
# 12    133.786679
# 13     65.453010
# 14    159.929196
# 15     64.886089
# 16     98.399062
# 17     69.921154
# 18     36.796350
# 19    175.823033
# 20     65.056465
# 21     61.508898
# 22     37.021175
# 23    122.265866
# 24    164.552273
# 25     39.457798
# 26    166.926478
# 27    160.209254
# 28     93.997042
# 29      4.277878
# 30     64.986533
# 31      8.485659
# 32     13.925323
# 33    135.416092
# 34     74.690024
# 35      6.529606
# 36    120.003398
# 37    136.511104
# 38     90.954012
# 39    179.103939
# 40     27.177587
# 41    131.760685
# 42     44.408846
# 43     25.028119
# 44    147.626422
# 45    105.798898
# 46     58.332194
# 47    135.330668
# 48     47.949563
# 49     68.909785
# Name: 15, dtype: float64
#   Angle2_row: Series:
# 0     167.362077
# 1      84.033971
# 2      98.958885
# 3     145.206569
# 4     120.548498
# 5      59.295056
# 6     152.347597
# 7     106.436671
# 8      16.819774
# 9     150.838085
# 10      1.211250
# 11     74.690502
# 12    154.987321
# 13    103.795730
# 14    166.770457
# 15    117.454131
# 16    124.303755
# 17     35.333160
# 18    157.256564
# 19    177.719989
# 20    133.628060
# 21    113.135722
# 22     10.739283
# 23      8.026505
# 24    140.073236
# 25     59.589418
# 26    128.333955
# 27     31.711836
# 28     85.172279
# 29    175.572924
# 30     16.022434
# 31     49.646891
# 32     43.229834
# 33    159.939777
# 34     65.795138
# 35     99.735180
# 36     82.883944
# 37    147.553217
# 38    124.677000
# 39    118.437556
# 40    171.787014
# 41     65.600948
# 42    150.906591
# 43     64.395622
# 44     68.456040
# 45     28.619923
# 46     31.251056
# 47     61.717539
# 48     10.005736
# 49     59.817342
# Name: 15, dtype: float64
# --------------------
#
# Best Assignment for BS 4:
#  UAV Index: 0
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 52337.0469
#   P_m_down_value: 1.0174
#   P_m_har_value: 0.1378
#   T_m_har_value: 2.2263
#   f_km_value: 1.9185
#   T_km_up_value: 0.4018
#   V_lm_vfly_value: 21.3962
#   V_lm_hfly_value: 88.7669
#   P_km_up_value: 6.7182
#   Angle1_row: Series:
# 0       0.600434
# 1      46.977517
# 2     109.409604
# 3      31.648736
# 4     164.086702
# 5     159.154226
# 6     142.352232
# 7     140.183001
# 8      96.587100
# 9      50.965225
# 10    108.429304
# 11    109.655845
# 12    138.879239
# 13     16.178925
# 14      9.101213
# 15     53.139042
# 16     98.007248
# 17     68.203538
# 18     45.584580
# 19     85.428840
# 20     20.718594
# 21     10.916340
# 22     31.375729
# 23     56.928042
# 24    105.929156
# 25    147.929776
# 26    165.907906
# 27     67.573968
# 28    150.812190
# 29    110.133275
# 30      1.225758
# 31    126.415268
# 32    135.587639
# 33     83.225945
# 34     53.193572
# 35    132.953227
# 36     67.226359
# 37     82.518105
# 38     97.481182
# 39    103.920024
# 40     51.995299
# 41    100.130239
# 42    171.144928
# 43     94.001591
# 44    106.762735
# 45    142.344379
# 46     12.189945
# 47     68.120732
# 48    107.827847
# 49    165.611808
# Name: 5, dtype: float64
#   Angle_row: Series:
# 0      95.649722
# 1     146.885147
# 2     170.072155
# 3      53.687541
# 4     104.901586
# 5       3.536663
# 6      19.652744
# 7      22.006053
# 8     159.652903
# 9      27.446438
# 10    135.570649
# 11      4.686452
# 12    100.408609
# 13     23.693539
# 14     84.627811
# 15     36.992948
# 16    103.660684
# 17    154.663431
# 18     79.449750
# 19     67.082240
# 20    106.833988
# 21    151.731140
# 22    117.013747
# 23     74.741190
# 24    114.822192
# 25     32.262577
# 26     76.365199
# 27     77.914310
# 28    164.351964
# 29     39.165401
# 30     26.188838
# 31     17.799869
# 32     12.493606
# 33     77.844063
# 34    153.902698
# 35    120.867625
# 36     17.693516
# 37    124.360660
# 38     12.146339
# 39    123.388437
# 40     83.272541
# 41    100.850651
# 42      9.720816
# 43    114.030222
# 44     78.794677
# 45      6.686173
# 46    140.355889
# 47    129.516868
# 48     23.090110
# 49      9.716449
# Name: 5, dtype: float64
#   Angle2_row: Series:
# 0      42.006991
# 1     132.358520
# 2     119.113068
# 3      63.981884
# 4       5.502533
# 5      42.933185
# 6      54.832569
# 7      67.898692
# 8     117.333493
# 9       6.725359
# 10    104.759414
# 11    134.424482
# 12     64.412910
# 13    111.512385
# 14     52.688073
# 15     63.875238
# 16    168.634912
# 17      5.944516
# 18     93.969787
# 19    106.991353
# 20     22.555967
# 21    102.914005
# 22    128.084998
# 23     55.252121
# 24    125.716238
# 25     91.270778
# 26    155.599486
# 27    132.095869
# 28     21.328692
# 29    175.174360
# 30     11.851720
# 31    174.541009
# 32    140.047230
# 33     59.607255
# 34    149.405965
# 35    109.066364
# 36      7.470803
# 37    135.261333
# 38     59.724331
# 39    102.866841
# 40    168.712547
# 41    105.114556
# 42     35.521455
# 43    170.157981
# 44    131.153719
# 45      0.213345
# 46     71.153537
# 47    139.781222
# 48    105.920958
# 49     42.438600
# Name: 5, dtype: float64
# --------------------
#
# Best Assignment for BS 2:
#  UAV Index: 1
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 53234.4712
#   P_m_down_value: 0.9092
#   P_m_har_value: 0.7848
#   T_m_har_value: 0.4714
#   f_km_value: 0.9217
#   T_km_up_value: 0.4023
#   V_lm_vfly_value: 72.6939
#   V_lm_hfly_value: 64.4919
#   P_km_up_value: 5.3115
#   Angle1_row: Series:
# 0     124.575126
# 1     129.801670
# 2      60.713401
# 3     168.601746
# 4      71.996327
# 5       6.432813
# 6     142.574824
# 7     151.068232
# 8     132.658310
# 9     174.996462
# 10     88.450347
# 11     61.937195
# 12     76.518895
# 13     48.715239
# 14    155.300122
# 15     53.225666
# 16    168.870980
# 17     12.600017
# 18    115.642301
# 19     49.108372
# 20    170.598073
# 21     55.573569
# 22     82.362819
# 23      5.388364
# 24    154.908669
# 25    164.815359
# 26     67.944407
# 27    124.152345
# 28    161.250259
# 29    163.337647
# 30    111.410509
# 31    152.006875
# 32     63.822796
# 33     49.831808
# 34    104.307184
# 35    144.888902
# 36    102.030040
# 37     93.078785
# 38    117.949012
# 39     79.606126
# 40     88.012875
# 41     88.854304
# 42     76.924121
# 43     79.212437
# 44    128.018432
# 45     84.182969
# 46    159.714764
# 47     41.987185
# 48    174.040946
# 49     89.754644
# Name: 21, dtype: float64
#   Angle_row: Series:
# 0     140.085198
# 1     122.974584
# 2      20.282329
# 3     121.135034
# 4     115.929800
# 5       3.485440
# 6      93.726393
# 7      17.607077
# 8      96.700469
# 9     167.746994
# 10     77.108176
# 11     73.552104
# 12     27.300849
# 13    151.428191
# 14     90.937285
# 15    145.117618
# 16     16.093470
# 17    102.336567
# 18    161.303708
# 19    129.607159
# 20    112.097864
# 21    146.980747
# 22     98.248221
# 23     55.864130
# 24     10.512933
# 25     33.263861
# 26     47.127558
# 27     71.678430
# 28      0.526536
# 29    175.913524
# 30     47.600833
# 31     95.828251
# 32      1.881378
# 33     56.565326
# 34     62.830239
# 35     13.382615
# 36     73.087973
# 37     57.627919
# 38     73.845357
# 39     63.393981
# 40    114.279187
# 41    117.309711
# 42     49.076928
# 43    133.532649
# 44     19.545121
# 45     54.882795
# 46    128.255615
# 47     82.562778
# 48     95.959205
# 49     33.588547
# Name: 21, dtype: float64
#   Angle2_row: Series:
# 0      74.261961
# 1     112.942214
# 2     151.644695
# 3      57.603027
# 4      51.448255
# 5     143.007300
# 6      52.331160
# 7     127.970795
# 8      80.571862
# 9      71.997810
# 10    133.562746
# 11     40.030711
# 12     63.860459
# 13    156.486732
# 14    109.195053
# 15    114.367578
# 16     83.479587
# 17     83.547265
# 18    122.897130
# 19    120.913980
# 20     67.308617
# 21    153.483736
# 22    176.857295
# 23      2.990441
# 24     48.845001
# 25    158.093942
# 26    124.942703
# 27     22.075022
# 28     14.027225
# 29     12.339921
# 30    118.448808
# 31    140.233472
# 32     57.767728
# 33     65.396520
# 34    104.907688
# 35     62.041436
# 36     79.247959
# 37     97.834095
# 38     39.139785
# 39    143.425782
# 40    109.592724
# 41    122.671351
# 42    131.245104
# 43    167.820283
# 44    104.378319
# 45     56.034631
# 46     52.321067
# 47    106.541081
# 48     78.658796
# 49     89.092401
# Name: 21, dtype: float64
# --------------------
#
# Best Assignment for BS 0:
#  UAV Index: 3
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 55222.5229
#   P_m_down_value: 0.1974
#   P_m_har_value: 0.1353
#   T_m_har_value: 0.3937
#   f_km_value: 0.8347
#   T_km_up_value: 0.4037
#   V_lm_vfly_value: 66.6344
#   V_lm_hfly_value: 66.8574
#   P_km_up_value: 6.2707
#   Angle1_row: Series:
# 0      76.267654
# 1      81.422305
# 2     132.241222
# 3      69.129860
# 4      28.089600
# 5     136.664021
# 6     123.939352
# 7      27.333332
# 8      16.734789
# 9      11.823278
# 10    108.293631
# 11     56.643737
# 12     52.921650
# 13    118.873387
# 14     53.579715
# 15     70.617304
# 16     99.349636
# 17     50.939219
# 18     79.750986
# 19    120.264697
# 20    149.290440
# 21     10.193946
# 22     36.080532
# 23    128.986302
# 24     26.457226
# 25     68.350412
# 26     75.052635
# 27     76.019673
# 28     83.088389
# 29     11.200406
# 30     17.751409
# 31     57.833657
# 32     70.696433
# 33    109.474438
# 34     88.046674
# 35     21.805610
# 36     39.487174
# 37     50.788607
# 38     19.901508
# 39     62.774903
# 40     51.288738
# 41     30.809959
# 42    169.317003
# 43    108.319259
# 44    133.701611
# 45    177.921096
# 46     41.908463
# 47    111.838841
# 48    177.597566
# 49     17.279991
# Name: 11, dtype: float64
#   Angle_row: Series:
# 0      71.093420
# 1     117.176311
# 2     177.369062
# 3      87.190656
# 4      57.333286
# 5      68.620816
# 6     106.277195
# 7     128.828184
# 8     103.148427
# 9      24.774205
# 10    123.647441
# 11    108.413388
# 12     29.526227
# 13    142.675758
# 14    153.738393
# 15    163.671811
# 16     60.983124
# 17     97.847862
# 18    128.615459
# 19    156.283014
# 20    103.359309
# 21     73.087225
# 22     94.902055
# 23    140.533781
# 24     89.907863
# 25    109.908993
# 26    150.076063
# 27     16.723191
# 28     16.233387
# 29    161.544735
# 30    127.150051
# 31     62.534656
# 32     32.029402
# 33     27.294803
# 34      4.624176
# 35    111.818568
# 36    130.518813
# 37     48.609911
# 38    171.735585
# 39    142.389602
# 40      8.260281
# 41    152.165728
# 42    119.882831
# 43     64.980940
# 44     97.554305
# 45    142.949421
# 46     82.432206
# 47     60.632606
# 48    121.330081
# 49    139.868420
# Name: 11, dtype: float64
#   Angle2_row: Series:
# 0      29.956870
# 1     140.251706
# 2     103.167212
# 3     124.027088
# 4     159.557622
# 5      98.725344
# 6     104.547199
# 7      63.346282
# 8     139.467368
# 9     119.136386
# 10     54.728162
# 11     75.840291
# 12     47.361038
# 13    171.581999
# 14    121.165241
# 15    156.570764
# 16    120.648980
# 17      5.513301
# 18     54.851939
# 19     53.835855
# 20     98.725952
# 21    123.432551
# 22     63.895514
# 23    139.672657
# 24    179.484705
# 25     65.096452
# 26    123.262886
# 27     62.348885
# 28     39.226559
# 29    138.722613
# 30    136.467242
# 31    170.795342
# 32     42.723820
# 33     19.744984
# 34     44.512603
# 35    131.739742
# 36    176.487926
# 37     82.512453
# 38    167.366678
# 39    154.424954
# 40    120.060509
# 41     85.564167
# 42    130.847773
# 43    128.658838
# 44     77.028891
# 45    120.764127
# 46    147.002425
# 47    115.218238
# 48     24.493904
# 49     31.994127
# Name: 11, dtype: float64
# --------------------
#
# Best Assignment for BS 3:
#  UAV Index: 7
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 62957.5470
#   P_m_down_value: 0.9554
#   P_m_har_value: 0.4164
#   T_m_har_value: 0.7701
#   f_km_value: 0.9055
#   T_km_up_value: 0.5964
#   V_lm_vfly_value: 22.4843
#   V_lm_hfly_value: 55.0057
#   P_km_up_value: 6.1915
#   Angle1_row: Series:
# 0      67.267172
# 1      15.580315
# 2     136.425750
# 3     130.210050
# 4     173.740429
# 5     175.662720
# 6     139.103541
# 7     118.392252
# 8      63.314755
# 9     171.026817
# 10     61.324655
# 11      1.031516
# 12     28.050517
# 13    114.281842
# 14    141.927908
# 15     89.413933
# 16    156.314183
# 17     54.034975
# 18     25.650541
# 19     96.181714
# 20     61.971261
# 21     32.544374
# 22    161.262249
# 23      9.544527
# 24     33.561741
# 25    128.191905
# 26    103.021474
# 27     89.765928
# 28     92.437918
# 29     28.596698
# 30    179.794336
# 31     13.972599
# 32      2.625744
# 33     47.641128
# 34     70.426622
# 35    115.373778
# 36      2.772605
# 37    140.575864
# 38     36.526272
# 39    145.605341
# 40     45.889866
# 41      7.788611
# 42     27.291225
# 43     83.586563
# 44      6.330627
# 45     11.352934
# 46     67.634739
# 47     33.098984
# 48     14.777918
# 49     68.257831
# Name: 4, dtype: float64
#   Angle_row: Series:
# 0     126.113531
# 1       4.026667
# 2      15.849699
# 3     143.822378
# 4      19.099744
# 5     143.859728
# 6     178.159509
# 7      53.970188
# 8      80.765708
# 9      93.891960
# 10    130.916129
# 11     89.996414
# 12     74.804196
# 13     75.073533
# 14     36.931091
# 15     10.362978
# 16     10.654617
# 17    168.603834
# 18     72.699190
# 19     72.718763
# 20      1.913116
# 21     20.207862
# 22     54.548078
# 23    114.836844
# 24     75.099550
# 25     78.740839
# 26     66.379770
# 27     57.199828
# 28     57.895295
# 29     11.254611
# 30     53.818965
# 31     28.073736
# 32     38.957229
# 33     27.105584
# 34     23.272327
# 35     32.180534
# 36    122.693548
# 37     30.030923
# 38      7.808200
# 39    122.309908
# 40     73.012342
# 41    130.432335
# 42    165.317702
# 43     50.956321
# 44     29.533083
# 45     61.822679
# 46     91.872546
# 47     91.500336
# 48    178.982342
# 49      9.398024
# Name: 4, dtype: float64
#   Angle2_row: Series:
# 0      71.526499
# 1     158.006791
# 2      62.163958
# 3      70.557842
# 4       0.180292
# 5     178.824865
# 6     111.000461
# 7     126.730106
# 8     168.014016
# 9      39.212848
# 10     15.392780
# 11      5.858435
# 12    176.753222
# 13     93.941327
# 14     39.223387
# 15     94.987643
# 16    100.516084
# 17    176.229609
# 18     72.783118
# 19     19.432155
# 20    162.826521
# 21     25.734913
# 22    149.760323
# 23     94.100665
# 24     60.257040
# 25     22.447327
# 26     68.369022
# 27    154.671351
# 28     85.149655
# 29    150.883496
# 30    124.477151
# 31     45.826326
# 32     87.065719
# 33     58.956295
# 34     87.118589
# 35    138.857586
# 36     20.454918
# 37     12.486016
# 38     19.964707
# 39     23.124104
# 40    138.085790
# 41      8.748793
# 42    179.202050
# 43     43.575903
# 44    176.625567
# 45    120.027971
# 46    108.404995
# 47    122.860405
# 48    157.154038
# 49     46.916224
# Name: 4, dtype: float64
# --------------------
#
# --- UAVs without Assigned Base Stations ---
#   UAV 4 : No BS is assigned
# --------------------
#   UAV 5 : No BS is assigned
# --------------------
#   UAV 6 : No BS is assigned
# --------------------

# %%
# Plotting graph for Sum of Fitness vs num_irs_ele
irs_element_values =range(10, 51, 5)
plt.figure(figsize=(10, 6))
plt.plot(irs_element_values, fitness_sums_GA, marker='o', linestyle='-')
plt.xlabel('Number of IRS Elements ')
plt.ylabel('Energy ')
plt.title('Energy vs Number of IRS Elements')
plt.xticks(irs_element_values)
plt.tight_layout()
plt.show()

# %%
num_population=25
num_bs = 5
num_generation = 1
num_uav_irs = 8
population_size = 25

numerical_keys_for_hc = [
    'P_m_down_value', 'P_m_har_value', 'T_m_har_value',
    'f_km_value', 'V_lm_vfly_value', 'V_lm_hfly_value',
    'P_km_up_value','f_km_value',
]

fitness_sums_HC = [] # Store sum of fitness values for each num_irs_ele
irs_element_values = range(10, 51, 5) # num_irs_ele values from 10 to 50 in steps of 5


for num_irs_ele in irs_element_values: # Loop through different num_irs_ele values
    print(f"Calculation for num_irs_ele: {num_irs_ele}")

    Angle_df=pd.read_csv(r'Angle.csv') # number of IRS is 500 store in each column
    h_l_km_df=pd.read_csv(r'h_l_km.csv') # number of IRS is 500 store in each column
    h_l_m_df=pd.read_csv(r'h_l_m.csv') # number of IRS is 500 store in each column

    Angle_UP_df=pd.read_csv(r'Angle1.csv') # number of IRS is 500 store in each column
    g_l_km_df=pd.read_csv(r'h_l_km1.csv') # number of IRS is 500 store in each column
    g_l_m_df=pd.read_csv(r'h_l_m1.csv') # number of IRS is 500 store in each column # corrected filename

    Angle_har_df=pd.read_csv(r'Angle2.csv') # number of IRS is 500 store in each column
    f_l_km_df=pd.read_csv(r'h_l_km2.csv') # number of IRS is 500 store in each column
    f_l_m_df=pd.read_csv(r'h_l_m2.csv') # number of IRS is 500 store in each column # corrected filename


    all_best_combinations = []
    all_best_individuals = []

    for l in range(num_bs):
        all_best_individuals_bs = []
        P_m_har_value = P_m_har.values[l]
        T_m_har_value = T_m_har.values[l]
        P_m_down_value = P_m_down.values[l]

        index_list = list(range(500))
        random.shuffle(index_list)
        unique_row_indices = index_list[:population_size]

        h_l_km_df_bs = h_l_km_df.iloc[unique_row_indices, :num_irs_ele].reset_index(drop=True) # Sliced columns
        g_l_km_df_bs = g_l_km_df.iloc[unique_row_indices, :num_irs_ele].reset_index(drop=True) # Sliced columns
        f_l_km_df_bs = f_l_km_df.iloc[unique_row_indices, :num_irs_ele].reset_index(drop=True) # Sliced columns
        f_km_bs = f_km[unique_row_indices].reset_index(drop=True)
        valid_indices = [i for i in unique_row_indices if i < len(P_km_up)]
        P_km_up_bs = P_km_up.iloc[valid_indices].reset_index(drop=True)


        for k in range(num_uav_irs):
            best_fitness = float('inf')
            best_individual = {}
            population = []
            V_lm_vfly_value = V_lm_vfly.values[k]
            V_lm_hfly_value = V_lm_hfly.values[k]
            D_l_hfly_value = D_l_hfly
            Wl_value = Wl
            Sub_value=0

            for i in range(len(valid_indices)):
                # Slice the Angle_UP_df, g_l_m_df, g_l_km_df_bs to num_irs_ele columns
                Angle_UP_df_sliced = Angle_UP_df.iloc[i, :num_irs_ele]
                g_l_m_df_sliced = g_l_m_df.iloc[k, :num_irs_ele]
                g_l_km_df_bs_sliced = g_l_km_df_bs.iloc[i, :num_irs_ele]

                h_il_up_value=h_kml_down(Angle_UP_df_sliced, g_l_m_df_sliced, g_l_km_df_bs_sliced, num_irs_ele) # Pass num_irs_ele
                Sub_value+=sub(P_km_up_bs[i],h_il_up_value)


            initial_solution_data = {}
            i=0 # Using first index for initialization
            f_km_value = f_km_bs[i] # Use BS-specific f_km
            P_km_up_value = P_km_up_bs[i] # Use BS-specific P_km_up

            Angle_row = Angle_df.iloc[i, :] # Use BS-specific Angle_df
            h_l_m_row = h_l_m_df.iloc[k, :] # Use BS-specific h_l_m_df
            h_l_km_row = h_l_km_df_bs.iloc[i, :] # Use BS-specific h_l_km_df
            Angle1_row = Angle_UP_df.iloc[i, :] # Use BS-specific Angle_UP_df
            g_l_m_row = g_l_m_df.iloc[k, :] # Use BS-specific g_l_m_df
            g_l_km_row = g_l_km_df_bs.iloc[i, :] # Use BS-specific g_l_km_df
            Angle2_row = Angle_har_df.iloc[i, :] # Use BS-specific Angle_har_df
            f_l_m_row = f_l_m_df.iloc[k, :] # Use BS-specific f_l_m_df
            f_l_km_row = f_l_km_df_bs.iloc[i, :] # Use BS-specific f_l_km_df


            # Calculate Bh and p_l_b


            # Calculate power values
            P_lm_blade_value = P_lm_blade(Nr, p_l_b, V_tip, V_lm_hfly_value)
            P_lm_fuselage_value = P_lm_fuselage(Cd, Af, Bh, V_lm_hfly_value)
            P_lm_induced_value = P_lm_induced(Nr, Bh, Ar, Wl_value, V_lm_vfly_value)

            # Calculate time and energy values
            T_l_vfly_value = H_value / V_lm_vfly_value
            T_l_hfly_value = D_l_hfly_value / V_lm_hfly_value # Corrected: D_l_hfly / V_lm_hfly
            E_ml_har_value = P_m_har_value * T_m_har_value
            h_kml_down_value=h_kml_down(Angle_row,h_l_m_row,h_l_km_row,num_irs_ele) # Pass Series
            h_ml_worst_value=h_ml_worst(h_kml_down_value,sigma_km)
            R_ml_down_value=R_ml_down(B,P_m_down_value,h_ml_worst_value)
            T_ml_down_value=D_m_current/R_ml_down_value
            E_ml_down_value = P_m_down_value * T_ml_down_value
            T_km_com_value = D_km / f_km_value
            h_kml_up_value=h_kml_down(Angle1_row,g_l_m_row,g_l_km_row,num_irs_ele) # Pass Series, using same function, might need different one if logic is different

            R_kml_up_value=R_kml_up(B,P_km_up_value,h_kml_up_value,Sub_value,sigma_km)
            T_km_up_value=D_m_current/R_kml_up_value # equation number 5
            T_lm_hov_value = T_lm_hov(T_km_com_value, T_km_up_value, T_ml_down_value)
            P_l_hov_value = P_l_hov(Wl_value, p_l_b, Nr, Ar, Bh)
            P_l_vfly_value = P_l_vfly(Wl_value, V_lm_vfly_value, p_l_b, Nr, Ar, Bh)
            P_lm_hfly_value = P_lm_hfly(P_lm_blade_value, P_lm_fuselage_value, P_lm_induced_value)
            E_ml_UAV_value = E_ml_UAV(P_l_vfly_value, T_l_vfly_value, P_lm_hfly_value, T_l_hfly_value, P_l_hov_value, T_lm_hov_value)

            # Calculate fitness for initial solution
            initial_fitness = Fitness(E_ml_har_value, E_ml_down_value, E_ml_UAV_value)

            current_solution = {
                'fitness': initial_fitness,
                'data': {
                    'P_m_down_value': P_m_down_value,
                    'P_m_har_value': P_m_har_value,
                    'T_m_har_value': T_m_har_value,
                    'f_km_value': f_km_value,
                    'T_km_up_value': T_km_up_value,
                    'V_lm_vfly_value': V_lm_vfly_value,
                    'V_lm_hfly_value': V_lm_hfly_value,
                    'P_km_up_value':P_km_up_value,
                    'Angle1_row':Angle1_row.iloc[:num_irs_ele].copy(), # Sliced Series here
                    'Angle_row':Angle_row.iloc[:num_irs_ele].copy(), # Sliced Series here
                    'Angle2_row': Angle2_row.iloc[:num_irs_ele].copy(), # Sliced Series here
                }
            }
            best_individual = current_solution
            best_fitness = initial_fitness


            generations_data = []
            for j in range(num_generation): # Hill Climbing iterations
                # Generate neighbor solution by perturbing the current solution
                neighbor_solution_data = current_solution['data'].copy()
                for i in range(10):
                    for key in numerical_keys_for_hc:
                        if key in ['Angle1_row','Angle_row','Angle2_row']: # Handle Angle Series
                            neighbor_solution_data[key] = pd.Series(index=Angle_df.columns, dtype='float64') # Initialize empty Series for child
                            for col in Angle_df.columns: # Iterate through each column (angle direction)
                                neighbor_solution_data[key][col] = random.normal(loc=0, scale=1, size=(1))[0]
                        else:
                                neighbor_solution_data[key] += random.normal(loc=0, scale=1, size=(1))[0] # Reduced scale for smaller perturbations in HC

                    # Compute neighbor fitness
                    def compute_fitness(data):
                        P_m_down_value = data['P_m_down_value']
                        P_m_har_value = data['P_m_har_value']
                        T_m_har_value = data['T_m_har_value']
                        f_km_value = data['f_km_value']
                        T_km_up_value = data['T_km_up_value']
                        V_lm_vfly_value = data['V_lm_vfly_value']
                        V_lm_hfly_value = data['V_lm_hfly_value']
                        P_km_up_value=data['P_km_up_value']
                        Angle_row = data['Angle_row'] # Retrieve angle row from neighbor data
                        Angle1_row = data['Angle1_row'] # Retrieve angle row from neighbor data
                        Angle2_row = data['Angle2_row'] # Retrieve angle row from neighbor data


                        # Calculate Bh and p_l_b for neighbor
                        Bh = (1 - 2.2558 * pow(10, 4) * H_value)
                        Bh = max(1, Bh)
                        p_l_b = (delta / 8) * Bh * Ar * s * pow(V_tip, 3)

                        # Calculate power values
                        P_lm_blade_value = P_lm_blade(Nr, p_l_b, V_tip, V_lm_hfly_value)
                        P_lm_fuselage_value = P_lm_fuselage(Cd, Af, Bh, V_lm_hfly_value)
                        P_lm_induced_value = P_lm_induced(Nr, Bh, Ar, Wl_value, V_lm_vfly_value)

                        # Calculate time and energy values
                        T_l_vfly_value = H_value / V_lm_vfly_value
                        T_l_hfly_value = D_l_hfly_value / V_lm_hfly_value # Corrected: D_l_hfly / V_lm_hfly
                        E_ml_har_value = P_m_har_value * T_m_har_value # Corrected:

                        h_kml_down_value_compute=h_kml_down(Angle_row,h_l_m_row,h_l_km_row,num_irs_ele) # Using original Angle_row, h_l_m_row, h_l_km_row for neighbor as well - might need to be based on neighbor data if angles are also part of optimization
                        h_ml_worst_value=h_ml_worst(h_kml_down_value_compute,sigma_km)
                        R_ml_down_value=R_ml_down(B,P_m_down_value,h_ml_worst_value)
                        if R_ml_down_value <= 0: # check if R_ml_down_value is zero or negative
                            R_ml_down_value = 1e-9 # Assign a small positive value to avoid division by zero
                        T_ml_down_value=D_m_current/R_ml_down_value
                        E_ml_down_value = P_m_down_value * T_ml_down_value
                        T_km_com_value = D_km / f_km_value
                        T_lm_hov_value = T_lm_hov(T_km_com_value, T_km_up_value, T_ml_down_value)
                        P_l_hov_value = P_l_hov(Wl_value, p_l_b, Nr, Ar, Bh)
                        P_l_vfly_value = P_l_vfly(Wl_value, V_lm_vfly_value, p_l_b, Nr, Ar, Bh)
                        P_lm_hfly_value = P_lm_hfly(P_lm_blade_value, P_lm_fuselage_value, P_lm_induced_value)
                        E_ml_UAV_value = E_ml_UAV(P_l_vfly_value, T_l_vfly_value, P_lm_hfly_value, T_l_hfly_value, P_l_hov_value, T_lm_hov_value)
                        h_kml_har_value_compute=h_kml_down(Angle2_row,f_l_m_row,f_l_km_row,num_irs_ele) # Corrected index to Angle2_row
                        E_kml_har_value=E_kml_har(P_m_har_value,T_m_har_value,h_kml_har_value_compute) # Corrected function call for E_kml_har
                        E_kml_com_value = E_km_com(f_km_value, T_km_com_value)
                        E_kml_up_value=E_kml_up(P_km_up_value,T_km_up_value)


                        # Calculate fitness
                        fitness_value = Fitness(E_ml_har_value, E_ml_down_value, E_ml_UAV_value)
                        current_data = {
                            'P_m_down_value': P_m_down_value,
                            'P_m_har_value': P_m_har_value,
                            'T_m_har_value': T_m_har_value,
                            'f_km_value': f_km_value,
                            'T_km_up_value': T_km_up_value,
                            'V_lm_vfly_value': V_lm_vfly_value,
                            'V_lm_hfly_value': V_lm_hfly_value,
                            'P_km_up_value':P_km_up_value,
                            'Angle1_row':Angle1_row,
                            'Angle_row':Angle_row,
                            'Angle2_row': Angle2_row, # Carry forward original index
                                                                                }
                        if V_lm_hfly_value>0 and T_m_har_value>0 and T_ml_down_value>0 and T_km_up_value>0 and P_m_har_value<=p_max and P_m_down_value<=p_max and P_km_up_value<=p_km_max and (T_km_com_value+T_km_up_value+T_ml_down_value)<=T_m and f_km_value>0  and E_kml_har_value>=(E_kml_up_value+E_kml_com_value) and V_lm_vfly_value>0:
                            return fitness_value, current_data
                        else:
                            return  float('inf'),{} # Return empty dict instead of float('inf') for data


                    neighbor_fitness, neighbor_data1 = compute_fitness(neighbor_solution_data)


                    # Decide whether to accept the neighbor
                    if neighbor_fitness < current_solution['fitness']:
                        current_solution = {'fitness': neighbor_fitness, 'data': neighbor_data1}


                generations_data.append(current_solution.copy())
                # print(population[0])

            best_individual_pair = current_solution.copy()
            best_individual_pair['generation'] = j + 1 # Use last j from loop, corrected index
            best_individual_pair['type'] = 'GA'
            best_individual_pair['bs_index'] = l
            best_individual_pair['uav_index'] = k
            all_best_individuals_bs.append(best_individual_pair)

            all_best_combinations.append({
                'bs_index': l,
                'uav_index': k,
                'best_fitness': current_solution['fitness'],
                'best_individual': best_individual_pair,
                'generation_fitness': [gen['fitness'] for gen in generations_data],
                'unique_row_indices': unique_row_indices # Store unique_row_indices in best_combinations
            })
            # print(f"Best Fitness for BS {l}, UAV {k}: {population[0]['fitness']:.4f}")

        # Find best individual for current BS across all UAVs
        best_individual_for_bs = min(all_best_individuals_bs, key=lambda x: x['fitness'])
        # print(f"Best Fitness for BS {l} across all UAVs: {best_individual_for_bs['fitness']:.4f}")


    # Select the best unique Base station and UAV-IRS pair using Auction based method
    combination_lookup = {}
    for combination in all_best_combinations:
        if combination['bs_index'] not in combination_lookup:
            combination_lookup[combination['bs_index']] = {}
        combination_lookup[combination['bs_index']][combination['uav_index']] = combination

    # Auction-based assignment
    best_assignments = []
    unassigned_bs = list(range(num_bs))
    unassigned_uavs = list(range(num_uav_irs))

    while unassigned_bs and unassigned_uavs:
        best_combination_overall = None

        for l in unassigned_bs:
            best_fitness_for_bs = float('inf')
            best_combination_for_bs = None
            for k in unassigned_uavs:
                if l in combination_lookup and k in combination_lookup[l]:
                    combination = combination_lookup[l][k]
                    if combination['best_fitness'] < best_fitness_for_bs: # Use 'best_fitness' instead of 'best_individual']['fitness']
                        best_fitness_for_bs = combination['best_fitness']
                        best_combination_for_bs = combination

            if best_combination_for_bs:
                if best_combination_overall is None or best_combination_for_bs['best_fitness'] < best_combination_overall['best_fitness']: # Compare with current best overall
                    best_combination_overall = best_combination_for_bs

        if best_combination_overall:
            best_assignments.append(best_combination_overall)
            unassigned_bs.remove(best_combination_overall['bs_index'])
            unassigned_uavs.remove(best_combination_overall['uav_index'])

    # Print and Plotting
    print(f"\n--- Best Unique UAV Assignments (Auction Based Method) ---")
    best_pair_for_plot = None
    min_fitness_for_plot = float('inf')

    sum_fitness_current_p_max = 0 # Sum of best fitness for current p_max
    for assignment in best_assignments:
        print(f"\nBest Assignment for BS {assignment['bs_index']}:")
        print(f" UAV Index: {assignment['uav_index']}")
        best_ind = assignment['best_individual']
        print(f" Best Individual:")
        print(f"  Generation: {best_ind['generation']}, Type: {best_ind['type']}")
        print(f"  Fitness: {best_ind['fitness']:.4f}") # Print current best fitness only
        unique_indices_to_print = assignment['unique_row_indices'] # Retrieve unique_row_indices
        for key, value in best_ind['data'].items():
            if isinstance(value, pd.Series):
                print(f"  {key}: Series: \n{value}") # Print the entire Series directly - corrected line
            elif isinstance(value, list): # Handle list type values explicitly
                print(f"  {key}: {value}") # print list directly without formatting
            else:
                print(f"  {key}: {value:.4f}") # Format scalar values

        print("-" * 20)
        sum_fitness_current_p_max += best_ind['fitness'] # Sum fitness values

        if assignment['best_individual']['fitness'] < min_fitness_for_plot:
            min_fitness_for_plot = assignment['best_individual']['fitness']
            best_pair_for_plot = assignment

    fitness_sums_HC.append(sum_fitness_current_p_max) # Store sum of fitness for this p_max

    # Unassigned BS/UAVs
    if unassigned_bs:
        print("\n--- Base Stations without Assigned UAVs ---")
        for bs_index in unassigned_bs:
            print(f"  BS {bs_index} : No UAV is assigned")
            print("-" * 20)

    if unassigned_uavs:
        print("\n--- UAVs without Assigned Base Stations ---")
        for uav_index in unassigned_uavs:
            print(f"  UAV {uav_index} : No BS is assigned")
            print("-" * 20)
# Out:
# Calculation for num_irs_ele: 10
#
# --- Best Unique UAV Assignments (Auction Based Method) ---
#
# Best Assignment for BS 1:
#  UAV Index: 5
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 40399.4502
#   P_m_down_value: 1.7524
#   P_m_har_value: 0.1776
#   T_m_har_value: 0.1817
#   f_km_value: 3.1665
#   T_km_up_value: 0.2136
#   V_lm_vfly_value: 46.7151
#   V_lm_hfly_value: 34.8138
#   P_km_up_value: 9.5369
#   Angle1_row: Series:
# 0     23.094594
# 1      5.875864
# 2     33.462215
# 3    113.455504
# 4    141.308037
# 5     88.359471
# 6    156.697950
# 7    107.600529
# 8     67.455781
# 9     59.842569
# Name: 0, dtype: float64
#   Angle_row: Series:
# 0    109.636284
# 1     32.019189
# 2    133.727994
# 3    178.387272
# 4     71.930267
# 5    167.406641
# 6     84.470200
# 7     39.691029
# 8      9.299199
# 9      9.438781
# Name: 0, dtype: float64
#   Angle2_row: Series:
# 0     11.752947
# 1     84.771303
# 2     77.449059
# 3    176.780151
# 4    146.369943
# 5    147.888861
# 6    113.170820
# 7    149.949867
# 8     41.271809
# 9    135.585468
# Name: 0, dtype: float64
# --------------------
#
# Best Assignment for BS 4:
#  UAV Index: 7
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 46254.9289
#   P_m_down_value: 1.2277
#   P_m_har_value: 1.3430
#   T_m_har_value: 1.1271
#   f_km_value: 5.2478
#   T_km_up_value: 0.4453
#   V_lm_vfly_value: 20.6716
#   V_lm_hfly_value: 51.3047
#   P_km_up_value: 5.0300
#   Angle1_row: Series:
# 0     23.094594
# 1      5.875864
# 2     33.462215
# 3    113.455504
# 4    141.308037
# 5     88.359471
# 6    156.697950
# 7    107.600529
# 8     67.455781
# 9     59.842569
# Name: 0, dtype: float64
#   Angle_row: Series:
# 0    109.636284
# 1     32.019189
# 2    133.727994
# 3    178.387272
# 4     71.930267
# 5    167.406641
# 6     84.470200
# 7     39.691029
# 8      9.299199
# 9      9.438781
# Name: 0, dtype: float64
#   Angle2_row: Series:
# 0     11.752947
# 1     84.771303
# 2     77.449059
# 3    176.780151
# 4    146.369943
# 5    147.888861
# 6    113.170820
# 7    149.949867
# 8     41.271809
# 9    135.585468
# Name: 0, dtype: float64
# --------------------
#
# Best Assignment for BS 2:
#  UAV Index: 2
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 46691.2005
#   P_m_down_value: 1.6360
#   P_m_har_value: 7.6989
#   T_m_har_value: 0.3745
#   f_km_value: 3.0792
#   T_km_up_value: 0.5453
#   V_lm_vfly_value: 61.8288
#   V_lm_hfly_value: 61.7881
#   P_km_up_value: 5.1232
#   Angle1_row: Series:
# 0     23.094594
# 1      5.875864
# 2     33.462215
# 3    113.455504
# 4    141.308037
# 5     88.359471
# 6    156.697950
# 7    107.600529
# 8     67.455781
# 9     59.842569
# Name: 0, dtype: float64
#   Angle_row: Series:
# 0    109.636284
# 1     32.019189
# 2    133.727994
# 3    178.387272
# 4     71.930267
# 5    167.406641
# 6     84.470200
# 7     39.691029
# 8      9.299199
# 9      9.438781
# Name: 0, dtype: float64
#   Angle2_row: Series:
# 0     11.752947
# 1     84.771303
# 2     77.449059
# 3    176.780151
# 4    146.369943
# 5    147.888861
# 6    113.170820
# 7    149.949867
# 8     41.271809
# 9    135.585468
# Name: 0, dtype: float64
# --------------------
#
# Best Assignment for BS 0:
#  UAV Index: 1
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 47596.7911
#   P_m_down_value: 0.5610
#   P_m_har_value: 1.3470
#   T_m_har_value: 0.9120
#   f_km_value: 1.1751
#   T_km_up_value: 0.3181
#   V_lm_vfly_value: 71.5121
#   V_lm_hfly_value: 65.0072
#   P_km_up_value: 8.1219
#   Angle1_row: Series:
# 0     23.094594
# 1      5.875864
# 2     33.462215
# 3    113.455504
# 4    141.308037
# 5     88.359471
# 6    156.697950
# 7    107.600529
# 8     67.455781
# 9     59.842569
# Name: 0, dtype: float64
#   Angle_row: Series:
# 0    109.636284
# 1     32.019189
# 2    133.727994
# 3    178.387272
# 4     71.930267
# 5    167.406641
# 6     84.470200
# 7     39.691029
# 8      9.299199
# 9      9.438781
# Name: 0, dtype: float64
#   Angle2_row: Series:
# 0     11.752947
# 1     84.771303
# 2     77.449059
# 3    176.780151
# 4    146.369943
# 5    147.888861
# 6    113.170820
# 7    149.949867
# 8     41.271809
# 9    135.585468
# Name: 0, dtype: float64
# --------------------
#
# Best Assignment for BS 3:
#  UAV Index: 0
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 175565.6916
#   P_m_down_value: 0.9554
#   P_m_har_value: 0.4164
#   T_m_har_value: 0.7701
#   f_km_value: 0.8517
#   T_km_up_value: 4.3761
#   V_lm_vfly_value: 20.2764
#   V_lm_hfly_value: 88.5908
#   P_km_up_value: 0.8077
#   Angle1_row: Series:
# 0     23.094594
# 1      5.875864
# 2     33.462215
# 3    113.455504
# 4    141.308037
# 5     88.359471
# 6    156.697950
# 7    107.600529
# 8     67.455781
# 9     59.842569
# Name: 0, dtype: float64
#   Angle_row: Series:
# 0    109.636284
# 1     32.019189
# 2    133.727994
# 3    178.387272
# 4     71.930267
# 5    167.406641
# 6     84.470200
# 7     39.691029
# 8      9.299199
# 9      9.438781
# Name: 0, dtype: float64
#   Angle2_row: Series:
# 0     11.752947
# 1     84.771303
# 2     77.449059
# 3    176.780151
# 4    146.369943
# 5    147.888861
# 6    113.170820
# 7    149.949867
# 8     41.271809
# 9    135.585468
# Name: 0, dtype: float64
# --------------------
#
# --- UAVs without Assigned Base Stations ---
#   UAV 3 : No BS is assigned
# --------------------
#   UAV 4 : No BS is assigned
# --------------------
#   UAV 6 : No BS is assigned
# --------------------
# Calculation for num_irs_ele: 15
#
# --- Best Unique UAV Assignments (Auction Based Method) ---
#
# Best Assignment for BS 1:
#  UAV Index: 7
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 44553.4393
#   P_m_down_value: 0.4167
#   P_m_har_value: 0.0550
#   T_m_har_value: 0.1553
#   f_km_value: 2.3590
#   T_km_up_value: 0.2920
#   V_lm_vfly_value: 22.6113
#   V_lm_hfly_value: 55.7426
#   P_km_up_value: 5.7822
#   Angle1_row: Series:
# 0      23.094594
# 1       5.875864
# 2      33.462215
# 3     113.455504
# 4     141.308037
# 5      88.359471
# 6     156.697950
# 7     107.600529
# 8      67.455781
# 9      59.842569
# 10     35.252186
# 11    108.365955
# 12     65.187590
# 13     50.935502
# 14     89.536183
# Name: 0, dtype: float64
#   Angle_row: Series:
# 0     109.636284
# 1      32.019189
# 2     133.727994
# 3     178.387272
# 4      71.930267
# 5     167.406641
# 6      84.470200
# 7      39.691029
# 8       9.299199
# 9       9.438781
# 10    110.124557
# 11    130.063755
# 12    176.637165
# 13     76.885776
# 14    117.355833
# Name: 0, dtype: float64
#   Angle2_row: Series:
# 0      11.752947
# 1      84.771303
# 2      77.449059
# 3     176.780151
# 4     146.369943
# 5     147.888861
# 6     113.170820
# 7     149.949867
# 8      41.271809
# 9     135.585468
# 10      0.486053
# 11      6.624886
# 12    138.690123
# 13    104.555036
# 14     39.070498
# Name: 0, dtype: float64
# --------------------
#
# Best Assignment for BS 4:
#  UAV Index: 2
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 45389.9760
#   P_m_down_value: 5.7524
#   P_m_har_value: 0.1721
#   T_m_har_value: 0.2031
#   f_km_value: 3.9095
#   T_km_up_value: 0.5294
#   V_lm_vfly_value: 58.3083
#   V_lm_hfly_value: 61.9958
#   P_km_up_value: 8.2058
#   Angle1_row: Series:
# 0      23.094594
# 1       5.875864
# 2      33.462215
# 3     113.455504
# 4     141.308037
# 5      88.359471
# 6     156.697950
# 7     107.600529
# 8      67.455781
# 9      59.842569
# 10     35.252186
# 11    108.365955
# 12     65.187590
# 13     50.935502
# 14     89.536183
# Name: 0, dtype: float64
#   Angle_row: Series:
# 0     109.636284
# 1      32.019189
# 2     133.727994
# 3     178.387272
# 4      71.930267
# 5     167.406641
# 6      84.470200
# 7      39.691029
# 8       9.299199
# 9       9.438781
# 10    110.124557
# 11    130.063755
# 12    176.637165
# 13     76.885776
# 14    117.355833
# Name: 0, dtype: float64
#   Angle2_row: Series:
# 0      11.752947
# 1      84.771303
# 2      77.449059
# 3     176.780151
# 4     146.369943
# 5     147.888861
# 6     113.170820
# 7     149.949867
# 8      41.271809
# 9     135.585468
# 10      0.486053
# 11      6.624886
# 12    138.690123
# 13    104.555036
# 14     39.070498
# Name: 0, dtype: float64
# --------------------
#
# Best Assignment for BS 3:
#  UAV Index: 0
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 48186.1098
#   P_m_down_value: 3.1356
#   P_m_har_value: 1.6939
#   T_m_har_value: 0.1028
#   f_km_value: 5.0498
#   T_km_up_value: 0.3988
#   V_lm_vfly_value: 19.9258
#   V_lm_hfly_value: 88.9075
#   P_km_up_value: 7.3410
#   Angle1_row: Series:
# 0      23.094594
# 1       5.875864
# 2      33.462215
# 3     113.455504
# 4     141.308037
# 5      88.359471
# 6     156.697950
# 7     107.600529
# 8      67.455781
# 9      59.842569
# 10     35.252186
# 11    108.365955
# 12     65.187590
# 13     50.935502
# 14     89.536183
# Name: 0, dtype: float64
#   Angle_row: Series:
# 0     109.636284
# 1      32.019189
# 2     133.727994
# 3     178.387272
# 4      71.930267
# 5     167.406641
# 6      84.470200
# 7      39.691029
# 8       9.299199
# 9       9.438781
# 10    110.124557
# 11    130.063755
# 12    176.637165
# 13     76.885776
# 14    117.355833
# Name: 0, dtype: float64
#   Angle2_row: Series:
# 0      11.752947
# 1      84.771303
# 2      77.449059
# 3     176.780151
# 4     146.369943
# 5     147.888861
# 6     113.170820
# 7     149.949867
# 8      41.271809
# 9     135.585468
# 10      0.486053
# 11      6.624886
# 12    138.690123
# 13    104.555036
# 14     39.070498
# Name: 0, dtype: float64
# --------------------
#
# Best Assignment for BS 2:
#  UAV Index: 5
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 51499.3910
#   P_m_down_value: 3.1187
#   P_m_har_value: 0.2385
#   T_m_har_value: 0.5501
#   f_km_value: 2.5354
#   T_km_up_value: 0.5545
#   V_lm_vfly_value: 44.6308
#   V_lm_hfly_value: 34.5169
#   P_km_up_value: 6.0340
#   Angle1_row: Series:
# 0      23.094594
# 1       5.875864
# 2      33.462215
# 3     113.455504
# 4     141.308037
# 5      88.359471
# 6     156.697950
# 7     107.600529
# 8      67.455781
# 9      59.842569
# 10     35.252186
# 11    108.365955
# 12     65.187590
# 13     50.935502
# 14     89.536183
# Name: 0, dtype: float64
#   Angle_row: Series:
# 0     109.636284
# 1      32.019189
# 2     133.727994
# 3     178.387272
# 4      71.930267
# 5     167.406641
# 6      84.470200
# 7      39.691029
# 8       9.299199
# 9       9.438781
# 10    110.124557
# 11    130.063755
# 12    176.637165
# 13     76.885776
# 14    117.355833
# Name: 0, dtype: float64
#   Angle2_row: Series:
# 0      11.752947
# 1      84.771303
# 2      77.449059
# 3     176.780151
# 4     146.369943
# 5     147.888861
# 6     113.170820
# 7     149.949867
# 8      41.271809
# 9     135.585468
# 10      0.486053
# 11      6.624886
# 12    138.690123
# 13    104.555036
# 14     39.070498
# Name: 0, dtype: float64
# --------------------
#
# Best Assignment for BS 0:
#  UAV Index: 3
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 84626.6754
#   P_m_down_value: 0.1974
#   P_m_har_value: 0.1353
#   T_m_har_value: 0.3937
#   f_km_value: 0.5758
#   T_km_up_value: 1.1632
#   V_lm_vfly_value: 66.6344
#   V_lm_hfly_value: 66.8574
#   P_km_up_value: 2.4763
#   Angle1_row: Series:
# 0      23.094594
# 1       5.875864
# 2      33.462215
# 3     113.455504
# 4     141.308037
# 5      88.359471
# 6     156.697950
# 7     107.600529
# 8      67.455781
# 9      59.842569
# 10     35.252186
# 11    108.365955
# 12     65.187590
# 13     50.935502
# 14     89.536183
# Name: 0, dtype: float64
#   Angle_row: Series:
# 0     109.636284
# 1      32.019189
# 2     133.727994
# 3     178.387272
# 4      71.930267
# 5     167.406641
# 6      84.470200
# 7      39.691029
# 8       9.299199
# 9       9.438781
# 10    110.124557
# 11    130.063755
# 12    176.637165
# 13     76.885776
# 14    117.355833
# Name: 0, dtype: float64
#   Angle2_row: Series:
# 0      11.752947
# 1      84.771303
# 2      77.449059
# 3     176.780151
# 4     146.369943
# 5     147.888861
# 6     113.170820
# 7     149.949867
# 8      41.271809
# 9     135.585468
# 10      0.486053
# 11      6.624886
# 12    138.690123
# 13    104.555036
# 14     39.070498
# Name: 0, dtype: float64
# --------------------
#
# --- UAVs without Assigned Base Stations ---
#   UAV 1 : No BS is assigned
# --------------------
#   UAV 4 : No BS is assigned
# --------------------
#   UAV 6 : No BS is assigned
# --------------------
# Calculation for num_irs_ele: 20
#
# --- Best Unique UAV Assignments (Auction Based Method) ---
#
# Best Assignment for BS 0:
#  UAV Index: 1
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 40922.2591
#   P_m_down_value: 1.8496
#   P_m_har_value: 0.6576
#   T_m_har_value: 1.5699
#   f_km_value: 5.3063
#   T_km_up_value: 0.4198
#   V_lm_vfly_value: 73.8534
#   V_lm_hfly_value: 64.1273
#   P_km_up_value: 7.4258
#   Angle1_row: Series:
# 0      23.094594
# 1       5.875864
# 2      33.462215
# 3     113.455504
# 4     141.308037
# 5      88.359471
# 6     156.697950
# 7     107.600529
# 8      67.455781
# 9      59.842569
# 10     35.252186
# 11    108.365955
# 12     65.187590
# 13     50.935502
# 14     89.536183
# 15     45.705993
# 16     56.490913
# 17     60.113257
# 18     17.264603
# 19    122.773477
# Name: 0, dtype: float64
#   Angle_row: Series:
# 0     109.636284
# 1      32.019189
# 2     133.727994
# 3     178.387272
# 4      71.930267
# 5     167.406641
# 6      84.470200
# 7      39.691029
# 8       9.299199
# 9       9.438781
# 10    110.124557
# 11    130.063755
# 12    176.637165
# 13     76.885776
# 14    117.355833
# 15     27.323852
# 16     97.977491
# 17     86.595990
# 18    117.052411
# 19    132.459102
# Name: 0, dtype: float64
#   Angle2_row: Series:
# 0      11.752947
# 1      84.771303
# 2      77.449059
# 3     176.780151
# 4     146.369943
# 5     147.888861
# 6     113.170820
# 7     149.949867
# 8      41.271809
# 9     135.585468
# 10      0.486053
# 11      6.624886
# 12    138.690123
# 13    104.555036
# 14     39.070498
# 15     66.167509
# 16     35.290788
# 17    134.368024
# 18    169.131264
# 19    165.836249
# Name: 0, dtype: float64
# --------------------
#
# Best Assignment for BS 3:
#  UAV Index: 3
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 46572.6046
#   P_m_down_value: 0.0589
#   P_m_har_value: 0.2626
#   T_m_har_value: 0.8437
#   f_km_value: 6.0631
#   T_km_up_value: 0.6029
#   V_lm_vfly_value: 66.0989
#   V_lm_hfly_value: 71.1316
#   P_km_up_value: 5.1785
#   Angle1_row: Series:
# 0      23.094594
# 1       5.875864
# 2      33.462215
# 3     113.455504
# 4     141.308037
# 5      88.359471
# 6     156.697950
# 7     107.600529
# 8      67.455781
# 9      59.842569
# 10     35.252186
# 11    108.365955
# 12     65.187590
# 13     50.935502
# 14     89.536183
# 15     45.705993
# 16     56.490913
# 17     60.113257
# 18     17.264603
# 19    122.773477
# Name: 0, dtype: float64
#   Angle_row: Series:
# 0     109.636284
# 1      32.019189
# 2     133.727994
# 3     178.387272
# 4      71.930267
# 5     167.406641
# 6      84.470200
# 7      39.691029
# 8       9.299199
# 9       9.438781
# 10    110.124557
# 11    130.063755
# 12    176.637165
# 13     76.885776
# 14    117.355833
# 15     27.323852
# 16     97.977491
# 17     86.595990
# 18    117.052411
# 19    132.459102
# Name: 0, dtype: float64
#   Angle2_row: Series:
# 0      11.752947
# 1      84.771303
# 2      77.449059
# 3     176.780151
# 4     146.369943
# 5     147.888861
# 6     113.170820
# 7     149.949867
# 8      41.271809
# 9     135.585468
# 10      0.486053
# 11      6.624886
# 12    138.690123
# 13    104.555036
# 14     39.070498
# 15     66.167509
# 16     35.290788
# 17    134.368024
# 18    169.131264
# 19    165.836249
# Name: 0, dtype: float64
# --------------------
#
# Best Assignment for BS 1:
#  UAV Index: 7
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 50931.3952
#   P_m_down_value: 0.9682
#   P_m_har_value: 1.3986
#   T_m_har_value: 0.6936
#   f_km_value: 2.6872
#   T_km_up_value: 0.5626
#   V_lm_vfly_value: 25.1609
#   V_lm_hfly_value: 55.4275
#   P_km_up_value: 4.5129
#   Angle1_row: Series:
# 0      23.094594
# 1       5.875864
# 2      33.462215
# 3     113.455504
# 4     141.308037
# 5      88.359471
# 6     156.697950
# 7     107.600529
# 8      67.455781
# 9      59.842569
# 10     35.252186
# 11    108.365955
# 12     65.187590
# 13     50.935502
# 14     89.536183
# 15     45.705993
# 16     56.490913
# 17     60.113257
# 18     17.264603
# 19    122.773477
# Name: 0, dtype: float64
#   Angle_row: Series:
# 0     109.636284
# 1      32.019189
# 2     133.727994
# 3     178.387272
# 4      71.930267
# 5     167.406641
# 6      84.470200
# 7      39.691029
# 8       9.299199
# 9       9.438781
# 10    110.124557
# 11    130.063755
# 12    176.637165
# 13     76.885776
# 14    117.355833
# 15     27.323852
# 16     97.977491
# 17     86.595990
# 18    117.052411
# 19    132.459102
# Name: 0, dtype: float64
#   Angle2_row: Series:
# 0      11.752947
# 1      84.771303
# 2      77.449059
# 3     176.780151
# 4     146.369943
# 5     147.888861
# 6     113.170820
# 7     149.949867
# 8      41.271809
# 9     135.585468
# 10      0.486053
# 11      6.624886
# 12    138.690123
# 13    104.555036
# 14     39.070498
# 15     66.167509
# 16     35.290788
# 17    134.368024
# 18    169.131264
# 19    165.836249
# Name: 0, dtype: float64
# --------------------
#
# Best Assignment for BS 2:
#  UAV Index: 2
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 51751.0207
#   P_m_down_value: 0.0792
#   P_m_har_value: 1.1038
#   T_m_har_value: 0.4526
#   f_km_value: 1.0943
#   T_km_up_value: 0.4252
#   V_lm_vfly_value: 59.0257
#   V_lm_hfly_value: 61.2029
#   P_km_up_value: 6.0464
#   Angle1_row: Series:
# 0      23.094594
# 1       5.875864
# 2      33.462215
# 3     113.455504
# 4     141.308037
# 5      88.359471
# 6     156.697950
# 7     107.600529
# 8      67.455781
# 9      59.842569
# 10     35.252186
# 11    108.365955
# 12     65.187590
# 13     50.935502
# 14     89.536183
# 15     45.705993
# 16     56.490913
# 17     60.113257
# 18     17.264603
# 19    122.773477
# Name: 0, dtype: float64
#   Angle_row: Series:
# 0     109.636284
# 1      32.019189
# 2     133.727994
# 3     178.387272
# 4      71.930267
# 5     167.406641
# 6      84.470200
# 7      39.691029
# 8       9.299199
# 9       9.438781
# 10    110.124557
# 11    130.063755
# 12    176.637165
# 13     76.885776
# 14    117.355833
# 15     27.323852
# 16     97.977491
# 17     86.595990
# 18    117.052411
# 19    132.459102
# Name: 0, dtype: float64
#   Angle2_row: Series:
# 0      11.752947
# 1      84.771303
# 2      77.449059
# 3     176.780151
# 4     146.369943
# 5     147.888861
# 6     113.170820
# 7     149.949867
# 8      41.271809
# 9     135.585468
# 10      0.486053
# 11      6.624886
# 12    138.690123
# 13    104.555036
# 14     39.070498
# 15     66.167509
# 16     35.290788
# 17    134.368024
# 18    169.131264
# 19    165.836249
# Name: 0, dtype: float64
# --------------------
#
# Best Assignment for BS 4:
#  UAV Index: 0
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 132808.0992
#   P_m_down_value: 0.5754
#   P_m_har_value: 0.8595
#   T_m_har_value: 0.3629
#   f_km_value: 0.9574
#   T_km_up_value: 2.9447
#   V_lm_vfly_value: 20.2764
#   V_lm_hfly_value: 88.5908
#   P_km_up_value: 1.0521
#   Angle1_row: Series:
# 0      23.094594
# 1       5.875864
# 2      33.462215
# 3     113.455504
# 4     141.308037
# 5      88.359471
# 6     156.697950
# 7     107.600529
# 8      67.455781
# 9      59.842569
# 10     35.252186
# 11    108.365955
# 12     65.187590
# 13     50.935502
# 14     89.536183
# 15     45.705993
# 16     56.490913
# 17     60.113257
# 18     17.264603
# 19    122.773477
# Name: 0, dtype: float64
#   Angle_row: Series:
# 0     109.636284
# 1      32.019189
# 2     133.727994
# 3     178.387272
# 4      71.930267
# 5     167.406641
# 6      84.470200
# 7      39.691029
# 8       9.299199
# 9       9.438781
# 10    110.124557
# 11    130.063755
# 12    176.637165
# 13     76.885776
# 14    117.355833
# 15     27.323852
# 16     97.977491
# 17     86.595990
# 18    117.052411
# 19    132.459102
# Name: 0, dtype: float64
#   Angle2_row: Series:
# 0      11.752947
# 1      84.771303
# 2      77.449059
# 3     176.780151
# 4     146.369943
# 5     147.888861
# 6     113.170820
# 7     149.949867
# 8      41.271809
# 9     135.585468
# 10      0.486053
# 11      6.624886
# 12    138.690123
# 13    104.555036
# 14     39.070498
# 15     66.167509
# 16     35.290788
# 17    134.368024
# 18    169.131264
# 19    165.836249
# Name: 0, dtype: float64
# --------------------
#
# --- UAVs without Assigned Base Stations ---
#   UAV 4 : No BS is assigned
# --------------------
#   UAV 5 : No BS is assigned
# --------------------
#   UAV 6 : No BS is assigned
# --------------------
# Calculation for num_irs_ele: 25
#
# --- Best Unique UAV Assignments (Auction Based Method) ---
#
# Best Assignment for BS 1:
#  UAV Index: 5
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 42883.3750
#   P_m_down_value: 1.3861
#   P_m_har_value: 0.2680
#   T_m_har_value: 0.7524
#   f_km_value: 8.8095
#   T_km_up_value: 0.4385
#   V_lm_vfly_value: 47.0861
#   V_lm_hfly_value: 38.3246
#   P_km_up_value: 6.5937
#   Angle1_row: Series:
# 0      23.094594
# 1       5.875864
# 2      33.462215
# 3     113.455504
# 4     141.308037
# 5      88.359471
# 6     156.697950
# 7     107.600529
# 8      67.455781
# 9      59.842569
# 10     35.252186
# 11    108.365955
# 12     65.187590
# 13     50.935502
# 14     89.536183
# 15     45.705993
# 16     56.490913
# 17     60.113257
# 18     17.264603
# 19    122.773477
# 20    141.388984
# 21     30.332991
# 22    148.467459
# 23     76.101256
# 24    171.567149
# Name: 0, dtype: float64
#   Angle_row: Series:
# 0     109.636284
# 1      32.019189
# 2     133.727994
# 3     178.387272
# 4      71.930267
# 5     167.406641
# 6      84.470200
# 7      39.691029
# 8       9.299199
# 9       9.438781
# 10    110.124557
# 11    130.063755
# 12    176.637165
# 13     76.885776
# 14    117.355833
# 15     27.323852
# 16     97.977491
# 17     86.595990
# 18    117.052411
# 19    132.459102
# 20      1.615197
# 21     59.246292
# 22     12.463104
# 23    132.841005
# 24    129.280926
# Name: 0, dtype: float64
#   Angle2_row: Series:
# 0      11.752947
# 1      84.771303
# 2      77.449059
# 3     176.780151
# 4     146.369943
# 5     147.888861
# 6     113.170820
# 7     149.949867
# 8      41.271809
# 9     135.585468
# 10      0.486053
# 11      6.624886
# 12    138.690123
# 13    104.555036
# 14     39.070498
# 15     66.167509
# 16     35.290788
# 17    134.368024
# 18    169.131264
# 19    165.836249
# 20     73.528784
# 21     76.576815
# 22    122.719697
# 23     46.180955
# 24     94.467126
# Name: 0, dtype: float64
# --------------------
#
# Best Assignment for BS 2:
#  UAV Index: 2
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 49605.0791
#   P_m_down_value: 2.2797
#   P_m_har_value: 1.5066
#   T_m_har_value: 0.7632
#   f_km_value: 1.4712
#   T_km_up_value: 0.4664
#   V_lm_vfly_value: 59.5249
#   V_lm_hfly_value: 62.1197
#   P_km_up_value: 9.0253
#   Angle1_row: Series:
# 0      23.094594
# 1       5.875864
# 2      33.462215
# 3     113.455504
# 4     141.308037
# 5      88.359471
# 6     156.697950
# 7     107.600529
# 8      67.455781
# 9      59.842569
# 10     35.252186
# 11    108.365955
# 12     65.187590
# 13     50.935502
# 14     89.536183
# 15     45.705993
# 16     56.490913
# 17     60.113257
# 18     17.264603
# 19    122.773477
# 20    141.388984
# 21     30.332991
# 22    148.467459
# 23     76.101256
# 24    171.567149
# Name: 0, dtype: float64
#   Angle_row: Series:
# 0     109.636284
# 1      32.019189
# 2     133.727994
# 3     178.387272
# 4      71.930267
# 5     167.406641
# 6      84.470200
# 7      39.691029
# 8       9.299199
# 9       9.438781
# 10    110.124557
# 11    130.063755
# 12    176.637165
# 13     76.885776
# 14    117.355833
# 15     27.323852
# 16     97.977491
# 17     86.595990
# 18    117.052411
# 19    132.459102
# 20      1.615197
# 21     59.246292
# 22     12.463104
# 23    132.841005
# 24    129.280926
# Name: 0, dtype: float64
#   Angle2_row: Series:
# 0      11.752947
# 1      84.771303
# 2      77.449059
# 3     176.780151
# 4     146.369943
# 5     147.888861
# 6     113.170820
# 7     149.949867
# 8      41.271809
# 9     135.585468
# 10      0.486053
# 11      6.624886
# 12    138.690123
# 13    104.555036
# 14     39.070498
# 15     66.167509
# 16     35.290788
# 17    134.368024
# 18    169.131264
# 19    165.836249
# 20     73.528784
# 21     76.576815
# 22    122.719697
# 23     46.180955
# 24     94.467126
# Name: 0, dtype: float64
# --------------------
#
# Best Assignment for BS 3:
#  UAV Index: 7
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 51859.5730
#   P_m_down_value: 3.0415
#   P_m_har_value: 1.4411
#   T_m_har_value: 0.6703
#   f_km_value: 3.6244
#   T_km_up_value: 0.6332
#   V_lm_vfly_value: 24.0533
#   V_lm_hfly_value: 52.5969
#   P_km_up_value: 4.8687
#   Angle1_row: Series:
# 0      23.094594
# 1       5.875864
# 2      33.462215
# 3     113.455504
# 4     141.308037
# 5      88.359471
# 6     156.697950
# 7     107.600529
# 8      67.455781
# 9      59.842569
# 10     35.252186
# 11    108.365955
# 12     65.187590
# 13     50.935502
# 14     89.536183
# 15     45.705993
# 16     56.490913
# 17     60.113257
# 18     17.264603
# 19    122.773477
# 20    141.388984
# 21     30.332991
# 22    148.467459
# 23     76.101256
# 24    171.567149
# Name: 0, dtype: float64
#   Angle_row: Series:
# 0     109.636284
# 1      32.019189
# 2     133.727994
# 3     178.387272
# 4      71.930267
# 5     167.406641
# 6      84.470200
# 7      39.691029
# 8       9.299199
# 9       9.438781
# 10    110.124557
# 11    130.063755
# 12    176.637165
# 13     76.885776
# 14    117.355833
# 15     27.323852
# 16     97.977491
# 17     86.595990
# 18    117.052411
# 19    132.459102
# 20      1.615197
# 21     59.246292
# 22     12.463104
# 23    132.841005
# 24    129.280926
# Name: 0, dtype: float64
#   Angle2_row: Series:
# 0      11.752947
# 1      84.771303
# 2      77.449059
# 3     176.780151
# 4     146.369943
# 5     147.888861
# 6     113.170820
# 7     149.949867
# 8      41.271809
# 9     135.585468
# 10      0.486053
# 11      6.624886
# 12    138.690123
# 13    104.555036
# 14     39.070498
# 15     66.167509
# 16     35.290788
# 17    134.368024
# 18    169.131264
# 19    165.836249
# 20     73.528784
# 21     76.576815
# 22    122.719697
# 23     46.180955
# 24     94.467126
# Name: 0, dtype: float64
# --------------------
#
# Best Assignment for BS 4:
#  UAV Index: 0
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 56485.1539
#   P_m_down_value: 0.2365
#   P_m_har_value: 3.1329
#   T_m_har_value: 3.2382
#   f_km_value: 5.1965
#   T_km_up_value: 0.6955
#   V_lm_vfly_value: 20.4321
#   V_lm_hfly_value: 89.3362
#   P_km_up_value: 3.7076
#   Angle1_row: Series:
# 0      23.094594
# 1       5.875864
# 2      33.462215
# 3     113.455504
# 4     141.308037
# 5      88.359471
# 6     156.697950
# 7     107.600529
# 8      67.455781
# 9      59.842569
# 10     35.252186
# 11    108.365955
# 12     65.187590
# 13     50.935502
# 14     89.536183
# 15     45.705993
# 16     56.490913
# 17     60.113257
# 18     17.264603
# 19    122.773477
# 20    141.388984
# 21     30.332991
# 22    148.467459
# 23     76.101256
# 24    171.567149
# Name: 0, dtype: float64
#   Angle_row: Series:
# 0     109.636284
# 1      32.019189
# 2     133.727994
# 3     178.387272
# 4      71.930267
# 5     167.406641
# 6      84.470200
# 7      39.691029
# 8       9.299199
# 9       9.438781
# 10    110.124557
# 11    130.063755
# 12    176.637165
# 13     76.885776
# 14    117.355833
# 15     27.323852
# 16     97.977491
# 17     86.595990
# 18    117.052411
# 19    132.459102
# 20      1.615197
# 21     59.246292
# 22     12.463104
# 23    132.841005
# 24    129.280926
# Name: 0, dtype: float64
#   Angle2_row: Series:
# 0      11.752947
# 1      84.771303
# 2      77.449059
# 3     176.780151
# 4     146.369943
# 5     147.888861
# 6     113.170820
# 7     149.949867
# 8      41.271809
# 9     135.585468
# 10      0.486053
# 11      6.624886
# 12    138.690123
# 13    104.555036
# 14     39.070498
# 15     66.167509
# 16     35.290788
# 17    134.368024
# 18    169.131264
# 19    165.836249
# 20     73.528784
# 21     76.576815
# 22    122.719697
# 23     46.180955
# 24     94.467126
# Name: 0, dtype: float64
# --------------------
#
# Best Assignment for BS 0:
#  UAV Index: 6
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 124857.8300
#   P_m_down_value: 0.9144
#   P_m_har_value: 0.4648
#   T_m_har_value: 0.9306
#   f_km_value: 3.9170
#   T_km_up_value: 2.9640
#   V_lm_vfly_value: 97.6323
#   V_lm_hfly_value: 22.2157
#   P_km_up_value: 0.0950
#   Angle1_row: Series:
# 0      23.094594
# 1       5.875864
# 2      33.462215
# 3     113.455504
# 4     141.308037
# 5      88.359471
# 6     156.697950
# 7     107.600529
# 8      67.455781
# 9      59.842569
# 10     35.252186
# 11    108.365955
# 12     65.187590
# 13     50.935502
# 14     89.536183
# 15     45.705993
# 16     56.490913
# 17     60.113257
# 18     17.264603
# 19    122.773477
# 20    141.388984
# 21     30.332991
# 22    148.467459
# 23     76.101256
# 24    171.567149
# Name: 0, dtype: float64
#   Angle_row: Series:
# 0     109.636284
# 1      32.019189
# 2     133.727994
# 3     178.387272
# 4      71.930267
# 5     167.406641
# 6      84.470200
# 7      39.691029
# 8       9.299199
# 9       9.438781
# 10    110.124557
# 11    130.063755
# 12    176.637165
# 13     76.885776
# 14    117.355833
# 15     27.323852
# 16     97.977491
# 17     86.595990
# 18    117.052411
# 19    132.459102
# 20      1.615197
# 21     59.246292
# 22     12.463104
# 23    132.841005
# 24    129.280926
# Name: 0, dtype: float64
#   Angle2_row: Series:
# 0      11.752947
# 1      84.771303
# 2      77.449059
# 3     176.780151
# 4     146.369943
# 5     147.888861
# 6     113.170820
# 7     149.949867
# 8      41.271809
# 9     135.585468
# 10      0.486053
# 11      6.624886
# 12    138.690123
# 13    104.555036
# 14     39.070498
# 15     66.167509
# 16     35.290788
# 17    134.368024
# 18    169.131264
# 19    165.836249
# 20     73.528784
# 21     76.576815
# 22    122.719697
# 23     46.180955
# 24     94.467126
# Name: 0, dtype: float64
# --------------------
#
# --- UAVs without Assigned Base Stations ---
#   UAV 1 : No BS is assigned
# --------------------
#   UAV 3 : No BS is assigned
# --------------------
#   UAV 4 : No BS is assigned
# --------------------
# Calculation for num_irs_ele: 30
#
# --- Best Unique UAV Assignments (Auction Based Method) ---
#
# Best Assignment for BS 2:
#  UAV Index: 3
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 49610.1366
#   P_m_down_value: 0.0853
#   P_m_har_value: 3.0407
#   T_m_har_value: 0.6639
#   f_km_value: 2.0392
#   T_km_up_value: 0.5545
#   V_lm_vfly_value: 63.2665
#   V_lm_hfly_value: 67.3347
#   P_km_up_value: 7.5613
#   Angle1_row: Series:
# 0      23.094594
# 1       5.875864
# 2      33.462215
# 3     113.455504
# 4     141.308037
# 5      88.359471
# 6     156.697950
# 7     107.600529
# 8      67.455781
# 9      59.842569
# 10     35.252186
# 11    108.365955
# 12     65.187590
# 13     50.935502
# 14     89.536183
# 15     45.705993
# 16     56.490913
# 17     60.113257
# 18     17.264603
# 19    122.773477
# 20    141.388984
# 21     30.332991
# 22    148.467459
# 23     76.101256
# 24    171.567149
# 25    162.967164
# 26     87.990031
# 27     21.818495
# 28      6.736053
# 29     97.398055
# Name: 0, dtype: float64
#   Angle_row: Series:
# 0     109.636284
# 1      32.019189
# 2     133.727994
# 3     178.387272
# 4      71.930267
# 5     167.406641
# 6      84.470200
# 7      39.691029
# 8       9.299199
# 9       9.438781
# 10    110.124557
# 11    130.063755
# 12    176.637165
# 13     76.885776
# 14    117.355833
# 15     27.323852
# 16     97.977491
# 17     86.595990
# 18    117.052411
# 19    132.459102
# 20      1.615197
# 21     59.246292
# 22     12.463104
# 23    132.841005
# 24    129.280926
# 25     89.050736
# 26     68.021463
# 27     40.157171
# 28    121.256166
# 29    159.564753
# Name: 0, dtype: float64
#   Angle2_row: Series:
# 0      11.752947
# 1      84.771303
# 2      77.449059
# 3     176.780151
# 4     146.369943
# 5     147.888861
# 6     113.170820
# 7     149.949867
# 8      41.271809
# 9     135.585468
# 10      0.486053
# 11      6.624886
# 12    138.690123
# 13    104.555036
# 14     39.070498
# 15     66.167509
# 16     35.290788
# 17    134.368024
# 18    169.131264
# 19    165.836249
# 20     73.528784
# 21     76.576815
# 22    122.719697
# 23     46.180955
# 24     94.467126
# 25    111.951565
# 26     58.380228
# 27    168.862002
# 28     70.760816
# 29    118.992774
# Name: 0, dtype: float64
# --------------------
#
# Best Assignment for BS 3:
#  UAV Index: 1
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 58564.0498
#   P_m_down_value: 2.1230
#   P_m_har_value: 1.7921
#   T_m_har_value: 0.2540
#   f_km_value: 1.0168
#   T_km_up_value: 0.6375
#   V_lm_vfly_value: 73.1568
#   V_lm_hfly_value: 64.9645
#   P_km_up_value: 4.2546
#   Angle1_row: Series:
# 0      23.094594
# 1       5.875864
# 2      33.462215
# 3     113.455504
# 4     141.308037
# 5      88.359471
# 6     156.697950
# 7     107.600529
# 8      67.455781
# 9      59.842569
# 10     35.252186
# 11    108.365955
# 12     65.187590
# 13     50.935502
# 14     89.536183
# 15     45.705993
# 16     56.490913
# 17     60.113257
# 18     17.264603
# 19    122.773477
# 20    141.388984
# 21     30.332991
# 22    148.467459
# 23     76.101256
# 24    171.567149
# 25    162.967164
# 26     87.990031
# 27     21.818495
# 28      6.736053
# 29     97.398055
# Name: 0, dtype: float64
#   Angle_row: Series:
# 0     109.636284
# 1      32.019189
# 2     133.727994
# 3     178.387272
# 4      71.930267
# 5     167.406641
# 6      84.470200
# 7      39.691029
# 8       9.299199
# 9       9.438781
# 10    110.124557
# 11    130.063755
# 12    176.637165
# 13     76.885776
# 14    117.355833
# 15     27.323852
# 16     97.977491
# 17     86.595990
# 18    117.052411
# 19    132.459102
# 20      1.615197
# 21     59.246292
# 22     12.463104
# 23    132.841005
# 24    129.280926
# 25     89.050736
# 26     68.021463
# 27     40.157171
# 28    121.256166
# 29    159.564753
# Name: 0, dtype: float64
#   Angle2_row: Series:
# 0      11.752947
# 1      84.771303
# 2      77.449059
# 3     176.780151
# 4     146.369943
# 5     147.888861
# 6     113.170820
# 7     149.949867
# 8      41.271809
# 9     135.585468
# 10      0.486053
# 11      6.624886
# 12    138.690123
# 13    104.555036
# 14     39.070498
# 15     66.167509
# 16     35.290788
# 17    134.368024
# 18    169.131264
# 19    165.836249
# 20     73.528784
# 21     76.576815
# 22    122.719697
# 23     46.180955
# 24     94.467126
# 25    111.951565
# 26     58.380228
# 27    168.862002
# 28     70.760816
# 29    118.992774
# Name: 0, dtype: float64
# --------------------
#
# Best Assignment for BS 4:
#  UAV Index: 5
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 77960.9161
#   P_m_down_value: 1.1061
#   P_m_har_value: 0.0165
#   T_m_har_value: 2.1415
#   f_km_value: 1.7115
#   T_km_up_value: 1.4154
#   V_lm_vfly_value: 45.2730
#   V_lm_hfly_value: 37.0620
#   P_km_up_value: 2.9625
#   Angle1_row: Series:
# 0      23.094594
# 1       5.875864
# 2      33.462215
# 3     113.455504
# 4     141.308037
# 5      88.359471
# 6     156.697950
# 7     107.600529
# 8      67.455781
# 9      59.842569
# 10     35.252186
# 11    108.365955
# 12     65.187590
# 13     50.935502
# 14     89.536183
# 15     45.705993
# 16     56.490913
# 17     60.113257
# 18     17.264603
# 19    122.773477
# 20    141.388984
# 21     30.332991
# 22    148.467459
# 23     76.101256
# 24    171.567149
# 25    162.967164
# 26     87.990031
# 27     21.818495
# 28      6.736053
# 29     97.398055
# Name: 0, dtype: float64
#   Angle_row: Series:
# 0     109.636284
# 1      32.019189
# 2     133.727994
# 3     178.387272
# 4      71.930267
# 5     167.406641
# 6      84.470200
# 7      39.691029
# 8       9.299199
# 9       9.438781
# 10    110.124557
# 11    130.063755
# 12    176.637165
# 13     76.885776
# 14    117.355833
# 15     27.323852
# 16     97.977491
# 17     86.595990
# 18    117.052411
# 19    132.459102
# 20      1.615197
# 21     59.246292
# 22     12.463104
# 23    132.841005
# 24    129.280926
# 25     89.050736
# 26     68.021463
# 27     40.157171
# 28    121.256166
# 29    159.564753
# Name: 0, dtype: float64
#   Angle2_row: Series:
# 0      11.752947
# 1      84.771303
# 2      77.449059
# 3     176.780151
# 4     146.369943
# 5     147.888861
# 6     113.170820
# 7     149.949867
# 8      41.271809
# 9     135.585468
# 10      0.486053
# 11      6.624886
# 12    138.690123
# 13    104.555036
# 14     39.070498
# 15     66.167509
# 16     35.290788
# 17    134.368024
# 18    169.131264
# 19    165.836249
# 20     73.528784
# 21     76.576815
# 22    122.719697
# 23     46.180955
# 24     94.467126
# 25    111.951565
# 26     58.380228
# 27    168.862002
# 28     70.760816
# 29    118.992774
# Name: 0, dtype: float64
# --------------------
#
# Best Assignment for BS 1:
#  UAV Index: 7
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 88171.4645
#   P_m_down_value: 3.0187
#   P_m_har_value: 0.0345
#   T_m_har_value: 1.4517
#   f_km_value: 4.4178
#   T_km_up_value: 1.9333
#   V_lm_vfly_value: 24.4603
#   V_lm_hfly_value: 57.1183
#   P_km_up_value: -0.7919
#   Angle1_row: Series:
# 0      23.094594
# 1       5.875864
# 2      33.462215
# 3     113.455504
# 4     141.308037
# 5      88.359471
# 6     156.697950
# 7     107.600529
# 8      67.455781
# 9      59.842569
# 10     35.252186
# 11    108.365955
# 12     65.187590
# 13     50.935502
# 14     89.536183
# 15     45.705993
# 16     56.490913
# 17     60.113257
# 18     17.264603
# 19    122.773477
# 20    141.388984
# 21     30.332991
# 22    148.467459
# 23     76.101256
# 24    171.567149
# 25    162.967164
# 26     87.990031
# 27     21.818495
# 28      6.736053
# 29     97.398055
# Name: 0, dtype: float64
#   Angle_row: Series:
# 0     109.636284
# 1      32.019189
# 2     133.727994
# 3     178.387272
# 4      71.930267
# 5     167.406641
# 6      84.470200
# 7      39.691029
# 8       9.299199
# 9       9.438781
# 10    110.124557
# 11    130.063755
# 12    176.637165
# 13     76.885776
# 14    117.355833
# 15     27.323852
# 16     97.977491
# 17     86.595990
# 18    117.052411
# 19    132.459102
# 20      1.615197
# 21     59.246292
# 22     12.463104
# 23    132.841005
# 24    129.280926
# 25     89.050736
# 26     68.021463
# 27     40.157171
# 28    121.256166
# 29    159.564753
# Name: 0, dtype: float64
#   Angle2_row: Series:
# 0      11.752947
# 1      84.771303
# 2      77.449059
# 3     176.780151
# 4     146.369943
# 5     147.888861
# 6     113.170820
# 7     149.949867
# 8      41.271809
# 9     135.585468
# 10      0.486053
# 11      6.624886
# 12    138.690123
# 13    104.555036
# 14     39.070498
# 15     66.167509
# 16     35.290788
# 17    134.368024
# 18    169.131264
# 19    165.836249
# 20     73.528784
# 21     76.576815
# 22    122.719697
# 23     46.180955
# 24     94.467126
# 25    111.951565
# 26     58.380228
# 27    168.862002
# 28     70.760816
# 29    118.992774
# Name: 0, dtype: float64
# --------------------
#
# Best Assignment for BS 0:
#  UAV Index: 2
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 140183.1840
#   P_m_down_value: 2.1319
#   P_m_har_value: 0.4841
#   T_m_har_value: 0.0760
#   f_km_value: 1.5417
#   T_km_up_value: 3.6570
#   V_lm_vfly_value: 60.7764
#   V_lm_hfly_value: 60.2502
#   P_km_up_value: 2.5674
#   Angle1_row: Series:
# 0      23.094594
# 1       5.875864
# 2      33.462215
# 3     113.455504
# 4     141.308037
# 5      88.359471
# 6     156.697950
# 7     107.600529
# 8      67.455781
# 9      59.842569
# 10     35.252186
# 11    108.365955
# 12     65.187590
# 13     50.935502
# 14     89.536183
# 15     45.705993
# 16     56.490913
# 17     60.113257
# 18     17.264603
# 19    122.773477
# 20    141.388984
# 21     30.332991
# 22    148.467459
# 23     76.101256
# 24    171.567149
# 25    162.967164
# 26     87.990031
# 27     21.818495
# 28      6.736053
# 29     97.398055
# Name: 0, dtype: float64
#   Angle_row: Series:
# 0     109.636284
# 1      32.019189
# 2     133.727994
# 3     178.387272
# 4      71.930267
# 5     167.406641
# 6      84.470200
# 7      39.691029
# 8       9.299199
# 9       9.438781
# 10    110.124557
# 11    130.063755
# 12    176.637165
# 13     76.885776
# 14    117.355833
# 15     27.323852
# 16     97.977491
# 17     86.595990
# 18    117.052411
# 19    132.459102
# 20      1.615197
# 21     59.246292
# 22     12.463104
# 23    132.841005
# 24    129.280926
# 25     89.050736
# 26     68.021463
# 27     40.157171
# 28    121.256166
# 29    159.564753
# Name: 0, dtype: float64
#   Angle2_row: Series:
# 0      11.752947
# 1      84.771303
# 2      77.449059
# 3     176.780151
# 4     146.369943
# 5     147.888861
# 6     113.170820
# 7     149.949867
# 8      41.271809
# 9     135.585468
# 10      0.486053
# 11      6.624886
# 12    138.690123
# 13    104.555036
# 14     39.070498
# 15     66.167509
# 16     35.290788
# 17    134.368024
# 18    169.131264
# 19    165.836249
# 20     73.528784
# 21     76.576815
# 22    122.719697
# 23     46.180955
# 24     94.467126
# 25    111.951565
# 26     58.380228
# 27    168.862002
# 28     70.760816
# 29    118.992774
# Name: 0, dtype: float64
# --------------------
#
# --- UAVs without Assigned Base Stations ---
#   UAV 0 : No BS is assigned
# --------------------
#   UAV 4 : No BS is assigned
# --------------------
#   UAV 6 : No BS is assigned
# --------------------
# Calculation for num_irs_ele: 35
#
# --- Best Unique UAV Assignments (Auction Based Method) ---
#
# Best Assignment for BS 4:
#  UAV Index: 3
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 44377.9368
#   P_m_down_value: 1.3098
#   P_m_har_value: 3.5846
#   T_m_har_value: 1.3383
#   f_km_value: 8.4524
#   T_km_up_value: 0.5600
#   V_lm_vfly_value: 65.1264
#   V_lm_hfly_value: 67.1276
#   P_km_up_value: 4.7835
#   Angle1_row: Series:
# 0      23.094594
# 1       5.875864
# 2      33.462215
# 3     113.455504
# 4     141.308037
# 5      88.359471
# 6     156.697950
# 7     107.600529
# 8      67.455781
# 9      59.842569
# 10     35.252186
# 11    108.365955
# 12     65.187590
# 13     50.935502
# 14     89.536183
# 15     45.705993
# 16     56.490913
# 17     60.113257
# 18     17.264603
# 19    122.773477
# 20    141.388984
# 21     30.332991
# 22    148.467459
# 23     76.101256
# 24    171.567149
# 25    162.967164
# 26     87.990031
# 27     21.818495
# 28      6.736053
# 29     97.398055
# 30    110.165349
# 31     98.767866
# 32     85.788262
# 33    177.335823
# 34     45.087377
# Name: 0, dtype: float64
#   Angle_row: Series:
# 0     109.636284
# 1      32.019189
# 2     133.727994
# 3     178.387272
# 4      71.930267
# 5     167.406641
# 6      84.470200
# 7      39.691029
# 8       9.299199
# 9       9.438781
# 10    110.124557
# 11    130.063755
# 12    176.637165
# 13     76.885776
# 14    117.355833
# 15     27.323852
# 16     97.977491
# 17     86.595990
# 18    117.052411
# 19    132.459102
# 20      1.615197
# 21     59.246292
# 22     12.463104
# 23    132.841005
# 24    129.280926
# 25     89.050736
# 26     68.021463
# 27     40.157171
# 28    121.256166
# 29    159.564753
# 30    177.634289
# 31     57.620061
# 32    152.395402
# 33      8.365745
# 34    126.309947
# Name: 0, dtype: float64
#   Angle2_row: Series:
# 0      11.752947
# 1      84.771303
# 2      77.449059
# 3     176.780151
# 4     146.369943
# 5     147.888861
# 6     113.170820
# 7     149.949867
# 8      41.271809
# 9     135.585468
# 10      0.486053
# 11      6.624886
# 12    138.690123
# 13    104.555036
# 14     39.070498
# 15     66.167509
# 16     35.290788
# 17    134.368024
# 18    169.131264
# 19    165.836249
# 20     73.528784
# 21     76.576815
# 22    122.719697
# 23     46.180955
# 24     94.467126
# 25    111.951565
# 26     58.380228
# 27    168.862002
# 28     70.760816
# 29    118.992774
# 30     29.042170
# 31     59.225369
# 32     80.280066
# 33    121.782029
# 34     87.328264
# Name: 0, dtype: float64
# --------------------
#
# Best Assignment for BS 3:
#  UAV Index: 2
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 51508.7246
#   P_m_down_value: 3.5014
#   P_m_har_value: 1.5930
#   T_m_har_value: 0.9573
#   f_km_value: 2.8784
#   T_km_up_value: 0.7026
#   V_lm_vfly_value: 60.3394
#   V_lm_hfly_value: 60.5641
#   P_km_up_value: 3.1379
#   Angle1_row: Series:
# 0      23.094594
# 1       5.875864
# 2      33.462215
# 3     113.455504
# 4     141.308037
# 5      88.359471
# 6     156.697950
# 7     107.600529
# 8      67.455781
# 9      59.842569
# 10     35.252186
# 11    108.365955
# 12     65.187590
# 13     50.935502
# 14     89.536183
# 15     45.705993
# 16     56.490913
# 17     60.113257
# 18     17.264603
# 19    122.773477
# 20    141.388984
# 21     30.332991
# 22    148.467459
# 23     76.101256
# 24    171.567149
# 25    162.967164
# 26     87.990031
# 27     21.818495
# 28      6.736053
# 29     97.398055
# 30    110.165349
# 31     98.767866
# 32     85.788262
# 33    177.335823
# 34     45.087377
# Name: 0, dtype: float64
#   Angle_row: Series:
# 0     109.636284
# 1      32.019189
# 2     133.727994
# 3     178.387272
# 4      71.930267
# 5     167.406641
# 6      84.470200
# 7      39.691029
# 8       9.299199
# 9       9.438781
# 10    110.124557
# 11    130.063755
# 12    176.637165
# 13     76.885776
# 14    117.355833
# 15     27.323852
# 16     97.977491
# 17     86.595990
# 18    117.052411
# 19    132.459102
# 20      1.615197
# 21     59.246292
# 22     12.463104
# 23    132.841005
# 24    129.280926
# 25     89.050736
# 26     68.021463
# 27     40.157171
# 28    121.256166
# 29    159.564753
# 30    177.634289
# 31     57.620061
# 32    152.395402
# 33      8.365745
# 34    126.309947
# Name: 0, dtype: float64
#   Angle2_row: Series:
# 0      11.752947
# 1      84.771303
# 2      77.449059
# 3     176.780151
# 4     146.369943
# 5     147.888861
# 6     113.170820
# 7     149.949867
# 8      41.271809
# 9     135.585468
# 10      0.486053
# 11      6.624886
# 12    138.690123
# 13    104.555036
# 14     39.070498
# 15     66.167509
# 16     35.290788
# 17    134.368024
# 18    169.131264
# 19    165.836249
# 20     73.528784
# 21     76.576815
# 22    122.719697
# 23     46.180955
# 24     94.467126
# 25    111.951565
# 26     58.380228
# 27    168.862002
# 28     70.760816
# 29    118.992774
# 30     29.042170
# 31     59.225369
# 32     80.280066
# 33    121.782029
# 34     87.328264
# Name: 0, dtype: float64
# --------------------
#
# Best Assignment for BS 1:
#  UAV Index: 5
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 51873.4195
#   P_m_down_value: 1.2358
#   P_m_har_value: 2.2892
#   T_m_har_value: 0.7392
#   f_km_value: 2.2503
#   T_km_up_value: 0.5565
#   V_lm_vfly_value: 45.0804
#   V_lm_hfly_value: 35.6119
#   P_km_up_value: 7.7062
#   Angle1_row: Series:
# 0      23.094594
# 1       5.875864
# 2      33.462215
# 3     113.455504
# 4     141.308037
# 5      88.359471
# 6     156.697950
# 7     107.600529
# 8      67.455781
# 9      59.842569
# 10     35.252186
# 11    108.365955
# 12     65.187590
# 13     50.935502
# 14     89.536183
# 15     45.705993
# 16     56.490913
# 17     60.113257
# 18     17.264603
# 19    122.773477
# 20    141.388984
# 21     30.332991
# 22    148.467459
# 23     76.101256
# 24    171.567149
# 25    162.967164
# 26     87.990031
# 27     21.818495
# 28      6.736053
# 29     97.398055
# 30    110.165349
# 31     98.767866
# 32     85.788262
# 33    177.335823
# 34     45.087377
# Name: 0, dtype: float64
#   Angle_row: Series:
# 0     109.636284
# 1      32.019189
# 2     133.727994
# 3     178.387272
# 4      71.930267
# 5     167.406641
# 6      84.470200
# 7      39.691029
# 8       9.299199
# 9       9.438781
# 10    110.124557
# 11    130.063755
# 12    176.637165
# 13     76.885776
# 14    117.355833
# 15     27.323852
# 16     97.977491
# 17     86.595990
# 18    117.052411
# 19    132.459102
# 20      1.615197
# 21     59.246292
# 22     12.463104
# 23    132.841005
# 24    129.280926
# 25     89.050736
# 26     68.021463
# 27     40.157171
# 28    121.256166
# 29    159.564753
# 30    177.634289
# 31     57.620061
# 32    152.395402
# 33      8.365745
# 34    126.309947
# Name: 0, dtype: float64
#   Angle2_row: Series:
# 0      11.752947
# 1      84.771303
# 2      77.449059
# 3     176.780151
# 4     146.369943
# 5     147.888861
# 6     113.170820
# 7     149.949867
# 8      41.271809
# 9     135.585468
# 10      0.486053
# 11      6.624886
# 12    138.690123
# 13    104.555036
# 14     39.070498
# 15     66.167509
# 16     35.290788
# 17    134.368024
# 18    169.131264
# 19    165.836249
# 20     73.528784
# 21     76.576815
# 22    122.719697
# 23     46.180955
# 24     94.467126
# 25    111.951565
# 26     58.380228
# 27    168.862002
# 28     70.760816
# 29    118.992774
# 30     29.042170
# 31     59.225369
# 32     80.280066
# 33    121.782029
# 34     87.328264
# Name: 0, dtype: float64
# --------------------
#
# Best Assignment for BS 2:
#  UAV Index: 6
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 85516.8632
#   P_m_down_value: 6.1524
#   P_m_har_value: 0.9740
#   T_m_har_value: 0.5699
#   f_km_value: 11.8468
#   T_km_up_value: 1.7016
#   V_lm_vfly_value: 100.3653
#   V_lm_hfly_value: 22.9340
#   P_km_up_value: 2.9180
#   Angle1_row: Series:
# 0      23.094594
# 1       5.875864
# 2      33.462215
# 3     113.455504
# 4     141.308037
# 5      88.359471
# 6     156.697950
# 7     107.600529
# 8      67.455781
# 9      59.842569
# 10     35.252186
# 11    108.365955
# 12     65.187590
# 13     50.935502
# 14     89.536183
# 15     45.705993
# 16     56.490913
# 17     60.113257
# 18     17.264603
# 19    122.773477
# 20    141.388984
# 21     30.332991
# 22    148.467459
# 23     76.101256
# 24    171.567149
# 25    162.967164
# 26     87.990031
# 27     21.818495
# 28      6.736053
# 29     97.398055
# 30    110.165349
# 31     98.767866
# 32     85.788262
# 33    177.335823
# 34     45.087377
# Name: 0, dtype: float64
#   Angle_row: Series:
# 0     109.636284
# 1      32.019189
# 2     133.727994
# 3     178.387272
# 4      71.930267
# 5     167.406641
# 6      84.470200
# 7      39.691029
# 8       9.299199
# 9       9.438781
# 10    110.124557
# 11    130.063755
# 12    176.637165
# 13     76.885776
# 14    117.355833
# 15     27.323852
# 16     97.977491
# 17     86.595990
# 18    117.052411
# 19    132.459102
# 20      1.615197
# 21     59.246292
# 22     12.463104
# 23    132.841005
# 24    129.280926
# 25     89.050736
# 26     68.021463
# 27     40.157171
# 28    121.256166
# 29    159.564753
# 30    177.634289
# 31     57.620061
# 32    152.395402
# 33      8.365745
# 34    126.309947
# Name: 0, dtype: float64
#   Angle2_row: Series:
# 0      11.752947
# 1      84.771303
# 2      77.449059
# 3     176.780151
# 4     146.369943
# 5     147.888861
# 6     113.170820
# 7     149.949867
# 8      41.271809
# 9     135.585468
# 10      0.486053
# 11      6.624886
# 12    138.690123
# 13    104.555036
# 14     39.070498
# 15     66.167509
# 16     35.290788
# 17    134.368024
# 18    169.131264
# 19    165.836249
# 20     73.528784
# 21     76.576815
# 22    122.719697
# 23     46.180955
# 24     94.467126
# 25    111.951565
# 26     58.380228
# 27    168.862002
# 28     70.760816
# 29    118.992774
# 30     29.042170
# 31     59.225369
# 32     80.280066
# 33    121.782029
# 34     87.328264
# Name: 0, dtype: float64
# --------------------
#
# Best Assignment for BS 0:
#  UAV Index: 1
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 153576.1200
#   P_m_down_value: 0.1974
#   P_m_har_value: 0.1353
#   T_m_har_value: 0.3937
#   f_km_value: 0.1305
#   T_km_up_value: 0.6252
#   V_lm_vfly_value: 72.6939
#   V_lm_hfly_value: 64.4919
#   P_km_up_value: 5.9974
#   Angle1_row: Series:
# 0      23.094594
# 1       5.875864
# 2      33.462215
# 3     113.455504
# 4     141.308037
# 5      88.359471
# 6     156.697950
# 7     107.600529
# 8      67.455781
# 9      59.842569
# 10     35.252186
# 11    108.365955
# ...
# 22    122.719697
# 23     46.180955
# 24     94.467126
# 25    111.951565
# 26     58.380228
# 27    168.862002
# 28     70.760816
# 29    118.992774
# 30     29.042170
# 31     59.225369
# 32     80.280066
# 33    121.782029
# 34     87.328264
# 35     20.353576
# 36    112.231522
# 37     27.065531
# 38    115.750045
# 39     23.301450
# 40    142.393086
# 41    121.068747
# 42     69.632270
# 43    115.510163
# 44     52.417097
# Name: 0, dtype: float64
# --------------------
#
# --- UAVs without Assigned Base Stations ---
#   UAV 1 : No BS is assigned
# --------------------
#   UAV 4 : No BS is assigned
# --------------------
#   UAV 7 : No BS is assigned
# --------------------
# Calculation for num_irs_ele: 50
#
# --- Best Unique UAV Assignments (Auction Based Method) ---
#
# Best Assignment for BS 2:
#  UAV Index: 3
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 45518.3660
#   P_m_down_value: 2.9280
#   P_m_har_value: 1.6156
#   T_m_har_value: 0.7432
#   f_km_value: 2.2131
#   T_km_up_value: 0.4384
#   V_lm_vfly_value: 64.9453
#   V_lm_hfly_value: 64.9885
#   P_km_up_value: 9.3514
#   Angle1_row: Series:
# 0      23.094594
# 1       5.875864
# 2      33.462215
# 3     113.455504
# 4     141.308037
# 5      88.359471
# 6     156.697950
# 7     107.600529
# 8      67.455781
# 9      59.842569
# 10     35.252186
# 11    108.365955
# 12     65.187590
# 13     50.935502
# 14     89.536183
# 15     45.705993
# 16     56.490913
# 17     60.113257
# 18     17.264603
# 19    122.773477
# 20    141.388984
# 21     30.332991
# 22    148.467459
# 23     76.101256
# 24    171.567149
# 25    162.967164
# 26     87.990031
# 27     21.818495
# 28      6.736053
# 29     97.398055
# 30    110.165349
# 31     98.767866
# 32     85.788262
# 33    177.335823
# 34     45.087377
# 35     31.968683
# 36     29.127282
# 37    144.865710
# 38     29.345036
# 39     61.393954
# 40    133.709694
# 41     78.258936
# 42    103.445152
# 43    109.600364
# 44     70.971332
# 45    143.094330
# 46     28.566073
# 47    164.528915
# 48    123.915523
# 49     14.180238
# Name: 0, dtype: float64
#   Angle_row: Series:
# 0     109.636284
# 1      32.019189
# 2     133.727994
# 3     178.387272
# 4      71.930267
# 5     167.406641
# 6      84.470200
# 7      39.691029
# 8       9.299199
# 9       9.438781
# 10    110.124557
# 11    130.063755
# 12    176.637165
# 13     76.885776
# 14    117.355833
# 15     27.323852
# 16     97.977491
# 17     86.595990
# 18    117.052411
# 19    132.459102
# 20      1.615197
# 21     59.246292
# 22     12.463104
# 23    132.841005
# 24    129.280926
# 25     89.050736
# 26     68.021463
# 27     40.157171
# 28    121.256166
# 29    159.564753
# 30    177.634289
# 31     57.620061
# 32    152.395402
# 33      8.365745
# 34    126.309947
# 35     58.145430
# 36     81.077582
# 37    128.585131
# 38    139.009653
# 39    172.704530
# 40    108.854948
# 41      7.347894
# 42    157.048124
# 43     31.015365
# 44    112.736102
# 45    175.233340
# 46    128.674886
# 47      3.969908
# 48     81.508176
# 49    163.344559
# Name: 0, dtype: float64
#   Angle2_row: Series:
# 0      11.752947
# 1      84.771303
# 2      77.449059
# 3     176.780151
# 4     146.369943
# 5     147.888861
# 6     113.170820
# 7     149.949867
# 8      41.271809
# 9     135.585468
# 10      0.486053
# 11      6.624886
# 12    138.690123
# 13    104.555036
# 14     39.070498
# 15     66.167509
# 16     35.290788
# 17    134.368024
# 18    169.131264
# 19    165.836249
# 20     73.528784
# 21     76.576815
# 22    122.719697
# 23     46.180955
# 24     94.467126
# 25    111.951565
# 26     58.380228
# 27    168.862002
# 28     70.760816
# 29    118.992774
# 30     29.042170
# 31     59.225369
# 32     80.280066
# 33    121.782029
# 34     87.328264
# 35     20.353576
# 36    112.231522
# 37     27.065531
# 38    115.750045
# 39     23.301450
# 40    142.393086
# 41    121.068747
# 42     69.632270
# 43    115.510163
# 44     52.417097
# 45     60.474468
# 46    126.742356
# 47      5.020283
# 48    151.991549
# 49     24.440674
# Name: 0, dtype: float64
# --------------------
#
# Best Assignment for BS 0:
#  UAV Index: 2
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 47126.9896
#   P_m_down_value: 1.0145
#   P_m_har_value: 0.9353
#   T_m_har_value: 0.9433
#   f_km_value: 2.0006
#   T_km_up_value: 0.4733
#   V_lm_vfly_value: 60.4032
#   V_lm_hfly_value: 60.4405
#   P_km_up_value: 3.4045
#   Angle1_row: Series:
# 0      23.094594
# 1       5.875864
# 2      33.462215
# 3     113.455504
# 4     141.308037
# 5      88.359471
# 6     156.697950
# 7     107.600529
# 8      67.455781
# 9      59.842569
# 10     35.252186
# 11    108.365955
# 12     65.187590
# 13     50.935502
# 14     89.536183
# 15     45.705993
# 16     56.490913
# 17     60.113257
# 18     17.264603
# 19    122.773477
# 20    141.388984
# 21     30.332991
# 22    148.467459
# 23     76.101256
# 24    171.567149
# 25    162.967164
# 26     87.990031
# 27     21.818495
# 28      6.736053
# 29     97.398055
# 30    110.165349
# 31     98.767866
# 32     85.788262
# 33    177.335823
# 34     45.087377
# 35     31.968683
# 36     29.127282
# 37    144.865710
# 38     29.345036
# 39     61.393954
# 40    133.709694
# 41     78.258936
# 42    103.445152
# 43    109.600364
# 44     70.971332
# 45    143.094330
# 46     28.566073
# 47    164.528915
# 48    123.915523
# 49     14.180238
# Name: 0, dtype: float64
#   Angle_row: Series:
# 0     109.636284
# 1      32.019189
# 2     133.727994
# 3     178.387272
# 4      71.930267
# 5     167.406641
# 6      84.470200
# 7      39.691029
# 8       9.299199
# 9       9.438781
# 10    110.124557
# 11    130.063755
# 12    176.637165
# 13     76.885776
# 14    117.355833
# 15     27.323852
# 16     97.977491
# 17     86.595990
# 18    117.052411
# 19    132.459102
# 20      1.615197
# 21     59.246292
# 22     12.463104
# 23    132.841005
# 24    129.280926
# 25     89.050736
# 26     68.021463
# 27     40.157171
# 28    121.256166
# 29    159.564753
# 30    177.634289
# 31     57.620061
# 32    152.395402
# 33      8.365745
# 34    126.309947
# 35     58.145430
# 36     81.077582
# 37    128.585131
# 38    139.009653
# 39    172.704530
# 40    108.854948
# 41      7.347894
# 42    157.048124
# 43     31.015365
# 44    112.736102
# 45    175.233340
# 46    128.674886
# 47      3.969908
# 48     81.508176
# 49    163.344559
# Name: 0, dtype: float64
#   Angle2_row: Series:
# 0      11.752947
# 1      84.771303
# 2      77.449059
# 3     176.780151
# 4     146.369943
# 5     147.888861
# 6     113.170820
# 7     149.949867
# 8      41.271809
# 9     135.585468
# 10      0.486053
# 11      6.624886
# 12    138.690123
# 13    104.555036
# 14     39.070498
# 15     66.167509
# 16     35.290788
# 17    134.368024
# 18    169.131264
# 19    165.836249
# 20     73.528784
# 21     76.576815
# 22    122.719697
# 23     46.180955
# 24     94.467126
# 25    111.951565
# 26     58.380228
# 27    168.862002
# 28     70.760816
# 29    118.992774
# 30     29.042170
# 31     59.225369
# 32     80.280066
# 33    121.782029
# 34     87.328264
# 35     20.353576
# 36    112.231522
# 37     27.065531
# 38    115.750045
# 39     23.301450
# 40    142.393086
# 41    121.068747
# 42     69.632270
# 43    115.510163
# 44     52.417097
# 45     60.474468
# 46    126.742356
# 47      5.020283
# 48    151.991549
# 49     24.440674
# Name: 0, dtype: float64
# --------------------
#
# Best Assignment for BS 1:
#  UAV Index: 0
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 53159.4843
#   P_m_down_value: 1.5922
#   P_m_har_value: 0.7276
#   T_m_har_value: 0.1701
#   f_km_value: 2.8831
#   T_km_up_value: 0.5509
#   V_lm_vfly_value: 23.9619
#   V_lm_hfly_value: 86.5656
#   P_km_up_value: 6.7017
#   Angle1_row: Series:
# 0      23.094594
# 1       5.875864
# 2      33.462215
# 3     113.455504
# 4     141.308037
# 5      88.359471
# 6     156.697950
# 7     107.600529
# 8      67.455781
# 9      59.842569
# 10     35.252186
# 11    108.365955
# 12     65.187590
# 13     50.935502
# 14     89.536183
# 15     45.705993
# 16     56.490913
# 17     60.113257
# 18     17.264603
# 19    122.773477
# 20    141.388984
# 21     30.332991
# 22    148.467459
# 23     76.101256
# 24    171.567149
# 25    162.967164
# 26     87.990031
# 27     21.818495
# 28      6.736053
# 29     97.398055
# 30    110.165349
# 31     98.767866
# 32     85.788262
# 33    177.335823
# 34     45.087377
# 35     31.968683
# 36     29.127282
# 37    144.865710
# 38     29.345036
# 39     61.393954
# 40    133.709694
# 41     78.258936
# 42    103.445152
# 43    109.600364
# 44     70.971332
# 45    143.094330
# 46     28.566073
# 47    164.528915
# 48    123.915523
# 49     14.180238
# Name: 0, dtype: float64
#   Angle_row: Series:
# 0     109.636284
# 1      32.019189
# 2     133.727994
# 3     178.387272
# 4      71.930267
# 5     167.406641
# 6      84.470200
# 7      39.691029
# 8       9.299199
# 9       9.438781
# 10    110.124557
# 11    130.063755
# 12    176.637165
# 13     76.885776
# 14    117.355833
# 15     27.323852
# 16     97.977491
# 17     86.595990
# 18    117.052411
# 19    132.459102
# 20      1.615197
# 21     59.246292
# 22     12.463104
# 23    132.841005
# 24    129.280926
# 25     89.050736
# 26     68.021463
# 27     40.157171
# 28    121.256166
# 29    159.564753
# 30    177.634289
# 31     57.620061
# 32    152.395402
# 33      8.365745
# 34    126.309947
# 35     58.145430
# 36     81.077582
# 37    128.585131
# 38    139.009653
# 39    172.704530
# 40    108.854948
# 41      7.347894
# 42    157.048124
# 43     31.015365
# 44    112.736102
# 45    175.233340
# 46    128.674886
# 47      3.969908
# 48     81.508176
# 49    163.344559
# Name: 0, dtype: float64
#   Angle2_row: Series:
# 0      11.752947
# 1      84.771303
# 2      77.449059
# 3     176.780151
# 4     146.369943
# 5     147.888861
# 6     113.170820
# 7     149.949867
# 8      41.271809
# 9     135.585468
# 10      0.486053
# 11      6.624886
# 12    138.690123
# 13    104.555036
# 14     39.070498
# 15     66.167509
# 16     35.290788
# 17    134.368024
# 18    169.131264
# 19    165.836249
# 20     73.528784
# 21     76.576815
# 22    122.719697
# 23     46.180955
# 24     94.467126
# 25    111.951565
# 26     58.380228
# 27    168.862002
# 28     70.760816
# 29    118.992774
# 30     29.042170
# 31     59.225369
# 32     80.280066
# 33    121.782029
# 34     87.328264
# 35     20.353576
# 36    112.231522
# 37     27.065531
# 38    115.750045
# 39     23.301450
# 40    142.393086
# 41    121.068747
# 42     69.632270
# 43    115.510163
# 44     52.417097
# 45     60.474468
# 46    126.742356
# 47      5.020283
# 48    151.991549
# 49     24.440674
# Name: 0, dtype: float64
# --------------------
#
# Best Assignment for BS 3:
#  UAV Index: 1
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 69958.0571
#   P_m_down_value: 0.9554
#   P_m_har_value: 0.4164
#   T_m_har_value: 0.7701
#   f_km_value: 0.4674
#   T_km_up_value: 0.4603
#   V_lm_vfly_value: 72.6939
#   V_lm_hfly_value: 64.4919
#   P_km_up_value: 9.9011
#   Angle1_row: Series:
# 0      23.094594
# 1       5.875864
# 2      33.462215
# 3     113.455504
# 4     141.308037
# 5      88.359471
# 6     156.697950
# 7     107.600529
# 8      67.455781
# 9      59.842569
# 10     35.252186
# 11    108.365955
# 12     65.187590
# 13     50.935502
# 14     89.536183
# 15     45.705993
# 16     56.490913
# 17     60.113257
# 18     17.264603
# 19    122.773477
# 20    141.388984
# 21     30.332991
# 22    148.467459
# 23     76.101256
# 24    171.567149
# 25    162.967164
# 26     87.990031
# 27     21.818495
# 28      6.736053
# 29     97.398055
# 30    110.165349
# 31     98.767866
# 32     85.788262
# 33    177.335823
# 34     45.087377
# 35     31.968683
# 36     29.127282
# 37    144.865710
# 38     29.345036
# 39     61.393954
# 40    133.709694
# 41     78.258936
# 42    103.445152
# 43    109.600364
# 44     70.971332
# 45    143.094330
# 46     28.566073
# 47    164.528915
# 48    123.915523
# 49     14.180238
# Name: 0, dtype: float64
#   Angle_row: Series:
# 0     109.636284
# 1      32.019189
# 2     133.727994
# 3     178.387272
# 4      71.930267
# 5     167.406641
# 6      84.470200
# 7      39.691029
# 8       9.299199
# 9       9.438781
# 10    110.124557
# 11    130.063755
# 12    176.637165
# 13     76.885776
# 14    117.355833
# 15     27.323852
# 16     97.977491
# 17     86.595990
# 18    117.052411
# 19    132.459102
# 20      1.615197
# 21     59.246292
# 22     12.463104
# 23    132.841005
# 24    129.280926
# 25     89.050736
# 26     68.021463
# 27     40.157171
# 28    121.256166
# 29    159.564753
# 30    177.634289
# 31     57.620061
# 32    152.395402
# 33      8.365745
# 34    126.309947
# 35     58.145430
# 36     81.077582
# 37    128.585131
# 38    139.009653
# 39    172.704530
# 40    108.854948
# 41      7.347894
# 42    157.048124
# 43     31.015365
# 44    112.736102
# 45    175.233340
# 46    128.674886
# 47      3.969908
# 48     81.508176
# 49    163.344559
# Name: 0, dtype: float64
#   Angle2_row: Series:
# 0      11.752947
# 1      84.771303
# 2      77.449059
# 3     176.780151
# 4     146.369943
# 5     147.888861
# 6     113.170820
# 7     149.949867
# 8      41.271809
# 9     135.585468
# 10      0.486053
# 11      6.624886
# 12    138.690123
# 13    104.555036
# 14     39.070498
# 15     66.167509
# 16     35.290788
# 17    134.368024
# 18    169.131264
# 19    165.836249
# 20     73.528784
# 21     76.576815
# 22    122.719697
# 23     46.180955
# 24     94.467126
# 25    111.951565
# 26     58.380228
# 27    168.862002
# 28     70.760816
# 29    118.992774
# 30     29.042170
# 31     59.225369
# 32     80.280066
# 33    121.782029
# 34     87.328264
# 35     20.353576
# 36    112.231522
# 37     27.065531
# 38    115.750045
# 39     23.301450
# 40    142.393086
# 41    121.068747
# 42     69.632270
# 43    115.510163
# 44     52.417097
# 45     60.474468
# 46    126.742356
# 47      5.020283
# 48    151.991549
# 49     24.440674
# Name: 0, dtype: float64
# --------------------
#
# Best Assignment for BS 4:
#  UAV Index: 7
#  Best Individual:
#   Generation: 1, Type: GA
#   Fitness: 2993055.3779
#   P_m_down_value: 0.5754
#   P_m_har_value: 0.8595
#   T_m_har_value: 0.3629
#   f_km_value: 0.2756
#   T_km_up_value: 101.8706
#   V_lm_vfly_value: 22.4843
#   V_lm_hfly_value: 55.0057
#   P_km_up_value: 0.0324
#   Angle1_row: Series:
# 0      23.094594
# 1       5.875864
# 2      33.462215
# 3     113.455504
# 4     141.308037
# 5      88.359471
# 6     156.697950
# 7     107.600529
# 8      67.455781
# 9      59.842569
# 10     35.252186
# 11    108.365955
# 12     65.187590
# 13     50.935502
# 14     89.536183
# 15     45.705993
# 16     56.490913
# 17     60.113257
# 18     17.264603
# 19    122.773477
# 20    141.388984
# 21     30.332991
# 22    148.467459
# 23     76.101256
# 24    171.567149
# 25    162.967164
# 26     87.990031
# 27     21.818495
# 28      6.736053
# 29     97.398055
# 30    110.165349
# 31     98.767866
# 32     85.788262
# 33    177.335823
# 34     45.087377
# 35     31.968683
# 36     29.127282
# 37    144.865710
# 38     29.345036
# 39     61.393954
# 40    133.709694
# 41     78.258936
# 42    103.445152
# 43    109.600364
# 44     70.971332
# 45    143.094330
# 46     28.566073
# 47    164.528915
# 48    123.915523
# 49     14.180238
# Name: 0, dtype: float64
#   Angle_row: Series:
# 0     109.636284
# 1      32.019189
# 2     133.727994
# 3     178.387272
# 4      71.930267
# 5     167.406641
# 6      84.470200
# 7      39.691029
# 8       9.299199
# 9       9.438781
# 10    110.124557
# 11    130.063755
# 12    176.637165
# 13     76.885776
# 14    117.355833
# 15     27.323852
# 16     97.977491
# 17     86.595990
# 18    117.052411
# 19    132.459102
# 20      1.615197
# 21     59.246292
# 22     12.463104
# 23    132.841005
# 24    129.280926
# 25     89.050736
# 26     68.021463
# 27     40.157171
# 28    121.256166
# 29    159.564753
# 30    177.634289
# 31     57.620061
# 32    152.395402
# 33      8.365745
# 34    126.309947
# 35     58.145430
# 36     81.077582
# 37    128.585131
# 38    139.009653
# 39    172.704530
# 40    108.854948
# 41      7.347894
# 42    157.048124
# 43     31.015365
# 44    112.736102
# 45    175.233340
# 46    128.674886
# 47      3.969908
# 48     81.508176
# 49    163.344559
# Name: 0, dtype: float64
#   Angle2_row: Series:
# 0      11.752947
# 1      84.771303
# 2      77.449059
# 3     176.780151
# 4     146.369943
# 5     147.888861
# 6     113.170820
# 7     149.949867
# 8      41.271809
# 9     135.585468
# 10      0.486053
# 11      6.624886
# 12    138.690123
# 13    104.555036
# 14     39.070498
# 15     66.167509
# 16     35.290788
# 17    134.368024
# 18    169.131264
# 19    165.836249
# 20     73.528784
# 21     76.576815
# 22    122.719697
# 23     46.180955
# 24     94.467126
# 25    111.951565
# 26     58.380228
# 27    168.862002
# 28     70.760816
# 29    118.992774
# 30     29.042170
# 31     59.225369
# 32     80.280066
# 33    121.782029
# 34     87.328264
# 35     20.353576
# 36    112.231522
# 37     27.065531
# 38    115.750045
# 39     23.301450
# 40    142.393086
# 41    121.068747
# 42     69.632270
# 43    115.510163
# 44     52.417097
# 45     60.474468
# 46    126.742356
# 47      5.020283
# 48    151.991549
# 49     24.440674
# Name: 0, dtype: float64
# --------------------
#
# --- UAVs without Assigned Base Stations ---
#   UAV 4 : No BS is assigned
# --------------------
#   UAV 5 : No BS is assigned
# --------------------
#   UAV 6 : No BS is assigned
# --------------------

# %%
# Plotting graph for Sum of Fitness vs num_irs_ele
irs_element_values =range(10, 51, 5)
plt.figure(figsize=(10, 6))
plt.rcParams["font.size"] = "20"
plt.plot(irs_element_values, fitness_sums_HC, marker='o', linestyle='-')
plt.xlabel('Number of IRS Elements ',size=22)
plt.ylabel('Energy ',size=22)
plt.title('Energy vs Number of IRS Elements',size=22)
plt.xticks(irs_element_values)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 7))
num_irs =range(10, 51, 5)

plt.rcParams["font.size"] = "20"
plt.plot(num_irs, fitness_sums_HC, label = "HC-A")
plt.plot(num_irs, fitness_sums_GA, label = "C2GA")
plt.xlabel('Number of IRS Elements',size=20)
plt.ylabel('Energy',size=22)
plt.legend()
plt.savefig("Energy vs IRS .pdf", format="pdf", bbox_inches="tight", dpi=800)
plt.show()

# %%
percentage_improvements = []
better_algorithm_counts = {'HC-A': 0, 'C2GA': 0, 'Tie': 0}
average_percentage_improvement_HC_A = 0
average_percentage_improvement_C2GA = 0

print("\n--- Algorithm Comparison ---")
for i in range(len(num_irs)):
    hc_a_fitness = fitness_sums_HC[i]
    c2ga_fitness = fitness_sums_GA[i]
    data_size = num_irs[i]

    if hc_a_fitness < c2ga_fitness:
        better_fitness = hc_a_fitness
        worse_fitness = c2ga_fitness
        better_algorithm = "HC-A"
        worse_algorithm = "C2GA"
        better_algorithm_counts['HC-A'] += 1
    elif c2ga_fitness < hc_a_fitness:
        better_fitness = c2ga_fitness
        worse_fitness = hc_a_fitness
        better_algorithm = "C2GA"
        worse_algorithm = "HC-A"
        better_algorithm_counts['C2GA'] += 1
    else:
        better_algorithm = "Tie"
        better_algorithm_counts['Tie'] += 1
        percentage_improvement = 0 # No improvement if it's a tie
        percentage_improvements.append(percentage_improvement) # Append 0 for tie
        print(f"Data size {data_size:.1f}: Tie in Energy ({hc_a_fitness:.2f} vs {c2ga_fitness:.2f}) - 0.00% Improvement")
        continue # Skip percentage calculation for tie

    percentage_improvement = ((worse_fitness - better_fitness) / worse_fitness) * 100
    percentage_improvements.append(percentage_improvement)

    print(f"Data size {data_size:.1f}: {better_algorithm} is better by {percentage_improvement:.2f}% (Energy: {better_fitness:.2f} vs {worse_fitness:.2f})")


# Calculate average percentage improvement for cases where HC-A is better
hc_a_improvements = [p for i, p in enumerate(percentage_improvements) if fitness_sums_HC[i] < fitness_sums_GA[i]]
if hc_a_improvements:
    average_percentage_improvement_HC_A = np.mean(hc_a_improvements)

# Calculate average percentage improvement for cases where C2GA is better
c2ga_improvements = [p for i, p in enumerate(percentage_improvements) if fitness_sums_GA[i] < fitness_sums_HC[i]]
if c2ga_improvements:
    average_percentage_improvement_C2GA = np.mean(c2ga_improvements)


print("\n--- Summary ---")
print("Algorithm Performance Comparison:")
print(f"  HC-A was better in {better_algorithm_counts['HC-A']} out of {len(num_irs)} cases.")
print(f"  C2GA was better in {better_algorithm_counts['C2GA']} out of {len(num_irs)} cases.")
print(f"  Tie in {better_algorithm_counts['Tie']} out of {len(num_irs)} cases.")

if better_algorithm_counts['HC-A'] > better_algorithm_counts['C2GA']:
    if hc_a_improvements:
        print(f"\nOverall, HC-A (Hill Climbing) is generally better.")
        print(f"On average, when HC-A is better, it reduces energy consumption by approximately {average_percentage_improvement_HC_A:.2f}%.")

elif better_algorithm_counts['C2GA'] > better_algorithm_counts['HC-A']:
    if c2ga_improvements:
        print(f"\nOverall, C2GA (Genetic Algorithm) is generally better.")
        print(f"On average, when C2GA is better, it reduces energy consumption by approximately {average_percentage_improvement_C2GA:.2f}%.")
else:
    print("\nOverall, both algorithms perform similarly on average based on the number of better cases.")
# Out:
# --- Algorithm Comparison ---
# Data size 10.0: C2GA is better by 25.57% (Energy: 265342.74 vs 356508.06)
# Data size 15.0: C2GA is better by 7.18% (Energy: 254574.50 vs 274255.59)
# Data size 20.0: C2GA is better by 16.06% (Energy: 271127.53 vs 322985.38)
# Data size 25.0: C2GA is better by 16.11% (Energy: 273224.90 vs 325691.01)
# Data size 30.0: C2GA is better by 34.07% (Energy: 273291.03 vs 414489.75)
# Data size 35.0: C2GA is better by 29.43% (Energy: 273015.98 vs 386853.06)
# Data size 40.0: C2GA is better by 37.37% (Energy: 272894.47 vs 435698.16)
# Data size 45.0: C2GA is better by 25.22% (Energy: 279207.68 vs 373374.80)
# Data size 50.0: C2GA is better by 91.56% (Energy: 270909.29 vs 3208818.27)
#
# --- Summary ---
# Algorithm Performance Comparison:
#   HC-A was better in 0 out of 9 cases.
#   C2GA was better in 9 out of 9 cases.
#   Tie in 0 out of 9 cases.
#
# Overall, C2GA (Genetic Algorithm) is generally better.
# On average, when C2GA is better, it reduces energy consumption by approximately 31.39%.
